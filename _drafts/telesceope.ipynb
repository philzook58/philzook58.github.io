# %% [markdown]
# Dobsonian
#
#
# https://ray-optics.readthedocs.io/en/latest/index.html
#
#
# 1/f = 1/di + 1/do
# M = hi/ho = -di/do
#
# 1/(1/f - 1/d0) = di
#
# angles = np.random()*2*np.pi
# offsets = np.random()
#
#
# white light point source can't be squeeze more than a fractio nof a millimeter? Is that right?

# %%
from ipywidgets import interact

# 1. A slider is created for integers
def slider_demo(x):
    return x

interact(slider_demo, x=10)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 4))

f = 1
ax.axhline(0, color="black", lw=.5)       # optical axis
ax.axvline(0, color="blue")               # lens
ax.plot([-f, f], [0, 0], "o")             # focal points

#for ray in rays:
#    ax.plot(ray.x, ray.y)

ax.set_aspect("equal")
ax.set_ylim(-3, 3)

# %%
@interact(f=(1., 10.), do=(1., 20.), h=(.1, 5.))
def demo(f=4, do=8, h=2):
    draw_lens(f, do, h)
