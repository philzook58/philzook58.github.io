# %% [markdown]
# Nested integegrators are like tries
# telescopes
#
#
# Probablistic termination is interesting, but is it really that different from picking a finite stopping point for streams?
#
#
# Estimating sums via monte carlo (pretty silly looking!)
# Well, maybe not... I had some of this model of randomly sampling
# E[sum^n a_i]  picking a stopping point. Kind of cool though actually.
# E[a_i] feels less silly?
#
#
# The analog might be using a quadrature integrator but randomly sampling how many N to go to.
#
# Anything that power series works, take the random form instead
#
# productive coinductive streams <-> proabblistic termination
# Rchiardson extrapolation.
# asymptotic divergent series? Optimal stopping points of series.
#
# Renormalization ~ adjust your priors as you learn more?
#
# particle filters
#
# Monte carlo estimation of perturbation theory of quadratic equation
#
# ax^2 + bx + c = 0
# x^5 + x = 1
# x = a + bx solve via monte carlo.
#
# Number of bounces. Rendering equation. Neutron diffusion.
# Random walking and diffusion / heat equation are intuitively talking about the same thing. Mathemtically it is perhaps not so obvious.
#
#
# a + b
#
# class WeightedPicker
#     choices
#     def choose():
#         return a.choose() if random.randbool() else b.choose()
#
# class Rando():
#     est :
#     def __add__()
#
#
# Randomized testing stuff. Remember the contract = dependent tyes thing. Hmm.
# Kind of the monte carlo approach to dealing with forall, exists quants instead of sum/integrate
#
# Recursive definitions with refinement types ~ green's function thing?
#
#
# volume 3 of ray tracing in one weekend
#
# bidirectional ray tracting

# %%
import random
random.random()
N = 100


def integ(a,b):
    return lambda f: sum(f(a + random.random()*(b-a)) for _ in range(N)) * (b-a) / N
integ(0,1)(lambda x: x**2)
integ(0,1)(lambda x: integ(0,x)(lambda y: y))
# Out:
# 0.15441606553784182

# %%
1/6
# Out:
# 0.16666666666666666

# %%
from sympy import *
x,y = symbols("x y")

integrate(y, (y,0,x), (x,0,1))
# Out:
# 1/6
