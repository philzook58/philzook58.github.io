# %% [markdown]
# Embedding egraphs into graph rewriting

# %%
from typing import NamedTuple
class Eclass(NamedTuple):
    out : int
    in1 : int
    in2 : int

class ENode(NamedTuple):
    out : int
    args : tuple[int, ...]
class Share(NamedTuple):
    out1 : int
    out2 : int
    in_ : int

def rule1(nodes):
    for n in nodes:
        for m in nodes:
            if ...:
                nodes.remove(m)
                nodes.remove(n)
                nodes.add()
                nodes.add()
                return False
    return True

def rw(nodes, rules):
    while True:
        done = True
        for rule in rules:
            done &= rule(nodes)
        if done:
            return
