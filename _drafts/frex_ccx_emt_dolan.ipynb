# %% [markdown]
# Frex https://github.com/frex-project/haskell-frex
#
# EMT
#
# CC(X) https://dl.acm.org/doi/abs/10.1016/j.entcs.2008.04.080
#
# and Dolan subtyping. https://www.cs.tufts.edu/~nr/cs257/archive/stephen-dolan/thesis.pdf Coproduct in the right category
#
#
# Normal form of distributive lattices with aliens?
#
# Mcbride https://types.pl/@pigworker/116166410462838955
# ```haskell
# data Value
#   = ...
#   | FunVal (Value -> Value)
#   | ListVal [Chunk]
#   | NeutVal Neutral  -- not for lists!
#
# data Chunk
#   = Single Value -- one element
#   | Stuck Neutral -- noncanonical list
#
# data Neutral
#   = Var DeBruijnLevel
#   | App Neutral Value
#   | ...
# ```
#
# """
# This fits very neatly with nbe. Crucially, just as you don't allow the usual neutral -> normal embedding constructor to be used at Pi, Sigma or Unit types, so you don't allow it at List types, either. So
#
# which means that some free variable
#
# xs : List X
# normalises not to NeutVal (Var xs) but to ListVal [Stuck (Var xs)].
#
# I tend to cook my metatheory according to a serious religion which builds from the bidierctional story to something with an even more precisely type-directed information flow. Also a very good fit with nbe.
# """
#
#
# discussions are quite similar
# "Alien terms"
# Semantic values
# interpretation
