# %% [markdown]
# SeqSort(World) # path
# Prefix(A,B) => p(A) -> p(B)
#
# https://plato.stanford.edu/entries/logic-intuitionistic/#KripBethSemaForIntuLogi
# I don't understand if this matches fitting's description of inutitionsitic tableau.
# What is brouwer's concept of "spread"
