# %%
print_endline "Hello world"
# Out:
# Hello world
# - : unit = ()

# %%
let x = 3
let y = 2
# Out:
# val x : int = 3
# File "[4]", line 2, characters 8-9:
# 2 | let y = 2
#             ^
# Error: This expression has type int
#        This is not a function; it cannot be applied.

# %%
#require "bindlib"

# %%
#help
# Out:
#                               General
# #help
#   Prints a list of all available directives, with corresponding argument type
#   if appropriate.
# #quit
#   Exit the toplevel.
#
#                               Loading code
# #cd <str>
#   Change the current working directory.
# #directory <str>
#   Add the given directory to search path for source and compiled files.
# #load <str>
#   Load in memory a bytecode object, produced by ocamlc.
# #load_rec <str>
#   As #load, but loads dependencies recursively.
# #mod_use <str>
#   Usage is identical to #use but #mod_use wraps the contents in a module.
# #remove_directory <str>
#   Remove the given directory from the search path.
# #show_dirs
#   List directories currently in the search path.
# #use <str>
#   Read, compile and execute source phrases from the given file.
# #use_output <str>
#   Execute a command and read, compile and execute source phrases from its
#   output.
#
#                               Environment queries
# ...

# %%
y
# Out:
# - : int = 2

# %%
Sys.command "echo hello"
# Out:
# hello
# - : int = 0

# %%
! echo hello (* doesn't work *)
# Out:
# File "[15]", line 1, characters 2-6:
# 1 | ! echo hello
#       ^^^^
# Error: Unbound value echo

# %%
let oc = open_out "/tmp/foo" in
output_string oc {|
hello world
|}; (* multi line strings  *)
close_out oc
# Out:
# - : unit = ()

# %%
#require "menhir"

# %%
(*let oc = open_in "/tmp/foo" in*)
let s = In_channel.with_open_text "/tmp/foo" In_channel.input_all
# Out:
# val s : string = "\nhello world\n"

# %%
# Out:
# - : string = "\nhello world\n"

# %% [markdown]
# Fun stuff
#
# HOL-light
# why3
# bauer types
# rocq
# elpi
# binsec
# ocaml hegel
# dolmen
#
# persistent data types?
# union find lattice
#
# traat / harrison
# sail
# frama-c
# goblint
# beluga
# gappa
# lambdapi
# dedukti
# s2n bignum
#
# pyml
# hardcaml
# colibir
#
#
# oxcaml
# mirage

# %%
#require "pyml"
# Out:
# No such package: pyml

# %%
#require "why3"
# Out:
# File "[25]", line 1:
# Error: Reference to undefined compilation unit `Stdlib__Ephemeron'
# Hint: This means that the interface of a module is loaded, but its implementation is not.
#       Did you mean to load a compiled implementation of the module
#       using #load or by passing it as an argument to the toplevel?

# %%
#require "logtk"
# Out:
# No such package: logtk

# %%
#directory "/home/philip/Documents/ocaml/hol-light";;

# %%
Unix.putenv "HOLLIGHT_DIR" "/home/philip/Documents/ocaml/hol-light";;
# Out:
# - : unit = ()

# %%
#load "bignum.cmo";;
#use "hol.ml";;

# %%
# Out:
# File "[41]", line 1, characters 0-3:
# 1 | HOL.mp
#     ^^^
# Error: Unbound value HOL
