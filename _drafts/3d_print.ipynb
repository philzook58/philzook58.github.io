# %% [markdown]
# 3d printing
# 3D printing
#
#
# My monoprice may be fucked. Donate it to the same place that takes laser cutter
#
# Linkages project
# Stirling engine
#
# Mortise and tenon models?
#
#
# 3d printing service?
