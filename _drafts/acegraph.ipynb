# %% [markdown]
# ACKBO.
# The simplest version in that paper
#
# Rebuilding might require the flavor of mutliset completion to happen
# Multisets of multiset rewriting. More uniform. Don't have to worry about symbols. Could almosty certainly encode
# CLP(multiset). ZF style Multiset theory. The first omega is already kind of {1, 0}? Non well founded multisets
#
# hash consing sets
#
#
#
# critical pairs
#
#
# AC terms == set of regular terms equivalent under ac
#
# overlap finding
#
#
# magic set
#
# do aegraphs solve congruence colsoure even?
#
#
# cycle free rebuilding
#
# make new id
# careful union FileNotFoundError
# f(a,b,c) -> e
#
# ac aegraph
#
#
# t1(X,Y,Z) -> f(X,Y)
# t2(X,Y,Z) -> f(X,Z)
