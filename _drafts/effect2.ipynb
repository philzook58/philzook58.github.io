# %% [markdown]
# BDD effects
# Egraphs?
# Smart constructors
# Normal Forms
#
# Delimitted continuations and handlers?
#
#
# Universal algerba
# Multiterms
#
# FuncDelc
#
# class MultiApp
#     heads : list[]
#     vars : list[]
