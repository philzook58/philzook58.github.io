# %% [markdown]
# https://www.leliobrun.net/publication/emsoft23/paper.pdf Equation-Directed Axiomatization of Lustre Semantics to
# Enable Optimized Code Validation
#
# Lustre
# Ansys scade
#
# https://lharri73.github.io/PySimlink/index.html
#
# simulink is like an xml format
#
# https://arxiv.org/html/2405.01695v1 Requirements-driven Slicing of Simulink Models Using LLMs
#
# https://github.com/NASA-SW-VnV/CoCoSim Automated Analysis Framework for Simulink/Stateflow models.
#
#
# sysmlv2 https://sim4edu.com/reading/kerml-sysml/formalsemantics#SimpleKerMLModels
# kerml
#
# alloy?
#
# Q framework sandia
# scxml https://www.w3.org/TR/scxml/#AlgorithmforSCXMLInterpretation
# https://github.com/Open-MBEE/scxml4py
# https://python-statemachine.readthedocs.io/en/latest/index.html looks slick scxml support
# https://github.com/pytransitions/transitions  6.5k
# https://github.com/AlexandreDecan/sismic
# https://github.com/Open-MBEE/sysmlv2x/blob/main/src/sysmlv2x_lib/sysmlv2x.py convert sysmlv2 to scxml using syside
#
# https://docs.rs/scxml/latest/scxml/ rust scxml
#
#
#
# https://news.ycombinator.com/item?id=21662484 hmm. pron arguing tla vs scade vs simulink. Interesting
#
#
# https://docs.nomagic.com/spaces/MD2022xR2/pages/122987975/Using+Metachain+Navigation  metachain navigation
# https://sensmetry.com/advent-of-sysml-v2-lesson-19-state-machine-simulation/
# https://sismic.readthedocs.io/en/latest/
#
# https://www.linkedin.com/pulse/understanding-kerml-sysml2-part-2-gerd-wagner-nml3e?utm_source=share&utm_medium=member_ios&utm_campaign=share_via  kerml is derived from both uml and owl?
#
# The claim is that sysml is first order logic based, but I haven’t seen this spelled out in an actionable way yet
# lean embedded macro dsl for sysml?
# Parse kerml to z3py?
# Alloy for sysml? https://nvlpubs.nist.gov/nistpubs/ir/2024/NIST.IR.8388-upd1.pdf  sysmlv2 looks like what i remember of alloy.
#
# Magicdraw is on it https://docs.nomagic.com/SYSML2P/2026x/catia-magic-cameo-sysml-v2-community-edition-286557495.html#id-(2026x)CATIAMagic/CameoSysMLv2CommunityEdition-DownloadingtheCATIAMagic/CameoSysMLv2CommunityEdition
#
# https://www.reddit.com/r/systems_engineering/comments/1smlti4/free_sysml_v2_tools_for_personal_research/
# RedditFrom the systems_engineering community on RedditExplore this post and more from the systems_engineering communityhttps://www.reddit.com/r/systems_engineering/comments/1smlti4/free_sysml_v2_tools_for_personal_research/[2:12 PM]https://github.com/daltskin/SysML-v2-Resources
#
#
# https://link.springer.com/chapter/10.1007/978-3-031-75872-0_8 An Analysis of the Semantic Foundation of KerML and SysML v2
