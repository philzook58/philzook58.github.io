# %% [markdown]
# forall x y z, exists a b c, ...
#
# Context should not be a list, nor a set. More like a trace.
# A list of sets. which represents possible dependency structure
#
# Generalized unification problem
#
# Harrop - predicates + equallity.
#
# rigid vs flex
#
#
# The alternating quantifier union find https://www.philipzucker.com/prim_level_uf/
#
# Should substitutions also have this structure? list[dict[str, Term]]

# %%
from enum import Enum
class RigFlex(Enum):
    RIGID = auto()
    FLEX = auto()


type Var = str
type Ctx = list[set[Var]]

type subst = dict[Var, Var]
def unify()
