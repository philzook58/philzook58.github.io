# %% [markdown]
# https://cstheory.stackexchange.com/questions/46767/defining-finite-sets-inductively-in-a-proof-assistant
#
# Noetherian finiteness - every sequence from N contains a duplicate
#
# https://www.isa-afp.org/browser_info/current/HOL/HOL/Finite_Set.html
#
# I have my mapping into sequences thing
#
# evidence
#
# finite_ev = smt.SeqSort()
#
# is_finite_wf = kd.define("is_finite_wf", [ev, S], )
#
# induction prnciples
#
# ```
# forall S x, not S[x] -> P[S] -> P[smt.Store(S, x, True, S)
# -----------------------------
#         finite(S) => P[S]
# ```
#
# finite(empty)
# finite(S) => finite(Store(S, x,True))
#
#
#
# strong induction. This looks stronger than finite induction.
#
# ```
# forall T (forall S, S < T, P[S]) -> P[T]
# ------
#          forall S, P[S]
# ```
