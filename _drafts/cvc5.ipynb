# %%
import cvc5.pythonic as cvc5
from cvc5.pythonic import *
x,y = Consts("x y", Float32())

prove(Implies(And(fpIsNormal(x), fpIsNormal(y),
 x >= 0, y >= 0, x <= 3, y <= 4), x * y >= 0) )
# Out:
# proved

# %%
from z3 import *
x,y = Consts("x y", Float32())

prove(Implies(And(fpIsNormal(x), fpIsNormal(y),
 x >= 0, y >= 0, x <= 3, y <= 4), x * y >= 0) )
# Out:
# proved
