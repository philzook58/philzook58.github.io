# %% [markdown]
# https://www.cs.bu.edu/faculty/snyder/publications/UnifChapter.pdf
# https://web.cecs.pdx.edu/~antoy/homepage/publications/narrowing/paper.pdf https://www.michaelhanus.de/papers/GanzingerFestschrift.pdf
#
# syntactic e-unification
#
# E-unification is in some sense as rich as unfailing knuth bendix
#
# `true =? false, E`
#
#
# `pat =? {t1,t2,t3,t4...}, R` We are matching against a databank of terms.
#
# https://www.cambridge.org/core/journals/theory-and-practice-of-logic-programming/article/abs/set-unification/2B789EB32DCF9F77021DBE26FC691032 set unification dovier
#
# https://www.sciencedirect.com/science/article/pii/S1571066109001376 variant narrowing and equational unification
#
#
# https://www.sciencedirect.com/science/article/pii/S0304397519301264 A formalisation of nominal α-equivalence with A, C, and AC function symbols
#
# https://link.springer.com/chapter/10.1007/978-3-642-31585-5_21 nominal completion for system with binders. Yes I'e seen this before
