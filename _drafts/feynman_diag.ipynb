# %% [markdown]
# NCA non crossing approximation and Lenses
#
# Feynman diagrams for caclulating fluids and stuff
#
# Feynman diagrams for spin
#
# Generating them and in what form
#
# powser kind of. coinductive approaches?
