# %% [markdown]
# ---
# title: Today I failed to prove sum_array
# date: 2025-11-24
# ---
#
# I've been building an assembly verification framework. It gets it's semantics from Ghidra pcode in the form of pypcode.
#
# I've been working
