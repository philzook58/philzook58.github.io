# %% [markdown]
# Zach was asking about what could be relevant to teach software engineers in a course.
# I said I think the pragmatic edge is a tool tour
#
# CBMC, kani, hwbmc, esbmc
# verus
# frama-C
# symexec. klee
# angr
#
# propery based testing. hypotheiss
# AFL / fuzzing
# I saw the llm just setup hypothesis to eventually discard the failing test cases rather than fix them.
# None of this is a silver bullet.
#
# compiler flags and analyzers
# infer
#
# at the far end, sometimes maybe lean, rocq, isabelle.
#
# You set the pins up and the llm knocks them down
# A huge test suite is good.
#
# It actually kind of sucks at making good test cases. They get very repetitive and useless in my experience after the first couple
#
# Red/Green TDD makes sense.
#
# LLMs don't usually use stuff like this
#
# https://simonwillison.net/guides/agentic-engineering-patterns/
