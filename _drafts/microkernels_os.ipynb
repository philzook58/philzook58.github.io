# %% [markdown]
# Operating systems
#
# https://en.wikipedia.org/wiki/Microkernel
#
#
#
# Atmosphere in rust Anton https://mars-research.github.io/projects/atmo/
#
#
# Safe kill the last instruction
# https://cacm.acm.org/research/safe-to-the-last-instruction/
# Safe to the Last Instruction: Automated Verification of a Type-Safe Operating System
# https://en.wikipedia.org/wiki/Verve_(operating_system)  https://en.wikipedia.org/wiki/Bartok_(compiler)
#
# Noah kept talking about Nemesis and exokernels?
#
# Derviation trees in sel4
# self paging
# capability
# cornucopia reloaded
#
# aws nitro
#
# https://en.wikipedia.org/wiki/Object-capability_model
#
#
# https://en.wikipedia.org/wiki/Exokernel
# https://en.wikipedia.org/wiki/Xen
#
# self paging https://www.usenix.org/legacy/events/osdi99/full_papers/hand/hand.pdf
# https://en.wikipedia.org/wiki/Nemesis_(operating_system)
#
# https://en.wikipedia.org/wiki/Hypervisor
#
#
# "Separation kernel" Noah seems to think is a big distinction. https://en.wikipedia.org/wiki/Separation_kernel
#
# The Design and Implementation of the 4.4 BSD Operating System (Uxix and Open Systems Series.) - Hardcover"
# Tannenbaum
# Risc v os
# https://osblog.stephenmarz.com/
#
# https://pages.cs.wisc.edu/~remzi/OSTEP/ 3 easy pieces
#
# https://www.reddit.com/r/osdev/comments/10nwwou/books_for_os_development/
#
# https://wiki.osdev.org/Microkernel
#
# https://os.phil-opp.com/ x86 kernel in rust
