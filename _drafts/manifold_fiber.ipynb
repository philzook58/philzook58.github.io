# %% [markdown]
# https://franknielsen.github.io/entropy-22-01100-v2.pdf information geometry.
#
#
# https://grinfeld.org/books/An-Introduction-To-Tensor-Calculus/
# https://grinfeld.org/books/A-Tensor-Description-Of-Surfaces-And-Curves/
# ntroduction to Tensor Analysis and the Calculus of Moving Surfaces
# https://en.wikipedia.org/wiki/Calculus_of_moving_surfaces
# https://dl.acm.org/doi/10.1145/2465506.2466576 A term rewriting system for the calculus of moving surfaces
#
#
# Vector fields are sections of fiber bundles
#
#
#
# Dependent types give you fibers. https://en.wikipedia.org/wiki/Fiber_(mathematics)
# https://en.wikipedia.org/wiki/Fiber_bundle
# https://en.wikipedia.org/wiki/Fibration
# Fiber
# How would I try to model dependent types in vampire? Fibers?
#
# https://en.wikipedia.org/wiki/Covering_space
#
#
# Aczel and Werner, interpret types into set theory
#
# categories with families
#
# a family of sets is the inverse of the projection map way of describing ? The set is the fiber?
# https://en.wikipedia.org/wiki/Family_of_sets hmm context dependent what this can mean.
# https://en.wikipedia.org/wiki/Indexed_family
# https://ncatlab.org/nlab/show/family+of+sets
#
# https://en.wikipedia.org/wiki/Model_category
# fibrations, weak equivalences and cofibrations, factorizations.
#
# retracts
# lifting
# factorization
#
#
# "setoids form a model category"
#
#
#
# Gluing
# https://en.wikipedia.org/wiki/Seifert%E2%80%93Van_Kampen_theorem
# homotopty group is amanglamted product
#
# topology and groupoids
#
# https://en.wikipedia.org/wiki/Covering_space
#
# The fibers are the type familieis not dependent functions
#
# https://en.wikipedia.org/wiki/Homotopy_lifting_property This is the mosty important propery of a coering
#
# https://news.ycombinator.com/item?id=42195994 mbid was also talking about lifiting property in response to my sql thing.
#
#
# So fibers are how dependent types are described.
#
# https://en.wikipedia.org/wiki/Fiber_bundle
#
# Fiber bundles. This is mentioned in physics, but I don't know that the mathematical topic ever hit home for me.
#
# In general relativity, there is a notion of curvature. I'm on board for that. Or rather on any curved surface.
#
# I'm more used to charts. (sections?) Twisted functions. Multivalued functions. Riemann sheets in the complex plane.
#
# https://en.wikipedia.org/wiki/Section_(category_theory)
# retacts and sections are inverses of some morphism
#
# consider a monoid theory that has some inverses.
#
#
#
# Wilson loops. Vector potentials are odd. Dirac Monopoles, ahaonov bohm. Spin 1/2. The belt trick.
#
# Mobius strips
#
#
# tangent bundles
# cotangent bundles
#
# I did that exterior deriasvtive stuff on
#
#
# Lee Topological Manifolds
# Lee Smooth Manifold
#
# massey topology
#
# https://www.youtube.com/watch?v=W_cPtHghJiI&list=PLqggUNm8QSqnmKiDA6k7TqzWlSIpoE1v-&index=4&t=50s&ab_channel=ViditNanda
# https://people.maths.ox.ac.uk/nanda/cat/ computational algebraic topology vidit nanda
#
# https://www.youtube.com/watch?v=XxFGokyYo6g&list=PLqggUNm8QSqnmKiDA6k7TqzWlSIpoE1v-&index=10&t=300s&ab_channel=MatNeth  pierre albin alegrbaic topology
#
# naive lie theory - stillwell
#
# https://groupoids.org.uk/pdffiles/galway7.pdf ronnie brown
#
#
# http://www.math.uchicago.edu/~may/CONCISE/ConciseRevised.pdf A Concise Course in Algebraic Topology
# J. P. May
#
# hatcher https://pi.math.cornell.edu/~hatcher/AT/AT+.pdf
#
# seifert and threllfall
# milner
#
# steenrod toplogy of fibrer bundles
#
# A fiber as a way of tupling a triangulated mesh. Not every mesh is a fiber
# It's kind of saying the mesh is a (twisted) product ,the way carteisna grids are
#
# The duamental group of bundle is factor group of base space
#
# Could asking to _find_ a fibration be an interesting computational task? Finding a factorization of a space. Computational group theory finds factorings or the group. Factoring matrices / linear operators is very useful. I dunno.
#
#
# https://arxiv.org/pdf/2012.08669 sheaves by example
#
#
# https://github.com/justachetan/DiffGeoOps This module implements the discrete versions of three differential geometry operators for Triangulated 2-manifolds that have been discussed in the paper. They are: mean curvature, gaussian, principlal curvature

# %% [markdown]
# # Lie Groups
#
# Conversion of extrinsic form to patched local coordinate form. Interesting maybe.
# Numerical or symbolic.
# orthogonal basis to gradf at point. QR maybe.
# Need to find enough points? Sectors? x >= 0, x <= 0 gluing? Cones? polytopal sectors?
# Sweeping with planes. Morse theory. Homotopy continuation. Hmm.
#
#
# https://proceedings.neurips.cc/paper/2020/file/33cc2b872dfe481abef0f61af181dfcf-Paper.pdf
#  Matrix Fisher distributions
# https://arxiv.org/abs/2410.11566
# https://en.wikipedia.org/wiki/Random_matrix an interesting topic
# https://github.com/fdcl-gwu/FFTSO3
# https://github.com/astro-informatics/so3
# https://github.com/AMLab-Amsterdam/lie_learn
# https://www.manopt.org/
# https://en.wikipedia.org/wiki/Wigner_D-matrix
# Maybe some connection to coherent states
# https://en.wikipedia.org/wiki/Coherent_states_in_mathematical_physics
#  . They are things that are "nice" wavepackets. I think there exists such a thing for spin
# fourier transforms over groups is a topic in quantum computing
# https://www.cs.umd.edu/~amchilds/teaching/w13/l06.pdf
#  probably not relevant
# https://en.wikipedia.org/wiki/Peter%E2%80%93Weyl_theorem
#
#
#
# https://arxiv.org/pdf/1812.01537 A micro Lie theory for state estimation in robotics https://github.com/artivis/manif https://www.youtube.com/watch?v=nHOcoIyJj2o&ab_channel=InstitutdeRob%C3%B2ticaiInform%C3%A0ticaIndustrial%2CCSIC-UPC
# https://ieeexplore.ieee.org/document/10752718 An Introduction to the Invariant Extended Kalman Filter [Lecture Notes]
#
# https://arxiv.org/pdf/1410.1465 The Invariant Extended Kalman filter as a stable observer
#
# Principles of Harmonic Analysis
# https://link.springer.com/book/10.1007/978-3-319-05792-7
#
# Lie Groups, Lie Algebras, and Representations (8 kB)
# https://link.springer.com/book/10.1007/978-3-319-13467-3
#
# Stochastic Models, Information Theory, and Lie Groups, Volume 1 (6 kB)
# https://link.springer.com/book/10.1007/978-0-8176-4803-9
#
# Probability on Compact Lie Groups (8 kB)
# https://link.springer.com/book/10.1007/978-3-319-07842-7
#
# https://hal.science/hal-00903252/document Discrete extended Kalman filter on lie groups
# https://ieeexplore.ieee.org/document/9444664 Invariant Extended Kalman Filtering for Underwater Navigation
# https://rpk.lcsr.jhu.edu/wp-content/uploads/2015/01/Wolfe11_Bayesian-Fusion-on-Lie-Groups.pdf Bayesian Fusion on Lie Groups
# https://arxiv.org/pdf/2309.13903 Invariant Smoothing for Localization: Including the IMU Biases
# https://arxiv.org/pdf/2007.14097 Associating Uncertainty to Extended Poses for on Lie Group IMU Preintegration with Rotating Earth
# https://www.roboticsproceedings.org/rss08/p34.pdf
#
#
#
#
#
#
# Am I really do dependent types or refinement types? What's the distinction? reinfoment types can be modelled by dependent ones.
# At the level of contexts its the same? It's abvout which type formers one introduces?
#
# Boumal, An introduction to optimization on smooth manifolds, 2023 https://www.nicolasboumal.net/book
# Absil, Mahony and Sepulchre, Optimization Algorithms on Matrix Manifolds, 2008 https://press.princeton.edu/absil
#
#
# Spin kata.
# sho kata
# Coherent state kata.
#
# clebsch gordon coefficients
# wigner eckhart
# representation theory. Schur stuff.
# prolongation
#
#
# Bake Campbell hausfordd
# The exponential map. exp is sort of a shorthand for solving a differential equation \partial_t psi = H psi
# \partial_t U = H U - U H . So maybe I could just ask sympy to do it (dsolve). That's kind of neat.

# %%
class R(Manifold): # primitive context x : R |-
    v : sympy.Symbol

class Product(Manifold): # Gamma |- A \times B \times C is type?


class TeleScope

class Fiber(): # Telescope. Gamm |- A type judgement
    ctx : list
    constraints : list[sympy.Expr] # Sympy boolean constraint >, ==, etc. SolveSets?

# %% [markdown]
# Circle with two axis points removed is fribation with path lifting property
# -1 < x < 1   |-  y : x^2 + y^2 = 1
#
# The points get the path lifting property confused.
#
# tengaent bundles do have path lifting property. That's transport

# %%
from sympy import *
from sympy.abc import x, y, z

And(-1 < x, x < 1)
solveset(x**2 + y**2 - 1, x, Interval(-1, 1))
#solve(x**2 + y**2 - 1, x)
#Interval(-1,1).complement(S.UniversalSet).interior
Interval(-1,1).interior

FALSE = S.EmptySet
TRUE = S.Reals
def Implies(a,b):
    return Union(a.complement(S.Reals), b).interior
def IOr(a,b):
    return Union(a, b)

Implies(TRUE, FALSE)
def SetConst(name):
    return ConditionSet(x, Function(name)(x) > 0)
#ConditionSet(x, Function("f")(x) > 0)
Implies(SetConst("A"), SetConst("A"))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[25], line 21
#      19     return ConditionSet(x, Function(name)(x) > 0)
#      20 #ConditionSet(x, Function("f")(x) > 0)
# ---> 21 Implies(SetConst("A"), SetConst("A"))
#
# Cell In[25], line 13, in Implies(a, b)
#      12 def Implies(a,b):
# ---> 13     return Union(a.complement(S.Reals), b).interior
#
# File ~/philzook58.github.io/.venv/lib/python3.12/site-packages/sympy/sets/sets.py:761, in Set.interior(self)
#     746 @property
#     747 def interior(self):
#     748     """
#     749     Property method which returns the interior of a set.
#     750     The interior of a set S consists all points of S that do not
#    (...)    759     EmptySet
#     760     """
# --> 761     return self - self.boundary
#
# File ~/philzook58.github.io/.venv/lib/python3.12/site-packages/sympy/sets/sets.py:684, in Set.boundary(self)
# ...

# %%
Fibration([((x,y), x**2 + y^^1 = 1)], (x,y,z)   )

v2 = sympy.MatrixSymbol('v2', 2, 1)
v1 = sympy.MatrixSymbol('v1', 1, 2)
Fibration([(v2, v2[0] **2 + v2[1]**2 - 1)],  (v3, t) ,   [cos(v3[2]) - v1[0], sin(v3[2]) - v1[1]])

# %%
class Manifold():
    vs : list[sympy.Symbol]
    phis : list[sympy.Expr] # equal 0

    def diff(self):
        # return tangent bundle?
        tvs = [sympy.Fresh(prefix="d" + v.name) for v in self.vs]
        return Fibration(self.vs + self.tvs, 
                  self.phis + [  sum([sympy.diff(phi, v)*dv for v in zip(self.vs, dvs)]) for phi in self.phis], 
                  proj=ManMap(self.vs ,newself, self))


class Fibration(Manifold):
    proj : ManMap


    # eq could be alpha equiv? Nah. Use identity

sphere = Manifold([x,y,z], [1-x**2-y**2-z**2])
circle = Manifold([x,y,z], [1-x**2-y**2, z])
R = Manifold([x], [])
Empty = Manifold([x], [1]) # ?. Initial Object Empty set
R0 = Manifold([], []) # ? Is this a valid construction? Not so sure.
point = Manifold([x], [x]) # x = 0 subset of R . Point



def product(M1, M2):
    # rename to avoid clash
    return Manifold(M1.vs + M2.vs, M1.phis + M2.phis)

def catprod(f : ManMap, g : ManMap):
    # Take two manmaps and 

def plane(normal, point):
    Manifold()

#intersection is not a thing. We need mappings to do it
class ManMap(): # DiffMap? Diffeomorphism?
    f : list[sympy.Expr] #
    dom : Manifold
    cod : Manifold

    @classmethod
    def id_(cls, M):
        return ManMap(M.vs, M, M)
    def __matmul__(self, other):
        assert other.cod == self.dom
        return ManMap(self.f @ other.f, other.dom, self.cod)
    

def arbitrary(Dom, Cod):
    return ManMap([sympy.FreshFunction(v.name)(*Dom.vs) for v in Cod.vs], Dom, Cod)

def pullback(lower : ManMap, right : ManMap):
    assert lower.cod == right.cod
    # sympy.solve? 



# Making these consturctions requires knowin the internals of the Manifold
def PointMap(p : list[smt.Expr], M):  # in catgoeyr theory, morphisms from unit object are good standins for points / elements
    return ManMap(p, point, M)





def RMap(f, M):
    return ManMap(,M,R)




class Point():
    p : list[sympy.Expr]
    M : Manifold


# class Lie(Point):
#   __mul__(self, other):

class Lie():
    M : Manifold
    mul : ManMap # MxM -> M
    id_ : ManMap # M -> M

def is_lie(M : Manifold):
    hasattr(M, "mul") and hasattr(M, "id_")
    assert M.mul.dom == product(M, M)
    assert M.mul.cod == M
    f = # aribtrary
    assert M.mul(M.id_, f) == f
    assert M.mul(f, M.id_) == f

SO2 = Manifold[[x00, x01, x10, x11], [x00**2 + x01**2 - 1, x10**2 + x11**2 - 1, x00*x10 + x01*x11]] # O^T * O = I
Dom = product(SO2, SO2)
SO2.mul = ManMap(Dom.vs   ,Dom,  SO2) # matrix multiplication
SO2Grp = Lie(SO2, )

# are Lie gorup manifolds of ManMap(f,M,M) which are 
#class Lie(Manifold):
#def __matmul__(self, other): # No. We Don't multiply Manifolds time Manifolds

#def Lie()

# %% [markdown]
# # Frames
# Nate asks: what is frame? How do you take a derivative of one? sounds like bullshit.
# Good point.
#
# https://en.wikipedia.org/wiki/Frenet%E2%80%93Serret_formulas
#
#
# darboux frame

# %% [markdown]
# ## Computer
# FinSet fibers. (finite) Models of GATs
#
#
#
# Keenan Crane. Discrete differential geometry
#
# Discrete Sheaf stuff. data structures as sheaves https://www.youtube.com/watch?v=m-odbpmtLZY&ab_channel=MichaelRobinson
#
#
# Julia manifolds
# Sagemifolds
# geomstats https://geomstats.github.io/
# manifold learning
# psycho
# information geometry
#
# Lie groups

# %%
E = DeclareSort("E")
B = DeclareSort("B")
p = Function("p", E, B) # continuous ?
is_open = Function("is_open", SetSort(E), BoolSort())
cont_p = ForAll([A], is_open(Lambda([x], A[p(x)])))


DeclareSort("EOpen")
DeclareSort("BOpen")

p = Function("p", BOpen, EOpen) # continuous image function. Do we really need points?

# fibers hasve path lifting property

# %% [markdown]
# Numerical gauss bonnet?
# Chern number
# Numerical transport
# charts.
# charts is kind of like a hybrid system.
#
# dedalus

# %%
import numpy as np
import scipy as sp

class FiberBundle():
    def proj(self):
        # return base point

class TangentBundle():
    base : 
    vec :
    def proj(self):
        return self.base 
    def transport(self, path, dpath):
        # path is function 0,1. 0 = base point
        def df(v,t):
            x = path(t)
            dx = dpath(t) #? Or make path autodiff?
            dv = connect(x) * dx
        odeint

class Section():

# %% [markdown]
# A vector potential $\vec{A}$is a connection. Fiber is phase combined with space. Parallel transport is integratinfg against A.
#
# Adiabatic transport of a system is parallel transport
# foucault
# berry phase
# geometric phase in physics book
# Cat rotation

# %%
def V(a):
    class Vec():
        basepoint=a
    return Vec

V(3) is V(3)
type("Vec", (), {"basepoint":3})
def V(a) -> type:
    return type("Vec", (), {"basepoint":a})
V(3) is V(3)
class Lincoeff():
    def __add__(self, other):
        assert type(other) == type(self)
        return self.coeff + other.coeff
    def __mul__(self, other):


class Base():
    def transport(self, path):

class Fiber():
    def proj(self) -> "Base":
        pass
    @classmethod
    def fiber(basepoint) -> type:


    def transport(self, path : Callable[float,Base]):


@dataclass
class LinInterp(Lincoeff):
    coeffs : np.ndarray[float]
# Out:
# False

# %% [markdown]
# # Discrete exterior calculus
# Relation to simplicial sets, homotopy, homology.
# Hmm. Simplicial complices are the "inelegant one"...
#
#
# https://www.youtube.com/watch?v=-cUhuzwW-_A&ab_channel=KeenanCrane Keenan Crane's talk on discrete exterior calculus
# https://brickisland.net/DDGSpring2024/ creane course
#
# http://graphics.stanford.edu/courses/cs468-13-spring/ diff geo for computer science solomon
#
# Discrete exterior calculus seems to me like it could host homology.
# Also it's fun.
# How might we approach it?
#
# https://en.wikipedia.org/wiki/Discrete_exterior_calculus
# http://www.cs.jhu.edu/~misha/Fall09/Hirani03.pdf hirani thesis
#
# https://algebraicjulia.github.io/CombinatorialSpaces.jl/dev/discrete_exterior_calculus/
# mesh = something

# %% [markdown]
# # Hodge Star
#
# Musical isomorphisms
# hodge start relates forms to vectors or forms to forms?
# What would be the distinction? Can such a question have meaning?
#
# Higher laplace operator

# %% [markdown]
# # Exterior Algebra and forms
# https://en.wikipedia.org/wiki/Exterior_algebra
# Measure
# https://en.wikipedia.org/wiki/Differential_form
#
# https://en.wikipedia.org/wiki/Differentiable_manifold
# Charts to "M". But M is not speakable in any way except via it's coordinates?
# a maximal differentiable manifold. That's interesting. So an infiinite number of charts. All charts.
# We can form a closure of a finite chart. Finitely generated diff manifold?
#
# We do kind of have an n^2 problem. If we add charts
#
# https://en.wikipedia.org/wiki/Bump_function compactly supported smooth functions https://leanprover-community.github.io/mathlib4_docs/Mathlib/Analysis/Calculus/BumpFunction/Basic.html
# https://en.wikipedia.org/wiki/Partition_of_unity
#
# tangent space is directional derivatives
#
#
# Sheaf
# Motive
# Cohomology
# Crytsalline cohomology

# %% [markdown]
# ## Stereographic
# https://en.wikipedia.org/wiki/Stereographic_projection
#
# Torus
# mobius strip
# cone
# cube
# WHat else?
# https://en.wikipedia.org/wiki/Klein_model
# https://en.wikipedia.org/wiki/Poincar%C3%A9_disk_model
# https://en.wikipedia.org/wiki/Poincar%C3%A9_half-space_model
# https://en.wikipedia.org/wiki/Hyperboloid_model
# Lie Groups. SO(3). Has extriunsic 3x3 matrix perspective. And intrinsic 3d perspective. https://en.wikipedia.org/wiki/3D_rotation_group
# configuration space of pendulums
# A circle. 3 or 4 intervals overlapped. Or again use 2 stereographics.

# %%
from sympy import *
# a chart mapping for sphere.
# stereographic projections
u,v = symbols("u v")
x,y,z = symbols("x y z")
stereo = [
    Eq(1, x**2 + y**2 + z**2),
    Eq(u, x/(1-z)),
    Eq(v, y/(1-z))
    ]
solve(stereo, x,y,z)
stereo[1].subs({x:1, y:0, z:1})
# projection from z=1 north pole.
#solve(stereo + [Eq(u,oo),Eq(v,oo)], z)
u1,v1 = symbols("u1 v1")
south_stereo = [
    Eq(1, x**2 + y**2 + z**2),
    Eq(u1, x/(1+z)),
    Eq(v1, y/(1+z))
    ]
solve(stereo + south_stereo, u,v, x,y,z)
solve(stereo + south_stereo, u1,v1, x,y,z)
d = Function("d")
def dit(t, vs):
    if isinstance(t, Eq):
        return Eq(dit(t.lhs, vs), dit(t.rhs, vs))
    return sum([t.diff(v)*d(v) for v in vs])
vs = [x,y,z,u,v,u1,v1]


# also put validity regions in here?
atlas = {
    ("nstereo", "sstereo") : list(zip([u,v], solve(stereo + south_stereo, u,v, x,y,z)[0][:2])),
    ("sstereo", "nstereo") : list(zip([u1,v1], solve(stereo + south_stereo, u1,v1, x,y,z)[0][:2])),
    }
atlas

t = symbols("t")
curve = [cos(2*pi*t), sin(2*pi*t), 0]
diff_constr = [dit(eq,vs) for eq in south_stereo + stereo]
diff_constr

class Curve():
    """
    piecewise in different coordinate systems.
    """
    t : sympy.Symbol
    segments : [(tinverval, Coordsys, exprs)]

# https://en.wikipedia.org/wiki/Directional_derivative

def dirderiv(f, curve, t):
    return f.subs({u : curve[0], v : curve[1]}, t).diff(t)

def dirderivcurry(f):
    return lambda curve, t: f.subs({u : curve[0], v : curve[1]}, t).diff(t)

# lambdas are not that different from classes with call implemented
class DirDeriv():
    def __init__(self, f):
        self.v = f.diff(u), f.diff(v)
    def __call__(self, curve, t):
        return [v.subs({u : curve[0], v : curve[1]}, t)*curve[i].diff(t) for i in range(2)]

def dirderivchain(f):
    return f.diff(u), f.diff(v)

def apply_dirderivchain(v, curve, t):
    return [v[i].subs({u : curve[0], v : curve[1]}, t)*curve[i].diff(t) for i in range(2)]

# Lie derivative

# abstract point. Has object identity.
# By construction in a space it has coordinates associatied with it

# a coordinate system is abstract? Meaningless devoid of the manifold?
"""
class Coord():
    def __init__(self, name, d):
        self.name = name
        self.d = d
"""
        
class ChartedManifold():

    def __init__(self):
        self.coords = [] # regions of validity
        self.transitions = {}
        class Point():
            M = self # This self refers to the ChartedManifold
        self.Point = Point

class Point():
    def __init__(self, M : ChartedManifold):
       self.M = M
       self.data = {} # constrints?
    def coord_set(self, coord, v):
        self.data[coord] = v
        # maybe check for consistency or propagate to other coords.
# Out:
# [Eq(0, 2*x*d(x) + 2*y*d(y) + 2*z*d(z)),
#  Eq(d(u1), -x*d(z)/(z + 1)**2 + d(x)/(z + 1)),
#  Eq(d(v1), -y*d(z)/(z + 1)**2 + d(y)/(z + 1)),
#  Eq(0, 2*x*d(x) + 2*y*d(y) + 2*z*d(z)),
#  Eq(d(u), x*d(z)/(1 - z)**2 + d(x)/(1 - z)),
#  Eq(d(v), y*d(z)/(1 - z)**2 + d(y)/(1 - z))]

# %% [markdown]
# Ok, so the chart approach says there is no actual "point" to look at. It's just interconencted of charts.
# But it does solve the N**2 problem to say therre is some canonical representiative of point.
#
# Embedding  into higher d seems to help.
# Embedding theorems
#
# x,y,z for sphere
#
#
# Should the class be the Point, or the Space?

# %%
class Point():
    def is_valid(self) -> bool: ...
    def __eq__(self): ...

class SpherePoint(Point):
    def __init__(self):

# %%
clas

# %%
Lambda(t,t+x)(7)
#f = Function("f")
#Lambda(f, f(3))
Lambda(t,t)
WildFunction("F") # whoa https://docs.sympy.org/latest/modules/core.html#sympy.core.function.WildFunction
# Out:
# F_

# %% [markdown]
# The differentials are rerally considering u,v,x,y,z as functions on the manifold u(P). The exterior derivative of these.
#
# I can convert a parametrized curve  into a parametrization of the u(t), v(t)

# %%
chart = DeclareSort("chart")
inv = Function("inv", chart, chart)
compose = Function("compose", chart, chart, chart)





class Atlas():
    def __init__(self):
        self.transitions = {
            ("x", "z") : lambda phix, thetax: () 
                            }

# %% [markdown]
# # Physics
# Frankel book
# Nash and sen
#
# berry phase
# chern number
#
# dirac belt. can it actually be modelled?
#
# GR
#
# Connections
# Piecewise mappings.
# The sphere as 6 glued hemispheres
# The cube
#
#
# Black hole thermodynamics. That sounds like a fun thing to think about
#
#
# That tensor canonization stuff. computational gravity
#
#
# Can thermodynamic cycles be modelled as a fiber bundle? Cycles do non trivial stuff.

# %%
CVec = namedtuple("cubevec", ["face", "vec"])
face = enum("face", "front", "back", "left", "right", "top", "bottom")
# pick meaning of vec.
# the ocnnection mcap tell us how to transfer coordinates from one face to another
# It's a groupoid... ok so what
connection_map = {
    (face.front, face.back): np.array([[],[]]),
}

def trans_of_path(path):
    A = np.eye(2)
    for t in zip(path[:-1], path[1:]):
        A = connection_map[t] @ A
    return A
    # one liner
    #return reduce(lambda A, t: connection_map[t] @ A, zip(path[:-1], path[1:]), np.eye(2))

def transport(path, CVec):
    curf = path[0]
    for t in zip(path[:-1], path[1:]):
        connection_map[curf] # v
        curf = f
    for f in path: # for t in zip(path[:-1], path[1:]):
        connection_map[( curf , f)]
        curf = f


# yea ok, this is fine as long as their is one way to go from one face to another


# cone


BasedVec = namedtuple("BasedVec", ["base", "vec"])
# base may be symbolic info, coordina

# %%
https://1lab.dev/1Lab.Path.html
DeclareSort("I") # iterval
i0, i1 = Consts("i0", I)
min = Function("min", I, I, I)
max = Function("max", I, I, I)
min(x,y) = min(y,x)
min(i0, x) == i0

le = define(min(x,y) == x)

pathA = DeclareSort("path(A)")
apply = Function("apply", path(A), I, A)

reflA = Const("refl", pathA)
refl_def = refl(x)[i] == x

sym = define("sym", )
sym(p)[i] == p[inv(i)]

# %%
# we could even for serious use floats between 0 and 1? Then its easy to compare and such.

class Interval():
    # abstractc Interval
    pts : list[Any]
    def __init__(self):
        self.pts = [0,1] # in total order
    def makepoint(self):
        self.pts.insert()

Fraction(0,1)

def neg(x):
    return 1-x
min
max
list

# %% [markdown]
# path induction. An actual fold operator over a path list.
#
# path as dictionary
#
# path = {0: x, 1/2 : z, ..}
#
# path as list
# path = [x,y,z,w]
#
# path as a rewrite.
#
# subdivision and gluing
