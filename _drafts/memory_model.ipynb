# %%
from z3 import *


Insn = DeclareSort('Insn')
po = Function('po',Insn,Insn,BoolSort()) # program order
before = Function('before',Insn,Insn,BoolSort()) # depenedncy ordering. May not be sequenction

# %% [markdown]
# Symbolic execution of buffer model.
#
# Use theory of sequences?
