# %%
class EGraph():
    memo : 
    eph : list[Node] # id < 0
    nodes : list[Node] # id > 0

    def compact(self):
        """
        Compact
        """

# %%
enum Id {
    Eph(u32),
    Node(u32)
}

struct Node {
    f : String,
    args : Vec<Id>
}
struct EGraph {
    nodes : Vec<Node>,
    eph : Vec<Node>
}

# %% [markdown]
# Separate arenas vs just a new flag to carry around.
# Compact on find perhaps
# Compaction ~ Path compression of semantic structure.
#
# Compact and then do ematching on compacted form
#
# Custom compaction rules for ephemeral. Happen during rebuilding rather than during. Replacement allowed akin to
# If you compact, the custom ematcher for the theory ought to still produce the old uncompacted and more.

# %%
struct Node {
    f : string,
    args : Vec<Id>
    eph : bool
}
struct Eraph {
    nodes : Vec<Node>
}
