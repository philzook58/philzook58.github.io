# %% [markdown]
# How is it even possible
# Noah seemed to want to claim some kind of microarchitecture oblivious way of doing it
#
#
# What does s2n bignum do?
#
# need to turn of or train branch predictors
#
# in datasheets, some archs have particular cycle count for particular instructions
# constant time extension
#
#
#
#
# Taint?
