// %%
#[derive(Debug, Copy, PartialEq, Eq, Hash)]
enum Id {
    Var(u32),
    Comp(u32)
}

#[derive(Debug, Clone, PartialEq, Eq, Hash)]
struct Node {
    f : String,
    args : Vec<Id>
}

#[derive(Debug, Clone, PartialEq, Eq, Hash)]
struct Clause {
    head : Node,
    body : Vec<Node>
}

#[derive(Debug, Clone, PartialEq, Eq, Hash, Default)]
struct State {
    subst : Vec<Id>
    clauses : Vec<Clause>,
    goals : Vec<Id>,
}

#[derive(Debug, Clone, PartialEq, Eq, Hash, Default)]
struct PrologState {
    tb : Vec<Node>,
    //clauses : Vec<(Node, Vec<Node>)>
    branches : Vec<State>
}


impl PrologState {
    fn query(&mut self, goals : Vec<Id>) {
        self.goals.push(State{subst : vec![], clauses : vec![], goals : goals});
        while let branch = branches.pop() {
            if let goal = branch.goals.pop() {
                
        }
    }

    fn clause_match(&self, goal : Id) -> Vec<Clause> {
        self.tb.iter().filter(|clause| clause.head.f == goal).cloned().collect()
}

}

// %% [markdown]
// https://www.philipzucker.com/ground_lambda_prolog/
//
// top down egglog
// Use aegraph style matching with a limit N.
//
//
// bar :- (a(-x) = b(-x) -> foo)
// harrop stle addition to the egraph.
//
// a(-x) = b(-x) is a filled in union.
//
// termbank
// union_rule1(x) :- (terms(-T), a(-x) = b(-x) -> conitnue)
//
// This thing is _not_ for rewriting problems (at least directly).
//
// a = b. is an acceptabed rule
// a(+x) = b(-x)  is not acceptable.
// foo(+x, -x)
//
// edge(+a, -b).  graph databases have a moding to them compared to datalog. Hmm. That's interesiting.
// +in -[?a]-> -out
// moding in datalog ~ indices
//
// mcbride subject, input, output
// bidirectional type krishnaswami and D
//
//
// Prolog is not actually declarative enough to handle declarative intent of rules very well. An ATP is.
// append, etc actually have special cased stuff that detects the current mode.
