# %% [markdown]
# https://cocotec.io/fdr/manual/command_line.html#command-line
#
# https://en.wikipedia.org/wiki/Process_calculus
#
# Hoare csp
#
# C. A. R. Hoare, Communicating Sequential Processes. https://antares.sip.ucm.es/~luis/doctorado06-07/cspbook.pdf
# A. W. Roscoe, The Theory and Practice of Concurrency. https://www.cs.ox.ac.uk/people/bill.roscoe/publications/68b.pdf
# M. C. B. Hennessy, Algebraic Theory of Processes.
# R. Milner, Concurrency and Communication.
# There are two main books on π-calculus:
#
# R. Milner, Communicating and Mobile Systems: The Pi Calculus.
# D. Sangiorgi, D. Walker, The Pi-Calculus: A Theory of Mobile Processes.
#
# https://cstheory.stackexchange.com/questions/38904/resources-books-etc-to-learn-about-concurrency-theory
#
#
#
# mcrl2
# vs tla+?

# %% [markdown]
# # FDR
# FDR

# %%
! ~/Downloads/fdr-3814-linux-x86_64/fdr/bin/refines --help
# Out:
# General Options:
#   --archive arg                         Creates an archive of the input files.
#   -b [ --brief ]                        Only outputs the result of each
#                                         assertion and does not include the
#                                         counterexample.
#   -d [ --divide ]                       Divide counterexamples.
#   -f [ --format ] arg (=colour)         The format. This should be either:
#                                           colour for human-readable colour
#                                         output.
#                                           plain for human-readable non-colour
#                                         output.
#                                           json for machine-readable JSON
#                                         output.
#                                           framed_json for machine-readable JSON
#                                         output,
# ...
