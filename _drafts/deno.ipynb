// %% [markdown]
// https://docs.deno.com/runtime/reference/cli/jupyter/

// %%
console.log("hello world")
// Out:
// hello world

// %%
Deno.jupyter.html`<canvas id="mycanvas"> </canvas>`;
// Out:
// <canvas id="mycanvas"> </canvas>

// %%
prompt("hi")
//confirm("yo")
// Out:
// ""

// %%
function wasclick(){
    document.getElementById("mybutton").innerHtml = "fart"

}

Deno.jupyter.html`<button onClick=wasclick>hi</button>`
// Out:
// <button onClick=wasclick>hi</button>

// %%
document.getElementById("mycanvas")
// Out:
// null

// %%
import { document, penguins } from "jsr:@ry/jupyter-helper";
document.getElementById("mycanvas")
// Out:
// null

// %% [markdown]
// Hangs if i run twice? Ok so don't do that

// %%
import { loadPyodide } from "npm:pyodide";
var pyodide = await loadPyodide();

// %%
await pyodide.runPythonAsync("1 + 1")
//console.log(pyodide.runPython("1 + 2"));
// Out:
// 2

// %%
pyodide.runPython("1 + 1")
// Out:
// 2
