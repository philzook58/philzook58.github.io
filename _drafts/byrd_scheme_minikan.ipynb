# %% [markdown]
# Roulette
# Other education racket stuff?
#
# Cur Bowman https://docs.racket-lang.org/cur/
#
# Shriram's stuff. forge. temporal logic
#
# # Compiler
# nano pass
# IU course.
#
#
# # PLT Redex
#
#
# # Rosette
# https://homes.cs.washington.edu/~djg/theses/bornholt_dissertation.pdf
# symbolic profiler
# Torlak boholt 2019
#
# https://emina.github.io/rosette/
#
# Man, my CAV 2019 notes.
#
# Symbolic union.
# merge dict from _results_ to path conditions. That's a surprising backwards move.
# Union find dict
#
# Map from symbolic path values (?), Omega sample space to values

# %%
! raco pkg install iracket
# Out:
# Resolving "iracket" via https://download.racket-lang.org/releases/8.17/catalog/
# Resolving "iracket" via https://pkgs.racket-lang.org
# Using cached17544319991754431999552 for https://github.com/rmculpepper/iracket.git
# The following uninstalled packages are listed as dependencies of iracket:
#    zeromq-r-lib
#    uuid
#    sha
# Would you like to install these dependencies? [Y/n/a/c/?] user break
#   context...:
#    /usr/racket/collects/pkg/private/print.rkt:44:0: ask
#    /usr/racket/collects/pkg/private/install.rkt:179:2: install-package/outer
#    /usr/racket/collects/pkg/private/install.rkt:705:4: loop
#    /usr/racket/collects/pkg/private/install.rkt:142:0: install-packages
#    /usr/racket/collects/pkg/private/install.rkt:957:4
#    /usr/racket/collects/racket/contract/private/arrow-val-first.rkt:555:3
#    /usr/racket/collects/racket/file.rkt:763:8
#    /usr/racket/collects/racket/file.rkt:752:0: call-with-file-lock
#    /usr/racket/collects/pkg/main.rkt:224:14
#    body of (submod "/usr/racket/collects/pkg/main.rkt" main)
#    /usr/racket/collects/raco/raco.rkt:41:0
#    body of "/usr/racket/collects/raco/raco.rkt"
#    body of "/usr/racket/collects/raco/main.rkt"
# ^C

# %%
# %%file /tmp/test.rkt
# #lang rosette
#
# (define (interpret formula)
#   (match formula
#     [`(∧ ,expr ...) (apply && (map interpret expr))]
#     [`(∨ ,expr ...) (apply || (map interpret expr))]
#     [`(¬ ,expr)     (! (interpret expr))]
#     [lit            (constant lit boolean?)]))
#
# ; This implements a SAT solver.
# (define (SAT formula)
#   (solve (assert (interpret formula))))
#
# (SAT `(∧ r o (∨ s e (¬ t)) t (¬ e)))
# Out:
# Writing /tmp/test.rkt

# %%
! which racket
# Out:
# /usr/local/bin/racket

# %%
! raco iracket install

# %%
! racket /tmp/test.rkt
# Out:
# (model
#  [r #t]
#  [o #t]
#  [s #t]
#  [e #f]
#  [t #t])

# %% [markdown]
# I don't know why, but I need toi instrall inside the jpuyter notebook to get libraries into snap enrinvoment

# %%
! raco pkg install --auto roulette
# Out:
# Resolving "roulette" via https://download.racket-lang.org/releases/8.17/catalog/
# Resolving "roulette" via https://pkgs.racket-lang.org
# Using cached17544317631754431763745 for https://github.com/camoy/roulette.git?path=roulette
# Resolving "roulette-lib" via https://download.racket-lang.org/releases/8.17/catalog/
# Resolving "roulette-lib" via https://pkgs.racket-lang.org
# Using cached17544317631754431763745 for https://github.com/camoy/roulette.git?path=roulette-lib
# 00: Resolving "roulette-x86_64-linux" via https://download.racket-lang.org/releases/8.17/catalog/
# 00: Resolving "roulette-x86_64-linux" via https://pkgs.racket-lang.org
# Resolving "ddict" via https://download.racket-lang.org/releases/8.17/catalog/
# Resolving "ddict" via https://pkgs.racket-lang.org
# Using cached17544317871754431787579 for https://github.com/camoy/roulette-native-libs.git?path=roulette-x86_64-linux
# Using cached17544317881754431788108 for git://github.com/pnwamk/ddict.git
# The following uninstalled packages were listed as dependencies
# and they were automatically installed:
#  dependencies of roulette:
#    roulette-lib
#  dependencies of roulette-lib:
#    roulette-x86_64-linux
#    ddict
# raco setup: version: 8.17
# raco setup: platform: x86_64-linux [cs]
# raco setup: target machine: ta6le
# raco setup: installation name: 8.17
# raco setup: variants: cs
# raco setup: main collects: /usr/racket/collects/
# raco setup: collects paths:
# raco setup:   /home/philip/snap/code/202/.local/share/racket/8.17/collects
# raco setup:   /usr/racket/collects/
# raco setup: main pkgs: /usr/racket/share/pkgs
# raco setup: pkgs paths:
# raco setup:   /usr/racket/share/pkgs
# raco setup:   /home/philip/snap/code/202/.local/share/racket/8.17/pkgs
# raco setup: links files:
# raco setup:   /usr/racket/share/links.rktd
# raco setup:   /home/philip/snap/code/202/.local/share/racket/8.17/links.rktd
# raco setup: main docs: /usr/racket/doc
# raco setup: --- updating info-domain tables ---                    [23:30:35]
# raco setup: updating: /home/philip/snap/code/202/.local/share/racket/8.17/share/info-cache.rktd
# raco setup: --- pre-installing collections ---                     [23:30:35]
# raco setup: --- installing foreign libraries ---                   [23:30:35]
# raco setup: installing: foreign library /home/philip/snap/code/202/.local/share/racket/8.17/lib/librsdd.so
# raco setup: --- installing shared files ---                        [23:30:35]
# raco setup: --- compiling collections ---                          [23:30:35]
# raco setup: --- parallel build using 8 jobs ---                    [23:30:35]
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# ██▍     ▏      ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏         3
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# ████▊   ▏      ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏         6
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# ███████▏▏      ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏         9
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 4 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
# ███████▊█▌     ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏        12
#
# raco setup: 4 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 3 making: <pkgs>/roulette-x86_64-linux
#
#
#
#
#
# ███████▊████   ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏        16
#
# raco setup: 3 making: <pkgs>/roulette-x86_64-linux
#
#
#
#
#
# raco setup: 4 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 2 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
#
#
# ███████▊██████▎▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏        19
#
# raco setup: 2 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-x86_64-linux
#
#
#
#
#
# raco setup: 4 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 1 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
#
#
# ███████▊██████▊█▊      ▏      ▏       ▏      ▏      ▏       ▏      ▏        22
#
# raco setup: 1 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
#
#
#
# raco setup: 2 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-x86_64-linux
#
#
#
#
#
# raco setup: 4 making: <pkgs>/roulette-lib (roulette)
#
#
#
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# raco setup: 0 making: <pkgs>/roulette-lib/engine
#
#
#
#
#
#
#
#
# ███████▊██████▊████    ▏      ▏       ▏      ▏      ▏       ▏      ▏        25raco setup: 2 awaiting: <pkgs>/roulette-lib/private/compiled/interface_rkt.zo[
#
#
#
#
#
#
# raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊██████▌ ▏      ▏       ▏      ▏      ▏       ▏      ▏        29
# raco setup: 6 awaiting: <pkgs>/ddict/data/compiled/ddict_rkt.zo[
#
#
# raco setup: 5: idle[
#
#
#
# raco setup: 5 making: <pkgs>/roulette (roulette)
#
#
#
# ███████▊██████▊███████▊▉      ▏       ▏      ▏      ▏       ▏      ▏        32raco setup: 4: idle[
#
#
#
#
# raco setup: 4 making: <pkgs>/roulette-lib/private[
#
#
#
#
# ███████▊██████▊███████▊███▎   ▏       ▏      ▏      ▏       ▏      ▏        35
# raco setup: 4 awaiting: <pkgs>/roulette-lib/private/compiled/interface_rkt.zo[
#
#
#
# raco setup: 1 awaiting: <pkgs>/ddict/data/compiled/ddict_rkt.zo[
#
#
#
#
#
#
# raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊█████▋ ▏       ▏      ▏      ▏       ▏      ▏        38
# raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊█       ▏      ▏      ▏       ▏      ▏        41raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███▍    ▏      ▏      ▏       ▏      ▏        45
# raco setup: 3 awaiting: <pkgs>/roulette-lib/private/compiled/measure_rkt.zo[
#
#
#
#
#
# raco setup: 0 awaiting: <pkgs>/ddict/data/compiled/ddict_rkt.zo[
#
#
#
#
#
#
#
# raco setup: 5 awaiting: <pkgs>/roulette-lib/compiled/main_rkt.zo
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# ███████▊██████▊███████▊██████▊███▍    ▏      ▏      ▏       ▏      ▏        45
# raco setup: 1: idle[
#
#
#
#
#
#
#
# raco setup: 0: idle[
#
#
#
#
#
#
#
#
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/ddict/data[
#
# ███████▊██████▊███████▊██████▊█████▉  ▏      ▏      ▏       ▏      ▏        48raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊█████▉  ▏      ▏      ▏       ▏      ▏        48
# raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊▏      ▏      ▏       ▏      ▏        51
# raco setup: 0 awaiting: <pkgs>/roulette-lib/private/compiled/util_rkt.zo
#
#
#
#
#
#
#
# raco setup: 1 awaiting: <pkgs>/roulette-lib/engine/compiled/rsdd_rkt.zo[
#
#
#
#
#
#
# raco setup: 6: idle[
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# ███████▊██████▊███████▊██████▊███████▊██▋    ▏      ▏       ▏      ▏        54raco setup: 0: idle[
#
#
#
#
#
#
#
#
# raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette-lib/private[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊█████  ▏      ▏       ▏      ▏        58raco setup: 3: idle[
#
#
#
#
#
# raco setup: 3 making: <pkgs>/roulette/example[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊▍      ▏       ▏      ▏        61
# raco setup: 3 awaiting: <pkgs>/roulette/example/compiled/disrupt_rkt.zo[
#
#
#
#
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/ddict/data/ddict (Simple, Deterministic Dictionarie
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██▊    ▏       ▏      ▏        64
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/ddict/data/ddict (Simple, Deterministic Dictionarie
#
# ███████▊██████▊███████▊██████▊███████▊██████▊█████▏ ▏       ▏      ▏        67raco setup: 1: idle[
#
#
#
#
#
#
#
# raco setup: 0 making: <pkgs>/roulette/example/disrupt[
#
#
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊▌       ▏      ▏        70
# raco setup: 0 awaiting: <pkgs>/roulette-lib/compiled/safe_rkt.zo
#
#
#
#
#
#
#
# raco setup: 2: idle[
#
#
#
#
#
#
# raco setup: 4: idle[
#
#
#
#
# raco setup: 4 making: <pkgs>/roulette/example/disrupt/private[
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███     ▏      ▏        74
# raco setup: 4 awaiting: <pkgs>/roulette-lib/compiled/main_rkt.zo
#
#
#
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/ddict/data/private[
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊█████▎  ▏      ▏        77
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/ddict/data/private[
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊▏      ▏        80
# raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/roulette/example/disrupt/private[
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██     ▏        83raco setup: 7: idle[
#
# raco setup: 7 making: <pkgs>/roulette/scribblings[
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊████▌  ▏        87raco setup: 0: idle[
#
#
#
#
#
#
#
#
# raco setup: 1 making: <pkgs>/roulette/test
#
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▉▏        90raco setup: 7 awaiting: <pkgs>/roulette-lib/compiled/main_rkt.zo
#
# raco setup: 1 awaiting: <pkgs>/roulette-lib/compiled/main_rkt.zo
#
#
#
#
#
#
# raco setup: 0 awaiting: <pkgs>/roulette/example/disrupt/private/compiled/interfa
#
#
#
#
#
#
#
# raco setup: 6: idle[
#
#
# raco setup: 6 making: <pkgs>/ddict/tests/data[
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊██▎      93raco setup: 5 making: <pkgs>/roulette/test
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊██▎      93
# raco setup: 4: idle[
#
#
#
#
# raco setup: 7 making: <pkgs>/roulette/scribblings[
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊██▎      93
# raco setup: 1 making: <pkgs>/roulette/test
#
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊██▎      93
# raco setup: 2 making: <pkgs>/roulette/test
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊████▋    96raco setup: 2 awaiting: <pkgs>/roulette/test/compiled/util_rkt.zo[
#
#
#
#
#
# raco setup: 2 making: <pkgs>/roulette/test
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊████▋    96raco setup: 5 awaiting: <pkgs>/roulette/example/disrupt/private/compiled/interfa
#
#
# raco setup: 1: idle[
#
#
#
#
#
#
#
# raco setup: 1 making: <pkgs>/roulette/test
#
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊███████ 100
# raco setup: 1: idle[
#
#
#
#
#
#
# raco setup: 7: idle[
# raco setup: 2: idle[
#
#
#
#
#
#
# raco setup: 6: idle[
#
# raco setup: 0: idle[
#
#
#
#
#
#
#
#
# raco setup: 5 making: <pkgs>/roulette/test
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊███████ 100raco setup: 3: idle[
#
#
#
#
# raco setup: 5: idle[
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊███████ 100
# raco setup: --- creating launchers ---                             [23:30:41]
# raco setup: --- installing man pages ---                           [23:30:41]
# raco setup: --- building documentation ---                         [23:30:41]
#
# raco setup: 3 running: <pkgs>/ddict/data/ddict/ddict.scrbl
#
# raco setup: 7 running: <pkgs>/roulette/scribblings/roulette.scrbl[raco setup: 3: idle[
# raco setup: 7: idle[
#
# raco setup: 7: idle[
#
#
# raco setup: 5 rendering: <pkgs>/ddict/data/ddict/ddict.scrbl
#
#
#         ▏      ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏         0
#
# raco setup: 5 rendering: <pkgs>/ddict/data/ddict/ddict.scrbl
#
#
# raco setup: 7: idle[
#
# raco setup: 4 rendering: <pkgs>/racket-index/scribblings/main/user/local-redirec
#
#
#
# ███████▊████▍  ▏       ▏      ▏       ▏      ▏      ▏       ▏      ▏        16raco setup: 3 rendering: <pkgs>/racket-index/scribblings/main/user/release.scrbl
#
#
#
#
# ███████▊██████▊███████▊█▊     ▏       ▏      ▏      ▏       ▏      ▏        33
#
# raco setup: 3 rendering: <pkgs>/racket-index/scribblings/main/user/release.scrbl
#
#
#
#
# raco setup: 4 rendering: <pkgs>/racket-index/scribblings/main/user/local-redirec
#
#
#
# raco setup: 5 rendering: <pkgs>/ddict/data/ddict/ddict.scrbl
#
#
# raco setup: 7: idle[
#
# raco setup: 2 rendering: <pkgs>/roulette/scribblings/roulette.scrbl[
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████ ▏      ▏      ▏       ▏      ▏        50
#
# raco setup: 2 rendering: <pkgs>/roulette/scribblings/roulette.scrbl[
#
#
#
#
#
# raco setup: 3 rendering: <pkgs>/racket-index/scribblings/main/user/release.scrbl
#
#
#
#
# raco setup: 4 rendering: <pkgs>/racket-index/scribblings/main/user/local-redirec
#
#
#
# raco setup: 5 rendering: <pkgs>/ddict/data/ddict/ddict.scrbl
#
#
# raco setup: 7: idle[
#
# raco setup: 1 rendering: <pkgs>/racket-index/scribblings/main/user/search.scrbl[
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊████▍  ▏       ▏      ▏        66
#
# raco setup: 1 rendering: <pkgs>/racket-index/scribblings/main/user/search.scrbl[
#
#
#
#
#
#
# raco setup: 2 rendering: <pkgs>/roulette/scribblings/roulette.scrbl[
#
#
#
#
#
# raco setup: 3 rendering: <pkgs>/racket-index/scribblings/main/user/release.scrbl
#
#
#
#
# raco setup: 4 rendering: <pkgs>/racket-index/scribblings/main/user/local-redirec
#
#
#
# raco setup: 5 rendering: <pkgs>/ddict/data/ddict/ddict.scrbl
#
#
# raco setup: 7: idle[
#
# raco setup: 0 rendering: <pkgs>/racket-index/scribblings/main/user/start.scrbl
#
#
#
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊█▊     ▏        83raco setup: 3: idle[
#
#
#
#
# raco setup: 4: idle[
#
#
# raco setup: 1: idle[
#
#
#
#
#
#
# raco setup: 5: idle[
#
# raco setup: 0: idle[
#
#
#
#
#
#
# raco setup: 2: idle[
#
#
#
#
# ███████▊██████▊███████▊██████▊███████▊██████▊██████▊███████▊██████▊███████ 100
# raco setup: --- installing collections ---                         [23:30:49]
# raco setup: --- post-installing collections ---                    [23:30:49]

# %% [markdown]
# # 2024/09
#
#
# LEanr a scheme
#
# Anything you can implement `var` / `varo` is nonlogical.
#
# copy_term
#
# Deeply embedded copyterm. Fasiling conmputation as a deep embedding
#
# ill type systems. Knowing a query must fail is hard. co-LP does it by finding loops. The query is rationally consistent / unfalisfiabile.
#
# David galois parsing https://david.darais.com/
# residuization FLP
#
# gotta be lazy.
# Declarative copy_term. Forall binders. Lambda prolog is not sufficient becausey ou traverse, which is gen and test
#
# ziggurat olin shivers  https://www.khoury.northeastern.edu/home/shivers/papers/ziggurat-jfp.pdf Building Language Towers with Ziggurat
#
# johnathan edwards subtext
#
# no cloning theorem of logic variables? Quantum worlds. Using a variable is observing it.
# https://wiki.c2.com/?AmbSpecialForm Amb. Cool example using C fork
# bagof
#
#
#
# Spritelyt goblins https://spritely.institute/goblins/
# https://ocapn.org/
# Christine lemmer webber
# Hoot guile
# https://www.w3.org/TR/activitypub/
#
#
# Robert Gluck - reversible computation. also a supercompilation guy?
# Jeremy Zucker
#
# Conj is the problem. infinite success /\ fail   is bad `fail /\ inf succ` is fine.
#
# Andorra prolog super advance
#
#
# plotkin and reynolds unification as lattice
# Plotkin, G. D. (1970). A note on inductive generalization
# Reynolds, J. C. (1970). Transformational systems and the algebraic structure of atomic formulas.
#
# minikanren in lattice datalog
# does z3 mininaren scale
#
#
# Maybe he'd be into Max's crazy scheme. Communication across the universes. Plus. Dynamically refactoring the universes into a database.
#
# Might be a nice foundation for a hygienic macro expander
#
# I'm trying to wrap my head around 'An Interpreter of the Algebra of Programming in MiniKanren'.  No environment, right?  Or is there an implicit environment?  Or does it use substitution?
# Can you encode the lambda calculus in the interpreter at the end?
# Could you synthesize the Y combinator, or quines, or anything else?

# %% [markdown]
# # Herbie
#
# Ok, so with racket notebooks I can explore herbie now yea?
# Run as a library?
#  /home/philip/.local/share/racket/8.13/bin/herbie
#  and fpbench
# cost model for libm https://github.com/herbie-fp/herbie/blob/main/src/platforms/libm.rkt interesting
# ```
#     [* 0.284122]
#     [+ 0.21685800000000022]
#     [- 0.2448160000000003]
#     [/ 0.3915630999999998]
#     [acos 0.8382765000000001]
#     [acosh 1.0949965999999995]
#     [asin 0.8879643999999998]
# ```

# %%
!  /home/philip/.local/share/racket/8.13/bin/herbie

# %%
(require herbie/)
# Out:
# subprocess: `execute' access denied for /bin/sh
#   context...:
#    /usr/racket/collects/racket/system.rkt:174:0: do-system*/exit-code
#    /usr/racket/collects/racket/system.rkt:214:0: system
#    /usr/racket/collects/racket/port.rkt:124:0: with-output-to-x
#    body of "/home/philip/.local/share/racket/8.13/pkgs/herbie/config.rkt"
#    body of top-level

# %% [markdown]
# # Minikanren
# https://github.com/gregr/first-order-miniKanren
# http://minikanren.org/workshop/2019/minikanren19-final2.pdf
#
# https://www.coalg.org/tease-lp/files/2020/05/kuklina-supercompilation_strategies_abstract.pdf supercompilatio gluck
# https://arxiv.org/abs/2109.02814 An Empirical Study of Partial Deduction for miniKanren
#
#
# https://github.com/michaelballantyne/hosted-minikanren?tab=readme-ov-file
# https://github.com/michaelballantyne/mkcdcl
#
# https://github.com/jdyb/first-order-miniKanren-guile
#
# http://minikanren.org/workshop/2019/minikanren19-final4.pdf constructive negation
#
# stable semantics http://minikanren.org/workshop/2023/minikanren23-final3.pdf
# https://www.youtube.com/watch?v=o4r3MKsFHKM&ab_channel=ACMSIGPLAN
#
# https://github.com/brandonwillard/mk-rewrite-completion
# https://github.com/pythological/unification
#
# https://codeberg.org/arunavagantait/term-rewriting-in-minikanren
# https://codeberg.org/arunavagantait/alphaleanTAP-revisited
#
# So evalo, internal scheme, is somehow achieving a lambda unification?
#
# Harrop kanren? Hypothetical kanren?
#
#
# Datakanren

# %%
#lang iracket/lang #:require racket/base #:reader scribble/reader

# %%
;;; This file was generated by writeminikanren.pl
;;; Generated at 2007-10-25 15:24:42
;; https://github.com/miniKanren/simple-miniKanren/blob/master/mk.scm
(define-syntax lambdag@
  (syntax-rules ()
    ((_ (p) e) (lambda (p) e))))

(define-syntax lambdaf@
  (syntax-rules ()
    ((_ () e) (lambda () e))))

(define-syntax run*
  (syntax-rules ()
    ((_ (x) g ...) (run #f (x) g ...))))

(define-syntax rhs
  (syntax-rules ()
    ((_ x) (cdr x))))

(define-syntax lhs
  (syntax-rules ()
    ((_ x) (car x))))

(define-syntax size-s
  (syntax-rules ()
    ((_ x) (length x))))

(define-syntax var
  (syntax-rules ()
    ((_ x) (vector x))))

(define-syntax var?
  (syntax-rules ()
    ((_ x) (vector? x))))

(define empty-s '())

(define walk
  (lambda (u S)
    (cond
      ((and (var? u) (assq u S)) =>
       (lambda (pr) (walk (rhs pr) S)))
      (else u))))

(define ext-s
  (lambda (x v s)
    (cons `(,x . ,v) s)))

(define unify
  (lambda (u v s)
    (let ((u (walk u s))
          (v (walk v s)))
      (cond
        ((eq? u v) s)
        ((var? u) (ext-s-check u v s))
        ((var? v) (ext-s-check v u s))
        ((and (pair? u) (pair? v))
         (let ((s (unify 
                    (car u) (car v) s)))
           (and s (unify 
                    (cdr u) (cdr v) s))))
        ((equal? u v) s)
        (else #f)))))

(define ext-s-check
  (lambda (x v s)
    (cond
      ((occurs-check x v s) #f)
      (else (ext-s x v s)))))

(define occurs-check
  (lambda (x v s)
    (let ((v (walk v s)))
      (cond
        ((var? v) (eq? v x))
        ((pair? v) 
         (or 
           (occurs-check x (car v) s)
           (occurs-check x (cdr v) s)))
        (else #f)))))

(define walk*
  (lambda (w s)
    (let ((v (walk w s)))
      (cond
        ((var? v) v)
        ((pair? v)
         (cons
           (walk* (car v) s)
           (walk* (cdr v) s)))
        (else v)))))

(define reify-s
  (lambda (v s)
    (let ((v (walk v s)))
      (cond
        ((var? v)
         (ext-s v (reify-name (size-s s)) s))
        ((pair? v) (reify-s (cdr v)
                     (reify-s (car v) s)))
        (else s)))))

(define reify-name
  (lambda (n)
    (string->symbol
      (string-append "_" "." (number->string n)))))

(define reify
  (lambda (v s)
    (let ((v (walk* v s)))
      (walk* v (reify-s v empty-s)))))

(define-syntax mzero 
  (syntax-rules () ((_) #f)))

(define-syntax inc 
  (syntax-rules () ((_ e) (lambdaf@ () e))))

(define-syntax unit 
  (syntax-rules () ((_ a) a)))

(define-syntax choice 
  (syntax-rules () ((_ a f) (cons a f))))
 
(define-syntax case-inf
  (syntax-rules ()
    ((_ e (() e0) ((f^) e1) ((a^) e2) ((a f) e3))
     (let ((a-inf e))
       (cond
         ((not a-inf) e0)
         ((procedure? a-inf)  (let ((f^ a-inf)) e1))
         ((not (and (pair? a-inf)
                    (procedure? (cdr a-inf))))
          (let ((a^ a-inf)) e2))
         (else (let ((a (car a-inf)) (f (cdr a-inf))) 
                 e3)))))))

(define-syntax run
  (syntax-rules ()
    ((_ n (x) g0 g ...)
     (take n
       (lambdaf@ ()
         ((fresh (x) g0 g ... 
            (lambdag@ (s)
              (cons (reify x s) '())))
          empty-s))))))
 
(define take
  (lambda (n f)
    (if (and n (zero? n)) 
      '()
      (case-inf (f)
        (() '())
        ((f) (take n f))
        ((a) a)
        ((a f)
         (cons (car a)
           (take (and n (- n 1)) f)))))))

(define ==
  (lambda (u v)
    (lambdag@ (s)
      (unify u v s))))
 
(define-syntax fresh
  (syntax-rules ()
    ((_ (x ...) g0 g ...)
     (lambdag@ (s)
       (inc
         (let ((x (var 'x)) ...)
           (bind* (g0 s) g ...)))))))
 
(define-syntax bind*
  (syntax-rules ()
    ((_ e) e)
    ((_ e g0 g ...) (bind* (bind e g0) g ...))))
 
(define bind
  (lambda (a-inf g)
    (case-inf a-inf
      (() (mzero))
      ((f) (inc (bind (f) g)))
      ((a) (g a))
      ((a f) (mplus (g a) (lambdaf@ () (bind (f) g)))))))

(define-syntax conde
  (syntax-rules ()
    ((_ (g0 g ...) (g1 g^ ...) ...)
     (lambdag@ (s) 
       (inc 
         (mplus* 
           (bind* (g0 s) g ...)
           (bind* (g1 s) g^ ...) ...))))))
 
(define-syntax mplus*
  (syntax-rules ()
    ((_ e) e)
    ((_ e0 e ...) (mplus e0 
                    (lambdaf@ () (mplus* e ...))))))
 
(define mplus
  (lambda (a-inf f)
    (case-inf a-inf
      (() (f))
      ((f^) (inc (mplus (f) f^)))
      ((a) (choice a f))
      ((a f^) (choice a (lambdaf@ () (mplus (f) f^)))))))

(define-syntax conda
  (syntax-rules ()
    ((_ (g0 g ...) (g1 g^ ...) ...)
     (lambdag@ (s)
       (inc
         (ifa ((g0 s) g ...)
              ((g1 s) g^ ...) ...))))))
 
(define-syntax ifa
  (syntax-rules ()
    ((_) (mzero))
    ((_ (e g ...) b ...)
     (let loop ((a-inf e))
       (case-inf a-inf
         (() (ifa b ...))
         ((f) (inc (loop (f))))
         ((a) (bind* a-inf g ...))
         ((a f) (bind* a-inf g ...)))))))

(define-syntax condu
  (syntax-rules ()
    ((_ (g0 g ...) (g1 g^ ...) ...)
     (lambdag@ (s)
       (inc
         (ifu ((g0 s) g ...)
              ((g1 s) g^ ...) ...))))))
 
(define-syntax ifu
  (syntax-rules ()
    ((_) (mzero))
    ((_ (e g ...) b ...)
     (let loop ((a-inf e))
       (case-inf a-inf
         (() (ifu b ...))
         ((f) (inc (loop (f))))
         ((a) (bind* a-inf g ...))
         ((a f) (bind* (unit a) g ...)))))))

(define-syntax project
  (syntax-rules ()
    ((_ (x ...) g g* ...)
     (lambdag@ (s)
       (let ((x (walk* x s)) ...)
         ((fresh () g g* ...) s))))))

(define succeed (== #f #f))

(define fail (== #f #t))

(define onceo
  (lambda (g)
    (condu
      (g succeed)
      ((== #f #f) fail))))

# %%
(run 1 (q) (== q w))
# Out:
# eval:1:0: run: bad syntax
#   in: (run 1 (q w) (== q w))
#   location...:
#    eval:1:0

# %% [markdown]
# # Scheme
#
#
# https://srfi.schemers.org/srfi-262/srfi-262.html extensible pattern matching
#
# https://groups.google.com/g/comp.lang.scheme/c/wyYJ5PwSxSM/m/cZ9Lrj3ROFQJ  How to write seemingly unhygienic macros using syntax-rules petrofsky. Oleg went to town on this later
#
#
# https://www.youtube.com/watch?v=DDROSL-gGOo&t=52s&ab_channel=ChristineLemmer-Webber  Unlock Lisp / Scheme's magic: beginner to Scheme-in-Scheme in one hour
#
# Guile
# https://jeko.frama.io/en/index.html
#
# https://elephly.net/guile-studio/
#
# Maybe one way of doing things is to use guile hoot -> wasmtime python?
#
# https://cm-gitlab.stanford.edu/bil/s7
# gambit
# biwa
#
#
# Org mode. I ought to love org mode
#
# https://gitlab.com/gule-log/guile-log
#
#
#
# https://pl-ai-seminar.seas.harvard.edu/publications harvard reading list
# judea pearl counterfactual
#
# https://docs.racket-lang.org/iracket/index.html
#
# Wow lots of problems getting emacs to work.
# https://guix.gnu.org/manual/en/html_node/The-Perfect-Setup.html
# some complaiting about defvar-1.
# You really need to reboot the computer after upgrading guix. Maybe i never should've install the ubuntu version. Too old.

# %%
#lang iracket/lang #:require r5rs

(display "Hello, World!")
(+ 1  1)
(define (double x) (* x 2))
(double 4)
'foo
'(+ 1 2)
(list 1 2)
(lambda (x) (* x 2))
(string-append "hi" " there")
(let ((name "horce")) name)
; let*
(apply + (list 1 2 3))
(string? 1)
#t
(if 15 "fred" "larry")
(cons 1 '())
(equal? 1 2)
;(use-modules (srfi srfi-1))
;(first '(1 2 3)) rest
; module ice-9 match
# Out:
# Hello, World!
# first: undefined;
#  cannot reference an identifier before its definition
#   in module: top-level
#   context...:
#    body of top-level

# %%
(require racket)
(display "hello world")
(substring "corduroys" 0 4) 
(equal? 6 6)
(member "fall" (list "hop" "skip" "jump"))
(pair? empty)
(quote (1 . 2))
# Out:
# hello world
# '(1 . 2)

# %%
(require minikanren)
(run 1 (y)
  (fresh (x z)
    (== x z)
    (== 3 y)))
# Out:
# '(3)

# %%
# %%file /tmp/hello.scm
#
# (println "Hello, World!")
# Out:
# Writing /tmp/hello.scm

# %%
! guile /tmp/hello.scm

# %% [markdown]
# ## Reflective Towers
# https://blog.sigplan.org/2021/08/12/reflective-towers-of-interpreters/
# https://github.com/nikitadanilov/3-lisp
# https://github.com/namin/reflective-towers

# %% [markdown]
# ## pexpect of scheme

# %%
import pexpect

scm = pexpect.spawn('guile')
#scm.expect_exact("scheme@(guile-user)> ")
#scm.close()

# %%
scm.sendline('(print "hell oworld")')
# Out:
# 22

# %%
def send_command(command):
    scm.sendline(command)
    scm.expect_exact('scheme@(guile-user)')
    return scm.before.decode().strip()
send_command('(+ 1 1)')
# Out:
# '[2]> (+ 1 1)\r\n$3 = 2'

# %%
import pexpect
import re

scheme_process = pexpect.spawn('guile')
# Read and discard the initial startup text
scheme_process.expect_exact('scheme@(guile-user)> ')
prompt_pattern = re.compile(rb'scheme@\((guile-user|guile-user \[\d+\])\)> ')

def send_command(command, timeout=10):
    scheme_process.sendline(command)
    try:
        scheme_process.expect_exact(command, timeout=timeout)
        scheme_process.expect(prompt_pattern, timeout=timeout)
        return scheme_process.before.decode().strip()
    except pexpect.TIMEOUT:
        return "Error: Command timed out."
    except pexpect.EOF:
        return "Error: Unexpected end of file encountered."

output = send_command('(display "Hello from Scheme!")')
print(output)

output = send_command('(newline)')
print(output)

output = send_command('(+ 1 2 3)')
print(output)

#send_command('(load "hello.scm")')

send_command("(display %load-path)")

send_command('(add-to-load-path "~/Documents/scheme/faster-miniKanren")')
print(send_command("(display %load-path)"))
send_command('(use-modules (faster-miniKanren))')
# Out:
# Hello from Scheme!
#
# $1 = 6
# (~/Documents/scheme/faster-miniKanren /usr/share/guile/3.0 /usr/share/guile/site/3.0 /usr/share/guile/site /usr/share/guile)
# 'While compiling expression:\r\nno code for module (faster-miniKanren)'

# %% [markdown]
# ## guix
# guix shell
# guix pull
