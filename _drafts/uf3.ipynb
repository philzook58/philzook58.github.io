# %% [markdown]
# Slotted uf
# contextual uf
# proof producing
# backtracking
#
#
#
# Primitive UFs + egglog. Indeed reconciling primitives and merge itself
#
# If I mush together eids and primitives, we'd probably want constant folding to be a baked in mechnism instead of rules.
# Primitive UFs are the least invasive notion of EMT, but also hence aren't that big a delta.
#
# giving an actual constant folding definition to fact(n)
# fact(n) is the eid?
#
# The sort API
#
#
# For leveled UF, scopes should not just be levels unless we're in kind of a bcacktracking flavored thing.
# levels = [lid, lid, lid, lid], eid
# scopes branch.
# We then never have any cleanup however though.
# Well, maybe at some point we are done with / seal a scope? And can clean it up observationally?
