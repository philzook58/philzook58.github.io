# %%
black_string = """(14,15,12)  (504,516,479,1588)  5012.011904761905   578.9218875502008
(14,15,12)  (497,513,477,1570)  5047.680080482897   573.9419678714859
(13,15,12)  (402,424,393,1297)  5115.701492537313   473.58413654618477
(14,15,12)  (426,444,410,1362)  5057.901408450704   497.83012048192785
(14,15,12)  (418,435,401,1332)  5046.047846889953   488.34959839357424
(13,15,12)  (406,425,393,1302)  5079.004926108375   476.46626506024097
(13,15,12)  (404,423,390,1294)  5068.970297029703   474.31244979919677
(14,15,12)  (419,435,401,1334)  5037.3245823389025  488.5612449799196
(14,15,12)  (474,489,454,1501)  5040.2405063291135  547.6168674698794
(13,15,12)  (534,563,526,1726)  5143.921348314607   624.6500000000001
(14,14,12)  (550,554,517,1729)  4971.983606557377   620.2489959839356
(13,15,12)  (425,444,411,1358)  5084.183962264151   496.7158634538152
(14,15,12)  (423,443,409,1353)  5074.900709219858   496.3299196787149
(14,15,12)  (417,436,401,1333)  5046.047846889953   489.6941767068273
(13,15,12)  (412,432,398,1321)  5071.533980582524   482.92771084337346
(13,15,12)  (410,429,397,1315)  5080.195121951219   480.0829317269076
(14,15,12)  (490,508,474,1560)  5084.367346938776   566.0612449799197
(14,15,12)  (463,476,439,1458)  5003.505399568035   536.4991967871487
(14,15,12)  (491,502,464,1544)  4983.729124236253   564.1502008032128
(13,15,12)  (408,427,395,1307)  5079.60294117647    478.6200803212852
(14,15,12)  (427,442,408,1357)  5031.070422535211   495.2343373493977
(14,15,12)  (393,407,373,1248)  5016.331632653061   459.31044176706826"""

# %%
def parse_line_string(string):
    bytes_string, raw_string, temp, lux = string.split()
    return parse_tuple_string(bytes_string), parse_tuple_string(raw_string), float(temp), float(lux)
    
def parse_tuple_string(string):
    return list(map(int, string.strip("()").split(",")))

def parse_string(string):
    lines = string.split("\n")
    return list(map(parse_line_string, lines))

# %%
parse_string(black_string)
# Out:
# [[504, 516, 479, 1588],
#  [497, 513, 477, 1570],
#  [402, 424, 393, 1297],
#  [426, 444, 410, 1362],
#  [418, 435, 401, 1332],
#  [406, 425, 393, 1302],
#  [404, 423, 390, 1294],
#  [419, 435, 401, 1334],
#  [474, 489, 454, 1501],
#  [534, 563, 526, 1726],
#  [550, 554, 517, 1729],
#  [425, 444, 411, 1358],
#  [423, 443, 409, 1353],
#  [417, 436, 401, 1333],
#  [412, 432, 398, 1321],
#  [410, 429, 397, 1315],
#  [490, 508, 474, 1560],
#  [463, 476, 439, 1458],
#  [491, 502, 464, 1544],
#  [408, 427, 395, 1307],
#  [427, 442, 408, 1357],
#  [393, 407, 373, 1248]]

# %%
"(1,2,3)".strip("()")
# Out:
# '1,2,3'
