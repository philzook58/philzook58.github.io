# %%
from sympy import *

from sympy.integrals.manualintegrate import integral_steps, parts_rule

# %%
x = symbols('x')
integrate(x  * x * exp(-x*x), (x,-oo, oo))
# Out:
# sqrt(pi)/2

# %%
a = symbols('a', real=True, positive=True)
integrate( series(exp(- x * x -  a * x*x*x*x), a, n = 8 ).removeO() , (x,-oo,oo))
#series(exp(- x * x -  a * x*x*x*x), a, n = 8 ).removeO()

# how to get it to do abstract matrix gaussians?
# Out:
# -677644592625*sqrt(pi)*a**7/262144 + 7027425405*sqrt(pi)*a**6/65536 - 43648605*sqrt(pi)*a**5/8192 + 675675*sqrt(pi)*a**4/2048 - 3465*sqrt(pi)*a**3/128 + 105*sqrt(pi)*a**2/32 - 3*sqrt(pi)*a/4 + sqrt(pi)

# %%
help(series)
# Out:
# Help on function series in module sympy.series.series:
#
# series(expr, x=None, x0=0, n=6, dir='+')
#     Series expansion of expr around point `x = x0`.
#
#     See the doctring of Expr.series() for complete details of this wrapper.

# %% [markdown]
# https://github.com/lisyarus/chembook/raw/master/qchem_done_wrong.pdf
#
# It'd be nice to be able to do the closed form integral derivations in sympy.
# I suspect they will need a little guidance though.
# And if they could be recorded in a Latex derivation that'd be nice
#
#
# Integration by parts
# https://github.com/sympy/sympy/blob/master/sympy/integrals/manualintegrate.py
# https://stackoverflow.com/questions/48997931/sympy-step-by-step-solution-of-integrals

# %%
parts_rule([ x**2, x])

# %%
integral_steps(x**2 * exp(x), x)
# Out:
# PartsRule(u=x**2, dv=exp(x), v_step=ExpRule(base=E, exp=x, context=exp(x), symbol=x), second_step=PartsRule(u=2*x, dv=exp(x), v_step=ExpRule(base=E, exp=x, context=exp(x), symbol=x), second_step=ConstantTimesRule(constant=2, other=exp(x), substep=ExpRule(base=E, exp=x, context=exp(x), symbol=x), context=2*exp(x), symbol=x), context=2*x*exp(x), symbol=x), context=x**2*exp(x), symbol=x)

# %%
manualintegrate(sin(x), x) == -cos(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1fd0ce52af2f> in <module>
# ----> 1 manualintegrate(sin(x), x) == -cos(x)
#
# TypeError: 'module' object is not callable

# %%
x, y , z = symbols("x y z")
integrate(exp(-x**2 - 3 * y**2 - 4 * x * y  + 3 * x + 4 * y), (x, -oo, oo), (y, -oo, oo))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c6b5c8b30c91> in <module>
#       1 x, y , z = symbols("x y z")
# ----> 2 integrate(exp(-x**2 - 3 * y**2 - 4 * x * y  + 3 * x + 4 * y), (x, -oo, oo), (y, -oo, oo))
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1463     if isinstance(integral, Integral):
#    1464         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1465                              risch=risch, manual=manual)
#    1466     else:
#    1467         return integral
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     536                 else:
#     537                     antideriv = self._eval_integral(
# --> 538                         function, xab[0], **eval_kwargs)
#     539                     if antideriv is None and meijerg is True:
#     540                         ret = try_meijerg(function, xab)
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     987                 try:
#     988                     if conds == 'piecewise':
# --> 989                         h = heurisch_wrapper(g, x, hints=[])
#     990                     else:
#     991                         h = heurisch(g, x, hints=[])
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     130
#     131     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 132                    unnecessary_permutations)
#     133     if not isinstance(res, Basic):
#     134         return res
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     700
#     701     if not (F.free_symbols - set(V)):
# --> 702         solution = _integrate('Q')
#     703
#     704         if solution is None:
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     654         # revise this code.
#     655         candidate = poly_part/poly_denom + Add(*log_part) + Add(*atan_part)
# --> 656         h = F - _derivation(candidate) / denom
#     657         raw_numer = h.as_numer_denom()[0]
#     658
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _derivation(h)
#     479     numers = [ cancel(denom*g) for g in diffs ]
#     480     def _derivation(h):
# --> 481         return Add(*[ d * h.diff(v) for d, v in zip(numers, V) ])
#     482
#     483     def _deflation(p):
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/heurisch.py in <listcomp>(.0)
#     479     numers = [ cancel(denom*g) for g in diffs ]
#     480     def _derivation(h):
# --> 481         return Add(*[ d * h.diff(v) for d, v in zip(numers, V) ])
#     482
#     483     def _deflation(p):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3026         new_symbols = list(map(sympify, symbols))  # e.g. x, 2, y, z
#    3027         assumptions.setdefault("evaluate", True)
# -> 3028         return Derivative(self, *new_symbols, **assumptions)
#    3029
#    3030     ###########################################################################
#
# /usr/local/lib/python3.7/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1259                 # object, the default in `Basic` will call a loop over
#    1260                 # `_eval_derivative`:
# -> 1261                 obj = expr._eval_derivative_n_times(v, count)
#    1262                 nderivs += count
#    1263                 if not is_symbol:
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in _eval_derivative_n_times(self, s, n)
#    1618             obj = self
#    1619             for i in range(n):
# -> 1620                 obj2 = obj._accept_eval_derivative(s)
#    1621                 if obj == obj2:
#    1622                     break
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in _accept_eval_derivative(self, s)
#    1594     def _accept_eval_derivative(self, s):
#    1595         # This method needs to be overridden by array-like objects
# -> 1596         return s._visit_eval_derivative_scalar(self)
#    1597
#    1598     def _visit_eval_derivative_scalar(self, base):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in _visit_eval_derivative_scalar(self, base)
#    1599         # Base is a scalar
#    1600         # Types are (base: scalar, self: scalar)
# -> 1601         return base._eval_derivative(self)
#    1602
#    1603     def _visit_eval_derivative_array(self, base):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/add.py in _eval_derivative(self, s)
#     381     @cacheit
#     382     def _eval_derivative(self, s):
# --> 383         return self.func(*[a.diff(s) for a in self.args])
#     384
#     385     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/add.py in <listcomp>(.0)
#     381     @cacheit
#     382     def _eval_derivative(self, s):
# --> 383         return self.func(*[a.diff(s) for a in self.args])
#     384
#     385     def _eval_nseries(self, x, n, logx):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3026         new_symbols = list(map(sympify, symbols))  # e.g. x, 2, y, z
#    3027         assumptions.setdefault("evaluate", True)
# -> 3028         return Derivative(self, *new_symbols, **assumptions)
#    3029
#    3030     ###########################################################################
#
# /usr/local/lib/python3.7/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1259                 # object, the default in `Basic` will call a loop over
#    1260                 # `_eval_derivative`:
# -> 1261                 obj = expr._eval_derivative_n_times(v, count)
#    1262                 nderivs += count
#    1263                 if not is_symbol:
#
# /usr/local/lib/python3.7/site-packages/sympy/core/mul.py in _eval_derivative_n_times(self, s, n)
#     914         m = len(args)
#     915         if m == 1:
# --> 916             return args[0].diff((s, n))*Mul.fromiter(coeff_args)
#     917
#     918         if isinstance(n, (int, Integer)):
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3026         new_symbols = list(map(sympify, symbols))  # e.g. x, 2, y, z
#    3027         assumptions.setdefault("evaluate", True)
# -> 3028         return Derivative(self, *new_symbols, **assumptions)
#    3029
#    3030     ###########################################################################
#
# /usr/local/lib/python3.7/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1113         expr = sympify(expr)
#    1114         try:
# -> 1115             has_symbol_set = isinstance(expr.free_symbols, set)
#    1116         except AttributeError:
#    1117             has_symbol_set = False
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in free_symbols(self)
#     505         Any other method that uses bound variables should implement a
#     506         free_symbols method."""
# --> 507         return set().union(*[a.free_symbols for a in self.args])
#     508
#     509     @property
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in <listcomp>(.0)
#     505         Any other method that uses bound variables should implement a
#     506         free_symbols method."""
# --> 507         return set().union(*[a.free_symbols for a in self.args])
#     508
#     509     @property
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in free_symbols(self)
#     505         Any other method that uses bound variables should implement a
#     506         free_symbols method."""
# --> 507         return set().union(*[a.free_symbols for a in self.args])
#     508
#     509     @property
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in <listcomp>(.0)
#     505         Any other method that uses bound variables should implement a
#     506         free_symbols method."""
# --> 507         return set().union(*[a.free_symbols for a in self.args])
#     508
#     509     @property
#
# /usr/local/lib/python3.7/site-packages/sympy/core/symbol.py in free_symbols(self)
#     283     @property
#     284     def free_symbols(self):
# --> 285         return {self}
#     286
#     287     binary_symbols = free_symbols  # in this case, not always
#
# /usr/local/lib/python3.7/site-packages/sympy/core/basic.py in __hash__(self)
#     119             setattr(self, k, v)
#     120
# --> 121     def __hash__(self):
#     122         # hash cannot be cached using cache_it because infinite recurrence
#     123         # occurs as hash is needed for setting cache dictionary keys
#
# KeyboardInterrupt:

# %%
x, y , z = symbols("x y z")
integrate(sym.exp(-x**2 - y**2 )/sqrt(y**2 + x**2), (x, -oo, oo), (y, -oo, oo)) #oo that is funny
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     208
# --> 209                         monom[indices[base]] = exp
#     210                     except KeyError:
#
# KeyError: polar_lift(y)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in factor(f, *gens, **args)
#    6325     try:
# -> 6326         return _generic_factor(f, gens, args, method='factor')
#    6327     except PolynomialError as msg:
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in _generic_factor(expr, gens, args, method)
#    6018     opt = options.build_options(gens, args)
# -> 6019     return _symbolic_factor(sympify(expr), opt, method)
#    6020
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor(expr, opt, method)
#    5963             return expr._eval_factor()
# -> 5964         coeff, factors = _symbolic_factor_list(together(expr), opt, method)
#    5965         return _keep_coeff(coeff, _factors_product(factors))
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in _symbolic_factor_list(expr, opt, method)
#    5925         try:
# -> 5926             poly, _ = _poly_from_expr(base, opt)
#    5927         except PolificationFailed as exc:
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in _poly_from_expr(expr, opt)
#    4287
# -> 4288     rep, opt = _dict_from_expr(expr, opt)
#    4289     if not opt.gens:
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polyutils.py in _dict_from_expr(expr, opt)
#     365     if opt.gens:
# --> 366         rep, gens = _dict_from_expr_if_gens(expr, opt)
#     367     else:
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polyutils.py in _dict_from_expr_if_gens(expr, opt)
#     304     """Transform an expression into a multinomial form given generators. """
# --> 305     (poly,), gens = _parallel_dict_from_expr_if_gens((expr,), opt)
#     306     return poly, gens
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     214                             raise PolynomialError("%s contains an element of "
# --> 215                                                   "the set of generators." % factor)
#     216
#
# PolynomialError: polar_lift(y) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# <ipython-input-18-5619457bacf7> in <module>
#       1 x, y , z = symbols("x y z")
# ----> 2 integrate(sym.exp(-x**2 - y**2 )/sqrt(y**2 + x**2), (x, -oo, oo), (y, -oo, oo)) #oo that is funny
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1463     if isinstance(integral, Integral):
#    1464         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1465                              risch=risch, manual=manual)
#    1466     else:
#    1467         return integral
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     476                 else:
#     477                     antideriv = self._eval_integral(
# --> 478                         function, xab[0], **eval_kwargs)
#     479             else:
#     480                 # There are a number of tradeoffs in using the
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     848         # Piecewise antiderivatives need to call special integrate.
#     849         if isinstance(f, Piecewise):
# --> 850             return f.piecewise_integrate(x, **eval_kwargs)
#     851
#     852         # let's cut it short if `f` does not depend on `x`; if
#
# /usr/local/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in piecewise_integrate(self, x, **kwargs)
#     369         """
#     370         from sympy.integrals import integrate
# --> 371         return self.func(*[(integrate(e, x, **kwargs), c) for e, c in self.args])
#     372
#     373     def _handle_irel(self, x, handler):
#
# /usr/local/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in <listcomp>(.0)
#     369         """
#     370         from sympy.integrals import integrate
# --> 371         return self.func(*[(integrate(e, x, **kwargs), c) for e, c in self.args])
#     372
#     373     def _handle_irel(self, x, handler):
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1463     if isinstance(integral, Integral):
#    1464         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1465                              risch=risch, manual=manual)
#    1466     else:
#    1467         return integral
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     536                 else:
#     537                     antideriv = self._eval_integral(
# --> 538                         function, xab[0], **eval_kwargs)
#     539                     if antideriv is None and meijerg is True:
#     540                         ret = try_meijerg(function, xab)
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#    1001                 # rewrite using G functions
#    1002                 try:
# -> 1003                     h = meijerint_indefinite(g, x)
#    1004                 except NotImplementedError:
#    1005                     from sympy.integrals.meijerint import _debug
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in meijerint_indefinite(f, x)
#    1619     results = []
#    1620     for a in sorted(_find_splitting_points(f, x) | {S(0)}, key=default_sort_key):
# -> 1621         res = _meijerint_indefinite_1(f.subs(x, x + a), x)
#    1622         if not res:
#    1623             continue
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _meijerint_indefinite_1(f, x)
#    1644     _debug('Trying to compute the indefinite integral of', f, 'wrt', x)
#    1645
# -> 1646     gs = _rewrite1(f, x)
#    1647     if gs is None:
#    1648         # Note: the code that calls us will do expand() and try again
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _rewrite1(f, x, recursive)
#    1567     """
#    1568     fac, po, g = _split_mul(f, x)
# -> 1569     g = _rewrite_single(g, x, recursive)
#    1570     if g:
#    1571         return fac, po, g[0], g[1]
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _rewrite_single(f, x, recursive)
#    1522     try:
#    1523         F, strip, _ = mellin_transform(f, x, s, integrator=my_integrator,
# -> 1524                                        simplify=False, needeval=True)
#    1525         g = my_imt(F, s, x, strip)
#    1526     except IntegralTransformError:
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/transforms.py in mellin_transform(f, x, s, **hints)
#     349     hankel_transform, inverse_hankel_transform
#     350     """
# --> 351     return MellinTransform(f, x, s).doit(**hints)
#     352
#     353
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     115             try:
#     116                 return self._compute_transform(self.function,
# --> 117                     self.function_variable, self.transform_variable, **hints)
#     118             except IntegralTransformError:
#     119                 pass
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/transforms.py in _compute_transform(self, f, x, s, **hints)
#     292
#     293     def _compute_transform(self, f, x, s, **hints):
# --> 294         return _mellin_transform(f, x, s, **hints)
#     295
#     296     def _as_integral(self, f, x, s):
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/transforms.py in wrapper(*args, **kwargs)
#     193         def wrapper(*args, **kwargs):
#     194             noconds = kwargs.pop('noconds', default)
# --> 195             res = func(*args, **kwargs)
#     196             if noconds:
#     197                 return res[0]
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/transforms.py in _mellin_transform(f, x, s_, integrator, simplify)
#     217     # convergence of the integral.
#     218     s = _dummy('s', 'mellin-transform', f)
# --> 219     F = integrator(x**(s - 1) * f, x)
#     220
#     221     if not F.has(Integral):
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in my_integrator(f, x)
#    1513     def my_integrator(f, x):
#    1514         from sympy import Integral, hyperexpand
# -> 1515         r = _meijerint_definite_4(f, x, only_double=True)
#    1516         if r is not None:
#    1517             res, cond = r
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _meijerint_definite_4(f, x, only_double)
#    1994
#    1995     # Try two G functions.
# -> 1996     gs = _rewrite2(f, x)
#    1997     if gs is not None:
#    1998         for full_pb in [False, True]:
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _rewrite2(f, x)
#    1581     """
#    1582     fac, po, g = _split_mul(f, x)
# -> 1583     if any(_rewrite_single(expr, x, False) is None for expr in _mul_args(g)):
#    1584         return None
#    1585     l = _mul_as_two_parts(g)
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in <genexpr>(.0)
#    1581     """
#    1582     fac, po, g = _split_mul(f, x)
# -> 1583     if any(_rewrite_single(expr, x, False) is None for expr in _mul_args(g)):
#    1584         return None
#    1585     l = _mul_as_two_parts(g)
#
# /usr/local/lib/python3.7/site-packages/sympy/integrals/meijerint.py in _rewrite_single(f, x, recursive)
#    1433     if isinstance(f, meijerg):
#    1434         from sympy import factor
# -> 1435         coeff, m = factor(f.argument, x).as_coeff_mul(x)
#    1436         if len(m) > 1:
#    1437             return None
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in factor(f, *gens, **args)
#    6330             return factor_nc(f)
#    6331         else:
# -> 6332             raise PolynomialError(msg)
#    6333
#    6334
#
# PolynomialError: polar_lift(y) contains an element of the set of generators.

# %%
r = symbols("r")
integrate(sym.exp(-r**2 ) * r**2 / abs(r) , (r, -oo, oo)) #oo that is funny
# Out:
# 1

# %%
w, k, e = symbols('w k e', Real=True)
1/(w - k**2 + 1j * e )
# Out:
# 1/(1.0*I*e - k**2 + w)

# %%
t, x = symbols('t x', Real=True)

# %%
inverse_fourier_transform(1/(w - 1.j ), w, t)
# Out:
# InverseFourierTransform(1/(w - 1.0*I), w, t)

# %%
fourier_transform(Heaviside(t), t, w)
# Out:
# FourierTransform(Heaviside(t), t, w)

# %%
fourier_transform(1/ (t**2 + 1) , t, w)
# Out:
# pi*exp(-2*pi*w)

# %%
x = symbols('x', real=True, positive=True)
fourier_transform(1/ (t**2 + x) , t, w)
# Out:
# pi*exp(-2*pi*w*sqrt(x))/sqrt(x)

# %%
w = symbols('w', real=True, negative = True)
fourier_transform(1/ (1.j*t + 1) , t, w)
# Out:
# 2.0*pi*exp(2.0*pi*w)

# %%
# Out:
# -2*I*pi*InverseFourierTransform(exp(2.0*pi*eps*t + 2*I*pi*k**2*t), k, x)

# %%
def Gret(k,w):
    return 1 / (k**2 - w - 1.j*eps)
def Gadv(k,w):
    return 1 / (k**2 - w + 1.j*eps)

# %%
w, t, k , x = symbols('w t k x', real=True)
eps = symbols('eps', real=True, positive = True)
inverse_fourier_transform(fourier_transform(exp(- eps * t) * Heaviside(t), t , w), w, t)
# Out:
# InverseFourierTransform(1/(eps + 2*I*pi*w), w, t)

# %%
integrate( exp((1.j - 0.01) * w * t) * Heaviside(t - 7), (t,-oo,oo))
# Out:
# Piecewise((0.00999900009999*(1 + 100.0*I)*exp(-0.07*w + 7.0*I*w)/w, ((pi/2 >= Abs(arg(w))) & (pi/2 > Abs(arg(w) - pi/2))) | ((pi/2 > Abs(arg(w))) & (pi/2 >= Abs(arg(w) - pi/2))) | ((pi/2 > Abs(arg(w))) & (pi/2 > Abs(arg(w) - pi/2)))), (Integral(exp(t*w*(-0.01 + 1.0*I))*Heaviside(t - 7), (t, -oo, oo)), True))

# %%
psi = Function("psi")
def p(psi):
    return 1.j * diff(psi,x)
def H(psi):
    return p(p(psi))
simplify(fourier_transform( fourier_transform( -1.j*diff(psi(x,t),t) - H(psi(x,t)) , x,k) ,t,w))
# Out:
# -1.0*I*FourierTransform(FourierTransform(Derivative(psi(x, t), t), x, k), t, w) + 1.0*FourierTransform(FourierTransform(Derivative(psi(x, t), (x, 2)), x, k), t, w)

# %%
w, t, k , x = symbols('w t k x', real=True)
psi = Function("psi")
psi2 = inverse_fourier_transform(inverse_fourier_transform(  psi(w,k) , w,t  ) , k,x)
simplify(-1.j*diff(psi2,t) - H(psi2))
# Out:
# 1.0*Derivative(InverseFourierTransform(InverseFourierTransform(psi(w, k), w, t), k, x), (x, 2)) - 1.0*I*Derivative(InverseFourierTransform(psi(w, k), w, t), t)*Subs(Derivative(InverseFourierTransform(_xi_1, k, x), _xi_1), (_xi_1,), (InverseFourierTransform(psi(w, k), w, t),))

# %%
psi = exp(1.j * (x * k - t * w ))
Hpsi = factor(-1.j*diff(psi,t) - H(psi))
Hpsi.args[1]
# Out:
# k**2 + w

# %%
w, t, k , x = symbols('w t k x', real=True)
eps = symbols('eps', real=True, positive = True)
inverse_fourier_transform(inverse_fourier_transform(1 / (k**2 - w - 1.j*eps) , w, t),k,x)
-1.j*diff(psi(x,t),t) - H(psi(x,t))
# Out:
# -1.0*I*Derivative(psi(x, t), t) + 1.0*Derivative(psi(x, t), (x, 2))

# %% [markdown]
# Domination by poles. Poles, 1 integral takes into exponential, then standard steepest descent. Maybe it's all steepest descent. It's just whether the maxmimal point is bounded or not. Why do fourier methods feel basically so systematic? We can reflect certain geometrical conditions in and out using heaviside and delta functions

# %%
vf ** 2 == vi ** 2 + 2 * a * d # energy equation? Or just a result of the other two



# grobner basis solving

# %%
t,a,d,vf,vi = symbols("t a d vf vi")
e1 = Eq(d , vi * t + 1/2 * a * t ** 2)
tsub = solve(Eq(vf , vi + a * t),t)[0]
print(tsub) # This is assuming a is nonzero though.
expand(simplify(e1.subs(t,tsub)))
# Out:
# (vf - vi)/a
# Eq(d, 0.5*vf**2/a - 0.5*vi**2/a)

# %% [markdown]
# I think it is easy to over emphasize the isolation method for solving systems of equations.
# Given a system of equations, the way I might go about it naturally is to isolated a variable on one side if I can. Then taking this and substitute into the other equations to eliminate that variable.
#
#
# The contour integral method does this. We integrate piece by piece, eliminating and subsituting variables. Can I contour integrate using a grobner basis of the poles? Yes basically right? You can have an elimination ordering. The pole is a big product structure. This is the union of all solutions.
#
#
# Another point: it is always safe to add a derived equation to your current set of equations. It is not always safe to mutate an equation into another form or delete some equation from your set.
# Gaussian elimination is the canonical model of how one solves equations.
# The way we do gaussian elmination and the way it is taught make this unclear. We maintain the shape of the matrix throught the calculation, destructivly updating rows. Now it so happens that if you do it right, this is ok, but in general this is not what you want to do.
# We can solve for t, but it is under the assumption that a \ne 0.  In other cases we need to be careful of the fact that an equation may have mutliple solutions. These are finicky points.
#
#
# A very primitive and reasonable thing is the 0x=0 no matter what x is. This is always safe. Also 0 + 0 = 0.
# If we write out equations in the form phi(x) =0, we can produce dervied equations via these rules.
#
# The grobner basis algorithm is doing exactly this. It attempts to fairly greedily remove higher power terms via these two moves.
# In addition for polynomial equations, there is a fairly systematic way of reducing redundancy in some pile of equations.  You do not need 2x = 1 and the equation 4 x = 2. One is derivable from the other.

# %%
from sympy import *
t,a,d,vf,vi = symbols("t a d vf vi")
G = groebner(  [vi * t + 1/2 * a * t ** 2 - d,  
                vi + a * t - vf] , 
                 t,vf,d,a,vi  )
for e in G:
    print(e)
# Out:
# -2.0*d + 1.0*t*vf + 1.0*t*vi
# 1.0*a*t - 1.0*vf + 1.0*vi
# -2.0*a*d + 1.0*vf**2 - 1.0*vi**2

# %%
e1 = vi * t + 1/2 * a * t ** 2 - d
e2 = vi + a * t - vf
e3 = simplify(e2 * t / 2 - e1) # here we have derived another one of the big 4
print(collect(e3,t))
#print(collect(e3,t) * t * a)
#e4 = simplify(collect(e3,t) * t * a - (-vf - vi)* e1)
#print(collect(e4,t))
#simplify(collect(e4,t) * a - e2 * (a*d + vf*vi + vi**2))
#simplify(  )
simplify(e2 * (-vf/2 - vi/2) - e3 * a) # This gets us equation
# Out:
# d + t*(-vf/2 - vi/2)
# a*t*(d + t*(-vf/2 - vi/2))
# -d*vf - d*vi + t*(a*d + vf*vi + vi**2)
# -a*d + vf**2/2 - vi**2/2

# %%
#elastic collisions
v1i,v2i,v1f,v2f, m1, m2 = symbols("v1i v2i v1f v2f  m1  m2 ")
dp = (m1 * v1f + m2 * v2f) - (m1 * v1i + m2 * v2i  )
dE = 1/2* m2 * v2f**2 + 1/2* m1 * v1f**2  - 1/2* m2 * v2i**2  - 1/2* m1 * v1i**2 
G = groebner([dp,dE], m1, m2,v2i,v2f ,v1i, v1f)
#print(len(G))
#print(factor(G[0]))
#print(factor(G[1]))
#print(G[1])
#print(factor(G[2]))

G = groebner([dp,dE], v1i,v1f, v2i,v2f,  m1, m2)
for e in G:
    print(factor(e))
# of course one solution is no collision at all.
# Out:
# -1.0*m2*(v2f - v2i)*(v1f + v1i - v2f - v2i)
# -1.0*(m1*v1f - m1*v1i + m2*v2f - m2*v2i)
# -1.0*m2*(1.0*v2f - 1.0*v2i)*(1.0*m1*v1f - 0.5*m1*v2f - 0.5*m1*v2i + 0.5*m2*v2f - 0.5*m2*v2i)

# %%
# simple planetary motion
t,x,y = symbols("t x y")
fx = Function("x")
fy = Function("y")
x = fx(t)
y = fy(t)
r = sqrt(x**2 + y**2)
V = 1 / r
e1 = Eq( diff(x,t,2) , - diff(V,x)   )
e2 = Eq( diff(y,t,2) , - diff(V,y)   )
dsolve( [e1,e2], [x,y])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-41-f4962ac6218d> in <module>
#       8 e1 = Eq( diff(x,t,2) , - diff(V,x)   )
#       9 e2 = Eq( diff(y,t,2) , - diff(V,y)   )
# ---> 10 dsolve( [e1,e2], [x,y])
#
# /usr/local/lib/python3.7/site-packages/sympy/solvers/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     607             "number of functions being equal to number of equations")
#     608         if match['type_of_equation'] is None:
# --> 609             raise NotImplementedError
#     610         else:
#     611             if match['is_linear'] == True:
#
# NotImplementedError:

# %%
# simple circular
t,x,y = symbols("t x y")
fx = Function("x")
fy = Function("y")
x = fx(t)
y = fy(t)
r = sqrt(x**2 + y**2)
V = 1 / r
e1 = Eq( diff(x,t,1) , - y   )
e2 = Eq( diff(y,t,1) , x   )
dsolve( [e1,e2], [x,y])
# Out:
# [Eq(x(t), -C1*cos(t) - C2*sin(t)), Eq(y(t), -C1*sin(t) + C2*cos(t))]

# %%
#elastic collisions
p1 + p2 = p3 + p4
p**2 + p**2 = p**2 + p**2

#completely inelastic

p1 + p2 = p3 + p4
p3/m = p4 / m


# often kinetic energy is decreasing. Except in bomb case. This is polynomial inequality constraint

# %%
r**2 = x**2 + y**2

# %%
class AffCat():
    def __init__(self,A,b):
        self.A = A
        self.b = b
    def compose(f,g):
        A = f.A @ g.A
        b = f.b + f.A @ g.b
        return AddCat(A,b)
    def idd(n):
        return AffCat(np.eye(n), np.zeros(n))
    def product(n,m):
        # same diff with zero offset vectors
        
    def pullback(f,g):
        stacked = np.hstack([f.A,-g.A]) 
        null = scipy.linalg.null_space( stacked )
        offset = g.b - f.b
        b = numpy.linalg.lstsq(offset,stacked)
        if np.allclose(  null@b , offset ): #equation solvable
            p1 = FinVect(null[:f.dom, :], b[:f.dom] )
            p2 = FinVect(null[f.dom:, :], b[f.dom:] )
            return p1, p2
        else:
            
@dataclass
class QuadForm():
    # represents the quadratic objective : xQx + xq + c
    Q : ndarray
    q : vector
    c : float
    def __plus__(self,a):
        return QuadForm(self.Q + a.Q, self.q + a.q , self.c + a.c )
    def fmap(self,f):
        # f is an AffCat
        # x = Ay + b
        # xQx + qx + c = ( Ay+b  )Q(Ay+b) + q(Ay+b) + c = yAQAy + bQAy + yAQb + qA + c + bq
        return QuadForm( f.A.T @ self.Q @ f.A,   
                        2 * f.A.T @ self.Q @ f.b   +  f.A.T @ self.q       ,
                        self.c + self.q @ self.b )
        


        
class Gaussian():
    def __init_(quad, l, r):
        assert(type(quad) == QuadForm)
        assert(type(l) == AffCat)
        assert(type(r) == AffCat)
        self.quad = quad
        self.l = l
        self.r = r
        
    def compose(f,g):
        = AffCat.pullback( f.r, g.l )

# %%
import numpy as np
x = np.ones(3)
x @ x
# Out:
# 3.0
