# %% [markdown]
# SAT solving with david sanders. SatisfiabilityInterface.jl ?
# Julia Constraint satisfaction
# Julog
#
#
# parametric inverse with solar lezama - very lensih feeling
# Remember I had an idea for a pseudo inverse as a lens.
# x -> (y, y -> x) where knowing x can let you pick a branch. But maybe this parametrized notion is better.
#
# (x -> y, y,phi -> x)
# They have a unified abstraction?
#
# https://en.wikipedia.org/wiki/Kinetic_data_structure
#
# vitek
# Coq proof of julia subtyping
#
#
# Learning to prover theorem by learnign to generate theorems
#
# https://arxiv.org/abs/2002.07019
# jonathan laurent
# Neural theorem proving
# He made a custom proof assistant
#
# Transformers / Graph neural networks
#
# first order theorem proving:
# https://www.research.ibm.com/publications/a-deep-reinforcement-learning-approach-to-first-order-logic-theorem-proving
#
# Well, duuuuh that there is a lot of work in this space
# https://arxiv.org/pdf/1809.02840.pdf neural kanren
# Also, look at "Learning theorem proving from self-play" from AITP 2020
#
# William Kimmerer intends to make julia translations of Kissat. That would be impressive
#
#
#
# Talks to check out
#
# AlgerbaPDF
# ZXXcalculus
# AlphaZero / muzero?
# JuliaSpice
# Probabilistic Model Checking using POMDPModelChecking.jl
# ebpfnative
#
#
# Hmm. They're talking hardware and they are a matlab competitor. I could be a natural canditate to work on the equivalent of matlab's formal mehtod thingy.
#
#
# https://arxiv.org/abs/2002.03447 mathoptinterface paper
#
#
# constraint rpgramming is popping off
#
# paul tarau talk which I mentioned again
# https://github.com/ptarau/LogicTransformers
# http://www.cse.unt.edu/~tarau/research/2021/
# https://arxiv.org/abs/1907.11354
# https://youtu.be/ja_OFA2ahSc?t=1745
# https://pdfs.semanticscholar.org/2ea5/0651e2c44f68bcdb77da1d02e88810757d2a.pdf
