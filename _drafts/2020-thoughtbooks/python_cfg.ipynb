# %%
import sys
# !{sys.executable} -m pip install pycfg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Created wheel for pycfg: filename=pycfg-0.1-py3-none-any.whl size=8381 sha256=38419656e53ad2f7e137d3c8200dabe8a43f1baf00ba902ad1e51e908130d155
#   Stored in directory: /home/philip/.cache/pip/wheels/1a/75/27/13c3bee05ad189f1fc439e3d908e30ec0cdacf5aa1b7b3da07
# Successfully built pycfg
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# What about angr?
# llvm
