# %% [markdown]
# # Relativity
#
#
#
# I think one gets real hung up on the math, and there is a give and take conversation there, but it isn't the starting essense. I think the essence of physics for a subject in a handful of problems that can be solved roughly with some algebra.

# %% [markdown]
# # SR
#
# What makes the speed of light different from the speed of sound?
#
# A key point is proper time
#
#
# ## The Principle of ray tracing
#
# When things get confusing, sometimes we need to model more carefully exactly what we're doing rather than take the ordinary shortcuts
#
# Inverse problems
#
#
# Angular diameter as it appears in a lens
#
# clock distance
#
#
#
# ###
# ### What do coordinates mean?
#
# Even more mundane physics can be done in strange coordinate systems with difficult mathemtical expressions.
#
# Perhaps one one point that because GR is about curving space-time,
#
# ## proper Time
#
# Light clocks
#
#
# ## Twins
#
# ## Length constraction
#
# ## Time dilation
#
# ## E = m c^2
#
# Yeah, what the hell is up with this one
#
#
# ## Doppler Shifts
#
#
# ## Electric and Magnetic turn into each other.
#
#
#
# # GR
#
#
# ### The equivalence Princple
# A room in free fall does not know it is in free fall or travelling freely through space. Evidently it can be reasoanble .
# Astronauts in the space station float around in exatlty the same way as astronauts going towards mars.
#
#
# From this persepctive, we who stand on the ground, are the weirdos. It is a conceptual shift that feels similar to the newtonian idea that force = acceleration. This ignores the most motion on earth has a lot of friction at play and decides that this is not a fundamental aspect of motion.
#
#
#
# # Gravitational redishit
#
# Consider
#
#
# # gravitational lensing
#
# I vaguely thought that the classical bending was off by a factor of two or something?
#
# # Expanding universe
#
#
#
# # gravitational waves
#
#
# # Black Holes
