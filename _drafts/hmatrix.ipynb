# %% [markdown]
# https://www.youtube.com/watch?v=P2JQiOKgrY0&pp=ygURR3VubmFyIE1hcnRpbnNzb24%3D Gunnar Matrinsson
#
# https://math.dartmouth.edu/~fastdirect/mat.php
# Interpolative decomposition
#
# Randomized approximation of SVD by like sampling columns
#
# https://declanoller.github.io/eigenoptions
# onder if the eigenvalue apporximation method has something to do with
#  https://scikit-learn.org/stable/modules/generated/sklearn.utils.extmath.randomized_svd.html
#  https://gregorygundersen.com/blog/2019/01/17/randomized-svd/
#   https://arxiv.org/abs/2002.01387
#
# I thought i remember there being some other library
#
#
#
# Fast multipole method
#
# H matrix
# hmatrix
# hierarchical matrix
#
# BEM
#
# emerge
# AWS palace
#
#
# https://computationalthinking.mit.edu/Fall24/  julia course
# https://www.youtube.com/watch?v=rRCGNvMdLEY&t=1757s
#
# PetSc https://petsc.org/release/
#
#
# pomdps
# dynamic programming toy. gridworld
# reinforcement learning
#
# Real valued vector spaces and maps
#
# multigrid
#
# strang book
# Back to basics baby
#
#
# https://numerical.recipes/
# ten digit algorithms https://people.maths.ox.ac.uk/trefethen/tda05.pdf
