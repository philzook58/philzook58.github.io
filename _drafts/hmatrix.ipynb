# %% [markdown]
# Fast multipole method
# H matrix
#
# BEM
#
# emerge
# AWS palace
#
#
# https://computationalthinking.mit.edu/Fall24/  julia course
# https://www.youtube.com/watch?v=rRCGNvMdLEY&t=1757s
#
#
# pomdps
# dynamic programming toy. gridworld
# reinforcement learning
#
# Real valued vector spaces and maps
#
# multigrid
#
# strang book
# Back to basics baby
