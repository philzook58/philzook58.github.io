# %% [markdown]
# https://github.com/rise-lang/shine/blob/main/src/main/scala/rise/core/primitives/primitives.rise
# https://rise-lang.org/doc/language-reference/rise-types
#
# https://www.youtube.com/watch?v=ixuPI6PCTTU
# https://theses.gla.ac.uk/83323/ koehler thesis
#
# Mimir https://dl.acm.org/doi/10.1145/3704840
# https://anydsl.github.io/
#
# strategic rewriting
