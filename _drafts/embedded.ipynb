# %% [markdown]
# https://ece4760.github.io/
#
# ganslee designing embedded
#
#
# https://micropython.org/download/RPI_PICO2/ copy over uf2 into bootsel
# pico2W is distinct firmware from pico2
#
# There is a riscv version. Interesting.
#
#
# Hardware fifo and spinlocks between two cores
# PIO - coprocessors
# DMA is mad useful
#
# Flexible fabraic between internal hardware and output pins
#
# SIO - single cycle input output
#
#
# def registers -> structs -> helper functions -> high level functions
# It may not be obvious was high level functions are using which resources (That's kind of an interesting veriication problem? Although, the thing probably won't work if you have such a clash?)
#
# udev rules
# RP2350 device at bus 7, address 10 appears to be in BOOTSEL mode, but picotool was unable to connect. Maybe try 'sudo' or check your permissions.
# https://github.com/raspberrypi/picotool/blob/master/udev/60-picotool.rules add this and reload
#
# The 2350 W is consistently kind of a pain in the ass huh
#
# https://pip-assets.raspberrypi.com/categories/1214-rp2350/documents/RP-008373-DS-2-rp2350-datasheet.pdf datasheet

# %%
! sigrok-cli -d fx2lafw -c samplerate=20k -C D0 --time 5s -o /tmp/gp15.sr
! pulseview -i /tmp/gp15.sr
