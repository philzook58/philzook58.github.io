# %% [markdown]
# I need to install afp entries using `isabelle components -u`
#
# https://lawrencecpaulson.github.io/2022/05/11/jEdit-tricks.html
# Ctrl+click gets docs
# ctrl+hover
#
#
# autocorres -
# SIMPL-C makes a verbose translation of C
# Deep embedding for commands, shallow for expressions.
#
# autocorres thesis is good
# https://trustworthy.systems/projects/OLD/autocorres/
# https://trustworthy.systems/publications/nicta_full_text/8758.pdf
#
# Ptr and heap. It is byte addressable with with type overlay?
#
# autocorres tries to functionalize it to a higher level model automatically
