# %%
! nix repl --expr "{a = 1 + 1;}"
# Out:
# Nix 2.32.2
# Type :? for help.
# Loading installable ''...
# Added 1 variables.
# a
# nix-repl>
#
# nix-repl>
#
# nix-repl>

# %%
# %%file /tmp/text.nix
# {
#     a = 1 + 1;
#     b = rec {
#     one = 1;
#     two = one + one;
# };
# }
# Out:
# Overwriting /tmp/text.nix

# %%
! nix-instantiate --eval --strict /tmp/text.nix
# Out:
# { a = 2; b = { one = 1; two = 2; }; }

# %% [markdown]
# nix langfuage is kind of interesting. https://nix.dev/tutorials/nix-language.html
#
# attribute sets. a built in json of sorts. But also kind of a dict basically right?
# {}

# %%
# Out:
# 2
