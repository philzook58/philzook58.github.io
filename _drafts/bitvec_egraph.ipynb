# %% [markdown]
# Bitectors as structured eids.
# We can on demand perform unification of them.
#
# Sadly the most caonnical one is probably the most broken up one
#
# Can this handle symbolic lengths? Maybe.

# %%
type Id = tuple[int, ...]

class BitVecUF: # TupleUF
    parents : list[Id]
    width : list[int]
    def makeset(self, width : int):
        id = len(self.parents)
        self.parents.append(id)
        self.width.append(width)
        return (id,)

    def find(self, x : Id):
        todo = list(xid) # work from the right
        res = []
        while todo:
            id = todo.pop()
            p = self.parents(id) 
            if p == id:
                res.append(id)
            else:
                todo.extend(p)
        return tuple(res)

    def union(self, x : Id, y : Id):
        x,y = self.find(x), self.find(y)
        # zip them together, making new ids as need be.
        if x != y:       
            i,j = 0,0
            xs = list(xs)
            ys = list(ys)
            while 

def concat(a, b):
    return a + b
