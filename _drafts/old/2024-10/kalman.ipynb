# %% [markdown]
# https://github.com/artivis/kalmanif lie group kalman
#
# https://github.com/jebohndavida/KalmanFilter klamb filter inC for ARM, quaternion
# https://github.com/sandialabs/elaenia
# https://github.com/ak-2485/Kalman_Filter ariel - coq

# %% [markdown]
# running sum filter
# Where did I learn klaman filtering from? Russ Tedrake?
# Maybe Stephen Boyd too?
# LQR more than kalman
# Klamn using python mouse reading
# Guassian Sympy
#
#
# Grewal and Andrew's *Kalman Filtering*
# Zarchan - Fundamentals of kalman filtering
#
#
#
# g-h filters / alpha-beta
# sensor fusion

# %%
import sympy as sp
from sympy.stats import MultivariateNormal, density, marginal_distribution
from sympy import symbols, MatrixSymbol
# https://docs.sympy.org/latest/modules/stats.html#sympy.stats.MultivariateNormal

n = symbols('n', integer=True, positive=True)
Sg = MatrixSymbol('Sg', n, n)
mu = MatrixSymbol('mu', n, 1)
obs = MatrixSymbol('obs', n, 1)
X = MultivariateNormal('X', mu, Sg)
sp.stats.Expectation(X).doit() ##.rewrite(sp.stats.Probability) #.rewrite(sp.Integral)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       9 obs = MatrixSymbol('obs', n, 1)
#      10 X = MultivariateNormal('X', mu, Sg)
# ---> 11 sp.stats.Expectation(X).doit()#.rewrite(sp.stats.Probability) #.rewrite(sp.Integral)
#
# File ~/.local/lib/python3.10/site-packages/sympy/stats/symbolic_probability.py:288, in Expectation.doit(self, **hints)
#     286     return self.func(expr)
#     287 # Otherwise case is simple, pass work off to the ProbabilitySpace
# --> 288 result = pspace(expr).compute_expectation(expr, evaluate=evaluate)
#     289 if hasattr(result, 'doit') and evaluate:
#     290     return result.doit(**hints)
#
# File ~/.local/lib/python3.10/site-packages/sympy/stats/joint_rv.py:112, in JointPSpace.compute_expectation(self, expr, rvs, evaluate, **kwargs)
#     111 def compute_expectation(self, expr, rvs=None, evaluate=False, **kwargs):
# --> 112     syms = tuple(self.value[i] for i in range(self.component_count))
#     113     rvs = rvs or syms
#     114     if not any(i in rvs for i in syms):
#
# File ~/.local/lib/python3.10/site-packages/sympy/stats/joint_rv.py:67, in JointPSpace.component_count(self)
#      65 @property
#      66 def component_count(self):
# ---> 67     _set = self.distribution.set
#      68     if isinstance(_set, ProductSet):
#      69         return S(len(_set.args))
#
# File ~/.local/lib/python3.10/site-packages/sympy/stats/joint_rv_types.py:160, in MultivariateNormalDistribution.set(self)
#     157 @property
#     158 def set(self):
#     159     k = self.mu.shape[0]
# --> 160     return S.Reals**k
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File ~/.local/lib/python3.10/site-packages/sympy/sets/sets.py:801, in Set.__pow__(self, exp)
#     798 @sympify_return([('exp', Expr)], NotImplemented)
#     799 def __pow__(self, exp):
#     800     if not (exp.is_Integer and exp >= 0):
# --> 801         raise ValueError("%s: Exponent must be a positive Integer" % exp)
#     802     return ProductSet(*[self]*exp)
#
# ValueError: n: Exponent must be a positive Integer
