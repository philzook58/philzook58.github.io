# %% [markdown]
# rosoclingo https://arxiv.org/abs/1307.7398 ROSoClingo: A ROS package for ASP-based robot control

# %% [markdown]
# https://ceur-ws.org/Vol-2970/gdepaper2.pdf Modeling and Verification of Timed Systems with the
# Event Calculus and s(CASP)
# fluents. model checking via query.
#
# Meson is also a stack inspecting thing. What is the relation of CoLP, scasp and meson?

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S0888613X24001725 An implementation of nonmonotonic reasoning with c-representations using an SMT solver
#
# Something like a kripke semantics.
# Maybe also something like a probability dsitrbution.
# ranking functions to say relatively speaking how likely each world is.
# nonmonotonic implication

# %% [markdown]
# WHat is answer set programming?
#
# Non monontonic reasoing
# https://dusa.rocks/ https://github.com/robsimmons/dusa
# https://arxiv.org/pdf/2405.19040
# https://www.rntz.net/files/fclp-popl24-draft.pdf finitew choice logic programming
#
# https://en.wikipedia.org/wiki/Stable_model_semantics
#
# Logic of here and there
# defaulty logic
# equiblirum lopgic
#
# https://github.com/alpha-asp/Alpha
#
# "easy" answer set programming https://www.youtube.com/watch?v=iL7SCofdEck&list=PL7DBaibuDD9O4I05DiQfilqPUgpClMKYu&index=1&ab_channel=Potassco https://arxiv.org/pdf/2111.06366
#
# ```
# a.
# % b.
# c :- a, not b
# ```
# Facts can go away upon increasing other facts. Even datalog under negtation.
#
# Will byrd said proving queires must fail is the hard part
#
# Coutnerfactuals
#
# https://arxiv.org/abs/2311.04412 Human Conditional Reasoning in Answer Set Programming
#
# https://www.youtube.com/watch?v=zDY3c3VnG68
# https://personal.utdallas.edu/~gupta/csr-scasp.pdf
#
# stablekanren is trying to not go the scasp approach?
#
# Datalog with foresight. Prescient datalog
#
# Could I do ASp in z3? Maybe a guess and then a datalog run? We only use the guess for the negation
#
# "first order asp" http://cs.engr.uky.edu/ai/papers.dir/VL65Final.pdf Connecting First-Order ASP and the Logic FO(ID)
# Through Reducts
# https://dl.acm.org/doi/10.1145/3412841.3441963 first order asp as CHR
# https://dl.acm.org/doi/10.1016/j.eswa.2023.121810 CHR++ https://vynce.gitlab.io/chrpp/
# https://gitlab.com/vynce/chr-graph-transformation
# https://gitlab.com/vynce/chrpp
#
# What is the deal with scasp.
# There was that minikanren variant at popl
#
# ```prolog
#
# ```
#
# https://swish.swi-prolog.org/example/scasp.swinb
#
# https://github.com/SWI-Prolog/sCASP
#
# `pack_install(scasp).`
#
# http://minikanren.org/workshop/2019/minikanren19-final4.pdf constructive negation for minikanren
# http://minikanren.org/workshop/2023/minikanren23-final3.pdf stable semantics minikanren
#
#
#
# https://www.dc.fi.udc.es/~cabalar/fal/ Functional Action Language (FAL)
# functional answer set programming https://arxiv.org/pdf/1006.3678 . mention's scott LPF / E logic
# Cabalar, P. and Lorenzo, D. 2004. Logic programs with functions and default values
# Cabalar, P. 2008. Partial functions and equality in answer set programming. In Proc. of
# Cabalar, P. 2009. Existential quantifiers in the rule body.
# https://www.dc.fi.udc.es/ai/~cabalar/asp05_C.pdf functional action laguage frontend
# Lin, F. and Wang, Y. 2008. Answer set programming with functions
# Functional ASP with Intensional Sets: Application to Gelfond-Zhang Aggregates https://www.cambridge.org/core/journals/theory-and-practice-of-logic-programming/article/abs/functional-answer-set-programming/DECE49047CEA0AE143E79E614C979C51?utm_campaign=shareaholic&utm_medium=copy_link&utm_source=bookmark
#
# Omega-Restricted Logic Programs - https://link.springer.com/chapter/10.1007/3-540-45402-0_20. stratify as much as can. leave remnants
#
# ASP (): Answer Set Programming with Algebraic Constraints - semirings  + ASP https://arxiv.org/abs/2008.04008
#
#
# # Classical -> ASP -> Intuitionistic
# ASP is intermediate between classical and intuitionstic.
# Classical is SAT solvers.
# Intuitionstic is deductive search mostly. (Maybe embeddable into QBF)
#
# https://en.wikipedia.org/wiki/Intermediate_logic
# https://arxiv.org/abs/2306.07550 Nested Sequents for Intermediate Logics: The Case of Gödel-Dummett Logics
#
# https://arxiv.org/pdf/cs/0305046
#
# Vaguely, I feel that negation as failure is somehow truncating the intuitionsitc character into a classical character under a single negation
#
# we need to justify positive assertions and just allow negative assertions. This is an in between of classical and intuitionistic logic.
# 1-world, 2-world, inf-world
#
# 3 world? possibly possibly.
# p, -p, --p, ---p, neg ----p
# Somekind of positivty change depth of an intuitionsitc formula? See qbf/ilp?
#
# https://arxiv.org/pdf/1907.09559 asp is beyond NP somehow
#
# ASP dignifies facts inside a model, but doesn't justidy which model
#
# "Classical propositional logic can be formalized by adding the law of the excluded middle
# F ∨ ¬F to this deductive system as another axiom schema. The logic of here-and-there
# is the result of adding a weaker axiom schema, Hosoi axiom (5). Thus the logic of hereand-there is intermediate between intuitionistic and classical.1"
# https://arxiv.org/pdf/2108.03187
# So if sequent gives us classical, what restriction gives us ASP?
# Maybe some kind of depth bound on the time travelling argumentation. Or refutations can be classical but justifications have to be constructive
# sequent ~ continuations in nat deduct
# co(LP) is looking at the stack (conitnuation) to see we're repeating ourselves
# Scasp / sasp is using co(LP)
# https://stackoverflow.com/questions/1693011/how-can-i-determine-the-return-address-on-stack
#
# nonmonotonic mathematics. Adding arithmetic to ASP may count. Or adding clp(set) to asp?
# Graham mentioned Rosser sets. Peanos smart children. Is this negation as failure?
# https://projecteuclid.org/journals/notre-dame-journal-of-formal-logic/volume-30/issue-2/Peanos-smart-children--a-provability-logical-study-of-systems/10.1305/ndjfl/1093635077.full
# https://projecteuclid.org/journals/notre-dame-journal-of-formal-logic/volume-35/issue-2/A-smart-child-of-Peanos/10.1305/ndjfl/1094061859.full
#
# "dynamic stratification" using integer arguments
#
# https://dl.acm.org/doi/10.1145/581771.581774 On the complexity analysis of static analyses - mcallester https://web.cs.ucla.edu/~palsberg/course/purdue/cs661/F01/papers/mcallester-to-appear.pdf Congryuebnce closure + datalog eh?
# https://link.springer.com/chapter/10.1007/3-540-44881-0_31 A Logical Algorithm for ML Type Inference
#
#
# https://iltp.de/ARQNL-2024/download/proceedings_preli/2_ARQNL_2024_paper_8.pdf implementing intermediate ligics. haskell superj, otten. Add intermiedtae axiom shcema to intuitionstic prover?

# %%
import janus_swi as janus


janus.consult("scasp_example", """
:- use_module(library(scasp)).
opera(D) :- not home(D).
home(D):- not opera(D).
home(monday).

false :- baby(D), opera(D).

baby(tuesday).

""")

janus.query_once("scasp(opera(D), [])")
# Out:
# ERROR: scasp_example:2:
# ERROR:    source_sink `library(scasp)' does not exist
# ...
# ERROR: scasp_example:3:16: Syntax error: Operator expected
# ERROR: scasp_example:4:14: Syntax error: Operator expected
# ERROR: scasp_example:7:
# ERROR:    No permission to modify static procedure `false/0'
# ERROR:    Defined at /lib/swi-prolog/boot/init.pl:557
# ---------------------------------------------------------------------------
# PrologError                               Traceback (most recent call last)
# Cell In[2], line 16
#       1 import janus_swi as janus
#       4 janus.consult("scasp_example", """
#       5 :- use_module(library(scasp)).
#       6 opera(D) :- not home(D).
#    (...)
#      13
#      14 """)
# ---> 16 janus.query_once("scasp(opera(D), [])")
#
# File ~/.local/lib/python3.10/site-packages/janus_swi/janus.py:243, in query_once(query, inputs, keep, truth_vals)
#     225 """
#     226 Call a Prolog predicate as `query_once/1`
#     227
#    (...)
# ...

# %% [markdown]
# # ASP typecheck
#
#
# I really liked
# <https://arxiv.org/abs/1908.05839>  Bidirectional Typing by dunfield krishnaswami
#
# Demand transformation.
# Datalog with constructors or arithmetic can go off into the stratosphere. One way to control this is to create demand relations.
#
# For example, we can comute a fibonacci function
#
# ```souffle
# .decl fib(n : number, m : number)
# .decl needfib(n : number)
#
# needfib(n-1) :- needfib(n), n >= 1.
# needfib(n-2) :- needfib(n), n >= 2.
#
# fib(0,1).
# fib(1,1).
# fib(n,a + b) :- needfib(n), fib(n-1,a), fib(n-2 ,b).
#
# needfib(5).
# .output fib
# .output needfib
# ```
#
# ```clingo
# needfib(N - 1) :- needfib(N), N >= 1.
# needfib(N - 2) :- needfib(N), N >= 2.
#
# fib(0,1).
# fib(1,1).
# fib(N,A + B) :- needfib(N), fib(N-1,A), fib(N-2,B).
#
# ```
#
# ```souffle
# type
# .decl need-type()
#
#
# ```
#
# ```clingo
# need()
# need()
#
# checks()
# synth()
#
# ```
#
# See frank pfenning where he has different notions of arrow.
# slog
# egglog
# functional compiling
#
# Another related idea:
# Pick priorities for parser operators to mnimize parentheses
# Pick juxtaposition operator to minimize parentheses. How would I do this?
