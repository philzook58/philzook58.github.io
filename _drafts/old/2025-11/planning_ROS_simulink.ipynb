# %% [markdown]
# # UAV
# https://www.youtube.com/watch?v=UCxcyUD8iwk&ab_channel=JeremyMaurer  ntroduction to Mission Planning for UAVs
#
# ground control points
# https://github.com/ArduPilot/ardupilot Paparazzi is a free and open-source hardware and software project for unmanned (air) vehicles. This is the main software repository.
# https://github.com/paparazzi/paparazzi
# PX4
# NuttX
#
# # Robot
#
# ROS https://docs.ros.org/en/foxy/index.html
# https://classic.gazebosim.org/
#
# annoying installation. bodes well. Ok. Given a month it got better.
#
# https://github.com/kiloreux/awesome-robotics
# https://github.com/AtsushiSakai/PythonRobotics
#
#
# https://github.com/pantor/ruckig  Motion Generation for Robots and Machines. Real-time. Jerk-constrained. Time-optimal.
# https://github.com/TimSchneider42/franky
#
# https://github.com/ai-winter/ros_motion_planning
#
# https://github.com/stack-of-tasks/pinocchio
# https://github.com/ompl/ompl
# https://github.com/symforce-org/symforce Fast symbolic computation, code generation, and nonlinear optimization for robotics
# https://github.com/motion-planning/rrt-algorithms
# rrt tree. rapidly exploring rantom trees
# https://github.com/loco-3d/crocoddyl/tree/devel Crocoddyl is an optimal control library for robot control under contact sequence. Its solver is based on various efficient Differential Dynamic Programming (DDP)-like algorithms
# https://github.com/RobotLocomotion/drake
#
# https://github.com/bulletphysics/bullet3
# https://github.com/google-deepmind/mujoco
#
#
# https://github.com/coin-or/CppAD
# eigen
# FCL
#
# SLAM
# https://github.com/cartographer-project/cartographer
# https://github.com/MichaelGrupp/evo  Python package for the evaluation of odometry and SLAM
# https://github.com/borglab/gtsam GTSAM is a library of C++ classes that implement smoothing and mapping (SAM) in robotics and vision, using factor graphs and Bayes networks as the underlying computing paradigm rather than sparse matrices.
#
#
# URDF
# SDF
# SRDF
#
#
# https://github.com/rdeits/meshcat
#
#
# EARS

# %%
! ros2 run turtlesim turtlesim_node

# %% [markdown]
# # state charts
#
# Q: A Sound Verification Framework for Statecharts and Their Implementations
# https://dl.acm.org/doi/10.1145/3563822.3568014
#
# Looks like Q is closed source inside sandia
# https://www.osti.gov/servlets/purl/1642936 dishawahers of armaageddeno
#
# http://lambda-the-ultimate.org/node/2342
#
# https://news.ycombinator.com/item?id=35328995
#
#
# statecharts for lean?
#
# https://aleph2c.github.io/miros/html/index.html miros python statecharts
#
# https://news.ycombinator.com/item?id=25454175
# https://www.edx.org/learn/computer-programming/israelx-programming-for-everyone-an-introduction-to-visual-programming-languages#syllabus
#
# https://www.hillelwayne.com/formally-specifying-uis/
#
#
#
# https://stately.ai/docs
#
#
# https://github.com/derkork/godot-statecharts
#
#
# https://en.wikipedia.org/wiki/Stateflow  "Stateflow uses a variant of the finite-state machine notation established by David Harel, enabling the representation of hierarchy, parallelism and history within a state chart"
# Scade?
#
# I realized I had just seen david harels name on this dynamic logic textbook
#
# https://www.google.com/books/edition/Dynamic_Logic/ZRXNOzX15d8C?hl=en This book is actually kind of a banger

# %% [markdown]
# # archimedes
# https://pinetreelabs.github.io/archimedes/index.html https://news.ycombinator.com/item?id=45939938

# %% [markdown]
# # pictorus
#
# https://github.com/pictorus-Labs/pictorus-rs
#
# https://blog.pictor.us/why-model-based-development-needs-hand-code/
#
# dbc CAN database file. a chema for interpeting CAN data
#
# .reqif file
# https://en.wikipedia.org/wiki/Requirements_Interchange_Format
# https://github.com/mhatzl/mantra
#
# rust
#
# Difference between this and gnuradio and labview
#
# kind of like unity state control stuff maybe
#
#
# # Scilab
#
# https://gitlab.com/scilab/scilab xcos
# https://www.youtube.com/watch?v=8Y5PDY5Q_Cs&ab_channel=CircuitBread
#
#
# someone on reddit is reccomending altair something
# https://www.youtube.com/watch?v=DhFTOra3m-E&ab_channel=KodyPowell collimator - web platofmr using python? https://www.collimator.ai/
#
#
# https://github.com/Copilot-Language/copilot Now thats a name I haven't heard in a looooooooong time
# https://github.com/nasa/ogma  Ogma is a tool to facilitate the integration of safe runtime monitors into other systems

# %% [markdown]
# # Matlab
# https://www.mathworks.com/videos/search.html?s_tid=gn_ev_rw&q=&fq%5B%5D=video-external-category%3Arecwebinar&page=1 on demand webinars
#
# Maybe getting a inwodws VM up is the way to go
# virtualbox vs vmware vs kvm.
#
#
#
# ## simulink
#
# https://www.mathworks.com/help/simscape/index.html
#
# diy
#
# class based methodology? What is interface?
# Logic based methodology?
# Draw using graphviz?
#
#
#
# ```python
# class Block():
#     def __init__(self, params):
#         pass
#     def run(self):
# ```

# %% [markdown]
# # Requirements
# https://en.wikipedia.org/wiki/Requirements_engineering
#
# https://www.reddit.com/r/ReqsEngineering/
#
# https://alistairmavin.com/ears/ Easy Approach to Requirements Syntax (EARS)
#
# RMF https://en.wikipedia.org/wiki/Risk_Management_Framework
# ATO authority to operate
# https://eclipse.dev/rmf/ ReqIF

# %% [markdown]
# # sysml
# https://link.springer.com/chapter/10.1007/978-3-031-49179-5_1 PySysML2: Building Knowledge from Models with SysML v2 and Python
#
# https://gaphor.org/ https://github.com/gaphor/gaphor https://www.youtube.com/watch?v=PnWKsr2csXg https://www.youtube.com/watch?v=9BYgI1nJCBA
#
# https://se-lib.org/ seems like pyML was renamed to this https://github.com/se-lib/se-lib
#
# https://www.youtube.com/watch?v=zP9SiDuXC-I chatgpt. python code blocks in sysml? Cameo? https://www.youtube.com/@MBSEExecution
#
# https://www.youtube.com/watch?v=998UznK9ogY 4 pillars of sysml
#
# sudo apt install libgirepository-2.0-dev gcc libcairo2-dev pkg-config python3-dev gir1.2-gtk-4.0
# uv pip install gaphor

# %%
from gaphor.core.modeling import ElementFactory
element_factory = ElementFactory()

# %% [markdown]
# # Julia ModelingToolkit

# %% [markdown]
# # flight software
#
# Basilisk https://avslab.github.io/basilisk/
#
#
# https://www.youtube.com/@FlightSoftwareWorkshop
#
# https://www.youtube.com/watch?v=-_gUwzQahH4&ab_channel=FlightSoftwareWorkshop
# application tutorial
#
# cFS. Is cfs a ros analog kind of?
#
# cfsat https://github.com/OpenSatKit/cfsat reaplced with https://github.com/cfs-tools/cfs-basecamp
# eds electronic datasheet
# why is all this computer bullshit part of flight software?
# Smells like ROS
#
# asbtracts over rtems linux vxworks
#
# software bus
# CCSDS messages
#
#
# F' https://github.com/nasa/fprime

# %% [markdown]
# # modelica
#
#
# https://news.ycombinator.com/item?id=42431186
#
# https://fmpy.readthedocs.io/en/latest/
# https://fmi-standard.org/
#
# https://modelica.org/libraries/
#
# acausal modelling
# python control?
#
# https://mbe.modelica.university/ modelica by example
#
# Spice for multiphysics? If true, I like the osund of that
#
#
# https://openmodelica.org/
#
# https://github.com/OpenModelica/OMPython
#
# OMEdit OMShell OMNotebook OMPlot OMShell-terminal OMSimulator OMSimulatorPython3
#
# Do NOT run under vscode.  I get this error when I do
# ```
# QSocketNotifier: Can only be used with threads started with QThread
# OMEdit: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE
# ```
#
# https://openmodelica.org/doc/OpenModelicaUsersGuide/1.24/solving.html DASSL IDA CVODE from sundials
# homotopy method to find initial conditions. Huh
#
# https://github.com/ORNL-Modelica/Modelica-GNU_ScientificLibrary
# https://github.com/ORNL-Modelica/awesome-modelica
#
#
# ```python
# %%file /tmp/simple.mo
# model FirstOrder
#   Real x;
# equation
#   der(x) = 1-x;
# end FirstOrder;
#
# ```
#
#     Writing /tmp/simple.mo
#
#
#
# ```python
# omc.sendExpression("loadModel(\"/tmp/simple.mo\")")
# omc.sendExpression("instantiateModel(FirstOrder)")
# ```
#
#
#
#
#     ''
#
#
#
#
# ```python
# import OMPython
# ```
#
#
#
# ```python
# from OMPython import OMCSessionZMQ
# omc = OMCSessionZMQ()
# omc.sendExpression("getVersion()")
#
#
# ```
#
#
#
#
#     'OpenModelica 1.24.3'
#
#
#
#
# ```python
# omc.sendExpression("X := 12")
# omc.sendExpression("model A Integer t = 1.5; end A;")
# omc.sendExpression("simulate(A, stopTime=1.0)")
# ```
#
#
#
#
#     ('A',)
#
#
#
#
# ```python
# omc.sendExpression("cd()")
# omc.sendExpression("loadModel(Modelica)")
# omc.sendExpression("loadFile(getInstallationDirectoryPath() + \"/share/doc/omc/testmodels/BouncingBall.mo\")")
# omc.sendExpression("instantiateModel(BouncingBall)")
# ```
#
#
# ```python
# omc.sendExpression("getClassNames()")
# omc.sendExpression("isPartial(BouncingBall)")
# omc.sendExpression("isPackage(BouncingBall)")
# omc.sendExpression("isModel(BouncingBall)")
# omc.sendExpression("checkModel(BouncingBall)")
# omc.sendExpression("getClassRestriction(BouncingBall)")
# omc.sendExpression("getClassInformation(BouncingBall)")
# omc.sendExpression("getConnectionCount(BouncingBall)")
# omc.sendExpression("getInheritanceCount(BouncingBall)")
# omc.sendExpression("getComponentModifierValue(BouncingBall,e)")
# omc.sendExpression("checkSettings()")
# ```
