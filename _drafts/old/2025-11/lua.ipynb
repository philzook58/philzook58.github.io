# %%
# %%script bash -c "cat > /tmp/test.lua && luajit /tmp/test.lua"
#
# print("hello world")
# t = {1,2,3}
# print(#t) -- prints 3
# print(type(type(t)))
# print(os.clock())
#
# function f(x)
#     return x + 1
# end
#
# print(f(10)) -- prints 11
# Out:
# hello world
# 3
# string
# 0.00265
# 11

# %% [markdown]
# http://lua-users.org/files/wiki_insecure/users/thomasl/luarefv51single.pdf
#
#
#
# https://github.com/luau-lang/luau gradually typed lua
# https://luau.org/getting-started

# %%
# %%file /tmp/test.lua
# function ispositive(x)
#     return x > 0
# end
#
# print(ispositive(1))
# print(ispositive("2"))
#
# function isfoo(a)
#     return a == "foo"
# end
#
# print(isfoo("bar"))
# print(isfoo(1))
# Out:
# Writing /tmp/test.lua

# %%
! luau-analyze /tmp/test.lua
