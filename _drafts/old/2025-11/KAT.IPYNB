# %% [markdown]
# https://perso.ens-lyon.fr/damien.pous/
#
# http://perso.ens-lyon.fr/damien.pous/ra/ kat in coq
#
# https://perso.ens-lyon.fr/damien.pous/symbolickat/
# Damien Pous. 2015. Symbolic Algorithms for Language Equivalence and Kleene Algebra with Tests. SIGPLAN Not.
# (2015). https://doi.org/10.1145/2775051.2677007
#
# https://perso.ens-lyon.fr/damien.pous/hknt/ bonchi pous
#
# https://dl.acm.org/doi/abs/10.1145/3571245?__cf_chl_tk=7xrzabxcY6h9CTY6.XdUaRfTKTrgnFXaCX5IJcyQHSM-1769717945-1.0.1.1-unVwhN1G8U5Hu1FMuR434T.YaHOyRd50Rl69fYFRz50 jules jacobs fast algebraic
# https://julesjacobs.com/pdf/katch.pdf
#
#
#
# hashing automata.
# Graham made the point that we don't need an observation ordering to first sort the states. We can directly hash the observation tree stream as we expand it and only expand it until we get distinct hashes for each state.
# Then we can combine those. Either by sorting the hashes and hashing that or combining with xor or something
#
#
#
#
#
#
# Implement Kleene algerba mod tests
#
# An Egraph modulo theories with KAT is maybe KLAT modulo theories?
#
#
# KAT equivalence checking?
#
# Hashing automata (minimize sure, but then what? Sort the s -> f s dict based on obersvations?)
#
#
# https://alexandrasilva.org/files/talks/kat-tutorial.pdf Programming and Reasoning
# with Kleene Algebra with Tests
# Part 1: Fundamentals
# Can we devise more efficient procedures?
# YES, e.g. antichains [Doyen et al, 2010] or up-to
# bisimulation [Bonchi-Pous, 2015]
# Σ - action symbols T - set of tests
# B - Free Boolean algebra generated by T
# At = atoms of B = {α,β,...}
#
# t: S x (At x Σ) —>S
# o: S —> B
#
# S -> ((At,Sig) -> S , B)
# guarded actions
#
# {b}p{c} <=> b p cbar ~ 0
# Compiler Optimizations [Kozen & Patron 00]
