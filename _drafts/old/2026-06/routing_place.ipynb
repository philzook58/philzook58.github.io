# %% [markdown]
# Routing and placement
#
# vpr vtr
#
# A whole other toolchain?
# Manuals contain routing tables
#
# switchboxes
#
# horiztonal bars, verticals. Grid
#
# CLB
#
# qflow
# tim Edwards https://opencircuitdesign.com/~tim/
# magic
#
# skywater
#
# rules about drawing. concentric circles matchin.
