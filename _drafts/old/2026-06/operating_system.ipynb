# %% [markdown]
# operating systems
# OS
# rtos
#
# plan 9
# inferno
# 9front is a maintained version. But the website is down. You need an image to boostrap yourself https://github.com/9front/9front
#
#
#
# https://principia-softwarica.org/
# ocaml version also?
#
# Lions commentary
#
# Oberon
#
# https://pdos.csail.mit.edu/6.828/2025/xv6.html xv6
#
# https://9p.io/wiki/plan9/Books/index.html Pricnples of Operating Systems Brian Stuart
#
#
#
#
# Toy OS model in python or anything?
#
# Allocation as being handed data
# virtual memory
# virtualized access
#
#
# https://github.com/jgrivera67/HiRTOS  About
# HiRTOS: a high-integrity multi-core RTOS kernel and separation kernel written in SPARK Ada
# atmosphere
#
# rtos
#
# https://github.com/weston-embedded/uC-OS2 microC os ii book
#
# What if I booted an os on ghidra
#
#
# https://github.com/antmicro/pyrenode3
# renode is like a whole other emulator ecosystem. That is crazy. How did this happen
#
# gem5

# %%
from dataclasses import dataclass,field
from collections import defaultdict

class Machine:
    ctx : pypcode.Context
    rom  :  dict[int,int] = field(default_factory=dict)
    pc : tuple[int,int] = (0,0)
    registers : defaultdict[int, int] = field(default_factory=lambda: defaultdict(int))
    ram : defaultdict[int, int]  = field(default_factory=lambda: defaultdict(int))
    unique : defaultdict[int, int]  = field(default_factory=lambda: defaultdict(int))
 

    def run_op(self, op : pypcode.PcodeOp):
        match op:
            case ADD
# Out:
#   Cell In[3], line 5
#     ram :
#           ^
# SyntaxError: invalid syntax

# %%
from collections import defaultdict
defaultdict(int)[
# Out:
# 0

# %%
import pypcode

# %%
d = bytearray(5)
type(d[0])
# Out:
# int

# %% [markdown]
# # plan 9

# %% [markdown]
# # xv6
#
# make qemu

# %% [markdown]
# # freebsd
#
# qemu-system-x86_64 -hda FreeBsd....qcow2 -nographic
#
# pkg install
# ee is simple editor
#
# -accel kvm
# -smp 2
# -m 2048
#
# -
#
# dmesg
# may want serial

# %% [markdown]
# # Free rtos
#
# zephyr
