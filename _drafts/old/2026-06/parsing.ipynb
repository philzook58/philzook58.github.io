# %% [markdown]
# https://github.com/SRI-CSL/parsley-lang
# https://github.com/secure-foundations/vest
#
#
# everparse https://project-everest.github.io/everparse/
#
# https://en.wikipedia.org/wiki/CBOR concise binary object representation
# https://en.wikipedia.org/wiki/Comparison_of_data-serialization_formats#Comparison_of_binary_formats
#
#
# https://github.com/AdaCore/RecordFlux for ada spark
#
# langsec
# https://arxiv.org/abs/1803.04870? narcissus. chilpala delaware rocq
#
#
# https://www.galois.com/project/daedalus
#
# Sam  https://github.com/slasser/vermillion
# https://github.com/slasser/CoStar
#
# https://github.com/dloss/binary-parsing awesome binary parsing
#
# Hmm. This might be interesting for metamath mmb.
#
# https://kaitai.io/
#
# construct seems cool
# https://matrixeditor.github.io/caterpillar/index.html caterpillar seems nice. dataclass like overloading
# https://scapy.net/
#
#
#
#
# little bites:
# metmath binary format?
# baby cbor?
#
# What otehr binary fomrtas
