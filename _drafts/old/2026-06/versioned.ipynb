# %% [markdown]
# versioned egraph
# https://programming-group.com/assets/pdf/papers/2026_Versioned-EGraphs.pdf
#
# This does seem pretty cool. How different is it from what I wrote.
#
# https://www.philipzucker.com/context_uf2/
