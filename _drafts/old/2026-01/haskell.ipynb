# %%
# %%file /tmp/test.hs
# #!/usr/bin/env cabal
# {- cabal:
# build-depends:
#   base >=4.19.0.0,
#   haskell-say ^>=1.0.0.0
# -}
#
# import HaskellSay (haskellSay)
#
# main :: IO ()
# main = haskellSay "Hello, Haskell!"
#
#
# -- https://cabal.readthedocs.io/en/stable/getting-started.html#running-a-single-file-haskell-script
# Out:
# Overwriting /tmp/test.hs

# %%
! cabal run /tmp/test.hs
# Out:
#   ________________________________________________________
#  /                                                        \
# | Hello, Haskell!                                          |
#  \____       _____________________________________________/
#       \    /
#        \  /
#         \/
#   _____   _____
#   \    \  \    \
#    \    \  \    \
#     \    \  \    \
#      \    \  \    \  \-----------|
#       \    \  \    \  \          |
#        \    \  \    \  \---------|
#        /    /  /     \
#       /    /  /       \  \-------|
#      /    /  /    ^    \  \      |
#     /    /  /    / \    \  \ ----|
#    /    /  /    /   \    \
#   /____/  /____/     \____\

# %% [markdown]
# https://hackage.haskell.org/package/twee-lib

# %%
# %%file /tmp/test.hs
# #!/usr/bin/env cabal
# {- cabal:
# build-depends:
#   base >=4.19.0.0,
#   twee-lib
# -}
#
# import Twee (initialState, State, defaultConfig)
# import Twee.Base (Function)
# mystate :: Function f => State f
# mystate = initialState defaultConfig
#
# main :: IO ()
# main = putStrLn "Hello, Haskell!"
# Out:
# Overwriting /tmp/test.hs

# %%
! cabal run /tmp/test.hs
# Out:
# Hello, Haskell!
