# %% [markdown]
# https://github.com/kilianFatras/awesome-optimal-transport
# optimal transport
#
# https://pythonot.github.io/ python optimal transport
# information geometry
#
# Can formulate as an LP
#
# https://codecrafters.io/blog/programming-project-ideas suggest you can use it for image warping / deep fake like stuff?
