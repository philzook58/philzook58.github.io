# %% [markdown]
# SQL categorical database
#
#
#
#
# What is a schema?
#
# A list of tables
# columns for tables and their data types
#
# Yes. Sure.
#
# But also there can be consistency constraints https://www.w3schools.com/sql/sql_constraints.asp
# https://www.sqlite.org/lang_createtable.html
# https://duckdb.org/docs/sql/constraints.html
# https://www.postgresql.org/docs/current/ddl-constraints.html
#
# - Unique keys
# - Primary keys
# - NOT NULL
# - Foreign Key
# - Check
#
#
#
# Functional dependency https://en.wikipedia.org/wiki/Functional_dependency
#
# https://en.wikipedia.org/wiki/Chase_(algorithm)  cody points out chase ~ knuth bendix
# https://www.cs.rice.edu/~vardi/papers/ttcs87.pdf vardi theory of depenencies
#
#
#
# A diagram is a kind of schema
# https://bartoszmilewski.com/2015/04/15/limits-and-colimits/
#
#
#
#
# A directed graph schema. https://algebraicjulia.github.io/Catlab.jl/dev/generated/graphs/graphs/
# E -a> V
# E -b> V
#
# labelled vertex graphs add
# V -> L
#
# https://blog.algebraicjulia.org/post/2021/04/cset-graphs-3/
# reflexive graphs
# V -> E
#
# invoutive
# E -inv> E
# inv.inv = id
#
#
#
#
#
# How to give this data

# %%
ob = {"V", "E"}
arr = {"a", "b"}
dom = {"a" : "V", "b" : "V"}
cod = {"a" : "E", "b" : "E"}
comp = {} # multiplication table
# preswented a multiplication table or generators + relations.
# very similar to computational group theory
# categories are a partial monoid
eq = NamedTuple("eq", [("lhs", list[Any]), ("rhs", list[Any])])
"""
eqs = [
    eq(["a", "a", "c"], ["a"]),
    eq(["a", "b"], ["b"]),
]
"""
arr = namedtuple("arr", ["name", "dom", "cod"])
arr

schema = namedtuple("schema", ["obs", "arrs"])

def db_of_schema(conn, obs, arrs):
    for ob in obs:
        "CREATE TABLE {ob}"
    for arr in arrs:
        "CREATE TABLE {arr} (id INT PRIMARY FOREIGN KEY, cod PRIMARYKEY)"
    return conn



def cset_of_db(conn, schema):

def chase(conn, obs, arr):

# %% [markdown]
# Catlab and CSets
#
# The chase
# https://blog.algebraicjulia.org/post/2022/06/chase/
# Kan extensions
#
# https://reyes-reyes.com/wp-content/uploads/2004/06/generic-figures.pdf
#
#
#
# simplicial sets
#
# A topological space as a database.
#
# https://www.youtube.com/watch?v=Ra-PLnog_M0&t=2482s&ab_channel=ToposInstitute Evan Patterson: "Categories of diagrams in data migration and computational physics"
# https://www.youtube.com/watch?v=IZcrASzCybs&ab_channel=SchmidCollege%2CChapmanUniversity Evan Patterson (Topos Inst.): Toward Formalizing Scientific Theories/Models Using Categorical Logic
#
# Ported graphs
#
#
# Adjunctions as data migration. Default added structure and forgetting that structure are adjoint
