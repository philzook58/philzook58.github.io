# %%
from sympy import *
vx = Function("vx")
vy = Function("vy")

v = Function("v") # complex?
phi = Function("phi") # fluid potential
z = symbols("z")
Eq(v(z), phi(z).diff(z))
zbar = z.conjugate()
x,y = symbols("x y", real=True)
solve(Eq(z, x + I*y), zbar,z,x,y)

r = sqrt(z * zbar)
-ln(z)
def cartese(t):
    return t.subs({z : x + I*y, zbar : x - I*y})

# %% [markdown]
# Redo will in pyiodide. static webpage
# pytorch
# old notes on fluids 2014
#
#
# Lorena Barba
#
# simulating fluids book - bridson
#
# Fluids are neat.
#
# eulerian vs lagrangian
#
# aerodynamics book
#
# vorticity $\omega = \nabla \times v$ the curl of velocity. https://en.wikipedia.org/wiki/Vorticity
#
# streamlines
#
# conservation law
# $\int j \cdot n dA = \int \rho v \cdot n dA =  \frac{dm}{dt}$
#
# Take small box.
#
# Solved examples.
# $ \Omega \times r = v$ velocity field of a rigid rotation. vorticity is rotation rate.
# $ v = a $ velocity field of rigid translation
#
# Outflow of pipe.
# basic point vortex. vorticity = 0 except at origin. Gets net circulation
#
#
#  $\nabla \cdot v = 0$ incompressible
#
# lift equations
#
# bernoulli
# hydrostatics
# The concept of v is bunk. Meanb velocity
#
# Renomralization book. nonlinear diagrammatics akin to feynman diagrams
#
# <https://www.youtube.com/watch?v=iKAVRgIrUOU&t=648&ab_channel=TenMinutePhysics> 17 - How to write an Eulerian fluid simulator with 200 lines of code.
# https://news.ycombinator.com/item?id=40429878  Fast real time fluid simulator based on MPM algorithm
#
# https://news.ycombinator.com/item?id=26610826 More fun with Lattice Boltzman Method (LBM) fluid simulations
# https://softologyblog.wordpress.com/2017/03/28/more-fun-with-lattice-boltzman-method-lbm-fluid-simulations/
#
#
# boundary layer
#
# demos from
#
# magnetohdyrodynamics
# plasma
# astronomy
#
#
#
# viscosity.
# shear
# navier stokes equation
# non equilbirum theormodynamics
#
#
# Reynolds number. https://en.wikipedia.org/wiki/Reynolds_number
# Life at high reynolds number
#
# karman vortex street

# %% [markdown]
# - <https://github.com/QuentinWach/Introduction-to-Fluid-Simulations>   Open-source 📚 book providing a hands-on introduction to 🌊 fluid simulations in Python.
#
# https://users.flatironinstitute.org/~parmitage/FluidsSchool.html  Flatiron fluid dynamics summer school
# Finite volume methods (Romain Teyssier)
# Finite volume MHD (Chris White)
# Introduction to discontinuous Galerkin methods (Andrew Giuliani)
# Spectral difference method (David Velasco-Romero)
# Finite volume methods for MHD on GPUs: AthenaK (Jim Stone)
# High-order finite difference methods (Wladimir Lyra)
# Spectral methods and Dedalus (Keaton Burns)
# Radiation hydrodynamics (Shane Davis)
#
# https://www.youtube.com/playlist?list=PLISXH-iEM4JmgBfU_QU262MQTYa7DoJK0  Simulations simply implemented in Python. playlist
#
# https://www.youtube.com/watch?v=JKQ0XdjLo7M&ab_channel=CyprienRusu  Everything you need to know about the Lattice Boltzmann Method (LBM) for CFD Simulation
#
# https://www.youtube.com/@JousefM
#
# [Dan Piponi's talk on youtube](https://www.youtube.com/watch?v=766obijdpuU)
#
# update fluids thing from will. I had that email request to make it work on colab
# https://www.philipzucker.com/annihilating-my-friend-will-with-a-python-fluid-simulation-like-the-cur-he-is/
#
#
# [https://github.com/PavelDoGreat/WebGL-Fluid-Simulation](https://github.com/PavelDoGreat/WebGL-Fluid-Simulation)
#
# https://developer.nvidia.com/gpugems/gpugems/part-vi-beyond-triangles/chapter-38-fast-fluid-dynamics-simulation-gpu
#
# [https://pdfs.semanticscholar.org/87ad/c1196efee7d65338966f051c61bb4985421f.pdf](https://pdfs.semanticscholar.org/87ad/c1196efee7d65338966f051c61bb4985421f.pdf) - Jos Stam stable fluid slides
# [http://taichi.graphics/links/](http://taichi.graphics/links/)
# [https://benedikt-bitterli.me/gpu-fluid.html](https://benedikt-bitterli.me/gpu-fluid.html)
#
# [https://github.com/austinEng/WebGL-PIC-FLIP-Fluid](https://github.com/austinEng/WebGL-PIC-FLIP-Fluid)
#
# [https://www.cs.ubc.ca/~rbridson/docs/zhu-siggraph05-sandfluid.pdf](https://www.cs.ubc.ca/~rbridson/docs/zhu-siggraph05-sandfluid.pdf)
#
# - <https://github.com/ProjectPhysX/FluidX3D>   "The fastest and most memory efficient lattice Boltzmann CFD software    running on all GPUs via OpenCL. Free for non-commercial use."
# - <https://github.com/WaterLily-jl/WaterLily.jl>   Fast and simple fluid simulator in Julia
# - - <https://github.com/GregTJ/stable-fluids>   A minimal Stable Fluids inspired fluid solver with Python and NumPy.
# - - <https://github.com/mharrys/fluids-2d>   Real-time fluid dynamics running on the GPU with the help of WebGL and Three.js
