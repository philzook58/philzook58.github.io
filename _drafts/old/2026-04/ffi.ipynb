# %% [markdown]
# LLMs are good at glue
#
# They can write parsers and printers fairly well
# They also can be good at generating bindings.
#
# These a mechanical ish tasks that are easy to write tests for. But also very laborious, boiler plate filled
#
# maturin is nice because so automated and it can be safe rust. I have a much higher degree of confidence than I would for the equivalent C bindings
#
# scryer
#
# (functor, [args])
# x ---> ("x", [])
# {"functor" : , "args" : } is so verbose. But the tuple is bit under verbose
# variables vs
# ("x", []) vs ("X", []) vs "X"
#
# I guess i would make dataclasses or wrapper classes from the python side, but this adds a whole other side to the bindings. Is that ok?
# Or do it from rust?
#
# steel scheme and scheme-rs
#
# pythonnet
# py4j https://www.py4j.org/
# leancall
#
# clojurepy https://github.com/clj-python/libpython-clj
#
# ocaml https://github.com/ocamllibs/ocaml-in-python . Yes. Maximum ocaml is < 5. That's not great
# Ok, this is still too far
#
#
# Eprover wrapped as a library?
# vampire?
#
# What else have i given up on?
#
#
# Z3 bindings in steel or in scryer
