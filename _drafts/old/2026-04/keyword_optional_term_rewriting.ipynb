# %% [markdown]
# ---
# title: Term Rewriting with Keyword Arguments
# ---
#
# What is algerbaic about algerbaic effects also has a generalizations in it. Parameters and generic arity
#
# Binary app and constants.
# Cody mentioned once that yes you can embed the term encodings, but you can't embed the notion of pattern matching /rewriting /equality cleanly. There is a gap there. How does one think about that?
#
# Ketword arguments with subrecords vs on the nose is a big difference. Record update syntax is more interesting in one.
#
# Keyword arguments and optional arguments are "sugar" maybe. But easy to integrate into term rewriting framework. That is also why they are not too complicated sugar in ocaml / python / others.
#
# K frame problem solution is that you have a record of the state and only rewrite over a piece.
# "keyed" AC
#
# Prolog maps with ground keys
#
# edcgs tag their effects
#
# Mutisets and sets require some more magumbo
# But a (ground) keyed map. The keys are initial. They shouldn't have an equational theory associated with them
# :a = :a only.
#
#
#
# do notation is just notation for bind and return, what's the big deal?
# 15 repliesPhilip Zucker  [11:57 AM]
# This is actually an interesting analogy, because dcgs are one sugar prolog can supply for dealing purely with stateful computation
# And you do kind of enter into a different universe / color of function to invoke them like one does for monads (edited)
# I do not think monads or do notation is a simple topic. (edited)
# Stateful computations are a stream of states. It's in the chapter
# There is also edcgs (extended). Which I think maybe were something like monad stacks or effect systems or something? https://webperso.info.ucl.ac.be/~pvr/edcg.html
# https://www.swi-prolog.org/pack/list?p=edcg
# hmm. Kind of reminds me of the funkiness in K
# "cells" https://kframework.org/k-distribution/k-tutorial/1_basic/13_rewrite_rules/
# kframework.orgLesson 1.13: Basics of K Rewriting | Runtime Verification IncDesign and implement your programming language and software analysis tools with mathematical rigor.[12:05 PM]There's something to that keyword arguments is actually a nice logical feature
# Keywords are concrete and never ambiguous
# record subtyping
# having a prolog term like [a-X, b-Y] considered as a map is not a problem
# [A-X,B-Y] is kind of a problem
# To use as a map
# I don't have good words to describe this phenomenon
# Reply…
#
#
# varoiable arity
# encoding tuple terms and single arity app
# lazy vs constructor tyuples
# fst(p) = a
# snd(p) = b
#
# vs
# (a,b)
#
#
# One can encode keyword args as key1(arg1, key2(arg2, nil)) or cons(key1-arg1, )  but key is always ground and not allowed to be a varialbe
#
# type KeyTerm =
#     | App of (string , KeyTerm) list == dict[string, keyterm]
#     | Var string
#
#
# type SingTerm =
#     | App

# %%
class App
    f : str
    arg : Term

type Term = tuple[App,...]
# type Term = Callable[[int], App]
