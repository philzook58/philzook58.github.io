# %% [markdown]
# Green's relations. (No relation :) ) https://en.wikipedia.org/wiki/Green%27s_relations
# Howie book
# lawson - inverse semigroups
# https://archive.org/details/fundamentalsofse0000howi fundamental of semigroup theory
# A. H. Clifford and G. B. Preston algerbaic theory of semigroups
#
#
# Lie semigroups https://www.heldermann-verlag.de/jlt/jlt02/LAWPL.PDF
#
# semigroups with involution https://en.wikipedia.org/wiki/Semigroup_with_involution
# monoids with involution
#
# Free semigroup with involution is string but dager reversed inner string.
#
# The pseudo inverse vs the tranpose
#
#
# Thinning is `<ctx| thin | t  >`  thinning on context is widening on term
#
# Dagger categories are  https://en.wikipedia.org/wiki/Dagger_category "aka category with involutions"
#
# Quantum
# Tensor monoidal categoires. Daggers?
#
#
# https://en.wikipedia.org/wiki/Heap_(mathematics) hmm
#
#
#
# snoc and cons generalizes to permutations of lists
#
# thinning + perm
#
#
# If I had
# ax + b = y
#
# but b was abstract, then at the 2-proof layer I could support 3 variables equations?
#
#
# Ok, rudi seems on board with inverse semigroup.
# I like his story about being able to go up and come back
