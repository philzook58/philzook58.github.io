# %% [markdown]
# Term Rewriting or All This
# TROAT
#
# maybe as an easier thing than arip
#
# Try to do term rewriting 101
#
# Make videos.
#
# Do it on discord on a regular schedule?
#
# Maybe people like videos.
# Could follow tutorial from summer schools. They didn't post them?

# %% [markdown]
# # Basics
# App
#
# pattern matching
# rules
#
# Examples:
# dnf
# nnf
# polynomial
#
# Ordered Rewriting
#
#
# Extended Basics
# Pos
# Context

# %% [markdown]
# # Ch2
# Properties and theorems about binary relations
#
# Binary relations as sets of tuples

# %% [markdown]
# # ch3
# A disaster.
# Undiscussable?
