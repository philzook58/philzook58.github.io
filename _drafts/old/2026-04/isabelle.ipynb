# %% [markdown]
# isabelle
#
# https://lawrencecpaulson.github.io/2024/12/20/Quickstart.html
# ok this is silly
# jedit is too good
# codex cli + jedit maybe way to go

# %%
! mkdir /tmp/isabelleplay

# %%
# %%file /tmp/isabelleplay/ROOT
# session Play = HOL +
#     theories
#        Fibnew
# Out:
# Writing /tmp/isabelleplay/ROOT

# %%
# %%file /tmp/isabelleplay/Fibnew.thy
# theory Fibnew
#     imports Main
# begin
#
# fun fib :: "nat => nat" where
#       "fib 0 = 0"
#     | "fib (Suc 0) = 1"
#     | "fib (Suc (Suc n)) = fib n + fib (Suc n)"
#
#
# end
# Out:
# Overwriting /tmp/isabelleplay/Fibnew.thy

# %%
! ~/Downloads/Isabelle2025_linux/Isabelle2025/bin/isabelle jedit /tmp/isabelleplay/Fibnew.thy
# Out:
# ^C

# %%
! ~/Downloads/Isabelle2025_linux/Isabelle2025/bin/isabelle build -d /tmp/isabelleplay Play
# Out:
# 0:00:03 elapsed time

# %%
! ~/Downloads/Isabelle2025_linux/Isabelle2025/bin/isabelle tptp_sledgehammer
# Out:
# Usage: isabelle tptp_sledgehammer TIMEOUT FILES
#
#   Runs Sledgehammer on TPTP problems.
#   Each problem is allocated at most TIMEOUT seconds.

# %% [markdown]
# tptp_translate also sounds useful

# %%
import isabelle_client
