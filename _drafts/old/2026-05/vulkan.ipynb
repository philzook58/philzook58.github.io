# %% [markdown]
# I'm quite impressed by llama.cpp vulkan backend.
# Gives me about 20t/s on gemma 4 a4b. 45 t/s on e2b.
# This is a quality and speed that is close to useful.
#
# I saw a bench where a4b got ~60t/s on mac
# 180t/s on latest nvidia gpu
#
# Kompute
# rust gfx
# Make a toy compiler to it?
#
# slang
#
# spir-v
# hlsl
#
# lunarG is like an owner kind of. vulkan sdk
#
# https://shader-slang.org/
# https://shader-slang.org/slang-playground/
