# %% [markdown]
# Guarded programs
# integer linear programs
# Guarded polynhomial and linear programs.
#
#
# Julia seems like it's got nice solvers so
#
# "Dynamical Systems and Computer Programs - Kind of the Same Thing"
# https://dl.acm.org/doi/abs/10.1145/3385412.3385969 - PLDI talk on polynomial invaraint generation using QCLP
#
#
# http://www.csl.sri.com/users/tiwari/papers/cav04.pdf
#
#
#
# Victor Magron has some interesting stuff
#
#
# Nondetermonisic or
# () || ( )
#
# update
# x := 3x + 4
# Guard   (x >= ) =>
#
# type Var = Int
# data Linear = Vector Double
# data Prop = Eq0 Linear | GTE0 Linear | GT0 Linear
# data Prog = Or Prog Prog | Update Var Linear | Guard Prop Prog | Seq Prog Prog | Star Prog
#
#
# What is the minimal thing
# data ProgSimple = Update | Seq
#
#
#
#
#
# 1. Guards
#
#  /\ /\ /\ /\ => /\ /\ /\
#  polytope containment
#
# 2.
#
#
#
# 3.
#
#
# one persepctive = diajsktras guarded commande language
# lamports TLA+, dijunction of all possible actions.
#
#
# prog =
# [
#  polytope_guard  => x := a*x # update,
#
#
# ]
#
# LP based techniques or could use polynomiaal interpretation
#
#
# bounded model checker:
# It's all Or, which is annoying to put into a MIP.
#
# Symbolic execution seems reasonable. A path checking guard condition is a linear program or MIP.
#
#
#
# invariant verifier:
# state invaraint = linear function of variables.
#
#
# termination function checker
#
# termination and invaraint inference.
#
# http://www2.imm.dtu.dk/courses/02917/FMSD05_Fraenzle_Herde.pdf HySAT. Interesting
# isat3 -
# https://hal.inria.fr/hal-01946733/document - wrapping computer algerba is surprisingly successful for nonlinear smt
#
#
# https://arxiv.org/pdf/1801.08723.pdf - abstraction refinement of nonlinear functions
#
# https://arxiv.org/pdf/1802.04408.pdf - combining numerical optimization wtih sat solving - solar-0lezama
#
# https://people.eecs.berkeley.edu/~sseshia/pubdir/hscc17-smc.pdf - satisfiability modul oconvex optimization
# https://yshoukry.bitbucket.io/SatEX/
# Julia seems to be a nice place for this maybe? They glued together a SAT solver and convex solvers.
#
#
# https://www.redlog.eu/ - redlog. Wassup with this
#
#
# Anyhow, the "TLA+" technqiue will already directyl support thesse linear programs. I don't really have any good examples though.
#
# x' := x + p
# p' := p - x
