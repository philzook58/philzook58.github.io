# %% [markdown]
# More "laziness".
#
#
# check = do some stuff but also wrap a delayed check
# gen = also doesn't need to fully produce. And maybe have delayed `assume` failure.
#
# Base types don't need these delays really.
#
# ascription,
# synth/check
# intro/elim
# According to intro=check recipe very similar.
#
# Ascribe = compute?
#
# A -> B needs you to supply an A before it is forced.
# whnf
#
#
# Int -> Int
# (Int -> Int) -> Int
# lam f. f 1
#
# draw(st.integers)
#
# def NatGen
# def NatGuard
#
# These are kind of like typing judgements but in different modes?
# Noth the bidirectional
#
# def gen(draw): # type -> value
#
# def guard(draw, x):
#     return

# %%
class Type:
    gen : 
    check_wrap : Callable[[object], object]

# %%
from dataclasses import dataclass

@dataclass
class GuardVal:
    val : object
    def force(self, )


def wrap(A,B,f):
    def res(x):
        f(A.guard(x))
