# %% [markdown]
# https://mastodon.social/@cfbolz/114614420141781776 debyugging into sail speck. verified VM. dynabook https://www.sciencedirect.com/science/article/pii/S2590118424000182
# Wild shit
#
# unix smalltalk stephen kell
#
# How to click on something and know what it is?
# I mean browsers are kind of like this.
# https://github.com/vilari-mickopf/hyprprop
# xprop
#
#
#
# <https://squeak.org/>
#
# <https://news.ycombinator.com/item?id=38861203> amber smalltlalk for web <https://amber-lang.net/>
#
# <https://news.ycombinator.com/item?id=38820557> cui smalltalk <https://cuis.st/> book <https://cuis-smalltalk.github.io/TheCuisBook/>
#
# https://www.reddit.com/r/smalltalk/
# https://en.wikipedia.org/wiki/Smalltalk
#
# pharo
#
# gnu smalltalk
#
# <https://news.ycombinator.com/item?id=38966345> Smalltalk simplicity and consistency vs. other languages
#
#
# A thng that makes this tough is the reliance on it's own universe. But that is supposed to be part of the mind blast.
# https://squeak.js.org/run/#zip=https://files.squeak.org/6.0/Squeak6.0-22148-32bit/Squeak6.0-22148-32bit.zip web sqeuak
#
# https://github.com/hpi-swa-lab/SqueakByExample-english/releases/download/6.0/SBE-6.0.pdf squeak by example
#
# http://stephane.ducasse.free.fr/FreeBooks/BlueBook/Bluebook.pdf blue book - Smalltalk-80: The Language and its Implementation
# https://wiki.squeak.org/squeak/692 purple book. The language. Missing implem,entation
#
#
# https://www.youtube.com/playlist?list=PL6601A198DF14788D squeak from the very start
#
# https://www.hpi.uni-potsdam.de/hirschfeld/trac/SqueakCommunityProjects/wiki/squeak_screencasts
#
# Image based. monticello as source control
#
# Hmm. maybe small talk doesn't inherit inductivness from its indfuctive source code. SInce there isn't any...
# Images are a way to escape this.
#
# http://www.mirandabanda.org/cogblog/2013/09/05/a-spur-gear-for-cog/ cog spur. object representation
# http://www.mirandabanda.org/cogblog/2011/03/01/build-me-a-jit-as-fast-as-you-can/ in-line message caching
# http://lists.squeakfoundation.org/pipermail/squeak-dev/2021-January/213418.html  context-to-stack mapping
# https://www.researchgate.net/publication/328509577_Two_Decades_of_Smalltalk_VM_Development_Live_VM_Development_through_Simulation_Tools
#
# insane. the C is generated from the smalltalk development
#
# The trusting trust aspect of all this is also pretty wild
#
# allInstances
# thisContext - the current stack-ish. continuation ish
#
#
# Self https://en.wikipedia.org/wiki/Self_(programming_language)
# Newspeak https://en.wikipedia.org/wiki/Newspeak_(programming_language)
# Beta https://en.wikipedia.org/wiki/BETA_(programming_language)
#
# https://github.com/sillycross/dsom deegen
#
# https://github.com/smarr/are-we-fast-yet
# https://som-st.github.io/ simple object machine
# https://github.com/SOM-st/PySOM
