# %% [markdown]
# How to refine (purify) ematching problem into theory part.
#
#
# ```
#
#
# ```

# %%
class Term:
    f : str
    args : list[FatId,...]

class FatId:
    data : object
    t : Term

class PVar:
    name : str
