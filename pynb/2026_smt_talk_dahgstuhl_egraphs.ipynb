# %% [markdown]
# # Satisfiability Modulo Theories
#
# Philip Zucker
#
# <https://colab.research.google.com/github/philzook58/philzook58.github.io/blob/master/pynb/2026_smt_talk_dahgstuhl_egraphs.ipynb>

# %% [markdown]
# # Overview
#
# - Glue together domain specific solvers with SAT
# - Applications
# - SMT Guts
# - Egraphs and SMT
#
# # Demo
#
#
# ## Find Stuff

# %%
# ! git clone https://github.com/philzook58/knuckledragger.git && cd knuckledragger && pip install -e .[pypcode]

# %%
import z3
x,y,z = z3.Ints("x y z")
s = z3.Solver()
s.add(x + y + z == 9)
s.add(z > 3)
s.add(y > 4)
s.add(x > 4)
s.check()
#s.model()
# Out:
# unsat

# %% [markdown]
# Or use the command line

# %%
# %%file /tmp/solve.smt2
# (set-logic ALL)
# (declare-const x Int)
# (declare-const y Int)
# (declare-const z Int)
# (assert (= (+ x y z) 10))
# (check-sat)
# (get-model)
# Out:
# Overwriting /tmp/solve.smt2

# %%
! z3 /tmp/solve.smt2
# Out:
# sat
# (
#   (define-fun y () Int
#     0)
#   (define-fun z () Int
#     0)
#   (define-fun x () Int
#     10)
# )

# %%
! cvc5 --produce-models /tmp/solve.smt2
# Out:
# sat
# (
# (define-fun x () Int 10)
# (define-fun y () Int 0)
# (define-fun z () Int 0)
# )

# %% [markdown]
# ## Don't Find Stuff (Counterexamples)

# %%
import z3
x = z3.BitVec("x", 32)
s = z3.Solver()
thm = x | x == x
s.add(z3.Not(thm))
s.check()
# Out:
# unsat

# %%
z3.prove(x | x == x)
# Out:
# proved

# %%
import z3
x = z3.BitVec("x", 32)
s = z3.Solver()
thm = x <= x + 1
s.add(z3.Not(thm))
s.check()
#s.model()
# Out:
# sat

# %% [markdown]
# # SMT Uses
# - Constraint Satisfaction
# - Theorem Proving
# - Software Verification
# - Synthesis
#
# ## Constraint Satisfaction
#   + Sudoku, N-queens, SEND + MORE = MONEY
#   + Graph coloring (register allocation)
#   + Scheduling
#   + Dependency Resolution
#   + https://www.philipzucker.com/compile_constraints/
#   + Unison https://unison-code.github.io/

# %% [markdown]
# ## Theorem proving
#   + Sledgehammer
#   + lean-smt
#   + SMTCoq
#   + Knuckledragger

# %% [markdown]
# ### Knuckledragger
#
# - https://www.kdrag.com
# - LCF style proof assistant for SMTLIB logic
# - Big Step SMT
# - Manual quantifier handling
# - Backwards tactics system and many goodies

# %%
from kdrag.all import *
kd.prove(smt.ForAll([x], x | x == x))
# Out:
# |= ForAll(x, x | x == x)

# %%
import kdrag.theories.logic.zf as zf
P = smt.Const("P", zf.Class)
@kd.Theorem(smt.Not(smt.ForAll([P], zf.is_set(P))))
def russell(l):
    x,A = smt.Consts("x A", zf.Set)
    l.unfold(zf.is_set).unfold(zf.reflects)
    l.assumes(smt.ForAll([P], smt.Exists([A], smt.ForAll([x], zf.elem(x, A) == P[x]))))
    Q = smt.Lambda([x], smt.Not(zf.elem(x, x)))
    l.have(smt.Exists([A], smt.ForAll([x], zf.elem(x, A) == Q[x]))).specialize(0, Q).auto()
    A1 = l.obtain(-1)
    l.have(zf.elem(A1, A1) == Q(A1)).specialize(-1, A1).auto()
    l.show(smt.BoolVal(False), by=[])
russell
# Out:
# |= Not(ForAll(P, is_set(P)))

# %% [markdown]
# ## Software Verification
# - Symbolic Execution
#   + CBMC Kani Klee
# - Alive
# - F*
# - Dafny
# - ASMC Assembly Checker https://github.com/philzook58/knuckledragger/tree/main/src/kdrag/contrib/pcode

# %%
# %%file /tmp/swap.S
# .include "/tmp/knuckle.s"
# kd_prelude "(declare-const olda (_ BitVec 32))"
# kd_prelude "(declare-const oldb (_ BitVec 32))"
#  .globl swap
# swap:
# kd_entry myentry "(distinct RSI (bvadd RSI (_ bv1 64)) (bvadd RSI (_ bv2 64)) (bvadd RSI (_ bv3 64)) RDI (bvadd RDI (_ bv1 64)) (bvadd RDI (_ bv2 64)) (bvadd RDI (_ bv3 64)))"
# kd_assign save_olda olda "(select ram32 RDI)"
# kd_assign save_oldb oldb "(select ram32 RSI)"
#  movl (%rdi), %eax
#  movl (%rsi), %edx
#  movl %edx, (%rdi)
#  movl %eax, (%rsi)
# kd_exit myexit "(and (= (select ram32 RSI) olda) (= (select ram32 RDI) oldb))"
#  ret
# Out:
# Overwriting /tmp/swap.S

# %%
! python3 -m kdrag.contrib.pcode /tmp/swap.S
# Out:
# Processing /tmp/swap.S with language ID x86:LE:64:default using assembler as
# Constructing Trace Fragments...
# Unexpected SP conflict
# Executing SpecStmt: Assign(label='save_olda', addr=4194304, name='olda', expr=ram32[RDI])
# Executing SpecStmt: Assign(label='save_oldb', addr=4194304, name='oldb', expr=ram32[RSI])
# Executing 0x400000/2: MOV EAX,dword ptr [RDI] at (4194304, 0) PCODE IMARK ram[400000:2]
# Executing 0x400000/2: MOV EAX,dword ptr [RDI] at (4194304, 1) PCODE unique[11f80:4] = *[ram]RDI
# Executing 0x400000/2: MOV EAX,dword ptr [RDI] at (4194304, 2) PCODE EAX = unique[11f80:4]
# Executing 0x400000/2: MOV EAX,dword ptr [RDI] at (4194304, 3) PCODE RAX = zext(EAX)
# Continuing execution at: 0x400002 trace_id [0] num insns 1
# Executing 0x400002/2: MOV EDX,dword ptr [RSI] at (4194306, 0) PCODE IMARK ram[400002:2]
# Executing 0x400002/2: MOV EDX,dword ptr [RSI] at (4194306, 1) PCODE unique[11f80:4] = *[ram]RSI
# Executing 0x400002/2: MOV EDX,dword ptr [RSI] at (4194306, 2) PCODE EDX = unique[11f80:4]
# Executing 0x400002/2: MOV EDX,dword ptr [RSI] at (4194306, 3) PCODE RDX = zext(EDX)
# Continuing execution at: 0x400004 trace_id [0] num insns 2
# Executing 0x400004/2: MOV dword ptr [RDI],EDX at (4194308, 0) PCODE IMARK ram[400004:2]
# Executing 0x400004/2: MOV dword ptr [RDI],EDX at (4194308, 1) PCODE unique[6b00:4] = EDX
# Executing 0x400004/2: MOV dword ptr [RDI],EDX at (4194308, 2) PCODE *[ram]RDI = unique[6b00:4]
# Continuing execution at: 0x400006 trace_id [0] num insns 3
# Executing 0x400006/2: MOV dword ptr [RSI],EAX at (4194310, 0) PCODE IMARK ram[400006:2]
# Executing 0x400006/2: MOV dword ptr [RSI],EAX at (4194310, 1) PCODE unique[6b00:4] = EAX
# Executing 0x400006/2: MOV dword ptr [RSI],EAX at (4194310, 2) PCODE *[ram]RSI = unique[6b00:4]
# Continuing execution at: 0x400008 trace_id [0] num insns 4
# Executing SpecStmt: Exit(myexit, 0x400008, And(ram32[RSI] == olda, ram32[RDI] == oldb))
# Checking verification conditions...
# [✅] Exit(myexit, 0x400008, And(ram32[RSI] == olda, ram32[RDI] == oldb))
# ✅✅✅✅ All 1 verification conditions passed! ✅✅✅✅

# %% [markdown]
# # SMT Guts
#
# $M_? \models \phi$
# - Finds models of logical formulas
#
#
# ## SAT Solving
# - Triumph of automated reasoning
#   + https://x.com/ArminBiere/status/1833515116186546472
# - "Run a circuit backwards"
# - CNF $ (\neg p \lor q \lor \neg r) \land (r \lor \neg q) \land ...$
# - Search + Propagation + Heuristics
# - Conflict Directed Clause Learning (CDCL)
#
# ## SMT
#
# - Eager - Compile theory problems into SAT
#   + Bit Blast
#   + Ackermannization - encode congruence closure into SAT $p_{x = y} \rightarrow p_{f(x) = f(y)}$
# - Lazy
#   + Abstract theory propositions as opaque `p`.
#   + Very Lazy - SAT Reduces to a conjunction of theory literals
#   + Regular Lazy - interleave theory propagation and SAT propagation
#
#
# ## Theories
#
# - Theories are a black box API
# - Theories as sets of formulas. Deductive closure of axioms

# %% [markdown]
# ### Theory Interface
#
# - https://microsoft.github.io/z3guide/programming/Example%20Programs/User%20Propagator/
# - https://z3prover.github.io/api/html/classz3py_1_1_user_propagate_base.html

# %%
class Theory():
    def push(self): ...
    def pop(self): ...
    def create(self, t : ExprRef): ... # notify of term creation
    def fresh(self, s : SortRef) -> ExprRef: ... # create fresh constant of sort s
    def fix(self, t : ExprRef, v : object): ... # assign concrete value to term
    def decide(self, lit : BoolRef, v : bool): ... # assign truth value to literal
    def assert_eq(self, t1 : ExprRef, t2 : ExprRef): ... # assert equality
    def assert_diseq(self, t1 : ExprRef, t2 : ExprRef): ... # assert disequality
    def finalize(self) -> bool: ... # finalize and check satisfiability
    def propagate(self) -> list[Eq | DisEq | BoolRef]: ... # Propagate new facts. BoolRefs are Equalities and disequalities and literals
    def explain(self) -> list[BoolRef]: ... # Small set of literals that cause conflict
    def explain_eq(self, t1 : ExprRef, t2 : ExprRef) -> list[BoolRef]: ...

# %% [markdown]
# ### Example Theories
#
# - Atomic equality `a = b`
# - Uninterpreted Functions EUF
# - Arithmetic
#   - Intervals `x <= 7`
#   - Linear Equality `3x + 2y = z + 4`
#   - Two Variable `x - y <= 4`
#   - Linear Inequalities
#   - Tractable theories often show up in abstract interpretations
# - Bitvectors
# - Arrays
#   + First class functions
#   + Support for Lambdas but YMMV
# - Algebraic Datatypes
# - Sequences
#
# ## Theory Combination
#
# - Nelson-Oppen
# - Shostak
#     + `solve` and `canon`
#     + https://resources.mpi-inf.mpg.de/departments/rg1/conferences/vtsa08/slides/barret2_smt.pdf
#
#
# ### Nelson Oppen Combination
#
# - Purify
#   + flatten `f(f(a) + 1) <= 7 -> [a = e1, f(e1) = e2, e2 + 1 = e3, f(e3) = e4]
#   + Hand off to solvers  [a = e1, f(e1) = e2, f(e3) = e4],  [e2 + 1 = e3, e4 <= 7]
# - Guess or find working arrangement `=` `!=` of shared e1,e2,e3,e4.
# - Some theory says unsat for all arrangements = unsat
# - Can build total model out of individual models with appropriate assumptions
#
#
#
# ### Theoretical Concerns
#
# - Stably Infinite
#     + Every satisfiable formula also has a model of infinite cardinality
#     + I suspect this is a model-theoreticy way of saying has a good notion of "fresh"
#     + Relaxations of this condition are possible
# - Convex - Propagates equality good.
# - Non-Convex - Doesn't propagate equalities good.
# - This is not a closed book. Polite, Shiny, others

# %% [markdown]
# # EGraphs and SMT
#
# ## Minimal Models
#
# - The model returned by z3 is basically an egraph.
# - But not a minimal egraph.

# %%
import z3
T = z3.DeclareSort("T")
#T = smt.IntSort()
s = z3.Solver()
a, b, x, y = z3.Consts("a b x y", T)
f = z3.Function("f", T, T)
s.add(f(f(f(a))) == a)
s.add(x == y)
s.check()
s.model()
# Out:
# [a = T!val!0,
#  y = T!val!1,
#  x = T!val!1,
#  f = [T!val!1 -> T!val!2,
#       T!val!2 -> T!val!0,
#       else -> T!val!1]]

# %%
s = z3.Optimize()
s.add(f(f(f(a))) == a)
s.add(x == y)
ts = [a, f(a), f(f(a)), f(f(f(a))), x, y]
for i, t in enumerate(ts):
    for t1 in ts[:i]:
        s.add_soft(t != t1) # maximize disequalities
s.check()
s.model()
# Out:
# [y = T!val!3,
#  a = T!val!0,
#  x = T!val!3,
#  f = [T!val!1 -> T!val!2,
#       T!val!2 -> T!val!0,
#       else -> T!val!1]]

# %%
s = z3.Solver()
s.add(f(f(f(a))) == a)
s.add(x == y)

s.push()
th = x == a
s.add(z3.Not(th))
print(s.check())
s.pop()

s.push()
th = x == y
s.add(z3.Not(th))
print(s.check())
s.pop()
# Out:
# sat
# unsat

# %% [markdown]
# ## SMT Based Egraphs Modulo Theories
#
# - Prototype for Egraphs modulo theories
#   + SMT is oracle for equality
#   + Throw terms into a set
#   + Rebuild records oracle equalities in union find
#   + Bottom up ematching + SMT query for egraph containment
#
# - Supports linear arith, arrays, polynomials, etc
# - Context via `smt.Implies`
#
# - Blog Posts
#   + https://www.philipzucker.com/brute_eggmt/
#   + https://www.philipzucker.com/egraph-mt2/

# %%
from kdrag.solvers.egraph import EGraph

a = smt.Int("a") 
E = EGraph()
t = (a * 2) / 2
E.add_term(t)
E.dot()

# %%
E.rebuild()
E.dot()

# %%
print(E.extract(t))
# Out:
# a

# %% [markdown]
# ## Half Baked: Ematching modulo theories as an SMT problem
# - You can encode SAT to ematching
# - Interleave decide enode/eclass and theory propagate

# %% [markdown]
# # Resources
#
# - de Moura https://leodemoura.github.io/files/oregon08.pdf
# - Tinelli  https://homepage.cs.uiowa.edu/~tinelli/talks/SATSMT-12.pdf
# - Bjorner <https://www.youtube.com/watch?v=TgAVIqraCHo&t=227s>
# - https://www.philipzucker.com/glue-cvc5-z3/
# - https://microsoft.github.io/z3guide/docs/logic/intro/
# - https://cvc5.github.io/tutorials/beginners/index.html
# - https://smt.st/SAT_SMT_by_example.pdf
# - https://link.springer.com/chapter/10.1007/978-3-030-22102-7_3  Theory Combination: Beyond Equality Sharing

# %% [markdown]
# # Bits and Bobbles
#
# # Syntax and Semantics
#
# M |= P
#
# Separating by signature does sensibly correspond to how theories are disjoint
#
# multiset rewriting is a decidable theory
#
# EPR
# # Quantifiers
# - Elimination
# - E-matching
# - MBQI Model Based Quantifier Instantiation
#
#
# ### Propagation
#
# - Many are relatives of Abstract interpretations / static analyses
# - Intervals
# - Octagon domain
# - Polyhedral domain
#
#
# # What do they give you
#
# - SAT
#   - Models - Counterexamples, Holes, Parameters, Solutions
# - UNSAT
#   - Unsat cores
#   - Proofs
#
# ## Synthesis.
#     - Guess and check
#     - Ruler
#     - CF's blog post <https://pypy.org/posts/2024/07/finding-simple-rewrite-rules-jit-z3.html>
#
# Could fill out some kind of constraint compiler demo
# ML superoptimize compiler things seem to be taking hold.
# - For some theoires propagation works better than
#
# - Model based theory combination
