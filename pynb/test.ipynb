# %%
import  matplotlib.pyplot as plt
import numpy as np

plt.plot([1,2,3,4],[1,4,9,16])

# %%
import networkx as nx
G = nx.path_graph(3)
nx.draw(G)

# %% [markdown]
# # And Some titles
#  and ome math
# $\cos(\pi)$
# and a link
#
# http://www.google.com

# %%
# %%bash
# # Some inline bash
# echo 'int main(){return 4;}' > /tmp/test.c
# gcc -o /tmp/test /tmp/test.c
# /tmp/test
# echo $?
# Out:
# 4
