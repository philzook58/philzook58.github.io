# %% [markdown]
# ---
# date: 2024-04-29
# title: Experiments in the Irrationality of Sqrt 2 with SMT
# ---
#
# A classical theorem is that $\sqrt{2}$ is irrational. https://en.wikipedia.org/wiki/Square_root_of_2#Proofs_of_irrationality This means it cannot be written as $\frac{p}{q}$ for integers $p$ and $q$.
#
# This and the existence of an infinite number of primes are some simple prominent theorems and reasonable test cases for a system intended to support proofs.
#
# There is an interesting article [The Seventeen Provers of the World](https://www.cs.ru.nl/~freek/comparison/comparison.pdf) compiled by Freek Wiedijk which does the irrationality of two in many different systems.
#
# I've been interested in trying to build infrastructure for a highly automated interactive proof system using off the shelf solvers and this is an test case.
#
# First off, just asking the question in a naive-ish way chokes the solvers. It is not inconceivable that they could have baked this in.

# %%
from z3 import *
# from cvc5.pythonic import * # cvc5 is a pretty good dropin. It also fails here.
n,m = Ints("n m")
prove(Not(Exists([n,m], And(m != 0, n*n == 2 * m * m))))
# Out:
# failed to prove
# ---------------------------------------------------------------------------
# Z3Exception                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/z3/z3.py:7130, in Solver.model(self)
#    7129 try:
# -> 7130     return ModelRef(Z3_solver_get_model(self.ctx.ref(), self.solver), self.ctx)
#    7131 except Z3Exception:
#
# File ~/.local/lib/python3.10/site-packages/z3/z3core.py:4065, in Z3_solver_get_model(a0, a1, _elems)
#    4064 r = _elems.f(a0, a1)
# -> 4065 _elems.Check(a0)
#    4066 return r
#
# File ~/.local/lib/python3.10/site-packages/z3/z3core.py:1475, in Elementaries.Check(self, ctx)
#    1474 if err != self.OK:
# -> 1475     raise self.Exception(self.get_error_message(ctx, err))
#
# Z3Exception: b'there is no current model'
#
# During handling of the above exception, another exception occurred:
#
# Z3Exception                               Traceback (most recent call last)
# /tmp/ipykernel_367156/575137406.py in ?()
#       1 from z3 import *
#       2 # from cvc5.pythonic import * # cvc5 is a pretty good dropin. It also fails here.
#       3 n,m = Ints("n m")
# ----> 4 prove(Not(Exists([n,m], And(m != 0, n*n == 2 * m * m))))
#
# ~/.local/lib/python3.10/site-packages/z3/z3.py in ?(claim, show, **keywords)
#    9087     if r == unsat:
#    9088         print("proved")
#    9089     elif r == unknown:
#    9090         print("failed to prove")
# -> 9091         print(s.model())
#    9092     else:
#    9093         print("counterexample")
#    9094         print(s.model())
#
# ~/.local/lib/python3.10/site-packages/z3/z3.py in ?(self)
#    7128         """
#    7129         try:
#    7130             return ModelRef(Z3_solver_get_model(self.ctx.ref(), self.solver), self.ctx)
#    7131         except Z3Exception:
# -> 7132             raise Z3Exception("model is not available")
#
# Z3Exception: model is not available

# %% [markdown]
# Ok, well we may have to help it along.
#
# I took a look in Baby Rudin to see what their proof looks like. This led me down a rabbithole that was seemingly leading no where.
#
# I started proving lemmas about even and odd numbers. There were some basic facts that seemed difficult to push through.

# %%
even = Function("even", IntSort(), BoolSort())
even_def = ForAll(x, even(x) == Exists([y], x == 2*y))
odd = Function("odd", IntSort(), BoolSort())
odd_def = ForAll(x, odd(x) == Exists([y], x == 2*y+1))

even_or_odd = ForAll(x, even(x) != odd(x))
# Z3 can't prove this for some reason. I suppose this might be a complex diophantine equation or something.
# CVC5 seemingly can prove this.
prove(Implies(And(even_def, odd_def), even_or_odd))

div2_even = ForAll([x], even(x) == (x == 2 * (x/2)))
prove(Implies(even_def, div2_even))

div2_odd = ForAll([x], odd(x) == (x == 2 * (x/2) + 1))
prove(Implies(odd_def, div2_odd))

# %% [markdown]
# So instead I took a look at the Otter proof in the above paper. Otter is an automated theorem and the predecessor of [Prover9](https://www.cs.unm.edu/~mccune/prover9/manual/2009-11A/). It offers some features with more operational flavor that the modern contingent of solvers (vampire and eprover) don't.
#
# This encoding of the problem seems pretty clever. `d(x,y)` is the y is divisible by x. `m` is multiplication. I think implicitly it is working over positive integers to avoid `!= 0` constraints.
#
# Note that in CNF, `~ foo | bar` should often be read as `foo => bar` which is classically equivalent. In that case, this reads as some equations and horn clauses / conditional equations.

# %%
# %%file /tmp/sqrt2.in
# % From the Wiedijk review. Wos, Beeson, McCune
# set(auto).
# %set(ur_res).
# %assign(max_distinct_vars, 1).
# formulas(sos).
#     x = x.  %? Why did they write this?
#     m(1,x) = x. % identity
#     m(x,1) = x.
#     m(x,m(y,z)) = m(m(x,y),z). % associativity
#     m(x,y) = m(y,x). % commutativity
#     m(x,y) != m(x,z) | y = z. % cancellation... ??? What about x = 0? Implicit positive integers only?
#     -d(x,y) | m(x,f(x,y)) = y. % this and next line define divides
#     m(x,z) != y | d(x,y).
#     -d(2,m(x,y)) | d(2,x) | d(2,y). % 2 is prime
#     m(a,a) = m(2,m(b,b)). % a/b = √2
#     -d(x,a) | -d(x,b) | x = 1. % a/b is in lowest terms
#     2 != 1. % I almost forgot this!
# end_of_list.
# Out:
# Overwriting /tmp/sqrt2.in

# %%
! prover9 -f /tmp/sqrt2.in
# Out:
# ============================== Prover9 ===============================
# Prover9 (64) version 2017-11A (CIIRC), November 2017.
# Process 370431 was started by philip on philip-ThinkPad-Z13-Gen-2,
# Mon Apr 29 20:47:34 2024
# The command was "prover9 -f /tmp/sqrt2.in".
# ============================== end of head ===========================
#
# ============================== INPUT =================================
#
# % Reading from file /tmp/sqrt2.in
#
# set(auto).
#     % set(auto) -> set(auto_inference).
#     % set(auto) -> set(auto_setup).
#     % set(auto_setup) -> set(predicate_elim).
#     % set(auto_setup) -> assign(eq_defs, unfold).
#     % set(auto) -> set(auto_limits).
#     % set(auto_limits) -> assign(max_weight, "100.000").
#     % set(auto_limits) -> assign(sos_limit, 20000).
#     % set(auto) -> set(auto_denials).
#     % set(auto) -> set(auto_process).
#
# formulas(sos).
# x = x.
# m(1,x) = x.
# m(x,1) = x.
# m(x,m(y,z)) = m(m(x,y),z).
# m(x,y) = m(y,x).
# m(x,y) != m(x,z) | y = z.
# -d(x,y) | m(x,f(x,y)) = y.
# m(x,z) != y | d(x,y).
# -d(2,m(x,y)) | d(2,x) | d(2,y).
# m(a,a) = m(2,m(b,b)).
# -d(x,a) | -d(x,b) | x = 1.
# 2 != 1.
# end_of_list.
#
# ============================== end of input ==========================
#
# ============================== PROCESS NON-CLAUSAL FORMULAS ==========
#
# % Formulas that are not ordinary clauses:
#
# ============================== end of process non-clausal formulas ===
#
# ============================== PROCESS INITIAL CLAUSES ===============
#
# % Clauses before input processing:
#
# formulas(usable).
# end_of_list.
#
# formulas(sos).
# x = x.  [assumption].
# m(1,x) = x.  [assumption].
# m(x,1) = x.  [assumption].
# m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# m(x,y) = m(y,x).  [assumption].
# m(x,y) != m(x,z) | y = z.  [assumption].
# -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# m(x,y) != z | d(x,z).  [assumption].
# -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# m(a,a) = m(2,m(b,b)).  [assumption].
# -d(x,a) | -d(x,b) | x = 1.  [assumption].
# 2 != 1.  [assumption].
# end_of_list.
#
# formulas(demodulators).
# end_of_list.
#
# ============================== PREDICATE ELIMINATION =================
#
# No predicates eliminated.
#
# ============================== end predicate elimination =============
#
# Auto_denials:  (non-Horn, no changes).
#
# Term ordering decisions:
# Predicate symbol precedence:  predicate_order([ =, d ]).
# Function symbol precedence:  function_order([ 2, 1, a, b, m, f ]).
# After inverse_order:  (no changes).
# Unfolding symbols: (none).
#
# Auto_inference settings:
#   % set(paramodulation).  % (positive equality literals)
#   % set(binary_resolution).  % (non-Horn)
#   % set(neg_ur_resolution).  % (non-Horn, less than 100 clauses)
#
# Auto_process settings:
#   % set(factor).  % (non-Horn)
#   % set(unit_deletion).  % (non-Horn)
#
# kept:      1 m(1,x) = x.  [assumption].
# kept:      2 m(x,1) = x.  [assumption].
#            3 m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# kept:      4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
#
# % Operation m is commutative; C redundancy checks enabled.
# kept:      5 m(x,y) = m(y,x).  [assumption].
# kept:      6 m(x,y) != m(x,z) | y = z.  [assumption].
# kept:      7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# kept:      8 m(x,y) != z | d(x,z).  [assumption].
# kept:      9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
#            10 m(a,a) = m(2,m(b,b)).  [assumption].
# kept:      11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
#            12 -d(x,a) | -d(x,b) | x = 1.  [assumption].
# kept:      13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
#            14 2 != 1.  [assumption].
# kept:      15 1 != 2.  [copy(14),flip(a)].
# kept:      16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
#
# ============================== end of process initial clauses ========
#
# ============================== CLAUSES FOR SEARCH ====================
#
# % Clauses after input processing:
#
# formulas(usable).
# end_of_list.
#
# formulas(sos).
# 1 m(1,x) = x.  [assumption].
# 2 m(x,1) = x.  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
# 6 m(x,y) != m(x,z) | y = z.  [assumption].
# 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# 8 m(x,y) != z | d(x,z).  [assumption].
# 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
# 15 1 != 2.  [copy(14),flip(a)].
# 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
# end_of_list.
#
# formulas(demodulators).
# 1 m(1,x) = x.  [assumption].
# 2 m(x,1) = x.  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
#         % (lex-dep)
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# end_of_list.
#
# ============================== end of clauses for search =============
#
# ============================== SEARCH ================================
#
# % Starting search at 0.00 seconds.
#
# given #1 (I,wt=5): 1 m(1,x) = x.  [assumption].
#
# given #2 (I,wt=5): 2 m(x,1) = x.  [assumption].
#
# given #3 (I,wt=11): 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
#
# given #4 (I,wt=7): 5 m(x,y) = m(y,x).  [assumption].
#
# % Operation m is associative-commutative; CAC redundancy checks enabled.
#
# given #5 (I,wt=10): 6 m(x,y) != m(x,z) | y = z.  [assumption].
#
# given #6 (I,wt=10): 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
#
# given #7 (I,wt=8): 8 m(x,y) != z | d(x,z).  [assumption].
#
# given #8 (I,wt=11): 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
#
# given #9 (I,wt=9): 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
#
# given #10 (I,wt=9): 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
#
# given #11 (I,wt=3): 15 1 != 2.  [copy(14),flip(a)].
#
# given #12 (I,wt=8): 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
#
# given #13 (A,wt=11): 17 m(x,m(y,z)) = m(y,m(x,z)).  [para(5(a,1),4(a,1,1)),rewrite([4(2)])].
#
# given #14 (F,wt=5): 38 m(x,2) != x.  [ur(6,b,15,a),rewrite([2(2)]),flip(a)].
#
# given #15 (F,wt=5): 45 m(2,x) != x.  [para(5(a,1),38(a,1))].
#
# given #16 (F,wt=7): 47 m(b,b) != m(a,a).  [para(11(a,1),45(a,1)),flip(a)].
#
# given #17 (F,wt=9): 44 m(x,m(y,2)) != m(x,y).  [ur(6,b,38,a)].
#
# given #18 (T,wt=3): 24 d(x,x).  [resolve(8,a,2,a)].
#
# given #19 (T,wt=3): 25 d(1,x).  [resolve(8,a,1,a)].
#
# given #20 (T,wt=5): 22 d(x,m(y,x)).  [resolve(8,a,5,a)].
#
# given #21 (T,wt=5): 27 d(x,m(x,y)).  [resolve(8,a,2,a(flip)),rewrite([5(3),1(3)])].
#
# given #22 (A,wt=8): 18 m(x,y) != x | 1 = y.  [para(2(a,1),6(a,1)),flip(a)].
#
# given #23 (F,wt=9): 46 m(x,m(2,y)) != m(x,y).  [ur(6,b,45,a)].
#
# given #24 (F,wt=9): 50 m(x,m(2,y)) != m(y,x).  [para(5(a,1),44(a,1)),rewrite([4(3)])].
#
# given #25 (F,wt=9): 51 m(x,m(y,2)) != m(y,x).  [para(5(a,1),44(a,2))].
#
# given #26 (F,wt=9): 66 m(2,m(x,y)) != m(y,x).  [para(5(a,1),46(a,1)),rewrite([4(3)])].
#
# given #27 (T,wt=5): 33 d(2,m(a,a)).  [resolve(11,a,8,a)].
#
# given #28 (T,wt=3): 79 d(2,a).  [resolve(33,a,16,a)].
#
# given #29 (T,wt=5): 55 f(1,x) = x.  [resolve(25,a,7,a),rewrite([1(4)])].
#
# given #30 (T,wt=6): 28 x != y | d(x,y).  [para(2(a,1),8(a,1))].
#
# given #31 (A,wt=14): 19 m(x,m(y,z)) != m(x,m(y,u)) | z = u.  [para(4(a,1),6(a,1)),rewrite([4(4)])].
#
# given #32 (F,wt=3): 82 -d(2,b).  [ur(13,a,79,a,c,15,a)].
#
# given #33 (F,wt=3): 100 b != 2.  [ur(28,b,82,a),flip(a)].
#
# given #34 (F,wt=5): 101 -d(2,m(b,b)).  [ur(16,b,82,a)].
#
# given #35 (F,wt=5): 102 m(2,x) != b.  [ur(8,b,82,a)].
#
# given #36 (T,wt=6): 53 -d(b,a) | b = 1.  [resolve(24,a,13,b),flip(b)].
#
# given #37 (T,wt=7): 39 d(x,m(y,m(x,z))).  [resolve(17,a,8,a)].
#
# given #38 (T,wt=5): 118 d(b,m(a,a)).  [para(11(a,1),39(a,2))].
#
# given #39 (T,wt=7): 54 m(x,f(x,x)) = x.  [resolve(24,a,7,a)].
#
# given #40 (A,wt=10): 20 m(x,y) != m(z,x) | z = y.  [para(5(a,1),6(a,1)),flip(a)].
#
# given #41 (F,wt=5): 105 m(b,b) != 2.  [ur(28,b,101,a),flip(a)].
#
# given #42 (F,wt=5): 111 m(x,2) != b.  [para(5(a,1),102(a,1))].
#
# given #43 (F,wt=5): 112 m(a,a) != b.  [para(11(a,1),102(a,1))].
#
# given #44 (F,wt=7): 104 m(x,b) != m(x,2).  [ur(6,b,100,a)].
#
# given #45 (T,wt=5): 120 f(x,x) = 1.  [resolve(54,a,18,a),flip(a)].
#
# given #46 (T,wt=6): 131 x != y | y = x.  [para(1(a,1),20(a,1)),rewrite([2(2)])].
#
# given #47 (T,wt=7): 57 d(x,m(y,m(z,x))).  [para(4(a,1),22(a,2))].
#
# given #48 (T,wt=7): 58 d(m(b,b),m(a,a)).  [para(11(a,1),22(a,2))].
#
# given #49 (A,wt=10): 21 m(x,y) != m(z,x) | y = z.  [para(5(a,1),6(a,2))].
#
# given #50 (F,wt=7): 107 -d(2,m(b,m(b,b))).  [ur(9,b,82,a,c,101,a)].
#
# given #51 (F,wt=7): 108 m(b,b) != m(2,x).  [ur(8,b,101,a),flip(a)].
#
# given #52 (F,wt=7): 113 m(x,m(2,y)) != b.  [para(17(a,1),102(a,1))].
#
# given #53 (F,wt=7): 122 m(b,x) != m(x,2).  [ur(20,b,100,a),flip(a)].
#
# given #54 (T,wt=7): 81 m(2,f(2,a)) = a.  [resolve(79,a,7,a)].
#
# given #55 (T,wt=5): 191 d(f(2,a),a).  [para(81(a,1),22(a,2))].
#
# given #56 (T,wt=5): 197 d(2,m(x,a)).  [para(81(a,1),39(a,2,2))].
#
# given #57 (T,wt=5): 206 d(2,m(a,x)).  [para(5(a,1),197(a,2))].
#
# given #58 (A,wt=9): 23 d(m(x,y),m(x,m(y,z))).  [resolve(8,a,4,a)].
#
# given #59 (F,wt=3): 196 b != a.  [para(81(a,1),102(a,1)),flip(a)].
#
# given #60 (F,wt=5): 190 f(2,a) != a.  [para(81(a,1),45(a,1)),flip(a)].
#
# given #61 (F,wt=5): 201 m(b,b) != a.  [para(81(a,1),108(a,2))].
#
# given #62 (F,wt=5): 202 m(x,a) != b.  [para(81(a,1),113(a,1,2))].
#
# given #63 (T,wt=6): 188 a != x | d(2,x).  [para(81(a,1),8(a,1))].
#
# given #64 (T,wt=7): 84 d(m(x,y),m(y,x)).  [resolve(28,a,5,a)].
#
# given #65 (T,wt=7): 200 d(f(2,a),m(x,a)).  [para(81(a,1),57(a,2,2))].
#
# given #66 (T,wt=7): 205 d(2,m(x,m(y,a))).  [para(4(a,1),197(a,2))].
#
# given #67 (A,wt=12): 29 m(x,m(y,z)) != u | d(m(x,y),u).  [para(4(a,1),8(a,1))].
#
# given #68 (F,wt=5): 233 m(a,x) != b.  [para(5(a,1),202(a,1))].
#
# given #69 (F,wt=3): 255 -d(a,b).  [ur(7,b,233,a)].
#
# given #70 (F,wt=7): 128 m(2,x) != m(x,b).  [ur(20,b,100,a(flip)),flip(a)].
#
# given #71 (F,wt=7): 147 m(x,m(y,2)) != b.  [para(4(a,1),111(a,1))].
#
# given #72 (T,wt=7): 208 d(2,m(x,m(a,y))).  [para(17(a,1),206(a,2))].
#
# given #73 (T,wt=7): 214 d(m(2,b),m(a,a)).  [para(11(a,1),23(a,2))].
#
# given #74 (T,wt=7): 217 d(m(x,2),m(x,a)).  [para(81(a,1),23(a,2,2))].
#
# given #75 (T,wt=7): 241 d(f(2,a),m(a,x)).  [para(5(a,1),200(a,2))].
#
# given #76 (A,wt=8): 30 m(x,y) != z | d(y,z).  [para(5(a,1),8(a,1))].
#
# given #77 (F,wt=7): 164 m(b,m(b,b)) != 2.  [ur(28,b,107,a),flip(a)].
#
# given #78 (F,wt=7): 172 m(b,b) != m(x,2).  [para(5(a,1),108(a,2))].
#
# given #79 (F,wt=7): 184 m(b,x) != m(2,x).  [para(5(a,1),122(a,2))].
#
# given #80 (F,wt=7): 218 m(a,x) != m(x,b).  [ur(21,b,196,a),flip(a)].
#
# given #81 (T,wt=7): 275 d(m(2,x),m(x,a)).  [para(5(a,1),217(a,1))].
#
# given #82 (T,wt=7): 276 d(m(x,2),m(a,x)).  [para(5(a,1),217(a,2))].
#
# given #83 (T,wt=7): 304 d(m(2,x),m(a,x)).  [para(5(a,1),275(a,2))].
#
# given #84 (T,wt=8): 37 m(a,a) != x | d(2,x).  [para(11(a,1),8(a,1))].
#
# given #85 (A,wt=15): 31 -d(2,m(x,m(y,z))) | d(2,m(x,y)) | d(2,z).  [para(4(a,1),9(a,2))].
#
# given #86 (F,wt=7): 219 m(b,x) != m(x,a).  [ur(20,b,196,a),flip(a)].
#
# given #87 (F,wt=7): 221 m(x,b) != m(x,a).  [ur(6,b,196,a)].
#
# given #88 (F,wt=7): 232 m(x,m(y,a)) != b.  [para(4(a,1),202(a,1))].
#
# given #89 (F,wt=7): 234 m(b,m(b,b)) != a.  [ur(188,b,107,a),flip(a)].
#
# given #90 (T,wt=8): 62 m(x,y) != y | 1 = x.  [para(5(a,1),18(a,1))].
#
# given #91 (T,wt=8): 192 a != 2 | f(2,a) = 1.  [para(81(a,1),18(a,1)),flip(b)].
#
# given #92 (T,wt=8): 282 a != x | d(f(2,a),x).  [para(81(a,1),30(a,1))].
#
# given #93 (T,wt=9): 59 d(m(x,y),m(x,m(z,y))).  [para(17(a,1),22(a,2))].
#
# given #94 (A,wt=14): 32 -d(2,m(x,m(y,m(x,y)))) | d(2,m(x,y)).  [factor(31,b,c)].
#
# given #95 (F,wt=7): 257 m(x,m(a,y)) != b.  [para(17(a,1),233(a,1))].
#
# given #96 (F,wt=7): 263 m(b,f(2,a)) != a.  [para(81(a,1),128(a,1)),rewrite([5(6)]),flip(a)].
#
# given #97 (F,wt=7): 301 m(b,x) != m(a,x).  [para(5(a,1),218(a,2)),flip(a)].
#
# given #98 (F,wt=9): 106 -d(2,m(b,m(b,m(b,b)))).  [ur(16,b,101,a),rewrite([17(8),5(7)])].
#
# given #99 (T,wt=9): 116 d(x,m(y,m(z,m(x,u)))).  [para(4(a,1),39(a,2))].
#
# given #100 (T,wt=7): 368 d(b,m(x,m(a,a))).  [para(11(a,1),116(a,2,2))].
#
# given #101 (T,wt=7): 371 d(b,m(a,m(a,x))).  [para(5(a,1),368(a,2)),rewrite([4(5)])].
#
# given #102 (T,wt=7): 372 d(b,m(a,m(x,a))).  [para(17(a,1),368(a,2))].
#
# given #103 (A,wt=13): 34 m(2,m(b,m(b,x))) = m(a,m(a,x)).  [para(11(a,1),4(a,1,1)),rewrite([4(4),4(9)]),flip(a)].
#
# given #104 (F,wt=9): 110 m(x,m(2,y)) != m(x,b).  [ur(6,b,102,a)].
#
# given #105 (F,wt=9): 121 m(2,m(x,y)) != m(y,b).  [ur(20,b,102,a),rewrite([4(5)]),flip(a)].
#
# given #106 (F,wt=9): 127 m(b,x) != m(x,m(2,y)).  [ur(20,b,102,a(flip)),flip(a)].
#
# given #107 (F,wt=9): 139 m(b,m(b,x)) != m(x,2).  [ur(20,b,105,a),rewrite([4(6)]),flip(a)].
#
# given #108 (T,wt=9): 158 d(x,m(y,m(z,m(u,x)))).  [para(4(a,1),57(a,2,2))].
#
# given #109 (T,wt=9): 159 d(m(b,b),m(x,m(a,a))).  [para(11(a,1),57(a,2,2))].
#
# given #110 (T,wt=9): 211 d(m(x,y),m(y,m(x,z))).  [para(5(a,1),23(a,1))].
#
# given #111 (T,wt=9): 212 d(m(x,y),m(y,m(z,x))).  [para(5(a,1),23(a,2)),rewrite([4(3)])].
#
# given #112 (A,wt=13): 35 m(b,m(b,m(x,2))) = m(x,m(a,a)).  [para(11(a,1),4(a,2,2)),rewrite([17(6),5(5)])].
#
# given #113 (F,wt=9): 141 m(x,m(b,b)) != m(x,2).  [ur(6,b,105,a)].
#
# given #114 (F,wt=7): 513 m(a,a) != m(2,2).  [para(11(a,1),141(a,1))].
#
# given #115 (F,wt=9): 142 m(2,x) != m(x,m(b,b)).  [ur(20,b,105,a(flip)),flip(a)].
#
# given #116 (F,wt=9): 143 m(x,m(2,y)) != m(y,b).  [ur(20,b,111,a),rewrite([4(5)]),flip(a)].
#
# given #117 (T,wt=9): 213 d(m(x,2),m(x,m(a,a))).  [para(11(a,1),23(a,2,2))].
#
# given #118 (T,wt=9): 240 d(f(2,a),m(x,m(y,a))).  [para(4(a,1),200(a,2))].
#
# given #119 (T,wt=9): 243 d(2,m(x,m(y,m(z,a)))).  [para(4(a,1),205(a,2,2))].
#
# given #120 (T,wt=9): 270 d(2,m(x,m(y,m(a,z)))).  [para(4(a,1),208(a,2))].
#
# given #121 (A,wt=12): 36 m(a,a) != m(2,x) | m(b,b) = x.  [para(11(a,1),6(a,1))].
#
# given #122 (F,wt=7): 548 m(a,a) != m(2,a).  [ur(36,b,201,a)].
#
# given #123 (F,wt=9): 145 m(x,m(y,2)) != m(x,b).  [ur(6,b,111,a)].
#
# given #124 (F,wt=9): 146 m(b,x) != m(x,m(y,2)).  [ur(20,b,111,a(flip)),flip(a)].
#
# given #125 (F,wt=9): 167 m(b,m(b,b)) != m(2,x).  [ur(8,b,107,a),flip(a)].
#
# given #126 (T,wt=9): 278 d(f(2,a),m(x,m(a,y))).  [para(17(a,1),241(a,2))].
#
# given #127 (T,wt=9): 305 d(m(a,a),m(a,m(b,b))).  [para(11(a,1),275(a,1)),rewrite([5(8)])].
#
# given #128 (T,wt=9): 339 d(m(x,y),m(z,m(y,x))).  [para(5(a,1),59(a,2)),rewrite([4(3)])].
#
# given #129 (T,wt=9): 342 d(m(x,f(2,a)),m(x,a)).  [para(81(a,1),59(a,2,2))].
#
# given #130 (A,wt=14): 40 m(x,m(y,z)) != m(y,u) | m(x,z) = u.  [para(17(a,1),6(a,1))].
#
# given #131 (F,wt=9): 173 m(b,b) != m(x,m(2,y)).  [para(17(a,1),108(a,2))].
#
# given #132 (F,wt=7): 639 m(b,b) != m(x,a).  [para(81(a,1),173(a,2,2))].
# -------- Proof 1 --------
#
# ============================== PROOF =================================
#
# % Proof 1 at 0.02 (+ 0.01) seconds.
# % Length of proof is 27.
# % Level of proof is 10.
# % Maximum clause weight is 12.000.
# % Given clauses 132 (13.200 givens/level).
#
# 3 m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
# 6 m(x,y) != m(x,z) | y = z.  [assumption].
# 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# 8 m(x,y) != z | d(x,z).  [assumption].
# 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# 10 m(a,a) = m(2,m(b,b)).  [assumption].
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# 12 -d(x,a) | -d(x,b) | x = 1.  [assumption].
# 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
# 14 2 != 1.  [assumption].
# 15 1 != 2.  [copy(14),flip(a)].
# 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
# 17 m(x,m(y,z)) = m(y,m(x,z)).  [para(5(a,1),4(a,1,1)),rewrite([4(2)])].
# 33 d(2,m(a,a)).  [resolve(11,a,8,a)].
# 36 m(a,a) != m(2,x) | m(b,b) = x.  [para(11(a,1),6(a,1))].
# 79 d(2,a).  [resolve(33,a,16,a)].
# 81 m(2,f(2,a)) = a.  [resolve(79,a,7,a)].
# 82 -d(2,b).  [ur(13,a,79,a,c,15,a)].
# 101 -d(2,m(b,b)).  [ur(16,b,82,a)].
# 108 m(b,b) != m(2,x).  [ur(8,b,101,a),flip(a)].
# 173 m(b,b) != m(x,m(2,y)).  [para(17(a,1),108(a,2))].
# 186 m(2,m(f(2,a),x)) = m(a,x).  [para(81(a,1),4(a,1,1)),flip(a)].
# 639 m(b,b) != m(x,a).  [para(81(a,1),173(a,2,2))].
# 642 m(a,a) != m(2,m(x,a)).  [ur(36,b,639,a)].
# 643 $F.  [resolve(642,a,186,a(flip))].
#
# ============================== end of proof ==========================
#
# ============================== STATISTICS ============================
#
# Given=132. Generated=2152. Kept=638. proofs=1.
# Usable=127. Sos=485. Demods=56. Limbo=1, Disabled=36. Hints=0.
# Kept_by_rule=0, Deleted_by_rule=0.
# Forward_subsumed=1514. Back_subsumed=15.
# Sos_limit_deleted=0. Sos_displaced=0. Sos_removed=0.
# New_demodulators=58 (2 lex), Back_demodulated=9. Back_unit_deleted=0.
# Demod_attempts=18123. Demod_rewrites=1480.
# Res_instance_prunes=0. Para_instance_prunes=0. Basic_paramod_prunes=0.
# Nonunit_fsub_feature_tests=1506. Nonunit_bsub_feature_tests=528.
# Megabytes=0.81.
# User_CPU=0.02, System_CPU=0.01, Wall_clock=0.
#
# ============================== end of statistics =====================
#
# ============================== end of search =========================
#
# THEOREM PROVED
#
# THEOREM PROVED
#
# Exiting with 1 proof.
#
# ------ process 370431 exit (max_proofs) ------
#
# Process 370431 exit (max_proofs) Mon Apr 29 20:47:34 2024

# %% [markdown]
# This problem is solved instantly. I thought the same problem given to vampire or eprover takes a while (10s for [vampire](https://vprover.github.io/usage.html), a couple minutes for [eprover](https://github.com/eprover/eprover)) but it turns out running them without their command line arguments significantly slows them down. I think this has tripped me up before. These seems like very bad defaults. I used the included `ladr_to_tptp` tool to extract the following [tptp](https://www.tptp.org/) problem.

# %%
# %%file /tmp/sqrt.p
#
# cnf(sos,axiom,m(one,A) = A).
# cnf(sos,axiom,m(A,one) = A).
# cnf(sos,axiom,m(A,m(B,C)) = m(m(A,B),C)).
# cnf(sos,axiom,m(A,B) = m(B,A)).
# cnf(sos,axiom,m(A,B) != m(A,C) | B = C).
# cnf(sos,axiom,~ d(A,B) | m(A,f(A,B)) = B).
# cnf(sos,axiom, m(A,B) != C | d(A,C)).
# cnf(sos,axiom,~ d(two,m(A,B)) | d(two,A) | d(two,B)).
# cnf(sos,axiom,m(a,a) = m(two,m(b,b))).
# cnf(sos,axiom,~ d(A,a) | ~ d(A,b) | A = one).
# cnf(sos,axiom,~ two = one).

# %% [markdown]
# Both of these succeed basically immediately, but the output is quite long.

# %%
! vampire --mode casc /tmp/sqrt.p
# Out:
# % Running in auto input_syntax mode. Trying TPTP
# % lrs+10_11_cond=on:drc=off:flr=on:fsr=off:gsp=on:gs=on:gsem=off:lma=on:msp=off:nm=4:nwc=1.5:nicw=on:sas=z3:sims=off:sp=scramble:stl=188_1169 on sqrt for (600ds/0Mi)
# perf_event_open failed (instruction limiting will be disabled): Permission denied
# (If you are seeing 'Permission denied' ask your admin to run 'sudo sysctl -w kernel.perf_event_paranoid=-1' for you.)
# % Refutation found. Thanks to Tanya!
# % SZS status Unsatisfiable for sqrt
# % SZS output start Proof for sqrt
# fof(f39584,plain,(
#   $false),
#   inference(avatar_smt_refutation,[],[f17,f22,f49,f84,f118,f123,f132,f137,f143,f186,f192,f212,f262,f268,f318,f322,f326,f332,f353,f363,f384,f393,f398,f400,f411,f419,f461,f704,f761,f766,f772,f981,f1016,f1022,f1284,f1409,f1414,f1416,f1442,f1447,f1452,f1516,f1569,f1807,f2104,f3775,f3966,f3971,f3977,f4241,f4400,f4406,f4415,f4437,f4442,f4666,f4671,f4677,f4683,f4950,f4963,f5012,f5016,f5020,f5062,f5069,f5217,f5222,f5227,f5242,f5247,f5254,f5259,f5320,f5539,f5544,f5549,f5554,f5559,f5564,f5569,f5574,f5579,f5586,f5591,f5596,f5689,f5695,f5960,f5967,f5976,f5983,f6011,f6026,f6035,f6042,f6048,f6054,f6060,f6066,f6072,f6078,f6084,f6090,f6096,f6102,f6108,f6206,f6211,f6216,f6222,f6229,f6234,f6235,f6245,f7019,f7058,f7063,f7068,f7165,f7166,f7171,f7172,f7177,f7182,f7187,f7194,f7199,f7200,f7208,f7660,f8108,f8114,f8120,f8124,f8130,f8135,f8141,f8146,f8165,f8170,f8175,f8177,f8191,f8196,f8219,f8222,f8234,f9517,f10565,f10647,f10753,f10759,f10819,f10826,f11051,f12292,f12299,f12305,f12428,f12436,f12560,f12750,f14032,f14316,f15133,f15139,f15145,f15151,f15157,f15163,f15164,f15169,f15174,f15183,f15190,f15205,f15210,f15216,f15227,f15233,f15242,f15291,f15297,f19429,f19489,f19498,f19591,f19599,f19668,f22729,f25452,f25458,f25464,f25538,f25718,f26169,f26173,f28151,f28165,f28811,f28822,f29812,f29824,f30299,f30816,f30951,f30975,f31082,f31241,f31255,f31260,f31294,f31482,f32339,f32354,f33397,f33412,f35130,f38938,f39203,f39210,f39215,f39221,f39239,f39245,f39254,f39262,f39265,f39270,f39278,f39290,f39297,f39302,f39310,f39311,f39312,f39313,f39315,f39355,f39365,f39377,f39398,f39410,f39415,f39436,f39449,f39462,f39467,f39472,f39477,f39512,f39525,f39530,f39544,f39550,f39570,f39575,f39578,f39583])).
# fof(f39583,plain,(
#   spl0_232 | ~spl0_118),
#   inference(avatar_split_clause,[],[f39577,f7158,f39580])).
# fof(f39580,plain,(
#   spl0_232 <=> b = m(two,f(two,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_232])])).
# fof(f7158,plain,(
#   spl0_118 <=> d(two,b)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_118])])).
# fof(f39577,plain,(
#   b = m(two,f(two,b)) | ~spl0_118),
#   inference(resolution,[],[f7160,f6])).
# fof(f6,axiom,(
#   ( ! [X0,X1] : (~d(X0,X1) | m(X0,f(X0,X1)) = X1) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f7160,plain,(
#   d(two,b) | ~spl0_118),
#   inference(avatar_component_clause,[],[f7158])).
# fof(f39578,plain,(
#   spl0_1 | ~spl0_17 | ~spl0_118),
#   inference(avatar_split_clause,[],[f39576,f7158,f315,f14])).
# fof(f14,plain,(
#   spl0_1 <=> one = two),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_1])])).
# fof(f315,plain,(
#   spl0_17 <=> d(two,a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_17])])).
# fof(f39576,plain,(
#   ~d(two,a) | one = two | ~spl0_118),
#   inference(resolution,[],[f7160,f10])).
# fof(f10,axiom,(
#   ( ! [X0] : (~d(X0,b) | ~d(X0,a) | one = X0) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f39575,plain,(
#   spl0_231 | ~spl0_206),
#   inference(avatar_split_clause,[],[f39568,f39200,f39572])).
# fof(f39572,plain,(
#   spl0_231 <=> m(b,b) = m(two,f(two,m(b,b)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_231])])).
# fof(f39200,plain,(
#   spl0_206 <=> d(two,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_206])])).
# fof(f39568,plain,(
#   m(b,b) = m(two,f(two,m(b,b))) | ~spl0_206),
#   inference(resolution,[],[f39202,f6])).
# fof(f39202,plain,(
#   d(two,m(b,b)) | ~spl0_206),
#   inference(avatar_component_clause,[],[f39200])).
# fof(f39570,plain,(
#   spl0_118 | ~spl0_206),
#   inference(avatar_split_clause,[],[f39569,f39200,f7158])).
# fof(f39569,plain,(
#   d(two,b) | ~spl0_206),
#   inference(duplicate_literal_removal,[],[f39567])).
# fof(f39567,plain,(
#   d(two,b) | d(two,b) | ~spl0_206),
#   inference(resolution,[],[f39202,f8])).
# fof(f8,axiom,(
#   ( ! [X0,X1] : (~d(two,m(X0,X1)) | d(two,X0) | d(two,X1)) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f39550,plain,(
#   spl0_230 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39545,f38935,f39547])).
# fof(f39547,plain,(
#   spl0_230 <=> a = f(m(one,f(two,a)),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_230])])).
# fof(f38935,plain,(
#   spl0_205 <=> m(b,b) = m(a,f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_205])])).
# fof(f39545,plain,(
#   a = f(m(one,f(two,a)),m(b,b)) | ~spl0_205),
#   inference(forward_demodulation,[],[f39188,f4])).
# fof(f4,axiom,(
#   ( ! [X0,X1] : (m(X0,X1) = m(X1,X0)) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f39188,plain,(
#   a = f(m(f(two,a),one),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f19170,f38937])).
# fof(f38937,plain,(
#   m(b,b) = m(a,f(two,a)) | ~spl0_205),
#   inference(avatar_component_clause,[],[f38935])).
# fof(f19170,plain,(
#   ( ! [X0,X1] : (f(m(X0,one),m(X1,X0)) = X1) )),
#   inference(superposition,[],[f18968,f11212])).
# fof(f11212,plain,(
#   ( ! [X0,X1] : (m(X0,X1) = m(m(X1,one),X0)) )),
#   inference(superposition,[],[f10282,f4])).
# fof(f10282,plain,(
#   ( ! [X0,X1] : (m(X1,X0) = m(X1,m(X0,one))) )),
#   inference(superposition,[],[f10249,f151])).
# fof(f151,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,X2)) = m(X2,m(X0,X1))) )),
#   inference(superposition,[],[f3,f4])).
# fof(f3,axiom,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,X2)) = m(m(X0,X1),X2)) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f10249,plain,(
#   ( ! [X0,X1] : (m(X0,X1) = m(X1,m(one,X0))) )),
#   inference(equality_resolution,[],[f8255])).
# fof(f8255,plain,(
#   ( ! [X2,X0,X1] : (m(X1,m(one,X0)) != X2 | m(X0,X1) = X2) )),
#   inference(superposition,[],[f50,f151])).
# fof(f50,plain,(
#   ( ! [X0,X1] : (m(one,X1) != X0 | X0 = X1) )),
#   inference(superposition,[],[f5,f1])).
# fof(f1,axiom,(
#   ( ! [X0] : (m(one,X0) = X0) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f5,axiom,(
#   ( ! [X2,X0,X1] : (m(X0,X1) != m(X0,X2) | X1 = X2) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f18968,plain,(
#   ( ! [X0,X1] : (f(X0,m(X0,X1)) = X1) )),
#   inference(equality_resolution,[],[f639])).
# fof(f639,plain,(
#   ( ! [X2,X0,X1] : (m(X0,X1) != m(X0,X2) | f(X0,m(X0,X1)) = X2) )),
#   inference(superposition,[],[f5,f67])).
# fof(f67,plain,(
#   ( ! [X0,X1] : (m(X0,X1) = m(X0,f(X0,m(X0,X1)))) )),
#   inference(resolution,[],[f6,f12])).
# fof(f12,plain,(
#   ( ! [X0,X1] : (d(X0,m(X0,X1))) )),
#   inference(equality_resolution,[],[f7])).
# fof(f7,axiom,(
#   ( ! [X2,X0,X1] : (d(X0,X2) | m(X0,X1) != X2) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f39544,plain,(
#   spl0_229 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39539,f38935,f39541])).
# fof(f39541,plain,(
#   spl0_229 <=> f(two,a) = f(m(a,one),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_229])])).
# fof(f39539,plain,(
#   f(two,a) = f(m(a,one),m(b,b)) | ~spl0_205),
#   inference(forward_demodulation,[],[f39187,f4])).
# fof(f39187,plain,(
#   f(two,a) = f(m(one,a),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f19169,f38937])).
# fof(f19169,plain,(
#   ( ! [X0,X1] : (f(m(one,X0),m(X0,X1)) = X1) )),
#   inference(superposition,[],[f18968,f10290])).
# fof(f10290,plain,(
#   ( ! [X0,X1] : (m(X1,X0) = m(m(one,X1),X0)) )),
#   inference(superposition,[],[f10249,f4])).
# fof(f39530,plain,(
#   spl0_228 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39173,f38935,f39527])).
# fof(f39527,plain,(
#   spl0_228 <=> a = f(f(two,a),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_228])])).
# fof(f39173,plain,(
#   a = f(f(two,a),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f19151,f38937])).
# fof(f19151,plain,(
#   ( ! [X0,X1] : (f(X0,m(X1,X0)) = X1) )),
#   inference(superposition,[],[f18968,f4])).
# fof(f39525,plain,(
#   spl0_227 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39172,f38935,f39522])).
# fof(f39522,plain,(
#   spl0_227 <=> f(two,a) = f(a,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_227])])).
# fof(f39172,plain,(
#   f(two,a) = f(a,m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f18968,f38937])).
# fof(f39512,plain,(
#   ~spl0_211 | spl0_217 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39511,f38935,f39352,f39242])).
# fof(f39242,plain,(
#   spl0_211 <=> a = m(b,b)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_211])])).
# fof(f39352,plain,(
#   spl0_217 <=> one = f(a,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_217])])).
# fof(f39511,plain,(
#   one = f(a,m(b,b)) | a != m(b,b) | ~spl0_205),
#   inference(forward_demodulation,[],[f39510,f38937])).
# fof(f39510,plain,(
#   one = f(a,m(a,f(two,a))) | a != m(b,b) | ~spl0_205),
#   inference(forward_demodulation,[],[f39165,f4])).
# fof(f39165,plain,(
#   a != m(b,b) | one = f(a,m(f(two,a),a)) | ~spl0_205),
#   inference(superposition,[],[f11431,f38937])).
# fof(f11431,plain,(
#   ( ! [X0,X1] : (m(X0,X1) != X0 | one = f(X0,m(X1,X0))) )),
#   inference(forward_demodulation,[],[f11298,f10269])).
# fof(f10269,plain,(
#   ( ! [X0,X1] : (m(X0,X1) = m(X1,m(X0,one))) )),
#   inference(superposition,[],[f10249,f4])).
# fof(f11298,plain,(
#   ( ! [X0,X1] : (m(X0,X1) != X0 | one = f(X0,m(X0,m(X1,one)))) )),
#   inference(superposition,[],[f644,f10282])).
# fof(f644,plain,(
#   ( ! [X0,X1] : (m(X0,X1) != X0 | one = f(X0,m(X0,X1))) )),
#   inference(superposition,[],[f51,f67])).
# fof(f51,plain,(
#   ( ! [X0,X1] : (m(X0,X1) != X0 | one = X1) )),
#   inference(superposition,[],[f5,f2])).
# fof(f2,axiom,(
#   ( ! [X0] : (m(X0,one) = X0) )),
#   file('/tmp/sqrt.p',unknown)).
# fof(f39477,plain,(
#   spl0_226 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39139,f38935,f39474])).
# fof(f39474,plain,(
#   spl0_226 <=> d(m(a,one),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_226])])).
# fof(f39139,plain,(
#   d(m(a,one),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f10311,f38937])).
# fof(f10311,plain,(
#   ( ! [X0,X1] : (d(m(X1,one),m(X1,X0))) )),
#   inference(superposition,[],[f549,f10249])).
# fof(f549,plain,(
#   ( ! [X2,X0,X1] : (d(m(X0,X2),m(X1,m(X2,X0)))) )),
#   inference(forward_demodulation,[],[f542,f3])).
# fof(f542,plain,(
#   ( ! [X2,X0,X1] : (d(m(X0,X2),m(m(X1,X2),X0))) )),
#   inference(superposition,[],[f237,f4])).
# fof(f237,plain,(
#   ( ! [X2,X0,X1] : (d(m(X2,X0),m(X2,m(X1,X0)))) )),
#   inference(superposition,[],[f159,f4])).
# fof(f159,plain,(
#   ( ! [X2,X0,X1] : (d(m(X0,X1),m(X0,m(X1,X2)))) )),
#   inference(superposition,[],[f12,f3])).
# fof(f39472,plain,(
#   spl0_215 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39471,f38935,f39275])).
# fof(f39275,plain,(
#   spl0_215 <=> d(m(one,f(two,a)),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_215])])).
# fof(f39471,plain,(
#   d(m(one,f(two,a)),m(b,b)) | ~spl0_205),
#   inference(forward_demodulation,[],[f39137,f4])).
# fof(f39137,plain,(
#   d(m(f(two,a),one),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f10300,f38937])).
# fof(f10300,plain,(
#   ( ! [X0,X1] : (d(m(X0,one),m(X1,X0))) )),
#   inference(superposition,[],[f159,f10249])).
# fof(f39467,plain,(
#   spl0_24 | spl0_225 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39463,f38935,f39465,f386])).
# fof(f386,plain,(
#   spl0_24 <=> one = f(two,a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_24])])).
# fof(f39465,plain,(
#   spl0_225 <=> ! [X0] : m(a,X0) != m(b,m(b,X0))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_225])])).
# fof(f39463,plain,(
#   ( ! [X0] : (m(a,X0) != m(b,m(b,X0)) | one = f(two,a)) ) | ~spl0_205),
#   inference(forward_literal_rewriting,[],[f39134,f2902])).
# fof(f2902,plain,(
#   ( ! [X2,X3,X0,X1] : (m(X2,m(X1,X0)) != X3 | m(m(X1,X2),X0) = X3) )),
#   inference(superposition,[],[f966,f885])).
# fof(f885,plain,(
#   ( ! [X2,X0,X1] : (m(X2,m(X0,X1)) = m(X1,m(X0,X2))) )),
#   inference(superposition,[],[f145,f4])).
# fof(f145,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,X2)) = m(m(X1,X0),X2)) )),
#   inference(superposition,[],[f3,f4])).
# fof(f966,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X0) != X2 | m(X0,X1) = X2) )),
#   inference(forward_demodulation,[],[f923,f2])).
# fof(f923,plain,(
#   ( ! [X2,X0,X1] : (m(X1,m(X0,one)) != X2 | m(X0,X1) = X2) )),
#   inference(superposition,[],[f61,f145])).
# fof(f61,plain,(
#   ( ! [X0,X1] : (m(X0,one) != X1 | X0 = X1) )),
#   inference(superposition,[],[f50,f4])).
# fof(f39134,plain,(
#   ( ! [X0] : (m(m(b,b),X0) != m(a,X0) | one = f(two,a)) ) | ~spl0_205),
#   inference(superposition,[],[f9502,f38937])).
# fof(f9502,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X0) != m(m(X1,X2),X0) | one = X2) )),
#   inference(superposition,[],[f897,f4])).
# fof(f897,plain,(
#   ( ! [X2,X0,X1] : (m(X0,X1) != m(X1,m(X0,X2)) | one = X2) )),
#   inference(superposition,[],[f51,f145])).
# fof(f39462,plain,(
#   ~spl0_44 | spl0_163 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39461,f38935,f15176,f1562])).
# fof(f1562,plain,(
#   spl0_44 <=> m(b,b) = f(two,a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_44])])).
# fof(f15176,plain,(
#   spl0_163 <=> one = a),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_163])])).
# fof(f39461,plain,(
#   one = a | m(b,b) != f(two,a) | ~spl0_205),
#   inference(forward_demodulation,[],[f39133,f18968])).
# fof(f39133,plain,(
#   m(b,b) != f(two,a) | one = f(f(two,a),m(f(two,a),a)) | ~spl0_205),
#   inference(superposition,[],[f9245,f38937])).
# fof(f9245,plain,(
#   ( ! [X0,X1] : (m(X1,X0) != X0 | one = f(X0,m(X0,X1))) )),
#   inference(superposition,[],[f644,f4])).
# fof(f39449,plain,(
#   spl0_223 | spl0_224 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39441,f38935,f39446,f39443])).
# fof(f39443,plain,(
#   spl0_223 <=> ! [X0] : m(X0,m(b,b)) != X0),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_223])])).
# fof(f39446,plain,(
#   spl0_224 <=> one = m(a,f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_224])])).
# fof(f39441,plain,(
#   ( ! [X0] : (one = m(a,f(two,a)) | m(X0,m(b,b)) != X0) ) | ~spl0_205),
#   inference(forward_literal_rewriting,[],[f39129,f966])).
# fof(f39129,plain,(
#   ( ! [X0] : (m(X0,m(b,b)) != X0 | one = m(f(two,a),a)) ) | ~spl0_205),
#   inference(superposition,[],[f6514,f38937])).
# fof(f6514,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X2,X1)) != X0 | one = m(X1,X2)) )),
#   inference(superposition,[],[f51,f2380])).
# fof(f2380,plain,(
#   ( ! [X2,X0,X1] : (m(X1,m(X0,X2)) = m(X1,m(X2,X0))) )),
#   inference(superposition,[],[f883,f151])).
# fof(f883,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,X2)) = m(X1,m(X0,X2))) )),
#   inference(superposition,[],[f145,f3])).
# fof(f39436,plain,(
#   spl0_24 | spl0_222 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39432,f38935,f39434,f386])).
# fof(f39434,plain,(
#   spl0_222 <=> ! [X0] : m(X0,a) != m(b,m(b,X0))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_222])])).
# fof(f39432,plain,(
#   ( ! [X0] : (m(X0,a) != m(b,m(b,X0)) | one = f(two,a)) ) | ~spl0_205),
#   inference(forward_literal_rewriting,[],[f39126,f2902])).
# fof(f39126,plain,(
#   ( ! [X0] : (m(m(b,b),X0) != m(X0,a) | one = f(two,a)) ) | ~spl0_205),
#   inference(superposition,[],[f5000,f38937])).
# fof(f5000,plain,(
#   ( ! [X2,X0,X1] : (m(X0,X1) != m(m(X1,X2),X0) | one = X2) )),
#   inference(superposition,[],[f161,f4])).
# fof(f161,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,X2)) != m(X0,X1) | one = X2) )),
#   inference(superposition,[],[f51,f3])).
# fof(f39415,plain,(
#   spl0_163 | spl0_221 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39114,f38935,f39413,f15176])).
# fof(f39413,plain,(
#   spl0_221 <=> ! [X0] : m(X0,m(b,b)) != m(X0,f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_221])])).
# fof(f39114,plain,(
#   ( ! [X0] : (m(X0,m(b,b)) != m(X0,f(two,a)) | one = a) ) | ~spl0_205),
#   inference(superposition,[],[f2464,f38937])).
# fof(f2464,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X2) != m(X1,m(X0,X2)) | one = X0) )),
#   inference(superposition,[],[f65,f883])).
# fof(f65,plain,(
#   ( ! [X0,X1] : (m(X1,X0) != X0 | one = X1) )),
#   inference(superposition,[],[f51,f4])).
# fof(f39410,plain,(
#   ~spl0_44 | spl0_163 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39409,f38935,f15176,f1562])).
# fof(f39409,plain,(
#   one = a | m(b,b) != f(two,a) | ~spl0_205),
#   inference(forward_demodulation,[],[f39111,f19151])).
# fof(f39111,plain,(
#   m(b,b) != f(two,a) | one = f(f(two,a),m(a,f(two,a))) | ~spl0_205),
#   inference(superposition,[],[f2253,f38937])).
# fof(f2253,plain,(
#   ( ! [X0,X1] : (m(X1,X0) != X0 | one = f(X0,m(X1,X0))) )),
#   inference(superposition,[],[f51,f68])).
# fof(f68,plain,(
#   ( ! [X0,X1] : (m(X1,X0) = m(X0,f(X0,m(X1,X0)))) )),
#   inference(resolution,[],[f6,f31])).
# fof(f31,plain,(
#   ( ! [X0,X1] : (d(X0,m(X1,X0))) )),
#   inference(superposition,[],[f12,f4])).
# fof(f39398,plain,(
#   spl0_163 | spl0_220 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39096,f38935,f39396,f15176])).
# fof(f39396,plain,(
#   spl0_220 <=> ! [X0] : m(X0,m(b,b)) != m(f(two,a),X0)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_220])])).
# fof(f39096,plain,(
#   ( ! [X0] : (m(X0,m(b,b)) != m(f(two,a),X0) | one = a) ) | ~spl0_205),
#   inference(superposition,[],[f1139,f38937])).
# fof(f1139,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X2) != m(X2,m(X0,X1)) | one = X0) )),
#   inference(superposition,[],[f65,f151])).
# fof(f39377,plain,(
#   spl0_24 | spl0_219 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39074,f38935,f39375,f386])).
# fof(f39375,plain,(
#   spl0_219 <=> ! [X0] : m(a,X0) != m(X0,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_219])])).
# fof(f39074,plain,(
#   ( ! [X0] : (m(a,X0) != m(X0,m(b,b)) | one = f(two,a)) ) | ~spl0_205),
#   inference(superposition,[],[f897,f38937])).
# fof(f39365,plain,(
#   spl0_218 | ~spl0_44 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39067,f38935,f1562,f39362])).
# fof(f39362,plain,(
#   spl0_218 <=> a = f(f(two,a),f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_218])])).
# fof(f39067,plain,(
#   m(b,b) != f(two,a) | a = f(f(two,a),f(two,a)) | ~spl0_205),
#   inference(superposition,[],[f833,f38937])).
# fof(f833,plain,(
#   ( ! [X0,X1] : (m(X1,X0) != X0 | f(X0,X0) = X1) )),
#   inference(superposition,[],[f74,f4])).
# fof(f74,plain,(
#   ( ! [X0,X1] : (m(X0,X1) != X0 | f(X0,X0) = X1) )),
#   inference(superposition,[],[f5,f69])).
# fof(f69,plain,(
#   ( ! [X0] : (m(X0,f(X0,X0)) = X0) )),
#   inference(resolution,[],[f6,f24])).
# fof(f24,plain,(
#   ( ! [X0] : (d(X0,X0)) )),
#   inference(superposition,[],[f12,f2])).
# fof(f39355,plain,(
#   ~spl0_211 | spl0_217 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39350,f38935,f39352,f39242])).
# fof(f39350,plain,(
#   one = f(a,m(b,b)) | a != m(b,b) | ~spl0_205),
#   inference(forward_demodulation,[],[f39062,f38937])).
# fof(f39062,plain,(
#   a != m(b,b) | one = f(a,m(a,f(two,a))) | ~spl0_205),
#   inference(superposition,[],[f644,f38937])).
# fof(f39315,plain,(
#   ~spl0_211 | spl0_24 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39314,f38935,f386,f39242])).
# fof(f39314,plain,(
#   one = f(two,a) | a != m(b,b) | ~spl0_205),
#   inference(forward_demodulation,[],[f39014,f79])).
# fof(f79,plain,(
#   ( ! [X0] : (one = f(X0,X0)) )),
#   inference(trivial_inequality_removal,[],[f78])).
# fof(f78,plain,(
#   ( ! [X0] : (X0 != X0 | one = f(X0,X0)) )),
#   inference(superposition,[],[f51,f69])).
# fof(f39014,plain,(
#   a != m(b,b) | f(two,a) = f(a,a) | ~spl0_205),
#   inference(superposition,[],[f74,f38937])).
# fof(f39313,plain,(
#   spl0_163 | ~spl0_44 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39013,f38935,f1562,f15176])).
# fof(f39013,plain,(
#   m(b,b) != f(two,a) | one = a | ~spl0_205),
#   inference(superposition,[],[f65,f38937])).
# fof(f39312,plain,(
#   spl0_24 | ~spl0_211 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39011,f38935,f39242,f386])).
# fof(f39011,plain,(
#   a != m(b,b) | one = f(two,a) | ~spl0_205),
#   inference(superposition,[],[f51,f38937])).
# fof(f39311,plain,(
#   spl0_208 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39010,f38935,f39212])).
# fof(f39212,plain,(
#   spl0_208 <=> d(f(two,a),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_208])])).
# fof(f39010,plain,(
#   d(f(two,a),m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f31,f38937])).
# fof(f39310,plain,(
#   spl0_207 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39009,f38935,f39207])).
# fof(f39207,plain,(
#   spl0_207 <=> d(a,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_207])])).
# fof(f39009,plain,(
#   d(a,m(b,b)) | ~spl0_205),
#   inference(superposition,[],[f12,f38937])).
# fof(f39302,plain,(
#   spl0_25 | ~spl0_211 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38997,f38935,f329,f39242,f390])).
# fof(f390,plain,(
#   spl0_25 <=> two = a),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_25])])).
# fof(f329,plain,(
#   spl0_20 <=> a = m(two,f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_20])])).
# fof(f38997,plain,(
#   a != m(b,b) | two = a | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f822,f38937])).
# fof(f822,plain,(
#   ( ! [X0] : (a != m(X0,f(two,a)) | two = X0) ) | ~spl0_20),
#   inference(superposition,[],[f469,f331])).
# fof(f331,plain,(
#   a = m(two,f(two,a)) | ~spl0_20),
#   inference(avatar_component_clause,[],[f329])).
# fof(f469,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X0) != m(X2,X0) | X1 = X2) )),
#   inference(superposition,[],[f52,f4])).
# fof(f52,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X0) != m(X0,X2) | X1 = X2) )),
#   inference(superposition,[],[f5,f4])).
# fof(f39297,plain,(
#   ~spl0_216 | ~spl0_195 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39292,f38935,f30945,f39294])).
# fof(f39294,plain,(
#   spl0_216 <=> f(two,a) = m(b,m(b,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_216])])).
# fof(f30945,plain,(
#   spl0_195 <=> ! [X0] : m(X0,m(a,a)) != X0),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_195])])).
# fof(f39292,plain,(
#   f(two,a) != m(b,m(b,a)) | (~spl0_195 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39291,f4])).
# fof(f39291,plain,(
#   f(two,a) != m(b,m(a,b)) | (~spl0_195 | ~spl0_205)),
#   inference(forward_literal_rewriting,[],[f38993,f6853])).
# fof(f6853,plain,(
#   ( ! [X2,X3,X0,X1] : (m(X0,m(X2,X1)) != X3 | m(X2,m(X0,X1)) = X3) )),
#   inference(superposition,[],[f966,f2382])).
# fof(f2382,plain,(
#   ( ! [X2,X0,X1] : (m(m(X1,X2),X0) = m(X1,m(X0,X2))) )),
#   inference(superposition,[],[f883,f4])).
# fof(f38993,plain,(
#   f(two,a) != m(a,m(b,b)) | (~spl0_195 | ~spl0_205)),
#   inference(superposition,[],[f31435,f38937])).
# fof(f31435,plain,(
#   ( ! [X0] : (m(a,m(a,X0)) != X0) ) | ~spl0_195),
#   inference(superposition,[],[f30946,f151])).
# fof(f30946,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != X0) ) | ~spl0_195),
#   inference(avatar_component_clause,[],[f30945])).
# fof(f39290,plain,(
#   spl0_87 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39289,f38935,f329,f5686])).
# fof(f5686,plain,(
#   spl0_87 <=> d(m(two,two),m(b,m(b,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_87])])).
# fof(f39289,plain,(
#   d(m(two,two),m(b,m(b,a))) | (~spl0_20 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39288,f151])).
# fof(f39288,plain,(
#   d(m(two,two),m(b,m(a,b))) | (~spl0_20 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38992,f151])).
# fof(f38992,plain,(
#   d(m(two,two),m(a,m(b,b))) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f28264,f38937])).
# fof(f28264,plain,(
#   ( ! [X0] : (d(m(two,two),m(a,m(a,X0)))) ) | ~spl0_20),
#   inference(superposition,[],[f27826,f4])).
# fof(f27826,plain,(
#   ( ! [X0] : (d(m(two,two),m(a,m(X0,a)))) ) | ~spl0_20),
#   inference(superposition,[],[f3592,f1102])).
# fof(f1102,plain,(
#   ( ! [X0] : (m(X0,a) = m(two,m(f(two,a),X0))) ) | ~spl0_20),
#   inference(superposition,[],[f151,f331])).
# fof(f3592,plain,(
#   ( ! [X0,X1] : (d(m(X0,two),m(a,m(X0,X1)))) ) | ~spl0_20),
#   inference(superposition,[],[f3506,f151])).
# fof(f3506,plain,(
#   ( ! [X0,X1] : (d(m(X0,two),m(X0,m(X1,a)))) ) | ~spl0_20),
#   inference(superposition,[],[f1143,f331])).
# fof(f1143,plain,(
#   ( ! [X2,X3,X0,X1] : (d(m(X3,X0),m(X3,m(X2,m(X0,X1))))) )),
#   inference(superposition,[],[f159,f151])).
# fof(f39278,plain,(
#   spl0_215 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38986,f38935,f329,f39275])).
# fof(f38986,plain,(
#   d(m(one,f(two,a)),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f15299,f38937])).
# fof(f15299,plain,(
#   ( ! [X0] : (d(m(one,f(two,a)),m(a,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f12893,f4])).
# fof(f12893,plain,(
#   ( ! [X0] : (d(m(one,f(two,a)),m(X0,a))) ) | ~spl0_20),
#   inference(forward_demodulation,[],[f12845,f4])).
# fof(f12845,plain,(
#   ( ! [X0] : (d(m(f(two,a),one),m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f10621,f331])).
# fof(f10621,plain,(
#   ( ! [X2,X0,X1] : (d(m(X2,one),m(X1,m(X0,X2)))) )),
#   inference(superposition,[],[f10300,f145])).
# fof(f39270,plain,(
#   spl0_214 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38980,f38935,f329,f39267])).
# fof(f39267,plain,(
#   spl0_214 <=> d(m(two,one),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_214])])).
# fof(f38980,plain,(
#   d(m(two,one),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f10499,f38937])).
# fof(f10499,plain,(
#   ( ! [X0] : (d(m(two,one),m(a,X0))) ) | ~spl0_20),
#   inference(forward_demodulation,[],[f10334,f4])).
# fof(f10334,plain,(
#   ( ! [X0] : (d(m(one,two),m(a,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f3589,f10249])).
# fof(f3589,plain,(
#   ( ! [X0,X1] : (d(m(X0,two),m(X1,m(X0,a)))) ) | ~spl0_20),
#   inference(superposition,[],[f3506,f883])).
# fof(f39265,plain,(
#   ~spl0_213 | ~spl0_137 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39264,f38935,f9515,f39259])).
# fof(f39259,plain,(
#   spl0_213 <=> m(b,m(b,a)) = m(b,f(two,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_213])])).
# fof(f9515,plain,(
#   spl0_137 <=> ! [X0] : m(X0,m(a,a)) != m(b,X0)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_137])])).
# fof(f39264,plain,(
#   m(b,m(b,a)) != m(b,f(two,a)) | (~spl0_137 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39263,f151])).
# fof(f39263,plain,(
#   m(b,m(a,b)) != m(b,f(two,a)) | (~spl0_137 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38979,f151])).
# fof(f38979,plain,(
#   m(a,m(b,b)) != m(b,f(two,a)) | (~spl0_137 | ~spl0_205)),
#   inference(superposition,[],[f9521,f38937])).
# fof(f9521,plain,(
#   ( ! [X0] : (m(a,m(a,X0)) != m(b,X0)) ) | ~spl0_137),
#   inference(superposition,[],[f9516,f151])).
# fof(f9516,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != m(b,X0)) ) | ~spl0_137),
#   inference(avatar_component_clause,[],[f9515])).
# fof(f39262,plain,(
#   ~spl0_213 | ~spl0_66 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39257,f38935,f5018,f39259])).
# fof(f5018,plain,(
#   spl0_66 <=> ! [X0] : m(X0,m(a,a)) != m(X0,b)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_66])])).
# fof(f39257,plain,(
#   m(b,m(b,a)) != m(b,f(two,a)) | (~spl0_66 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39256,f151])).
# fof(f39256,plain,(
#   m(b,m(a,b)) != m(b,f(two,a)) | (~spl0_66 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39255,f151])).
# fof(f39255,plain,(
#   m(a,m(b,b)) != m(b,f(two,a)) | (~spl0_66 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38978,f4])).
# fof(f38978,plain,(
#   m(a,m(b,b)) != m(f(two,a),b) | (~spl0_66 | ~spl0_205)),
#   inference(superposition,[],[f9014,f38937])).
# fof(f9014,plain,(
#   ( ! [X0] : (m(a,m(a,X0)) != m(X0,b)) ) | ~spl0_66),
#   inference(superposition,[],[f5019,f151])).
# fof(f5019,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != m(X0,b)) ) | ~spl0_66),
#   inference(avatar_component_clause,[],[f5018])).
# fof(f39254,plain,(
#   ~spl0_212 | ~spl0_20 | ~spl0_64 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39249,f38935,f5010,f329,f39251])).
# fof(f39251,plain,(
#   spl0_212 <=> a = m(b,m(b,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_212])])).
# fof(f5010,plain,(
#   spl0_64 <=> ! [X0] : m(X0,two) != m(X0,m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_64])])).
# fof(f39249,plain,(
#   a != m(b,m(b,a)) | (~spl0_20 | ~spl0_64 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39248,f331])).
# fof(f39248,plain,(
#   m(two,f(two,a)) != m(b,m(b,a)) | (~spl0_64 | ~spl0_205)),
#   inference(forward_literal_rewriting,[],[f39247,f966])).
# fof(f39247,plain,(
#   m(f(two,a),two) != m(b,m(b,a)) | (~spl0_64 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39246,f151])).
# fof(f39246,plain,(
#   m(f(two,a),two) != m(b,m(a,b)) | (~spl0_64 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38977,f151])).
# fof(f38977,plain,(
#   m(f(two,a),two) != m(a,m(b,b)) | (~spl0_64 | ~spl0_205)),
#   inference(superposition,[],[f8955,f38937])).
# fof(f8955,plain,(
#   ( ! [X0] : (m(X0,two) != m(a,m(a,X0))) ) | ~spl0_64),
#   inference(superposition,[],[f5011,f151])).
# fof(f5011,plain,(
#   ( ! [X0] : (m(X0,two) != m(X0,m(a,a))) ) | ~spl0_64),
#   inference(avatar_component_clause,[],[f5010])).
# fof(f39245,plain,(
#   ~spl0_211 | ~spl0_20 | ~spl0_65 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39240,f38935,f5014,f329,f39242])).
# fof(f5014,plain,(
#   spl0_65 <=> ! [X0] : m(X0,two) != m(X0,a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_65])])).
# fof(f39240,plain,(
#   a != m(b,b) | (~spl0_20 | ~spl0_65 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38976,f331])).
# fof(f38976,plain,(
#   m(b,b) != m(two,f(two,a)) | (~spl0_65 | ~spl0_205)),
#   inference(superposition,[],[f8370,f38937])).
# fof(f8370,plain,(
#   ( ! [X0] : (m(two,X0) != m(a,X0)) ) | ~spl0_65),
#   inference(superposition,[],[f7437,f4])).
# fof(f7437,plain,(
#   ( ! [X0] : (m(X0,two) != m(a,X0)) ) | ~spl0_65),
#   inference(superposition,[],[f5015,f4])).
# fof(f5015,plain,(
#   ( ! [X0] : (m(X0,two) != m(X0,a)) ) | ~spl0_65),
#   inference(avatar_component_clause,[],[f5014])).
# fof(f39239,plain,(
#   ~spl0_210 | ~spl0_20 | ~spl0_126 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39234,f38935,f7658,f329,f39236])).
# fof(f39236,plain,(
#   spl0_210 <=> m(b,a) = m(b,m(b,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_210])])).
# fof(f7658,plain,(
#   spl0_126 <=> ! [X0] : m(a,m(a,X0)) != m(b,m(X0,two))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_126])])).
# fof(f39234,plain,(
#   m(b,a) != m(b,m(b,a)) | (~spl0_20 | ~spl0_126 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39233,f4])).
# fof(f39233,plain,(
#   m(b,m(a,b)) != m(b,a) | (~spl0_20 | ~spl0_126 | ~spl0_205)),
#   inference(forward_literal_rewriting,[],[f39232,f6853])).
# fof(f39232,plain,(
#   m(a,m(b,b)) != m(b,a) | (~spl0_20 | ~spl0_126 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39231,f331])).
# fof(f39231,plain,(
#   m(a,m(b,b)) != m(b,m(two,f(two,a))) | (~spl0_126 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38975,f4])).
# fof(f38975,plain,(
#   m(a,m(b,b)) != m(b,m(f(two,a),two)) | (~spl0_126 | ~spl0_205)),
#   inference(superposition,[],[f7659,f38937])).
# fof(f7659,plain,(
#   ( ! [X0] : (m(a,m(a,X0)) != m(b,m(X0,two))) ) | ~spl0_126),
#   inference(avatar_component_clause,[],[f7658])).
# fof(f39221,plain,(
#   spl0_209 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38951,f38935,f329,f39218])).
# fof(f39218,plain,(
#   spl0_209 <=> d(m(f(two,a),f(two,a)),m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_209])])).
# fof(f38951,plain,(
#   d(m(f(two,a),f(two,a)),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f1040,f38937])).
# fof(f1040,plain,(
#   ( ! [X0] : (d(m(X0,f(two,a)),m(a,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f541,f4])).
# fof(f541,plain,(
#   ( ! [X0] : (d(m(X0,f(two,a)),m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f237,f331])).
# fof(f39215,plain,(
#   spl0_208 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38945,f38935,f329,f39212])).
# fof(f38945,plain,(
#   d(f(two,a),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f440,f38937])).
# fof(f440,plain,(
#   ( ! [X0] : (d(f(two,a),m(a,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f374,f4])).
# fof(f374,plain,(
#   ( ! [X0] : (d(f(two,a),m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f160,f331])).
# fof(f160,plain,(
#   ( ! [X2,X0,X1] : (d(X2,m(X0,m(X1,X2)))) )),
#   inference(superposition,[],[f31,f3])).
# fof(f39210,plain,(
#   spl0_207 | ~spl0_20 | ~spl0_205),
#   inference(avatar_split_clause,[],[f39205,f38935,f329,f39207])).
# fof(f39205,plain,(
#   d(a,m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(forward_demodulation,[],[f39204,f331])).
# fof(f39204,plain,(
#   d(m(two,f(two,a)),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(forward_demodulation,[],[f38944,f4])).
# fof(f38944,plain,(
#   d(m(f(two,a),two),m(b,b)) | (~spl0_20 | ~spl0_205)),
#   inference(superposition,[],[f431,f38937])).
# fof(f431,plain,(
#   ( ! [X0] : (d(m(X0,two),m(a,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f372,f4])).
# fof(f372,plain,(
#   ( ! [X0] : (d(m(X0,two),m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f159,f331])).
# fof(f39203,plain,(
#   spl0_206 | ~spl0_18 | ~spl0_205),
#   inference(avatar_split_clause,[],[f38943,f38935,f320,f39200])).
# fof(f320,plain,(
#   spl0_18 <=> ! [X0] : d(two,m(a,X0))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_18])])).
# fof(f38943,plain,(
#   d(two,m(b,b)) | (~spl0_18 | ~spl0_205)),
#   inference(superposition,[],[f321,f38937])).
# fof(f321,plain,(
#   ( ! [X0] : (d(two,m(a,X0))) ) | ~spl0_18),
#   inference(avatar_component_clause,[],[f320])).
# fof(f38938,plain,(
#   spl0_205 | ~spl0_20 | ~spl0_53),
#   inference(avatar_split_clause,[],[f38933,f4397,f329,f38935])).
# fof(f4397,plain,(
#   spl0_53 <=> m(b,b) = f(two,m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_53])])).
# fof(f38933,plain,(
#   m(b,b) = m(a,f(two,a)) | (~spl0_20 | ~spl0_53)),
#   inference(forward_literal_rewriting,[],[f38926,f966])).
# fof(f38926,plain,(
#   m(b,b) = m(f(two,a),a) | (~spl0_20 | ~spl0_53)),
#   inference(superposition,[],[f21460,f4399])).
# fof(f4399,plain,(
#   m(b,b) = f(two,m(a,a)) | ~spl0_53),
#   inference(avatar_component_clause,[],[f4397])).
# fof(f21460,plain,(
#   ( ! [X0] : (m(f(two,a),X0) = f(two,m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f19153,f331])).
# fof(f19153,plain,(
#   ( ! [X2,X0,X1] : (m(X1,X2) = f(X0,m(X2,m(X0,X1)))) )),
#   inference(superposition,[],[f18968,f151])).
# fof(f35130,plain,(
#   spl0_204 | ~spl0_20 | ~spl0_36),
#   inference(avatar_split_clause,[],[f35125,f1281,f329,f35127])).
# fof(f35127,plain,(
#   spl0_204 <=> d(m(b,f(two,a)),m(a,m(a,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_204])])).
# fof(f1281,plain,(
#   spl0_36 <=> m(a,a) = m(b,m(b,two))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_36])])).
# fof(f35125,plain,(
#   d(m(b,f(two,a)),m(a,m(a,a))) | (~spl0_20 | ~spl0_36)),
#   inference(forward_demodulation,[],[f35082,f4])).
# fof(f35082,plain,(
#   d(m(f(two,a),b),m(a,m(a,a))) | (~spl0_20 | ~spl0_36)),
#   inference(superposition,[],[f26274,f331])).
# fof(f26274,plain,(
#   ( ! [X0,X1] : (d(m(X0,b),m(a,m(a,m(X1,X0))))) ) | ~spl0_36),
#   inference(forward_demodulation,[],[f26220,f3])).
# fof(f26220,plain,(
#   ( ! [X0,X1] : (d(m(X0,b),m(m(a,a),m(X1,X0)))) ) | ~spl0_36),
#   inference(superposition,[],[f3507,f885])).
# fof(f3507,plain,(
#   ( ! [X0,X1] : (d(m(X0,b),m(X0,m(X1,m(a,a))))) ) | ~spl0_36),
#   inference(superposition,[],[f1143,f1283])).
# fof(f1283,plain,(
#   m(a,a) = m(b,m(b,two)) | ~spl0_36),
#   inference(avatar_component_clause,[],[f1281])).
# fof(f33412,plain,(
#   spl0_3 | spl0_203 | ~spl0_2),
#   inference(avatar_split_clause,[],[f33084,f19,f33410,f42])).
# fof(f42,plain,(
#   spl0_3 <=> one = b),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_3])])).
# fof(f33410,plain,(
#   spl0_203 <=> ! [X0,X1] : m(X1,m(X0,m(a,a))) != m(X1,m(b,m(X0,two)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_203])])).
# fof(f19,plain,(
#   spl0_2 <=> m(a,a) = m(two,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_2])])).
# fof(f33084,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(X1,m(b,m(X0,two))) | one = b) ) | ~spl0_2),
#   inference(superposition,[],[f2464,f1292])).
# fof(f1292,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(b,m(b,m(X0,two)))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f1291,f151])).
# fof(f1291,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(b,m(two,m(b,X0)))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f1290,f4])).
# fof(f1290,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(b,m(m(b,X0),two))) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f1289,f1001])).
# fof(f1001,plain,(
#   ( ! [X2,X3,X0,X1] : (m(X0,m(X1,X2)) != X3 | m(X2,m(X0,X1)) = X3) )),
#   inference(superposition,[],[f966,f3])).
# fof(f1289,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(two,m(b,m(b,X0)))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f1101,f3])).
# fof(f1101,plain,(
#   ( ! [X0] : (m(two,m(m(b,b),X0)) = m(X0,m(a,a))) ) | ~spl0_2),
#   inference(superposition,[],[f151,f21])).
# fof(f21,plain,(
#   m(a,a) = m(two,m(b,b)) | ~spl0_2),
#   inference(avatar_component_clause,[],[f19])).
# fof(f33397,plain,(
#   spl0_3 | spl0_202 | ~spl0_2),
#   inference(avatar_split_clause,[],[f33393,f19,f33395,f42])).
# fof(f33395,plain,(
#   spl0_202 <=> ! [X0,X1] : m(X1,m(X0,m(a,a))) != m(two,m(X0,m(b,X1)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_202])])).
# fof(f33393,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(two,m(X0,m(b,X1))) | one = b) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f33392,f2902])).
# fof(f33392,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(m(X0,two),m(b,X1)) | one = b) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f33073,f2902])).
# fof(f33073,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(m(b,m(X0,two)),X1) | one = b) ) | ~spl0_2),
#   inference(superposition,[],[f1139,f1292])).
# fof(f32354,plain,(
#   spl0_1 | spl0_201 | ~spl0_20),
#   inference(avatar_split_clause,[],[f32031,f329,f32352,f14])).
# fof(f32352,plain,(
#   spl0_201 <=> ! [X0,X1] : m(X1,m(a,X0)) != m(X1,m(f(two,a),X0))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_201])])).
# fof(f32031,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(X1,m(f(two,a),X0)) | one = two) ) | ~spl0_20),
#   inference(superposition,[],[f2464,f7211])).
# fof(f7211,plain,(
#   ( ! [X0] : (m(a,X0) = m(two,m(f(two,a),X0))) ) | ~spl0_20),
#   inference(forward_literal_rewriting,[],[f882,f6853])).
# fof(f882,plain,(
#   ( ! [X0] : (m(a,X0) = m(f(two,a),m(two,X0))) ) | ~spl0_20),
#   inference(superposition,[],[f145,f331])).
# fof(f32339,plain,(
#   spl0_1 | spl0_200 | ~spl0_20),
#   inference(avatar_split_clause,[],[f32335,f329,f32337,f14])).
# fof(f32337,plain,(
#   spl0_200 <=> ! [X0,X1] : m(X1,m(a,X0)) != m(X0,m(f(two,a),X1))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_200])])).
# fof(f32335,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(X0,m(f(two,a),X1)) | one = two) ) | ~spl0_20),
#   inference(forward_literal_rewriting,[],[f32020,f2902])).
# fof(f32020,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(m(f(two,a),X0),X1) | one = two) ) | ~spl0_20),
#   inference(superposition,[],[f1139,f7211])).
# fof(f31482,plain,(
#   ~spl0_67 | ~spl0_195),
#   inference(avatar_split_clause,[],[f31477,f30945,f5066])).
# fof(f5066,plain,(
#   spl0_67 <=> one = m(a,a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_67])])).
# fof(f31477,plain,(
#   one != m(a,a) | ~spl0_195),
#   inference(superposition,[],[f31434,f10286])).
# fof(f10286,plain,(
#   ( ! [X0,X1] : (m(X1,X0) = m(X1,m(one,X0))) )),
#   inference(superposition,[],[f10249,f885])).
# fof(f31434,plain,(
#   ( ! [X0] : (m(a,m(X0,a)) != X0) ) | ~spl0_195),
#   inference(superposition,[],[f30946,f151])).
# fof(f31294,plain,(
#   spl0_197 | spl0_1 | ~spl0_2),
#   inference(avatar_split_clause,[],[f31293,f19,f14,f31080])).
# fof(f31080,plain,(
#   spl0_197 <=> ! [X0] : m(X0,m(a,a)) != m(X0,m(b,b))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_197])])).
# fof(f31293,plain,(
#   ( ! [X0] : (one = two | m(X0,m(a,a)) != m(X0,m(b,b))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f30707,f18968])).
# fof(f30707,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != m(X0,m(b,b)) | one = f(m(X0,m(b,b)),m(m(X0,m(b,b)),two))) ) | ~spl0_2),
#   inference(superposition,[],[f9245,f1272])).
# fof(f1272,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(two,m(X0,m(b,b)))) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f1083,f1000])).
# fof(f1000,plain,(
#   ( ! [X2,X3,X0,X1] : (m(X1,m(X0,X2)) != X3 | m(X2,m(X0,X1)) = X3) )),
#   inference(superposition,[],[f966,f145])).
# fof(f1083,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) = m(m(b,b),m(X0,two))) ) | ~spl0_2),
#   inference(superposition,[],[f151,f21])).
# fof(f31260,plain,(
#   spl0_1 | spl0_199 | ~spl0_2),
#   inference(avatar_split_clause,[],[f30691,f19,f31258,f14])).
# fof(f31258,plain,(
#   spl0_199 <=> ! [X0,X1] : m(X1,m(X0,m(a,a))) != m(X1,m(X0,m(b,b)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_199])])).
# fof(f30691,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(X1,m(X0,m(b,b))) | one = two) ) | ~spl0_2),
#   inference(superposition,[],[f2464,f1272])).
# fof(f31255,plain,(
#   spl0_197 | spl0_1 | ~spl0_2),
#   inference(avatar_split_clause,[],[f31254,f19,f14,f31080])).
# fof(f31254,plain,(
#   ( ! [X0] : (one = two | m(X0,m(a,a)) != m(X0,m(b,b))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f30688,f19151])).
# fof(f30688,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != m(X0,m(b,b)) | one = f(m(X0,m(b,b)),m(two,m(X0,m(b,b))))) ) | ~spl0_2),
#   inference(superposition,[],[f2253,f1272])).
# fof(f31241,plain,(
#   spl0_1 | spl0_198 | ~spl0_2),
#   inference(avatar_split_clause,[],[f31237,f19,f31239,f14])).
# fof(f31239,plain,(
#   spl0_198 <=> ! [X0,X1] : m(X1,m(X0,m(a,a))) != m(b,m(b,m(X0,X1)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_198])])).
# fof(f31237,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(b,m(b,m(X0,X1))) | one = two) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f31236,f2902])).
# fof(f31236,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(m(b,b),m(X0,X1)) | one = two) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f30680,f2902])).
# fof(f30680,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,m(a,a))) != m(m(X0,m(b,b)),X1) | one = two) ) | ~spl0_2),
#   inference(superposition,[],[f1139,f1272])).
# fof(f31082,plain,(
#   spl0_1 | spl0_197 | ~spl0_2),
#   inference(avatar_split_clause,[],[f30600,f19,f31080,f14])).
# fof(f30600,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != m(X0,m(b,b)) | one = two) ) | ~spl0_2),
#   inference(superposition,[],[f65,f1272])).
# fof(f30975,plain,(
#   spl0_195 | spl0_196 | ~spl0_2),
#   inference(avatar_split_clause,[],[f30974,f19,f30948,f30945])).
# fof(f30948,plain,(
#   spl0_196 <=> one = m(b,m(b,two))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_196])])).
# fof(f30974,plain,(
#   ( ! [X0] : (one = m(b,m(b,two)) | m(X0,m(a,a)) != X0) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f30973,f4])).
# fof(f30973,plain,(
#   ( ! [X0] : (one = m(b,m(two,b)) | m(X0,m(a,a)) != X0) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f30548,f6853])).
# fof(f30548,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != X0 | one = m(two,m(b,b))) ) | ~spl0_2),
#   inference(superposition,[],[f2461,f1272])).
# fof(f2461,plain,(
#   ( ! [X2,X0,X1] : (m(X1,m(X0,X2)) != X0 | one = m(X1,X2)) )),
#   inference(superposition,[],[f51,f883])).
# fof(f30951,plain,(
#   spl0_195 | spl0_196 | ~spl0_2),
#   inference(avatar_split_clause,[],[f30943,f19,f30948,f30945])).
# fof(f30943,plain,(
#   ( ! [X0] : (one = m(b,m(b,two)) | m(X0,m(a,a)) != X0) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f30942,f4])).
# fof(f30942,plain,(
#   ( ! [X0] : (one = m(b,m(two,b)) | m(X0,m(a,a)) != X0) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f30941,f6853])).
# fof(f30941,plain,(
#   ( ! [X0] : (one = m(two,m(b,b)) | m(X0,m(a,a)) != X0) ) | ~spl0_2),
#   inference(forward_literal_rewriting,[],[f30539,f966])).
# fof(f30539,plain,(
#   ( ! [X0] : (m(X0,m(a,a)) != X0 | one = m(m(b,b),two)) ) | ~spl0_2),
#   inference(superposition,[],[f1136,f1272])).
# fof(f1136,plain,(
#   ( ! [X2,X0,X1] : (m(X2,m(X0,X1)) != X0 | one = m(X1,X2)) )),
#   inference(superposition,[],[f51,f151])).
# fof(f30816,plain,(
#   spl0_194 | ~spl0_2 | ~spl0_20),
#   inference(avatar_split_clause,[],[f30811,f329,f19,f30813])).
# fof(f30813,plain,(
#   spl0_194 <=> m(b,m(b,a)) = m(a,m(a,f(two,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_194])])).
# fof(f30811,plain,(
#   m(b,m(b,a)) = m(a,m(a,f(two,a))) | (~spl0_2 | ~spl0_20)),
#   inference(forward_literal_rewriting,[],[f30810,f20757])).
# fof(f20757,plain,(
#   ( ! [X2,X3,X0,X1] : (m(m(X1,X0),X2) != X3 | m(X0,m(X1,X2)) = X3) )),
#   inference(forward_literal_rewriting,[],[f20756,f11307])).
# fof(f11307,plain,(
#   ( ! [X2,X0,X1] : (m(X0,X1) != X2 | m(m(X1,one),X0) = X2) )),
#   inference(superposition,[],[f966,f10282])).
# fof(f20756,plain,(
#   ( ! [X2,X3,X0,X1] : (m(X0,m(X1,X2)) = X3 | m(m(X2,one),m(X1,X0)) != X3) )),
#   inference(forward_demodulation,[],[f20215,f3])).
# fof(f20215,plain,(
#   ( ! [X2,X3,X0,X1] : (m(m(X2,one),m(X1,X0)) != X3 | m(m(X0,X1),X2) = X3) )),
#   inference(superposition,[],[f8256,f6443])).
# fof(f6443,plain,(
#   ( ! [X2,X0,X1] : (m(m(X1,X2),X0) = m(X0,m(X2,X1))) )),
#   inference(superposition,[],[f2380,f4])).
# fof(f8256,plain,(
#   ( ! [X2,X0,X1] : (m(X0,m(X1,one)) != X2 | m(X0,X1) = X2) )),
#   inference(superposition,[],[f50,f151])).
# fof(f30810,plain,(
#   m(b,m(b,a)) = m(m(a,a),f(two,a)) | (~spl0_2 | ~spl0_20)),
#   inference(forward_literal_rewriting,[],[f30809,f966])).
# fof(f30809,plain,(
#   m(b,m(b,a)) = m(f(two,a),m(a,a)) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f30808,f151])).
# fof(f30808,plain,(
#   m(b,m(a,b)) = m(f(two,a),m(a,a)) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f30807,f151])).
# fof(f30807,plain,(
#   m(a,m(b,b)) = m(f(two,a),m(a,a)) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f30454,f4])).
# fof(f30454,plain,(
#   m(m(b,b),a) = m(f(two,a),m(a,a)) | (~spl0_2 | ~spl0_20)),
#   inference(superposition,[],[f1272,f1102])).
# fof(f30299,plain,(
#   spl0_193 | ~spl0_20),
#   inference(avatar_split_clause,[],[f30260,f329,f30296])).
# fof(f30296,plain,(
#   spl0_193 <=> d(m(f(two,a),f(two,a)),m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_193])])).
# fof(f30260,plain,(
#   d(m(f(two,a),f(two,a)),m(a,a)) | ~spl0_20),
#   inference(superposition,[],[f4721,f1102])).
# fof(f4721,plain,(
#   ( ! [X0,X1] : (d(m(f(two,a),X0),m(X1,m(X0,a)))) ) | ~spl0_20),
#   inference(superposition,[],[f1145,f331])).
# fof(f1145,plain,(
#   ( ! [X2,X3,X0,X1] : (d(m(X1,X2),m(X3,m(X2,m(X0,X1))))) )),
#   inference(superposition,[],[f160,f151])).
# fof(f29824,plain,(
#   spl0_1 | spl0_192 | ~spl0_20),
#   inference(avatar_split_clause,[],[f29549,f329,f29822,f14])).
# fof(f29822,plain,(
#   spl0_192 <=> ! [X0,X1] : m(X1,m(a,X0)) != m(X1,m(X0,f(two,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_192])])).
# fof(f29549,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(X1,m(X0,f(two,a))) | one = two) ) | ~spl0_20),
#   inference(superposition,[],[f2464,f3367])).
# fof(f3367,plain,(
#   ( ! [X0] : (m(a,X0) = m(two,m(X0,f(two,a)))) ) | ~spl0_20),
#   inference(forward_literal_rewriting,[],[f3203,f1000])).
# fof(f3203,plain,(
#   ( ! [X0] : (m(a,X0) = m(f(two,a),m(X0,two))) ) | ~spl0_20),
#   inference(superposition,[],[f1086,f331])).
# fof(f1086,plain,(
#   ( ! [X2,X0,X1] : (m(X2,m(X0,X1)) = m(m(X1,X2),X0)) )),
#   inference(superposition,[],[f151,f4])).
# fof(f29812,plain,(
#   spl0_1 | spl0_191 | ~spl0_20),
#   inference(avatar_split_clause,[],[f29808,f329,f29810,f14])).
# fof(f29810,plain,(
#   spl0_191 <=> ! [X0,X1] : m(X1,m(a,X0)) != m(f(two,a),m(X0,X1))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_191])])).
# fof(f29808,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(f(two,a),m(X0,X1)) | one = two) ) | ~spl0_20),
#   inference(forward_literal_rewriting,[],[f29538,f2902])).
# fof(f29538,plain,(
#   ( ! [X0,X1] : (m(X1,m(a,X0)) != m(m(X0,f(two,a)),X1) | one = two) ) | ~spl0_20),
#   inference(superposition,[],[f1139,f3367])).
# fof(f28822,plain,(
#   spl0_1 | spl0_190 | ~spl0_20),
#   inference(avatar_split_clause,[],[f28555,f329,f28820,f14])).
# fof(f28820,plain,(
#   spl0_190 <=> ! [X0,X1] : m(X1,m(X0,a)) != m(X1,m(X0,f(two,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_190])])).
# fof(f28555,plain,(
#   ( ! [X0,X1] : (m(X1,m(X0,a)) != m(X1,m(X0,f(two,a))) | one = two) ) | ~spl0_20),
#   inference(superposition,[],[f2464,f1273])).
# fof(f1273,plain,(
#   ( ! [X0] : (m(X0,a) = m(two,m(X0,f(two,a)))) ) | ~spl0_20),
#   inference(forward_literal_rewriting,[],[f1084,f1000])).
# fof(f1084,plain,(
#   ( ! [X0] : (m(X0,a) = m(f(two,a),m(X0,two))) ) | ~spl0_20),
#   inference(superposition,[],[f151,f331])).
# fof(f28811,plain,(
#   spl0_1 | spl0_189 | ~spl0_20),
# ...
# fof(f4395,plain,(
#   m(b,b) = f(two,m(a,a)) | (~spl0_2 | ~spl0_11)),
#   inference(trivial_inequality_removal,[],[f4330])).
# fof(f4330,plain,(
#   m(a,a) != m(a,a) | m(b,b) = f(two,m(a,a)) | (~spl0_2 | ~spl0_11)),
#   inference(superposition,[],[f108,f142])).
# fof(f4241,plain,(
#   spl0_52 | ~spl0_49),
#   inference(avatar_split_clause,[],[f4236,f3963,f4238])).
# fof(f4236,plain,(
#   m(a,m(a,a)) = m(m(two,two),f(m(two,two),m(a,m(a,a)))) | ~spl0_49),
#   inference(resolution,[],[f3965,f6])).
# fof(f3977,plain,(
#   spl0_51 | ~spl0_50),
#   inference(avatar_split_clause,[],[f3972,f3968,f3974])).
# fof(f3974,plain,(
#   spl0_51 <=> m(a,a) = m(m(two,two),f(m(two,two),m(a,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_51])])).
# fof(f3968,plain,(
#   spl0_50 <=> d(m(two,two),m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_50])])).
# fof(f3972,plain,(
#   m(a,a) = m(m(two,two),f(m(two,two),m(a,a))) | ~spl0_50),
#   inference(resolution,[],[f3970,f6])).
# fof(f3970,plain,(
#   d(m(two,two),m(a,a)) | ~spl0_50),
#   inference(avatar_component_clause,[],[f3968])).
# fof(f3971,plain,(
#   spl0_50 | ~spl0_20),
#   inference(avatar_split_clause,[],[f3946,f329,f3968])).
# fof(f3946,plain,(
#   d(m(two,two),m(a,a)) | ~spl0_20),
#   inference(superposition,[],[f3592,f331])).
# fof(f3966,plain,(
#   spl0_49 | ~spl0_2 | ~spl0_20),
#   inference(avatar_split_clause,[],[f3944,f329,f19,f3963])).
# fof(f3944,plain,(
#   d(m(two,two),m(a,m(a,a))) | (~spl0_2 | ~spl0_20)),
#   inference(superposition,[],[f3592,f21])).
# fof(f3775,plain,(
#   spl0_48 | ~spl0_20 | ~spl0_36),
#   inference(avatar_split_clause,[],[f3770,f1281,f329,f3772])).
# fof(f3770,plain,(
#   d(m(b,m(two,two)),m(a,m(a,a))) | (~spl0_20 | ~spl0_36)),
#   inference(forward_demodulation,[],[f3769,f151])).
# fof(f3769,plain,(
#   d(m(two,m(b,two)),m(a,m(a,a))) | (~spl0_20 | ~spl0_36)),
#   inference(forward_demodulation,[],[f3741,f4])).
# fof(f3741,plain,(
#   d(m(m(b,two),two),m(a,m(a,a))) | (~spl0_20 | ~spl0_36)),
#   inference(superposition,[],[f3587,f1283])).
# fof(f3587,plain,(
#   ( ! [X0,X1] : (d(m(X0,two),m(a,m(X1,X0)))) ) | ~spl0_20),
#   inference(superposition,[],[f3506,f885])).
# fof(f2104,plain,(
#   spl0_1 | spl0_47 | ~spl0_2),
#   inference(avatar_split_clause,[],[f2011,f19,f2102,f14])).
# fof(f2102,plain,(
#   spl0_47 <=> ! [X0] : m(a,m(a,X0)) != m(b,m(b,X0))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_47])])).
# fof(f2011,plain,(
#   ( ! [X0] : (m(a,m(a,X0)) != m(b,m(b,X0)) | one = two) ) | ~spl0_2),
#   inference(superposition,[],[f65,f166])).
# fof(f1807,plain,(
#   spl0_46 | ~spl0_28),
#   inference(avatar_split_clause,[],[f1802,f458,f1804])).
# fof(f1802,plain,(
#   m(b,m(b,a)) = m(m(a,a),f(m(a,a),m(b,m(b,a)))) | ~spl0_28),
#   inference(resolution,[],[f460,f6])).
# fof(f1569,plain,(
#   spl0_44 | ~spl0_45 | ~spl0_2 | ~spl0_20),
#   inference(avatar_split_clause,[],[f1555,f329,f19,f1566,f1562])).
# fof(f1555,plain,(
#   a != m(a,a) | m(b,b) = f(two,a) | (~spl0_2 | ~spl0_20)),
#   inference(superposition,[],[f108,f331])).
# fof(f1516,plain,(
#   spl0_43 | ~spl0_40),
#   inference(avatar_split_clause,[],[f1511,f1439,f1513])).
# fof(f1511,plain,(
#   m(a,a) = m(f(b,m(a,a)),f(f(b,m(a,a)),m(a,a))) | ~spl0_40),
#   inference(resolution,[],[f1441,f6])).
# fof(f1452,plain,(
#   spl0_42 | ~spl0_39 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1395,f1281,f1411,f1449])).
# fof(f1449,plain,(
#   spl0_42 <=> b = f(m(b,two),m(b,two))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_42])])).
# fof(f1395,plain,(
#   m(a,a) != m(b,two) | b = f(m(b,two),m(b,two)) | ~spl0_36),
#   inference(superposition,[],[f833,f1283])).
# fof(f1447,plain,(
#   spl0_41 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1394,f1281,f1444])).
# fof(f1394,plain,(
#   d(f(m(b,two),m(a,a)),m(a,a)) | ~spl0_36),
#   inference(superposition,[],[f691,f1283])).
# fof(f1442,plain,(
#   spl0_40 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1393,f1281,f1439])).
# fof(f1393,plain,(
#   d(f(b,m(a,a)),m(a,a)) | ~spl0_36),
#   inference(superposition,[],[f643,f1283])).
# fof(f1416,plain,(
#   ~spl0_38 | spl0_37 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1415,f1281,f1402,f1406])).
# fof(f1415,plain,(
#   one = m(b,two) | m(a,a) != b | ~spl0_36),
#   inference(forward_demodulation,[],[f1371,f79])).
# fof(f1371,plain,(
#   m(a,a) != b | m(b,two) = f(b,b) | ~spl0_36),
#   inference(superposition,[],[f74,f1283])).
# fof(f1414,plain,(
#   spl0_3 | ~spl0_39 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1369,f1281,f1411,f42])).
# fof(f1369,plain,(
#   m(a,a) != m(b,two) | one = b | ~spl0_36),
#   inference(superposition,[],[f65,f1283])).
# fof(f1409,plain,(
#   spl0_37 | ~spl0_38 | ~spl0_36),
#   inference(avatar_split_clause,[],[f1367,f1281,f1406,f1402])).
# fof(f1367,plain,(
#   m(a,a) != b | one = m(b,two) | ~spl0_36),
#   inference(superposition,[],[f51,f1283])).
# fof(f1284,plain,(
#   spl0_36 | ~spl0_2),
#   inference(avatar_split_clause,[],[f1279,f19,f1281])).
# fof(f1279,plain,(
#   m(a,a) = m(b,m(b,two)) | ~spl0_2),
#   inference(forward_demodulation,[],[f1091,f4])).
# fof(f1091,plain,(
#   m(a,a) = m(b,m(two,b)) | ~spl0_2),
#   inference(superposition,[],[f151,f21])).
# fof(f1022,plain,(
#   spl0_35 | ~spl0_22),
#   inference(avatar_split_clause,[],[f1017,f360,f1019])).
# fof(f1019,plain,(
#   spl0_35 <=> m(a,a) = m(m(b,m(b,two)),f(m(b,m(b,two)),m(a,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_35])])).
# fof(f360,plain,(
#   spl0_22 <=> d(m(b,m(b,two)),m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_22])])).
# fof(f1017,plain,(
#   m(a,a) = m(m(b,m(b,two)),f(m(b,m(b,two)),m(a,a))) | ~spl0_22),
#   inference(resolution,[],[f362,f6])).
# fof(f362,plain,(
#   d(m(b,m(b,two)),m(a,a)) | ~spl0_22),
#   inference(avatar_component_clause,[],[f360])).
# fof(f1016,plain,(
#   spl0_34 | ~spl0_21),
#   inference(avatar_split_clause,[],[f1011,f350,f1013])).
# fof(f1013,plain,(
#   spl0_34 <=> m(b,m(b,two)) = m(m(a,a),f(m(a,a),m(b,m(b,two))))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_34])])).
# fof(f350,plain,(
#   spl0_21 <=> d(m(a,a),m(b,m(b,two)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_21])])).
# fof(f1011,plain,(
#   m(b,m(b,two)) = m(m(a,a),f(m(a,a),m(b,m(b,two)))) | ~spl0_21),
#   inference(resolution,[],[f352,f6])).
# fof(f352,plain,(
#   d(m(a,a),m(b,m(b,two))) | ~spl0_21),
#   inference(avatar_component_clause,[],[f350])).
# fof(f981,plain,(
#   spl0_33 | ~spl0_29),
#   inference(avatar_split_clause,[],[f976,f701,f978])).
# fof(f978,plain,(
#   spl0_33 <=> m(a,a) = m(f(two,m(a,a)),f(f(two,m(a,a)),m(a,a)))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_33])])).
# fof(f976,plain,(
#   m(a,a) = m(f(two,m(a,a)),f(f(two,m(a,a)),m(a,a))) | ~spl0_29),
#   inference(resolution,[],[f703,f6])).
# fof(f772,plain,(
#   spl0_32 | ~spl0_31),
#   inference(avatar_split_clause,[],[f767,f763,f769])).
# fof(f769,plain,(
#   spl0_32 <=> a = m(f(f(two,a),a),f(f(f(two,a),a),a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_32])])).
# fof(f763,plain,(
#   spl0_31 <=> d(f(f(two,a),a),a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_31])])).
# fof(f767,plain,(
#   a = m(f(f(two,a),a),f(f(f(two,a),a),a)) | ~spl0_31),
#   inference(resolution,[],[f765,f6])).
# fof(f765,plain,(
#   d(f(f(two,a),a),a) | ~spl0_31),
#   inference(avatar_component_clause,[],[f763])).
# fof(f766,plain,(
#   spl0_31 | ~spl0_20),
#   inference(avatar_split_clause,[],[f754,f329,f763])).
# fof(f754,plain,(
#   d(f(f(two,a),a),a) | ~spl0_20),
#   inference(superposition,[],[f691,f331])).
# fof(f761,plain,(
#   spl0_30 | ~spl0_2),
#   inference(avatar_split_clause,[],[f753,f19,f758])).
# fof(f753,plain,(
#   d(f(m(b,b),m(a,a)),m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f691,f21])).
# fof(f704,plain,(
#   spl0_29 | ~spl0_2),
#   inference(avatar_split_clause,[],[f696,f19,f701])).
# fof(f696,plain,(
#   d(f(two,m(a,a)),m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f643,f21])).
# fof(f461,plain,(
#   spl0_28 | ~spl0_2 | ~spl0_20),
#   inference(avatar_split_clause,[],[f456,f329,f19,f458])).
# fof(f456,plain,(
#   d(m(a,a),m(b,m(b,a))) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f455,f151])).
# fof(f455,plain,(
#   d(m(a,a),m(b,m(a,b))) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f454,f151])).
# fof(f454,plain,(
#   d(m(a,a),m(a,m(b,b))) | (~spl0_2 | ~spl0_20)),
#   inference(forward_demodulation,[],[f445,f4])).
# fof(f445,plain,(
#   d(m(a,a),m(m(b,b),a)) | (~spl0_2 | ~spl0_20)),
#   inference(superposition,[],[f376,f21])).
# fof(f419,plain,(
#   spl0_18 | ~spl0_19),
#   inference(avatar_split_clause,[],[f414,f324,f320])).
# fof(f324,plain,(
#   spl0_19 <=> ! [X0] : d(two,m(X0,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_19])])).
# fof(f414,plain,(
#   ( ! [X0] : (d(two,m(a,X0))) ) | ~spl0_19),
#   inference(superposition,[],[f325,f4])).
# fof(f325,plain,(
#   ( ! [X0] : (d(two,m(X0,a))) ) | ~spl0_19),
#   inference(avatar_component_clause,[],[f324])).
# fof(f411,plain,(
#   spl0_27 | ~spl0_23),
#   inference(avatar_split_clause,[],[f406,f381,f408])).
# fof(f408,plain,(
#   spl0_27 <=> a = m(f(two,a),f(f(two,a),a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_27])])).
# fof(f381,plain,(
#   spl0_23 <=> d(f(two,a),a)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_23])])).
# fof(f406,plain,(
#   a = m(f(two,a),f(f(two,a),a)) | ~spl0_23),
#   inference(resolution,[],[f383,f6])).
# fof(f383,plain,(
#   d(f(two,a),a) | ~spl0_23),
#   inference(avatar_component_clause,[],[f381])).
# fof(f400,plain,(
#   spl0_19 | ~spl0_20),
#   inference(avatar_split_clause,[],[f375,f329,f324])).
# fof(f375,plain,(
#   ( ! [X0] : (d(two,m(X0,a))) ) | ~spl0_20),
#   inference(superposition,[],[f170,f331])).
# fof(f170,plain,(
#   ( ! [X2,X0,X1] : (d(X1,m(X2,m(X1,X0)))) )),
#   inference(superposition,[],[f160,f4])).
# fof(f398,plain,(
#   spl0_1 | ~spl0_26 | ~spl0_20),
#   inference(avatar_split_clause,[],[f371,f329,f395,f14])).
# fof(f371,plain,(
#   a != f(two,a) | one = two | ~spl0_20),
#   inference(superposition,[],[f65,f331])).
# fof(f393,plain,(
#   spl0_24 | ~spl0_25 | ~spl0_20),
#   inference(avatar_split_clause,[],[f370,f329,f390,f386])).
# fof(f370,plain,(
#   two != a | one = f(two,a) | ~spl0_20),
#   inference(superposition,[],[f51,f331])).
# fof(f384,plain,(
#   spl0_23 | ~spl0_20),
#   inference(avatar_split_clause,[],[f369,f329,f381])).
# fof(f369,plain,(
#   d(f(two,a),a) | ~spl0_20),
#   inference(superposition,[],[f31,f331])).
# fof(f363,plain,(
#   spl0_22 | ~spl0_2),
#   inference(avatar_split_clause,[],[f358,f19,f360])).
# fof(f358,plain,(
#   d(m(b,m(b,two)),m(a,a)) | ~spl0_2),
#   inference(forward_demodulation,[],[f357,f151])).
# fof(f357,plain,(
#   d(m(b,m(two,b)),m(a,a)) | ~spl0_2),
#   inference(forward_demodulation,[],[f356,f151])).
# fof(f356,plain,(
#   d(m(two,m(b,b)),m(a,a)) | ~spl0_2),
#   inference(forward_demodulation,[],[f345,f4])).
# fof(f345,plain,(
#   d(m(m(b,b),two),m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f276,f21])).
# fof(f353,plain,(
#   spl0_21 | ~spl0_2),
#   inference(avatar_split_clause,[],[f348,f19,f350])).
# fof(f348,plain,(
#   d(m(a,a),m(b,m(b,two))) | ~spl0_2),
#   inference(forward_demodulation,[],[f347,f151])).
# fof(f347,plain,(
#   d(m(a,a),m(b,m(two,b))) | ~spl0_2),
#   inference(forward_demodulation,[],[f346,f151])).
# fof(f346,plain,(
#   d(m(a,a),m(two,m(b,b))) | ~spl0_2),
#   inference(forward_demodulation,[],[f339,f4])).
# fof(f339,plain,(
#   d(m(a,a),m(m(b,b),two)) | ~spl0_2),
#   inference(superposition,[],[f276,f21])).
# fof(f332,plain,(
#   spl0_20 | ~spl0_17),
#   inference(avatar_split_clause,[],[f327,f315,f329])).
# fof(f327,plain,(
#   a = m(two,f(two,a)) | ~spl0_17),
#   inference(resolution,[],[f317,f6])).
# fof(f317,plain,(
#   d(two,a) | ~spl0_17),
#   inference(avatar_component_clause,[],[f315])).
# fof(f326,plain,(
#   spl0_19 | spl0_17 | ~spl0_2),
#   inference(avatar_split_clause,[],[f296,f19,f315,f324])).
# fof(f296,plain,(
#   ( ! [X0] : (d(two,a) | d(two,m(X0,a))) ) | ~spl0_2),
#   inference(resolution,[],[f8,f222])).
# fof(f222,plain,(
#   ( ! [X0] : (d(two,m(a,m(X0,a)))) ) | ~spl0_2),
#   inference(superposition,[],[f218,f4])).
# fof(f218,plain,(
#   ( ! [X0] : (d(two,m(a,m(a,X0)))) ) | ~spl0_2),
#   inference(forward_demodulation,[],[f214,f3])).
# fof(f214,plain,(
#   ( ! [X0] : (d(two,m(m(a,a),X0))) ) | ~spl0_2),
#   inference(superposition,[],[f199,f4])).
# fof(f199,plain,(
#   ( ! [X0] : (d(two,m(X0,m(a,a)))) ) | ~spl0_2),
#   inference(superposition,[],[f170,f21])).
# fof(f322,plain,(
#   spl0_18 | spl0_17 | ~spl0_2),
#   inference(avatar_split_clause,[],[f295,f19,f315,f320])).
# fof(f295,plain,(
#   ( ! [X0] : (d(two,a) | d(two,m(a,X0))) ) | ~spl0_2),
#   inference(resolution,[],[f8,f218])).
# fof(f318,plain,(
#   spl0_17 | ~spl0_6),
#   inference(avatar_split_clause,[],[f313,f115,f315])).
# fof(f115,plain,(
#   spl0_6 <=> d(two,m(a,a))),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_6])])).
# fof(f313,plain,(
#   d(two,a) | ~spl0_6),
#   inference(duplicate_literal_removal,[],[f294])).
# fof(f294,plain,(
#   d(two,a) | d(two,a) | ~spl0_6),
#   inference(resolution,[],[f8,f117])).
# fof(f117,plain,(
#   d(two,m(a,a)) | ~spl0_6),
#   inference(avatar_component_clause,[],[f115])).
# fof(f268,plain,(
#   spl0_16 | ~spl0_15),
#   inference(avatar_split_clause,[],[f263,f259,f265])).
# fof(f263,plain,(
#   m(a,a) = m(m(b,two),f(m(b,two),m(a,a))) | ~spl0_15),
#   inference(resolution,[],[f261,f6])).
# fof(f262,plain,(
#   spl0_15 | ~spl0_2),
#   inference(avatar_split_clause,[],[f257,f19,f259])).
# fof(f257,plain,(
#   d(m(b,two),m(a,a)) | ~spl0_2),
#   inference(forward_demodulation,[],[f246,f4])).
# fof(f246,plain,(
#   d(m(two,b),m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f159,f21])).
# fof(f212,plain,(
#   spl0_14 | ~spl0_7),
#   inference(avatar_split_clause,[],[f207,f120,f209])).
# fof(f207,plain,(
#   m(a,a) = m(m(b,b),f(m(b,b),m(a,a))) | ~spl0_7),
#   inference(resolution,[],[f122,f6])).
# fof(f192,plain,(
#   spl0_13 | ~spl0_12),
#   inference(avatar_split_clause,[],[f187,f183,f189])).
# fof(f187,plain,(
#   m(a,a) = m(b,f(b,m(a,a))) | ~spl0_12),
#   inference(resolution,[],[f185,f6])).
# fof(f186,plain,(
#   spl0_12 | ~spl0_2),
#   inference(avatar_split_clause,[],[f179,f19,f183])).
# fof(f179,plain,(
#   d(b,m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f160,f21])).
# fof(f143,plain,(
#   spl0_11 | ~spl0_6),
#   inference(avatar_split_clause,[],[f138,f115,f140])).
# fof(f138,plain,(
#   m(a,a) = m(two,f(two,m(a,a))) | ~spl0_6),
#   inference(resolution,[],[f117,f6])).
# fof(f137,plain,(
#   spl0_1 | ~spl0_10 | ~spl0_2),
#   inference(avatar_split_clause,[],[f113,f19,f134,f14])).
# fof(f113,plain,(
#   m(a,a) != m(b,b) | one = two | ~spl0_2),
#   inference(superposition,[],[f65,f21])).
# fof(f132,plain,(
#   spl0_8 | ~spl0_9 | ~spl0_2),
#   inference(avatar_split_clause,[],[f112,f19,f129,f125])).
# fof(f112,plain,(
#   two != m(a,a) | one = m(b,b) | ~spl0_2),
#   inference(superposition,[],[f51,f21])).
# fof(f123,plain,(
#   spl0_7 | ~spl0_2),
#   inference(avatar_split_clause,[],[f111,f19,f120])).
# fof(f111,plain,(
#   d(m(b,b),m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f31,f21])).
# fof(f118,plain,(
#   spl0_6 | ~spl0_2),
#   inference(avatar_split_clause,[],[f110,f19,f115])).
# fof(f110,plain,(
#   d(two,m(a,a)) | ~spl0_2),
#   inference(superposition,[],[f12,f21])).
# fof(f84,plain,(
#   spl0_5),
#   inference(avatar_split_clause,[],[f71,f81])).
# fof(f81,plain,(
#   spl0_5 <=> one = f(one,one)),
#   introduced(avatar_definition,[new_symbols(naming,[spl0_5])])).
# fof(f71,plain,(
#   one = f(one,one)),
#   inference(superposition,[],[f69,f1])).
# fof(f49,plain,(
#   spl0_3 | ~spl0_4),
#   inference(avatar_split_clause,[],[f39,f46,f42])).
# fof(f39,plain,(
#   ~d(b,a) | one = b),
#   inference(resolution,[],[f10,f24])).
# fof(f22,plain,(
#   spl0_2),
#   inference(avatar_split_clause,[],[f9,f19])).
# fof(f9,axiom,(
#   m(a,a) = m(two,m(b,b))),
#   file('/tmp/sqrt.p',unknown)).
# fof(f17,plain,(
#   ~spl0_1),
#   inference(avatar_split_clause,[],[f11,f14])).
# fof(f11,axiom,(
#   one != two),
#   file('/tmp/sqrt.p',unknown)).
# % SZS output end Proof for sqrt
# % ------------------------------
# % Version: Vampire 4.8 (commit 23d7e9c3b on 2024-03-22 08:41:08 +0000)
# % Linked with Z3 4.12.3.0 79bbbf76d0c123481c8ca05cd3a98939270074d3 z3-4.8.4-7980-g79bbbf76d
# % Termination reason: Refutation
#
# % Memory used [KB]: 6366
# % Time elapsed: 0.542 s
# % ------------------------------
# % ------------------------------
# % Success in time 0.568 s

# %%
! eprover-ho --auto-schedule --proof-object /tmp/sqrt.p
# Out:
# # Preprocessing class: FSSSSMSSSSSNFFN.
# # Scheduled 1 strats onto 1 cores with 300 seconds (300 total)
# # Starting G-E--_302_C18_F1_URBAN_RG_S04BN with 300s (1) cores
# # G-E--_302_C18_F1_URBAN_RG_S04BN with pid 415821 completed with status 0
# # Result found by G-E--_302_C18_F1_URBAN_RG_S04BN
# # No SInE strategy applied
# # Search class: FGUSM-FFSF22-SFFFFFNN
# # Scheduled 6 strats onto 1 cores with 300 seconds (300 total)
# # Starting SAT001_MinMin_p005000_rr_RG with 109s (1) cores
# # SAT001_MinMin_p005000_rr_RG with pid 415822 completed with status 0
# # Result found by SAT001_MinMin_p005000_rr_RG
# # Initializing proof state
# # Scanning for AC axioms
# # m is AC
# # AC handling enabled
# #
# #cnf(i_0_22, plain, (one!=two)).
# #
# #cnf(i_0_13, plain, (m(X1,one)=X1)).
# #
# #cnf(i_0_12, plain, (m(one,X1)=X1)).
# #
# #cnf(i_0_16, plain, (X2=X3|m(X1,X2)!=m(X1,X3))).
# #
# #cnf(i_0_21, plain, (X1=one|~d(X1,a)|~d(X1,b))).
# #
# #cnf(i_0_15, plain, (m(X1,X2)=m(X2,X1))).
# #
# #cnf(i_0_20, plain, (m(two,m(b,b))=m(a,a))).
# #
# #cnf(i_0_18, plain, (d(X1,X3)|m(X1,X2)!=X3)).
# #
# #cnf(i_0_18, plain, (d(X1,m(X1,X2)))).
# #
# #cnf(i_0_17, plain, (m(X1,f(X1,X2))=X2|~d(X1,X2))).
# #
# #cnf(i_0_19, plain, (d(two,X1)|d(two,X2)|~d(two,m(X1,X2)))).
# #
# #cnf(i_0_14, plain, (m(m(X1,X2),X3)=m(X1,m(X2,X3)))).
# # Presaturation interreduction done
# #
# #cnf(i_0_22, plain, (one!=two)).
# #
# #cnf(i_0_13, plain, (m(X1,one)=X1)).
# #
# #cnf(i_0_12, plain, (m(one,X1)=X1)).
# #
# #cnf(i_0_16, plain, (X1=X2|m(X3,X1)!=m(X3,X2))).
# #
# #cnf(i_0_20, plain, (m(two,m(b,b))=m(a,a))).
# #
# #cnf(i_0_26, plain, (X1=one|m(X2,X1)!=X2)).
# #
# #cnf(i_0_21, plain, (X1=one|~d(X1,a)|~d(X1,b))).
# #
# #cnf(i_0_18, plain, (d(X1,m(X1,X2)))).
# #
# #cnf(i_0_15, plain, (m(X1,X2)=m(X2,X1))).
# #
# #cnf(i_0_17, plain, (m(X1,f(X1,X2))=X2|~d(X1,X2))).
# #
# #cnf(i_0_14, plain, (m(m(X1,X2),X3)=m(X1,m(X2,X3)))).
# #
# #cnf(i_0_34, plain, (d(one,X1))).
# #
# #cnf(i_0_35, plain, (d(X1,X1))).
# #
# #cnf(i_0_73, plain, (b=one|~d(b,a))).
# ##
# #cnf(i_0_19, plain, (d(two,X2)|d(two,X1)|~d(two,m(X1,X2)))).
# #
# #cnf(i_0_40, plain, (X1=one|m(X1,X2)!=X2)).
# #
# #cnf(i_0_82, plain, (m(b,b)!=m(a,a))).
# ######
# #cnf(i_0_31, plain, (m(b,b)=one|m(a,a)!=two)).
# #
# #cnf(i_0_100, plain, (m(a,a)!=one|m(a,a)!=two)).
# ##
# #cnf(i_0_29, plain, (m(b,b)=X1|m(a,a)!=m(two,X1))).
# #
# #cnf(i_0_33, plain, (d(two,m(a,a)))).
# ##
# #cnf(i_0_109, plain, (d(two,a))).
# #
# #cnf(i_0_41, plain, (X1=X2|m(X1,X3)!=m(X3,X2))).
# ###
# #cnf(i_0_50, plain, (f(one,X1)=X1)).
# #
# #cnf(i_0_52, plain, (f(X1,X1)=one)).
# #
# #cnf(i_0_90, plain, (d(b,one)|m(a,a)!=two)).
# ###
# #cnf(i_0_39, plain, (d(X1,m(X2,X1)))).
# ####
# #cnf(i_0_84, plain, (X1=one|f(X1,X2)!=X2|~d(X1,X2))).
# ####
# #cnf(i_0_119, plain, (X1=X2|m(X1,X3)!=m(X2,X3))).
# ##
# #cnf(i_0_53, plain, (f(X1,m(X1,X2))=X2)).
# #######
# #cnf(i_0_160, plain, (f(b,one)=b|m(a,a)!=two)).
# ####
# #cnf(i_0_58, plain, (m(X1,m(X2,f(m(X1,X2),X3)))=X3|~d(m(X1,X2),X3))).
# #
# #cnf(i_0_165, plain, (f(X1,m(X2,X1))=X2)).
# ##
# #cnf(i_0_173, plain, (d(X1,X3)|~d(m(X1,X2),X3))).
# #
# #cnf(i_0_220, plain, (d(X1,X2)|~d(X3,X2)|~d(X1,X3))).
# #
# #cnf(i_0_231, plain, (d(X1,X2)|~d(X1,one))).
# ###
# #cnf(i_0_216, plain, (d(b,X1)|m(a,a)!=two)).
# #
# #cnf(i_0_241, plain, (b=one|m(a,a)!=two)).
# ##
# #cnf(i_0_60, plain, (d(m(X1,X2),m(X1,m(X2,X3))))).
# ##
# #cnf(i_0_223, plain, (d(X1,X2)|~d(m(X3,X1),X2))).
# ##
# #cnf(i_0_229, plain, (d(X1,a)|~d(X1,two))).
# #
# #cnf(i_0_283, plain, (b=one|~d(b,two))).
# ######
# #cnf(i_0_62, plain, (m(X1,m(X2,X3))=m(X3,m(X1,X2)))).
# ####
# #cnf(i_0_286, plain, (d(X1,a)|~d(X2,two)|~d(X1,X2))).
# ####
# #cnf(i_0_97, plain, (b=X1|m(a,a)!=two|m(b,X1)!=one)).
# ##
# #cnf(i_0_113, plain, (X1=b|m(a,a)!=two|m(X1,b)!=one)).
# ###
# #cnf(i_0_284, plain, (d(X1,a)|~d(m(X1,X2),two))).
# ###
# #cnf(i_0_285, plain, (d(X1,a)|~d(m(X2,X1),two))).
# ######
# #cnf(i_0_64, plain, (X1=one|m(X2,m(X3,X1))!=m(X2,X3))).
# ###
# #cnf(i_0_409, plain, (b=one|m(a,a)!=m(two,b))).
# ########
# #cnf(i_0_65, plain, (X1=X2|m(X3,m(X4,X1))!=m(X3,m(X4,X2)))).
# #
# #cnf(i_0_161, plain, (f(two,m(a,a))=m(b,b))).
# #########
# #cnf(i_0_143, plain, (X1=two|m(X1,m(b,b))!=m(a,a))).
# ##
# #cnf(i_0_133, plain, (d(m(b,b),m(a,a)))).
# #####
# #cnf(i_0_476, plain, (d(b,m(a,a)))).
# ####
# #cnf(i_0_327, plain, (X1=one|m(X3,m(X1,X2))!=m(X2,X3))).
# #
# #cnf(i_0_67, plain, (m(two,m(b,m(b,X1)))=m(a,m(a,X1)))).
# ##
# #cnf(i_0_510, plain, (m(b,m(b,X1))!=m(a,m(a,X1)))).
# ##
# #cnf(i_0_552, plain, (m(b,m(X1,b))!=m(a,m(a,X1)))).
# ##
# #cnf(i_0_554, plain, (m(a,m(a,b))!=b|m(a,a)!=two)).
# #####
# #cnf(i_0_69, plain, (m(X1,m(f(X1,X2),X3))=m(X2,X3)|~d(X1,X2))).
# #
# #cnf(i_0_134, plain, (d(X1,m(X2,m(X3,X1))))).
# #######
# #cnf(i_0_407, plain, (X1=one|m(X2,m(X1,X3))!=m(X2,X3))).
# ###
# #cnf(i_0_71, plain, (m(X2,m(X1,X3))=m(X1,m(X2,X3)))).
# ##
# #cnf(i_0_649, plain, (m(X1,m(b,b))!=m(X1,m(a,a)))).
# ##
# #cnf(i_0_809, plain, (m(two,m(a,a))!=m(a,a))).
# #############
# #cnf(i_0_808, plain, (m(X1,m(a,a))!=X1|m(a,a)!=two)).
# ####
# #cnf(i_0_824, plain, (m(a,m(a,X1))!=X1|m(a,a)!=two)).
# #
# #cnf(i_0_75, plain, (d(two,m(X2,X3))|d(two,X1)|~d(two,m(X2,m(X3,X1))))).
# #
# #cnf(i_0_208, plain, (f(m(b,b),m(a,a))=two)).
# ###
# #cnf(i_0_826, plain, (m(a,m(X1,a))!=X1|m(a,a)!=two)).
# #######
# #cnf(i_0_77, plain, (d(two,f(X1,X2))|d(two,X1)|~d(two,X2)|~d(X1,X2))).
# ###############
# #cnf(i_0_830, plain, (f(a,X1)!=m(a,X1)|m(a,a)!=two|~d(a,X1))).
# ########
# #cnf(i_0_226, plain, (d(X1,m(X2,m(X1,X3))))).
# #
# #cnf(i_0_887, plain, (f(a,X1)!=m(X1,a)|m(a,a)!=two|~d(a,X1))).
# ####
# #cnf(i_0_487, plain, (m(X1,m(a,a))!=m(b,m(b,X1)))).
# #####
# #cnf(i_0_83, plain, (m(X1,X2)=one|m(X1,m(X2,X3))!=X3)).
# ####
# #cnf(i_0_951, plain, (m(b,m(b,X1))!=m(a,m(X1,a)))).
# ####
# #cnf(i_0_970, plain, (m(two,b)=one|m(a,a)!=b)).
# ###
# #cnf(i_0_91, plain, (m(b,m(b,X1))=X1|m(a,a)!=two)).
# #####
# #cnf(i_0_991, plain, (m(b,m(X1,b))!=m(a,m(X1,a)))).
# #################
# #cnf(i_0_104, plain, (m(b,b)=X1|m(a,a)!=m(X1,two))).
# ############
# #cnf(i_0_1009, plain, (f(b,X1)=m(b,X1)|m(a,a)!=two)).
# #
# #cnf(i_0_556, plain, (m(X1,m(b,b))!=m(a,m(a,X1)))).
# ##########
# #cnf(i_0_255, plain, (d(m(two,b),m(a,a)))).
# #########
# #cnf(i_0_432, plain, (X1=b|m(two,m(b,X1))!=m(a,a))).
# ######
# #cnf(i_0_814, plain, (m(b,m(X1,b))!=m(X1,m(a,a)))).
# ##########################
# #cnf(i_0_470, plain, (X1=two|m(b,m(b,X1))!=m(a,a))).
# ##
# #cnf(i_0_115, plain, (X1=X2|m(X1,m(X3,X4))!=m(X3,m(X4,X2)))).
# ###########
# #cnf(i_0_122, plain, (m(X1,X2)=X3|m(X1,m(X2,X4))!=m(X4,X3))).
# ##
# #cnf(i_0_995, plain, (m(X1,m(b,b))!=m(a,m(X1,a)))).
# #########
# #cnf(i_0_124, plain, (X1=X2|m(f(X1,X3),X2)!=X3|~d(X1,X3))).
# ###################
# #cnf(i_0_472, plain, (X1=two|m(b,m(X1,b))!=m(a,a))).
# ###
# #cnf(i_0_136, plain, (d(f(X1,X2),X2)|~d(X1,X2))).
# ########
# #cnf(i_0_494, plain, (X1=one|m(X2,m(X3,X1))!=m(X3,X2))).
# ###
# #cnf(i_0_144, plain, (X1=m(X2,X3)|m(X1,X4)!=m(X2,m(X3,X4)))).
# ###########
# #cnf(i_0_146, plain, (X1=X2|m(X1,f(X2,X3))!=X3|~d(X2,X3))).
# #############
# #cnf(i_0_549, plain, (m(b,m(X2,m(b,X1)))!=m(a,m(a,m(X1,X2))))).
# ###
# #cnf(i_0_550, plain, (m(b,m(X1,m(X2,b)))!=m(a,m(a,m(X1,X2))))).
# #########
# #cnf(i_0_650, plain, (m(X1,m(b,m(b,X2)))!=m(X1,m(a,m(a,X2))))).
# ###
# #cnf(i_0_1445, plain, (m(two,m(a,m(a,b)))!=m(a,m(a,b)))).
# ####
# #cnf(i_0_664, plain, (X1=one|m(X1,m(X3,X2))!=m(X2,X3))).
# #
# #cnf(i_0_162, plain, (f(m(X1,X2),m(X1,m(X2,X3)))=X3)).
# ####
# #cnf(i_0_1501, plain, (m(two,m(a,m(a,X1)))!=m(a,m(a,X1)))).
# ##
# #cnf(i_0_1602, plain, (m(two,X1)!=X1|~d(m(a,a),X1))).
# ######
# #cnf(i_0_507, plain, (d(two,m(a,m(a,X1))))).
# ###
# #cnf(i_0_1609, plain, (m(two,a)!=a|~d(m(a,a),two))).
# #######
# #cnf(i_0_170, plain, (m(X1,m(X2,m(X3,f(m(X1,m(X2,X3)),X4))))=X4|~d(m(X1,m(X2,X3)),X4))).
# ##
# #cnf(i_0_1592, plain, (m(two,m(a,X1))!=m(a,X1)|~d(a,X1))).
# #
# #cnf(i_0_1800, plain, (m(two,a)!=a|~d(a,one))).
# #
# #cnf(i_0_1801, plain, (m(two,m(X1,a))!=m(X1,a)|~d(a,X1))).
# #########
# #cnf(i_0_1805, plain, (m(X1,m(two,a))!=m(a,X1)|~d(a,X1))).
# ####
# #cnf(i_0_1811, plain, (m(X1,m(two,a))!=m(X1,a)|~d(a,X1))).
# #####
# #cnf(i_0_172, plain, (X1=X2|m(X1,m(X3,f(m(X2,X3),X4)))!=X4|~d(m(X2,X3),X4))).
# #########
# #cnf(i_0_1134, plain, (X1=b|m(two,m(X1,b))!=m(a,a))).
# ##
# #cnf(i_0_174, plain, (m(X1,m(X2,m(f(m(X1,X2),X3),X4)))=m(X3,X4)|~d(m(X1,X2),X3))).
# ##
# #cnf(i_0_1819, plain, (m(two,m(X1,a))!=m(a,X1)|~d(a,X1))).
# ####
# #cnf(i_0_1824, plain, (m(two,m(a,X1))!=m(X1,a)|~d(a,X1))).
# ###
# #cnf(i_0_1138, plain, (X1=b|m(X1,m(two,b))!=m(a,a))).
# ##
# #cnf(i_0_175, plain, (m(X2,f(m(X1,X2),X3))=f(X1,X3)|~d(m(X1,X2),X3))).
# #
# #cnf(i_0_2139, plain, (f(b,m(a,a))=m(two,b))).
# ##########
# #cnf(i_0_176, plain, (X1=one|m(X2,f(m(X1,X2),X3))!=X3|~d(m(X1,X2),X3))).
# ###########
# #cnf(i_0_177, plain, (m(X1,m(X2,m(f(m(X1,X2),X3),f(X3,X4))))=X4|~d(m(X1,X2),X3)|~d(X3,X4))).
# #####
# #cnf(i_0_2201, plain, (m(two,X2)!=X2|~d(m(a,a),X1)|~d(X1,X2))).
# ######
# #cnf(i_0_178, plain, (d(two,m(X1,f(m(X2,X1),X3)))|d(two,X2)|~d(m(X2,X1),X3)|~d(two,X3))).
# ####
# #cnf(i_0_1594, plain, (m(two,m(a,X2))!=m(a,X2)|~d(m(a,X1),X2))).
# ##
# #cnf(i_0_1657, plain, (m(two,X2)!=X2|~d(m(a,m(a,X1)),X2))).
# ####
# #cnf(i_0_1271, plain, (m(two,b)=X1|m(b,X1)!=m(a,a))).
# #
# #cnf(i_0_180, plain, (d(m(X1,f(m(X2,X1),X3)),X3)|~d(m(X2,X1),X3))).
# ##
# #cnf(i_0_2401, plain, (m(two,X1)!=X1|~d(m(a,X2),X1)|~d(a,X2))).
# #
# #cnf(i_0_2498, plain, (m(two,X1)!=X1|~d(a,one))).
# ##
# #cnf(i_0_2499, plain, (m(two,X1)!=X1|~d(m(X2,a),X1)|~d(a,X2))).
# ######
# #cnf(i_0_181, plain, (X1=X2|m(X3,m(f(m(X1,X3),X4),X2))!=X4|~d(m(X1,X3),X4))).
# ##############
# #cnf(i_0_1894, plain, (m(two,m(X1,X2))!=m(X1,X2)|~d(m(a,a),X1))).
# #
# #cnf(i_0_2346, plain, (m(two,X1)!=X1|~d(m(X2,m(a,a)),X1))).
# #########
# #cnf(i_0_2391, plain, (m(two,m(a,X1))!=m(a,X1)|~d(m(X2,a),X1))).
# ###
# #cnf(i_0_2412, plain, (m(two,X1)!=X1|~d(m(a,m(X2,a)),X1))).
# ##################
# #cnf(i_0_909, plain, (d(two,m(X1,m(a,a))))).
# #####
# #cnf(i_0_2422, plain, (m(two,a)!=a|~d(m(a,m(a,X1)),two))).
# ######
# #cnf(i_0_924, plain, (d(b,m(a,m(a,X1))))).
# ##########
# #cnf(i_0_190, plain, (m(X1,m(f(X1,X2),f(X2,X3)))=X3|~d(X2,X3)|~d(X1,X2))).
# #
# #cnf(i_0_1137, plain, (f(m(two,b),m(a,a))=b)).
# #####
# #cnf(i_0_2596, plain, (m(two,a)!=a|~d(m(X1,m(a,a)),two))).
# ################
# #cnf(i_0_192, plain, (m(X1,m(X2,f(m(X2,X1),X3)))=X3|~d(m(X2,X1),X3))).
# ############
# #cnf(i_0_1627, plain, (d(two,m(a,m(X1,a))))).
# ##
# #cnf(i_0_1792, plain, (m(two,X1)!=X1|~d(a,f(a,X1))|~d(a,X1))).
# ##########
# #cnf(i_0_2342, plain, (m(two,X1)!=X1|~d(m(a,a),two)|~d(a,X1))).
# #
# #cnf(i_0_2501, plain, (m(two,a)!=a|~d(m(a,X1),two)|~d(a,X1))).
# ##
# #cnf(i_0_2513, plain, (m(two,a)!=a|~d(m(X1,a),two)|~d(a,X1))).
# #########
# #cnf(i_0_2657, plain, (m(two,a)!=a|~d(m(a,a),X1)|~d(X1,two))).
# ###
# #cnf(i_0_2623, plain, (m(two,a)!=a|~d(m(a,m(X1,a)),two))).
# ###
# #cnf(i_0_217, plain, (d(two,X1)|~d(m(a,a),X1))).
# ##
# #cnf(i_0_169, plain, (m(X1,f(m(two,X1),m(a,a)))=m(b,b)|~d(m(two,X1),m(a,a)))).
# ########
# #cnf(i_0_333, plain, (m(X1,X2)=one|m(X2,m(X3,X1))!=X3)).
# ###
# #cnf(i_0_179, plain, (m(X1,f(m(X2,X1),X2))=one|~d(m(X2,X1),X2))).
# #
# #cnf(i_0_3209, plain, (m(X1,X2)=one|m(X2,X1)!=one)).
# #
# #cnf(i_0_3277, plain, (m(two,a)!=a|~d(m(X1,a),X1))).
# ##
# #cnf(i_0_3422, plain, (m(two,a)!=a|~d(m(a,X1),X1))).
# #######
# #cnf(i_0_183, plain, (m(X1,f(m(X2,X1),m(X2,X3)))=X3|~d(m(X2,X1),m(X2,X3)))).
# ##########
# #cnf(i_0_696, plain, (m(X1,X2)=one|m(X1,m(X3,X2))!=X3)).
# ###
# #cnf(i_0_3282, plain, (m(two,X1)!=X1|~d(m(X2,a),X2)|~d(a,X1))).
# ##
# #cnf(i_0_3666, plain, (m(two,X1)!=X1|~d(m(a,X2),X2)|~d(a,X1))).
# #######
# #cnf(i_0_185, plain, (m(X2,f(m(X3,X2),m(X1,X3)))=X1|~d(m(X3,X2),m(X1,X3)))).
# #############
# #cnf(i_0_3281, plain, (m(two,m(a,X1))!=m(a,X1)|~d(m(X2,a),X2))).
# ##
# #cnf(i_0_3857, plain, (m(two,m(a,X1))!=m(a,X1)|~d(m(a,X2),X2))).
# ######
# #cnf(i_0_979, plain, (m(X1,X2)=one|m(X2,m(X1,X3))!=X3)).
# #
# #cnf(i_0_209, plain, (f(X1,m(X2,m(X3,X1)))=m(X2,X3))).
# ###########
# #cnf(i_0_211, plain, (f(f(X1,X2),X2)=X1|~d(X1,X2))).
# ##
# #cnf(i_0_3428, plain, (m(two,a)!=a|~d(X1,f(a,X1))|~d(a,X1))).
# #######
# #cnf(i_0_4028, plain, (m(two,a)!=a|m(a,a)!=two|~d(a,b))).
# ##
# #cnf(i_0_212, plain, (f(m(X1,f(m(X2,X1),X3)),X3)=X2|~d(m(X2,X1),X3))).
# ###########
# #cnf(i_0_218, plain, (d(m(X1,X2),X3)|~d(m(X1,m(X2,X4)),X3))).
# #
# #cnf(i_0_3955, plain, (f(b,X1)=m(X1,b)|m(a,a)!=two)).
# ##########
# #cnf(i_0_221, plain, (d(X1,X2)|~d(m(X1,X3),X4)|~d(X4,X2))).
# #####
# #cnf(i_0_2579, plain, (m(two,m(a,X1))!=m(a,X1)|~d(m(a,a),two))).
# ##
# #cnf(i_0_2680, plain, (d(b,X1)|~d(m(a,a),X1))).
# ####
# #cnf(i_0_230, plain, (d(X1,m(a,a))|~d(X1,two))).
# ###########
# #cnf(i_0_232, plain, (d(X1,m(X2,X3))|~d(X1,X2))).
# ###
# #cnf(i_0_4255, plain, (m(two,a)!=a|~d(m(a,m(X1,X2)),X1))).
# ##
# #cnf(i_0_4300, plain, (m(two,a)!=a|~d(m(a,X1),one))).
# ###
# #cnf(i_0_4353, plain, (m(two,a)!=a|~d(m(X1,a),one))).
# ###
# #cnf(i_0_233, plain, (d(X1,m(X2,X3))|~d(X1,X3))).
# ##
# #cnf(i_0_4340, plain, (m(two,a)!=a|~d(X1,one)|~d(a,X1))).
# #########
# #cnf(i_0_240, plain, (d(X1,X2)|m(a,a)!=two|~d(X1,b))).
# ##
# #cnf(i_0_4305, plain, (m(two,a)!=a|~d(m(X2,X1),X2)|~d(a,X1))).
# #########
# #cnf(i_0_244, plain, (d(X1,m(X2,m(X3,X4)))|~d(X1,m(X2,X3)))).
# ##
# #cnf(i_0_4447, plain, (m(two,a)!=a|~d(m(X2,X1),X1)|~d(a,X2))).
# #####
# #cnf(i_0_3242, plain, (m(X1,X2)=one|m(X3,m(X2,X1))!=X3)).
# ####
# #cnf(i_0_246, plain, (d(m(X1,b),X1)|m(a,a)!=two)).
# ###########
# #cnf(i_0_247, plain, (d(m(X1,two),m(X1,m(a,a))))).
# ##########
# #cnf(i_0_3276, plain, (d(b,a)|~d(m(X1,a),X1))).
# #
# #cnf(i_0_248, plain, (d(m(X1,m(X2,X3)),m(X1,m(X2,m(X3,X4)))))).
# #
# #cnf(i_0_4650, plain, (d(b,a)|~d(a,one))).
# #
# #cnf(i_0_4306, plain, (m(two,a)!=a|~d(m(a,X2),X1)|~d(X1,X2))).
# #####
# #cnf(i_0_4771, plain, (b=one|~d(a,one))).
# #
# #cnf(i_0_3302, plain, (d(X1,one)|~d(m(X2,X1),X2))).
# ###
# #cnf(i_0_250, plain, (d(m(X1,X2),m(X1,X3))|~d(X2,X3))).
# #
# #cnf(i_0_2678, plain, (d(b,m(a,m(X1,a))))).
# ######
# #cnf(i_0_3313, plain, (d(X1,a)|~d(m(X2,X1),X2))).
# ####
# #cnf(i_0_251, plain, (d(m(X1,X2),m(X1,X4))|~d(m(X2,X3),X4))).
# ####
# #cnf(i_0_4324, plain, (m(two,a)!=a|~d(m(X1,a),X2)|~d(X2,X1))).
# ###
# #cnf(i_0_3327, plain, (d(X1,X2)|~d(m(X3,X1),X3))).
# ####
# #cnf(i_0_253, plain, (d(m(X1,X2),m(X1,m(X3,X2))))).
# #
# #cnf(i_0_2684, plain, (d(b,m(X1,m(a,a))))).
# ##############
# #cnf(i_0_4260, plain, (m(two,a)!=a|~d(m(X1,m(X2,a)),X1))).
# ##########
# #cnf(i_0_4319, plain, (m(two,a)!=a|~d(m(a,m(X2,X1)),X1))).
# ########
# #cnf(i_0_258, plain, (d(m(X1,X2),m(X2,m(X3,X1))))).
# ####
# #cnf(i_0_4328, plain, (m(two,a)!=a|~d(m(X2,m(a,X1)),X1))).
# #########
# #cnf(i_0_4329, plain, (m(two,a)!=a|~d(m(X1,m(a,X2)),X1))).
# #####################
# #cnf(i_0_5242, plain, (d(m(X1,X2),m(X2,X1)))).
# #######
# #cnf(i_0_4209, plain, (d(b,a)|~d(m(a,a),two))).
# ###
# #cnf(i_0_265, plain, (d(X2,m(X1,m(f(X1,X2),X3)))|~d(X1,X2))).
# #####
# #cnf(i_0_4341, plain, (m(two,a)!=a|~d(X2,one)|~d(a,X1)|~d(X1,X2))).
# ######
# #cnf(i_0_266, plain, (d(X3,m(X1,m(X2,m(f(m(X1,X2),X3),X4))))|~d(m(X1,X2),X3))).
# #
# #cnf(i_0_354, plain, (m(b,m(X1,b))=X1|m(a,a)!=two)).
# ##########
# #cnf(i_0_268, plain, (d(m(X2,X1),m(X1,m(X2,X3))))).
# ####
# #cnf(i_0_4363, plain, (m(two,m(X1,X2))!=m(X1,X2)|~d(m(a,a),X2))).
# #########
# #cnf(i_0_4378, plain, (m(two,a)!=a|~d(m(X1,m(X2,a)),X2))).
# #########
# #cnf(i_0_271, plain, (d(m(b,b),X1)|~d(m(a,a),X1))).
# ###########
# #cnf(i_0_272, plain, (d(X1,X2)|~d(m(X3,m(X4,X1)),X2))).
# ###########
# #cnf(i_0_274, plain, (d(f(X1,X2),X3)|~d(X2,X3)|~d(X1,X2))).
# #######
# #cnf(i_0_4651, plain, (d(b,a)|~d(m(a,X1),X1))).
# ####
# #cnf(i_0_275, plain, (d(m(X1,f(m(X2,X1),X3)),X4)|~d(m(X2,X1),X3)|~d(X3,X4))).
# #
# #cnf(i_0_483, plain, (d(X1,m(a,a))|~d(X1,b))).
# ######
# #cnf(i_0_5043, plain, (d(X1,X2)|~d(m(X1,X3),X3))).
# ####
# #cnf(i_0_288, plain, (m(b,b)=m(X1,X2)|m(X1,m(X2,two))!=m(a,a))).
# #########
# #cnf(i_0_5045, plain, (d(X1,X2)|~d(m(a,X1),two))).
# #############
# #cnf(i_0_291, plain, (d(m(X1,X2),m(X1,m(X3,m(X4,X2)))))).
# #########
# #cnf(i_0_5950, plain, (d(b,X1)|~d(m(a,a),b))).
# ####################################
# #cnf(i_0_1017, plain, (d(m(b,X1),X1)|m(a,a)!=two)).
# ##########
# #cnf(i_0_299, plain, (m(X1,m(X2,m(X3,f(m(X2,m(X3,X1)),X4))))=X4|~d(m(X2,m(X3,X1)),X4))).
# ###########
# #cnf(i_0_300, plain, (d(m(X2,m(X3,X1)),m(X1,m(X2,m(X3,X4)))))).
# #
# #cnf(i_0_1018, plain, (f(m(b,X1),X1)=b|m(a,a)!=two)).
# #######
# #cnf(i_0_6207, plain, (d(X1,X2)|~d(m(X1,a),two))).
# ###############
# #cnf(i_0_1035, plain, (d(m(b,b),X1)|m(a,a)!=two)).
# #####
# #cnf(i_0_4348, plain, (m(two,a)!=a|~d(m(X2,m(a,X1)),one))).
# #################
# #cnf(i_0_1036, plain, (m(X1,m(b,b))=X1|m(a,a)!=two)).
# ###############################################
# #cnf(i_0_4342, plain, (m(two,a)!=a|~d(m(X1,X2),one)|~d(a,X1))).
# ########
# #cnf(i_0_6944, plain, (m(b,b)=b|m(a,a)!=two)).
# #
# #cnf(i_0_7315, plain, (m(a,a)!=b|m(a,a)!=two)).
# #######################
# #cnf(i_0_4343, plain, (m(two,a)!=a|~d(m(a,X1),X2)|~d(X2,one))).
# ######
# #cnf(i_0_7269, plain, (m(X1,b)=X1|m(a,a)!=two)).
# ######
# #cnf(i_0_4344, plain, (m(two,a)!=a|~d(m(X1,a),X2)|~d(X2,one))).
# ###########
# #cnf(i_0_6912, plain, (m(two,a)!=a|~d(m(X1,X2),one)|~d(a,X2))).
# #######
# #cnf(i_0_317, plain, (m(b,b)=m(X1,X2)|m(X2,m(two,X1))!=m(a,a))).
# ######
# #cnf(i_0_4350, plain, (m(two,a)!=a|~d(m(X1,m(X2,a)),one))).
# ################
# #cnf(i_0_320, plain, (d(m(X1,X2),m(X1,m(X4,m(X2,X3)))))).
# ##########
# #cnf(i_0_4770, plain, (d(X1,a)|~d(a,one)|~d(X1,b))).
# ############
# #cnf(i_0_322, plain, (X1=X2|m(X1,m(X3,X4))!=m(X4,m(X2,X3)))).
# ################################
# #cnf(i_0_534, plain, (b=one|m(a,m(a,X1))!=m(two,m(b,X1)))).
# #
# #cnf(i_0_326, plain, (f(X1,m(X3,m(X1,X2)))=m(X2,X3))).
# ###########
# #cnf(i_0_328, plain, (m(X1,m(X2,m(X3,f(m(X3,m(X1,X2)),X4))))=X4|~d(m(X3,m(X1,X2)),X4))).
# ###########
# #cnf(i_0_329, plain, (d(m(X3,m(X1,X2)),m(X1,m(X2,m(X3,X4)))))).
# #########################
# #cnf(i_0_4414, plain, (m(two,a)!=a|~d(a,f(X1,one))|~d(X1,one))).
# #####
# #cnf(i_0_1396, plain, (X1=m(two,b)|m(X1,b)!=m(a,a))).
# ###
# #cnf(i_0_332, plain, (d(two,m(X1,X2))|d(two,X3)|~d(two,m(X2,m(X3,X1))))).
# ######
# #cnf(i_0_6152, plain, (m(two,a)!=a|~d(m(a,m(a,a)),b))).
# ################
# #cnf(i_0_335, plain, (f(m(X1,X2),m(X2,m(X3,X1)))=X3)).
# ###
# #cnf(i_0_5897, plain, (m(two,m(X1,a))!=m(X1,a)|~d(m(a,a),two))).
# #######
# #cnf(i_0_7736, plain, (b=one|m(a,m(X1,a))!=m(two,m(b,X1)))).
# #
# #cnf(i_0_336, plain, (X1=X2|m(X4,m(X1,X3))!=m(X3,m(X4,X2)))).
# ####
# #cnf(i_0_1600, plain, (m(two,m(a,m(X1,a)))!=m(a,m(X1,a)))).
# ########
# #cnf(i_0_8417, plain, (f(m(X1,X2),m(X2,X1))=one)).
# ##
# #cnf(i_0_1603, plain, (m(two,m(X1,m(a,a)))!=m(X1,m(a,a)))).
# ########
# #cnf(i_0_338, plain, (d(X1,X2)|~d(m(X4,m(X1,X3)),X2))).
# ###########
# #cnf(i_0_339, plain, (m(X1,X2)=X3|m(X2,m(X4,X1))!=m(X4,X3))).
# ###########
# #cnf(i_0_340, plain, (d(m(X1,X2),X3)|~d(m(X2,m(X4,X1)),X3))).
# ######################
# #cnf(i_0_342, plain, (X1=m(X2,X3)|m(X1,X4)!=m(X3,m(X4,X2)))).
# ############################################
# #cnf(i_0_349, plain, (m(X1,m(f(X1,X2),X3))=m(X3,X2)|~d(X1,X2))).
# ###########
# #cnf(i_0_350, plain, (m(X1,m(X2,m(f(m(X1,X2),X3),X4)))=m(X4,X3)|~d(m(X1,X2),X3))).
# #########
# #cnf(i_0_421, plain, (X1=b|m(X2,m(b,X1))!=X2|m(a,a)!=two)).
# ##
# #cnf(i_0_352, plain, (m(X1,m(X2,X3))=m(X3,m(X2,X1)))).
# #######################################################
# #cnf(i_0_359, plain, (m(X3,m(X2,m(f(m(X2,X3),X4),X1)))=m(X1,X4)|~d(m(X2,X3),X4))).
# #################################
# #cnf(i_0_368, plain, (m(X1,X2)=b|m(X2,m(b,X1))!=one|m(a,a)!=two)).
# ###########
# #cnf(i_0_369, plain, (m(X1,X2)=b|m(X1,m(X2,b))!=one|m(a,a)!=two)).
# ######################
# #cnf(i_0_367, plain, (m(X1,f(m(b,X1),one))=b|m(a,a)!=two|~d(m(b,X1),one))).
# #
# #cnf(i_0_1339, plain, (d(f(X1,one),X2)|~d(X1,one))).
# ##########
# #cnf(i_0_379, plain, (d(m(X1,X2),a)|~d(m(X1,m(X2,X3)),two))).
# ###########
# #cnf(i_0_382, plain, (d(X1,a)|~d(m(X1,X2),X3)|~d(X3,two))).
# #
# #cnf(i_0_1548, plain, (f(m(X1,b),X1)=b|m(a,a)!=two)).
# ####
# #cnf(i_0_8729, plain, (m(X1,m(two,m(a,a)))!=m(X1,m(a,a)))).
# ######
# #cnf(i_0_383, plain, (d(X1,a)|~d(m(X3,m(X1,X2)),two))).
# #
# #cnf(i_0_1564, plain, (f(m(b,b),X1)=X1|m(a,a)!=two)).
# ##########
# #cnf(i_0_384, plain, (d(X1,a)|~d(m(X2,m(X3,X1)),two))).
# ###########
# #cnf(i_0_389, plain, (d(m(b,b),a)|~d(m(a,a),two))).
# #
# #cnf(i_0_1619, plain, (d(two,m(a,X1))|~d(a,X1))).
# ###
# #cnf(i_0_11356, plain, (m(two,m(a,m(a,X1)))!=m(X1,m(a,a)))).
# ######
# #cnf(i_0_9771, plain, (m(b,X1)=b|m(a,a)!=two|m(X2,X1)!=X2)).
# ########
# #cnf(i_0_9772, plain, (m(X1,b)=b|m(a,a)!=two|m(X2,X1)!=X2)).
# ####
# #cnf(i_0_392, plain, (d(f(X1,X2),a)|~d(X2,two)|~d(X1,X2))).
# ####
# #cnf(i_0_11606, plain, (m(two,m(a,m(X1,a)))!=m(X1,m(a,a)))).
# #######
# #cnf(i_0_393, plain, (d(m(X1,f(m(X2,X1),X3)),a)|~d(m(X2,X1),X3)|~d(X3,two))).
# ###########
# #cnf(i_0_394, plain, (d(m(X1,X2),a)|~d(m(X2,m(X3,X1)),two))).
# ######################
# #cnf(i_0_400, plain, (m(b,b)=one|m(X1,m(a,a))!=m(X1,two))).
# ##
# #cnf(i_0_2403, plain, (m(two,X1)!=X1|~d(m(a,X3),X1)|~d(m(a,X2),X3))).
# ##
# #cnf(i_0_11922, plain, (m(two,m(X1,a))!=m(X1,a)|~d(m(a,X2),X1))).
# #######
# #cnf(i_0_401, plain, (X1=one|m(X2,m(X3,m(X4,X1)))!=m(X2,m(X3,X4)))).
# ##
# #cnf(i_0_11931, plain, (m(two,m(X1,a))!=m(X1,a)|~d(m(X2,a),X2))).
# ##
# #cnf(i_0_11953, plain, (m(two,m(X1,a))!=m(X1,a)|~d(m(X2,a),X1))).
# #######
# #cnf(i_0_403, plain, (f(X1,X2)=one|m(X3,X2)!=m(X3,X1)|~d(X1,X2))).
# ####
# #cnf(i_0_12073, plain, (m(two,m(X1,a))!=m(X1,a)|~d(m(a,X2),X2))).
# ######
# #cnf(i_0_11660, plain, (m(b,X1)=b|m(a,a)!=two|m(X1,X2)!=X2)).
# #
# #cnf(i_0_404, plain, (m(X1,f(m(X2,X1),X3))=one|m(X4,X3)!=m(X4,X2)|~d(m(X2,X1),X3))).
# ##########
# #cnf(i_0_12177, plain, (f(X1,one)=one|m(X2,X1)!=X2|~d(X1,one))).
# #
# #cnf(i_0_405, plain, (m(X1,X2)=one|m(X3,m(X2,m(X4,X1)))!=m(X3,X4))).
# #####
# #cnf(i_0_11894, plain, (m(two,X1)!=X1|~d(m(a,X2),one)|~d(a,X1))).
# ######
# #cnf(i_0_406, plain, (m(X1,X2)=one|m(X3,m(X1,m(X2,X4)))!=m(X3,X4))).
# ###
# #cnf(i_0_12532, plain, (m(two,X1)!=X1|~d(X2,one)|~d(a,X1)|~d(a,X2))).
# ##########
# #cnf(i_0_12553, plain, (m(two,X1)!=X1|~d(m(X2,a),one)|~d(a,X1))).
# #########
# #cnf(i_0_422, plain, (X1=m(b,b)|m(X2,m(two,X1))!=m(X2,m(a,a)))).
# #
# #cnf(i_0_2667, plain, (d(b,m(a,X1))|~d(a,X1))).
# #######
# #cnf(i_0_12414, plain, (f(X1,one)=one|m(X1,X2)!=X2|~d(X1,one))).
# ###
# #cnf(i_0_423, plain, (X1=X2|m(X3,m(X4,m(X5,X1)))!=m(X3,m(X4,m(X5,X2))))).
# ###
# #cnf(i_0_2880, plain, (m(two,X1)!=X1|~d(m(a,X3),X1)|~d(m(X2,a),X3))).
# ###
# #cnf(i_0_4296, plain, (m(two,a)!=a|m(a,a)!=two|~d(m(a,X1),b))).
# #####
# #cnf(i_0_425, plain, (X1=f(X2,X3)|m(X4,m(X2,X1))!=m(X4,X3)|~d(X2,X3))).
# ###
# #cnf(i_0_4857, plain, (m(two,m(X1,X2))!=m(X1,X2)|~d(a,X1)|~d(a,X2))).
# #####
# #cnf(i_0_13213, plain, (m(b,b)!=two|m(a,a)!=two|~d(a,b))).
# ##
# #cnf(i_0_12021, plain, (b=one|m(X1,m(a,a))!=m(X1,m(two,b)))).
# #
# #cnf(i_0_426, plain, (X1=m(X2,f(m(X3,X2),X4))|m(X5,m(X3,X1))!=m(X5,X4)|~d(m(X3,X2),X4))).
# ##
# #cnf(i_0_11895, plain, (m(two,X1)!=X1|~d(m(X2,a),X1)|~d(m(a,X3),X2))).
# #########
# #cnf(i_0_427, plain, (X1=m(X2,X3)|m(X4,m(X5,X1))!=m(X4,m(X3,m(X5,X2))))).
# ###
# #cnf(i_0_12994, plain, (m(two,X1)!=X1|~d(m(X2,a),X1)|~d(m(X3,a),X2))).
# ###
# #cnf(i_0_5948, plain, (m(two,a)!=a|~d(m(a,a),b))).
# ####
# #cnf(i_0_1006, plain, (X1=b|m(X1,m(b,X2))!=X2|m(a,a)!=two)).
# #
# #cnf(i_0_428, plain, (X1=m(X2,X3)|m(X4,m(X5,X1))!=m(X4,m(X2,m(X3,X5))))).
# ###########
# #cnf(i_0_430, plain, (X1=X2|m(X3,m(X4,X1))!=m(X3,m(X2,X4)))).
# ##
# #cnf(i_0_13226, plain, (m(X2,m(two,X1))!=m(X1,X2)|~d(a,X1)|~d(a,X2))).
# #
# #cnf(i_0_13939, plain, (m(X1,two)!=X1|~d(a,one))).
# ###
# #cnf(i_0_6889, plain, (m(two,a)!=a|m(a,a)!=two|~d(a,m(b,b)))).
# #########
# #cnf(i_0_13227, plain, (m(X1,m(two,X2))!=m(X1,X2)|~d(a,X1)|~d(a,X2))).
# #########
# #cnf(i_0_13228, plain, (m(X2,m(X1,two))!=m(X1,X2)|~d(a,X1)|~d(a,X2))).
# #######
# #cnf(i_0_1180, plain, (X1=b|m(X1,m(X2,b))!=X2|m(a,a)!=two)).
# ####
# #cnf(i_0_13229, plain, (m(X1,m(X2,two))!=m(X1,X2)|~d(a,X1)|~d(a,X2))).
# ######
# #cnf(i_0_1225, plain, (b=X1|m(b,m(X2,X1))!=X2|m(a,a)!=two)).
# ############
# #cnf(i_0_1270, plain, (m(b,b)=X1|m(a,a)!=two|m(X2,X1)!=X2)).
# ##################
# #cnf(i_0_13959, plain, (m(two,m(X1,X2))!=m(X2,X1)|~d(a,X2)|~d(a,X1))).
# ###############
# #cnf(i_0_1395, plain, (X1=m(b,b)|m(a,a)!=two|m(X1,X2)!=X2)).
# ###############################
# #cnf(i_0_2178, plain, (X1=one|f(X1,X3)!=X3|~d(m(X1,X2),X3))).
# ######
# #cnf(i_0_14309, plain, (f(two,X1)!=X1|~d(m(a,a),X1))).
# ###
# #cnf(i_0_14310, plain, (f(two,X1)!=X1|~d(m(a,m(a,X2)),X1))).
# ########
# #cnf(i_0_14387, plain, (f(two,X1)!=X1|~d(m(X2,a),X2))).
# #
# #cnf(i_0_14451, plain, (f(two,X1)!=X1|~d(a,one))).
# #####
# #cnf(i_0_14454, plain, (f(two,X1)!=X1|~d(m(a,a),two))).
# ##
# #cnf(i_0_14452, plain, (f(two,X1)!=X1|~d(m(a,X2),X2))).
# ########
# #cnf(i_0_14468, plain, (m(two,X1)!=X1|~d(m(a,a),two))).
# #
# #cnf(i_0_14469, plain, (m(X1,two)!=X1|~d(m(a,a),two))).
# #########
# #cnf(i_0_14426, plain, (f(two,a)!=a|~d(m(a,m(a,X1)),two))).
# #
# #cnf(i_0_14455, plain, (f(two,X1)!=X1|~d(m(a,m(a,a)),two))).
# #
# #cnf(i_0_14456, plain, (f(two,X1)!=X1|~d(m(a,m(a,a)),b))).
# #####
# #cnf(i_0_14460, plain, (m(X1,m(X2,two))!=m(X1,X2)|~d(a,one))).
# ###
# #cnf(i_0_14461, plain, (m(X1,m(two,X2))!=m(X2,X1)|~d(a,one))).
# ###
# #cnf(i_0_14529, plain, (m(b,b)!=two|m(a,a)!=two|~d(a,one))).
# ####
# #cnf(i_0_3032, plain, (d(two,m(X1,a))|~d(a,X1))).
# #
# #cnf(i_0_14527, plain, (m(X1,m(two,X2))!=m(X1,X2)|~d(a,one))).
# ##############
# #cnf(i_0_14537, plain, (m(X2,m(X1,two))!=m(X1,X2)|~d(a,one))).
# ########
# #cnf(i_0_14538, plain, (m(two,m(X2,X1))!=m(X1,X2)|~d(a,one))).
# ################
# #cnf(i_0_14354, plain, (b=one|f(b,a)!=a|~d(m(a,a),two))).
# #
# #cnf(i_0_14370, plain, (b=one|f(b,X1)!=X1|~d(m(a,a),X1))).
# #########################
# #cnf(i_0_468, plain, (m(X1,X2)=two|m(X1,m(X2,m(b,b)))!=m(a,a))).
# ###########
# #cnf(i_0_475, plain, (d(X1,m(a,a))|~d(X1,m(b,b)))).
# ###########
# #cnf(i_0_488, plain, (m(X1,X2)=one|m(X3,m(X1,m(X2,X4)))!=m(X4,X3))).
# ####
# #cnf(i_0_14458, plain, (f(two,X1)!=X1|~d(m(X2,m(X3,a)),X2))).
# ##
# #cnf(i_0_14877, plain, (f(two,X1)!=X1|~d(m(X2,a),one))).
# ##
# #cnf(i_0_14896, plain, (f(two,X1)!=X1|~d(m(a,X2),one))).
# ###
# #cnf(i_0_489, plain, (X1=one|m(f(X1,X3),X2)!=m(X2,X3)|~d(X1,X3))).
# ######
# #cnf(i_0_14875, plain, (m(a,a)!=two|f(two,X1)!=X1|~d(a,b))).
# ###
# #cnf(i_0_14904, plain, (f(two,X1)!=X1|~d(X2,one)|~d(a,X2))).
# ##
# #cnf(i_0_490, plain, (X1=one|m(X3,m(f(m(X1,X3),X4),X2))!=m(X2,X4)|~d(m(X1,X3),X4))).
# ##
# #cnf(i_0_14986, plain, (m(two,X1)!=X1|~d(X2,one)|~d(a,X2))).
# ##
# #cnf(i_0_14987, plain, (m(X1,two)!=X1|~d(X2,one)|~d(a,X2))).
# ###
# #cnf(i_0_14980, plain, (m(a,a)!=two|m(two,X1)!=X1|~d(a,b))).
# #
# #cnf(i_0_14981, plain, (m(a,a)!=two|m(X1,two)!=X1|~d(a,b))).
# ###
# #cnf(i_0_491, plain, (X1=one|m(X2,m(X4,m(X1,X3)))!=m(X3,m(X4,X2)))).
# ###########
# #cnf(i_0_492, plain, (X1=one|m(X2,m(X3,m(X4,X1)))!=m(X3,m(X4,X2)))).
# ##
# #cnf(i_0_14880, plain, (f(two,X1)!=X1|~d(m(X3,a),X2)|~d(X2,X3))).
# #########
# #cnf(i_0_497, plain, (X1=one|m(X2,m(X3,m(X1,X4)))!=m(X4,m(X2,X3)))).
# ##
# #cnf(i_0_15311, plain, (f(two,X1)!=X1|~d(m(X2,X3),X2)|~d(a,X3))).
# ###
# #cnf(i_0_15431, plain, (f(two,X1)!=X1|~d(m(X3,X2),X2)|~d(a,X3))).
# ######
# #cnf(i_0_501, plain, (X1=one|m(X2,f(m(X2,X1),X3))!=X3|~d(m(X2,X1),X3))).
# ###########
# #cnf(i_0_504, plain, (d(m(X1,two),m(X1,m(a,m(a,X2)))))).
# ###########
# #cnf(i_0_505, plain, (m(b,m(b,m(X2,m(X1,two))))=m(X1,m(a,m(a,X2))))).
# ##
# #cnf(i_0_14881, plain, (f(two,X1)!=X1|~d(m(a,X3),X2)|~d(X2,X3))).
# #########
# #cnf(i_0_506, plain, (X1=two|m(X1,m(b,m(b,X2)))!=m(a,m(a,X2)))).
# ###########
# #cnf(i_0_509, plain, (f(two,m(a,m(a,X1)))=m(b,m(b,X1)))).
# ######
# #cnf(i_0_14479, plain, (m(a,a)!=two|f(two,X1)!=X1|~d(a,m(b,b)))).
# #######
# #cnf(i_0_14459, plain, (f(two,X1)!=X1|~d(m(X2,m(X3,a)),X3))).
# ###########
# #cnf(i_0_14505, plain, (f(two,X1)!=X1|~d(m(a,m(X2,X3)),X2))).
# ########
# #cnf(i_0_15440, plain, (f(two,X1)!=X1|~d(m(a,a),b))).
# ####
# #cnf(i_0_16226, plain, (m(two,X1)!=X1|~d(m(a,a),b))).
# #
# #cnf(i_0_16227, plain, (m(X1,two)!=X1|~d(m(a,a),b))).
# #######
# #cnf(i_0_516, plain, (m(b,m(b,X1))=one|m(a,m(a,X1))!=two)).
# ##
# #cnf(i_0_16406, plain, (m(a,m(a,a))!=two|f(two,X1)!=X1)).
# ####
# #cnf(i_0_16403, plain, (m(a,m(a,a))!=two|m(two,a)!=a)).
# #####
# #cnf(i_0_517, plain, (d(m(b,m(b,X1)),m(a,m(a,X1))))).
# ####
# #cnf(i_0_14506, plain, (f(two,X1)!=X1|~d(m(a,m(X2,X3)),X3))).
# ##
# #cnf(i_0_16621, plain, (m(a,m(a,a))!=two|m(two,X1)!=X1)).
# #
# #cnf(i_0_16622, plain, (m(a,m(a,a))!=two|m(X1,two)!=X1)).
# ####
# #cnf(i_0_518, plain, (f(m(b,m(b,X1)),m(a,m(a,X1)))=two)).
# ###########
# #cnf(i_0_519, plain, (d(m(b,m(b,X1)),a)|~d(m(a,m(a,X1)),two))).
# ##
# #cnf(i_0_14873, plain, (f(two,X1)!=X1|~d(m(X2,m(a,X3)),X2))).
# ####################
# #cnf(i_0_521, plain, (d(two,X1)|~d(m(a,m(a,X2)),X1))).
# ###
# #cnf(i_0_14878, plain, (f(two,X1)!=X1|~d(m(X3,m(a,X2)),X2))).
# ####
# #cnf(i_0_16258, plain, (d(b,one)|m(a,m(a,X1))!=two)).
# ###
# #cnf(i_0_16273, plain, (d(b,a)|m(a,m(a,X1))!=two)).
# #
# #cnf(i_0_522, plain, (m(X1,m(a,m(a,X2)))!=m(b,m(b,m(X2,X1))))).
# ######
# #cnf(i_0_16522, plain, (m(a,m(a,b))!=one|m(a,m(a,b))!=two)).
# ##
# #cnf(i_0_16324, plain, (d(b,X1)|m(a,m(a,X2))!=two)).
# ###
# #cnf(i_0_523, plain, (m(b,m(b,X1))=X2|m(a,m(a,X1))!=m(two,X2))).
# #########
# #cnf(i_0_16460, plain, (d(X1,one)|m(a,m(a,X1))!=two)).
# #
# #cnf(i_0_16467, plain, (d(X1,a)|m(a,m(a,X1))!=two)).
# #
# #cnf(i_0_524, plain, (m(b,m(b,X1))=one|m(X2,m(a,m(a,X1)))!=m(X2,two))).
# #######
# #cnf(i_0_16471, plain, (d(X1,X2)|m(a,m(a,X1))!=two)).
# ####
# #cnf(i_0_525, plain, (d(m(b,m(b,X1)),X2)|~d(m(a,m(a,X1)),X2))).
# ########
# #cnf(i_0_17412, plain, (d(b,X1)|m(a,m(X2,a))!=two)).
# ##########
# #cnf(i_0_17423, plain, (d(b,X1)|m(X2,m(a,a))!=two)).
# ####
# #cnf(i_0_527, plain, (X1=m(b,m(b,X2))|m(X1,two)!=m(a,m(a,X2)))).
# ##########
# #cnf(i_0_17414, plain, (d(b,X1)|~d(m(a,a),two))).
# #
# #cnf(i_0_528, plain, (m(b,m(b,X1))=X2|m(X3,m(a,m(a,X1)))!=m(X3,m(two,X2)))).
# ######
# #cnf(i_0_16562, plain, (m(X1,m(a,a))!=one|m(a,m(a,X1))!=two)).
# ###
# #cnf(i_0_17710, plain, (d(X1,X2)|m(a,m(X1,a))!=two)).
# ########
# #cnf(i_0_16564, plain, (m(a,m(a,X1))!=one|m(a,m(a,X1))!=two)).
# #####
# #cnf(i_0_530, plain, (d(m(two,b),m(a,m(a,X1))))).
# ##
# #cnf(i_0_18045, plain, (a!=one|a!=two|~d(m(X1,a),X1))).
# #
# #cnf(i_0_18142, plain, (a!=one|a!=two|~d(a,one))).
# #
# #cnf(i_0_18143, plain, (a!=one|a!=two|~d(m(a,X1),X1))).
# ###
# #cnf(i_0_18145, plain, (a!=one|a!=two|~d(m(a,a),two))).
# ####
# #cnf(i_0_531, plain, (m(b,X1)=one|m(a,m(a,X1))!=m(two,b))).
# ####
# #cnf(i_0_18046, plain, (m(a,X1)!=one|m(a,X1)!=two|~d(a,X1))).
# #######
# #cnf(i_0_532, plain, (m(b,X1)=X2|m(a,m(a,X1))!=m(two,m(b,X2)))).
# ######
# #cnf(i_0_16565, plain, (m(a,m(X1,a))!=one|m(a,m(a,X1))!=two)).
# ###
# #cnf(i_0_17721, plain, (d(X1,X2)|m(X1,m(a,a))!=two)).
# ###
# #cnf(i_0_4887, plain, (d(m(X1,X2),X1)|~d(X2,one))).
# ##########
# #cnf(i_0_535, plain, (m(b,m(b,X1))=m(b,b)|m(a,m(a,X1))!=m(a,a))).
# #######
# #cnf(i_0_18386, plain, (d(two,X1)|~d(a,one))).
# ####
# #cnf(i_0_536, plain, (m(a,m(a,f(b,X1)))=m(two,m(b,X1))|~d(b,X1))).
# ###########
# #cnf(i_0_537, plain, (m(a,m(a,m(X1,f(m(b,X1),X2))))=m(two,m(b,X2))|~d(m(b,X1),X2))).
# #
# #cnf(i_0_4921, plain, (d(b,m(X1,a))|~d(a,X1))).
# ##########
# #cnf(i_0_538, plain, (m(two,m(b,m(X2,m(b,X1))))=m(a,m(a,m(X1,X2))))).
# ########
# #cnf(i_0_18450, plain, (m(two,X1)!=X1|~d(m(a,a),one))).
# ###
# #cnf(i_0_539, plain, (m(two,m(b,m(X1,m(X2,b))))=m(a,m(a,m(X1,X2))))).
# ###########
# #cnf(i_0_541, plain, (m(two,m(b,m(X1,b)))=m(a,m(a,X1)))).
# ######################
# #cnf(i_0_543, plain, (m(a,m(a,b))=m(two,b)|m(a,a)!=two)).
# ##
# #cnf(i_0_20907, plain, (m(two,b)!=b|m(a,a)!=two)).
# ####
# #cnf(i_0_20924, plain, (m(two,b)!=one|m(a,a)!=two)).
# ###
# #cnf(i_0_20842, plain, (b=a|m(two,b)!=a|m(a,a)!=two)).
# ##
# #cnf(i_0_544, plain, (m(a,m(a,f(m(b,b),X1)))=m(two,X1)|~d(m(b,b),X1))).
# ########
# #cnf(i_0_20631, plain, (a=one|m(a,b)!=m(two,b)|m(a,a)!=two)).
# ###
# #cnf(i_0_545, plain, (m(two,m(X1,m(b,b)))=m(a,m(a,X1)))).
# ######################
# #cnf(i_0_547, plain, (m(a,m(a,f(b,X1)))!=m(b,X1)|~d(b,X1))).
# #####
# #cnf(i_0_21610, plain, (m(two,m(b,X1))!=m(b,X1)|~d(b,X1))).
# #####
# #cnf(i_0_21637, plain, (m(two,b)!=b|~d(b,one))).
# #
# #cnf(i_0_548, plain, (m(a,m(a,m(X1,f(m(b,X1),X2))))!=m(b,X2)|~d(m(b,X1),X2))).
# ##
# #cnf(i_0_21642, plain, (m(a,a)!=two|m(two,X1)!=X1)).
# ####
# #cnf(i_0_21658, plain, (m(b,b)!=two|m(a,a)!=two)).
# #####
# #cnf(i_0_555, plain, (m(a,m(a,f(m(b,b),X1)))!=X1|~d(m(b,b),X1))).
# #######
# #cnf(i_0_21755, plain, (m(two,X1)!=X1|~d(m(b,b),X1))).
# ####
# #cnf(i_0_565, plain, (m(a,m(a,m(f(b,X1),X2)))=m(two,m(b,m(X1,X2)))|~d(b,X1))).
# #########
# #cnf(i_0_21759, plain, (m(two,a)!=a|~d(m(b,b),two))).
# ##
# #cnf(i_0_566, plain, (m(f(b,X1),X2)=b|m(a,a)!=two|m(X1,X2)!=one)).
# ###########
# #cnf(i_0_567, plain, (m(a,m(a,m(f(b,X1),X2)))!=m(b,m(X1,X2))|~d(b,X1))).
# ###########
# #cnf(i_0_568, plain, (m(a,m(a,f(b,X1)))!=m(X1,b)|~d(b,X1))).
# ###########
# #cnf(i_0_569, plain, (m(f(two,X1),X2)=m(b,b)|m(a,a)!=m(X1,X2)|~d(two,X1))).
# ##
# #cnf(i_0_21638, plain, (m(two,m(X1,b))!=m(X1,b)|~d(b,X1))).
# #########
# #cnf(i_0_570, plain, (m(X2,m(f(f(X1,X2),X3),X4))=m(X1,m(X3,X4))|~d(f(X1,X2),X3)|~d(X1,X2))).
# ###
# #cnf(i_0_21655, plain, (m(X1,m(two,b))!=m(b,X1)|~d(b,X1))).
# #############
# #cnf(i_0_22739, plain, (m(two,m(b,X1))!=m(X1,b)|~d(b,X1))).
# ######
# #cnf(i_0_573, plain, (d(m(X1,X2),m(X1,m(X3,X4)))|~d(X2,X3))).
# ###########
# #cnf(i_0_574, plain, (m(f(X2,X3),m(X4,m(X1,X2)))=m(X1,m(X3,X4))|~d(X2,X3))).
# ##
# #cnf(i_0_23228, plain, (m(X1,m(two,b))!=m(X1,b)|~d(b,X1))).
# #########
# #cnf(i_0_575, plain, (X1=X2|m(X1,m(f(X2,X3),X4))!=m(X3,X4)|~d(X2,X3))).
# #############
# #cnf(i_0_23749, plain, (m(two,m(X1,b))!=m(b,X1)|~d(b,X1))).
# #########
# #cnf(i_0_578, plain, (f(X1,m(X2,X3))=m(f(X1,X2),X3)|~d(X1,X2))).
# #
# #cnf(i_0_24590, plain, (m(a,f(two,a))=m(b,b))).
# ##
# #cnf(i_0_24913, plain, (f(two,X1)!=X1|~d(m(b,b),one))).
# ##
# #cnf(i_0_24939, plain, (m(two,X1)!=X1|~d(m(b,b),one))).
# ##
# #cnf(i_0_24882, plain, (a=two|m(b,b)!=a)).
# ####
# #cnf(i_0_579, plain, (X1=one|m(f(X1,X2),X3)!=m(X2,X3)|~d(X1,X2))).
# ##
# #cnf(i_0_24940, plain, (m(X1,two)!=X1|~d(m(b,b),one))).
# #
# #cnf(i_0_25011, plain, (m(a,a)!=two|m(X1,two)!=X1)).
# ####
# #cnf(i_0_24952, plain, (a=two|m(a,a)!=two|a!=one)).
# ###
# #cnf(i_0_24738, plain, (a=one|f(two,a)!=m(b,b))).
# #
# #cnf(i_0_580, plain, (m(X1,m(f(X1,X2),m(X3,f(m(X2,X3),X4))))=X4|~d(m(X2,X3),X4)|~d(X1,X2))).
# #
# #cnf(i_0_24735, plain, (d(a,m(b,b)))).
# #
# #cnf(i_0_14479, plain, (m(a,a)!=two|f(two,X1)!=X1)).
# #####
# #cnf(i_0_24775, plain, (f(two,a)=one|m(b,b)!=a)).
# #
# #cnf(i_0_25599, plain, (m(b,b)!=a|a!=one)).
# ###
# #cnf(i_0_581, plain, (d(m(X2,X3),m(X1,m(f(X1,X2),m(X3,X4))))|~d(X1,X2))).
# ##
# #cnf(i_0_25636, plain, (m(a,a)!=two|a!=one)).
# ###
# #cnf(i_0_25607, plain, (m(b,b)!=a|m(X1,a)!=X1)).
# #
# #cnf(i_0_25609, plain, (m(b,b)!=a|m(a,X1)!=X1)).
# #####
# #cnf(i_0_582, plain, (m(X1,m(f(X1,X2),m(X3,X4)))=m(X4,m(X2,X3))|~d(X1,X2))).
# #
# #cnf(i_0_25588, plain, (d(a,one)|m(a,a)!=two)).
# ##########
# #cnf(i_0_583, plain, (d(X1,a)|~d(m(X2,X3),two)|~d(X1,X2))).
# #
# #cnf(i_0_26397, plain, (d(a,X1)|m(a,a)!=two)).
# ######
# #cnf(i_0_26469, plain, (m(a,a)!=two)).
# ####
# #cnf(i_0_584, plain, (d(two,m(f(X1,X2),X3))|d(two,X1)|~d(two,m(X2,X3))|~d(X1,X2))).
# #
# #cnf(i_0_24737, plain, (f(a,m(b,b))=f(two,a))).
# ##########
# #cnf(i_0_586, plain, (d(m(f(X1,X2),X3),m(X2,X3))|~d(X1,X2))).
# #
# #cnf(i_0_25598, plain, (m(a,X1)=m(two,X1)|m(b,b)!=a)).
# #
# #cnf(i_0_25012, plain, (m(X1,two)!=X1|~d(m(a,a),one))).
# #######
# #cnf(i_0_24731, plain, (f(two,X1)!=X1|~d(m(a,m(b,b)),a))).
# #
# #cnf(i_0_24924, plain, (f(two,X1)!=X1|~d(m(a,m(b,b)),X1))).
# #
# #cnf(i_0_587, plain, (f(m(f(X1,X2),X3),m(X2,X3))=X1|~d(X1,X2))).
# ########
# #cnf(i_0_24715, plain, (X1=a|m(X1,f(two,a))!=m(b,b))).
# ###
# #cnf(i_0_588, plain, (d(m(f(X1,X2),X3),a)|~d(m(X2,X3),two)|~d(X1,X2))).
# ###########
# #cnf(i_0_589, plain, (X1=X2|m(f(X1,X3),m(X4,X2))!=m(X3,X4)|~d(X1,X3))).
# ############
# #cnf(i_0_24776, plain, (d(f(two,a),m(b,b)))).
# ######
# #cnf(i_0_26562, plain, (a=X1|m(f(two,a),X1)!=m(b,b))).
# ####
# #cnf(i_0_591, plain, (d(X1,X2)|~d(m(X3,X4),X2)|~d(X1,X3))).
# #
# #cnf(i_0_24777, plain, (f(f(two,a),m(b,b))=a)).
# ##########
# #cnf(i_0_592, plain, (X1=one|m(f(X1,X3),m(X4,X2))!=m(X2,m(X3,X4))|~d(X1,X3))).
# #
# #cnf(i_0_24806, plain, (d(a,m(X1,m(b,b))))).
# ########
# #cnf(i_0_24814, plain, (a=one|f(a,X1)!=X1|~d(m(b,b),X1))).
# ##
# #cnf(i_0_593, plain, (m(f(X1,X2),X3)=X4|m(X2,X3)!=m(X1,X4)|~d(X1,X2))).
# #
# #cnf(i_0_24885, plain, (d(two,m(a,m(b,b))))).
# ##########
# #cnf(i_0_594, plain, (m(f(X1,X2),X3)=one|m(X4,m(X2,X3))!=m(X4,X1)|~d(X1,X2))).
# #
# #cnf(i_0_25605, plain, (m(two,X1)=m(X1,a)|m(b,b)!=a)).
# ##########
# #cnf(i_0_595, plain, (d(m(f(X1,X2),X3),X4)|~d(m(X2,X3),X4)|~d(X1,X2))).
# #################
# #cnf(i_0_18067, plain, (m(a,m(X1,a))!=one|m(a,m(X1,a))!=two)).
# ##
# #cnf(i_0_27759, plain, (m(X1,a)!=one|m(X1,a)!=two|~d(a,X1))).
# ###
# #cnf(i_0_597, plain, (X1=m(f(X2,X3),X4)|m(X1,X2)!=m(X3,X4)|~d(X2,X3))).
# #
# #cnf(i_0_27057, plain, (d(f(two,a),m(a,a)))).
# ##########
# #cnf(i_0_598, plain, (m(f(X1,X2),X3)=X4|m(X5,m(X2,X3))!=m(X5,m(X1,X4))|~d(X1,X2))).
# #######
# #cnf(i_0_18388, plain, (d(X1,a)|~d(m(X2,X1),one))).
# ###
# #cnf(i_0_18390, plain, (d(X1,a)|~d(m(X1,X2),one))).
# ###
# #cnf(i_0_14388, plain, (f(two,X1)!=X1|~d(m(a,X2),X1)|~d(a,X2))).
# ###
# #cnf(i_0_28257, plain, (f(two,m(a,X1))!=m(a,X1)|~d(a,X1))).
# ###
# #cnf(i_0_28314, plain, (m(two,a)!=a|~d(a,two))).
# ###
# #cnf(i_0_600, plain, (m(X2,f(m(X1,f(X1,X2)),X3))=X3|~d(m(X1,f(X1,X2)),X3)|~d(X1,X2))).
# #
# #cnf(i_0_27333, plain, (d(a,m(b,m(b,X1))))).
# #
# #cnf(i_0_28273, plain, (f(two,m(X1,a))!=m(X1,a)|~d(a,X1))).
# ####
# #cnf(i_0_18078, plain, (m(X1,m(a,a))!=one|m(X1,m(a,a))!=two)).
# ##
# #cnf(i_0_18447, plain, (d(X1,X2)|~d(m(X3,X1),one))).
# ###
# #cnf(i_0_601, plain, (d(m(X1,f(X1,X2)),m(X2,X3))|~d(X1,X2))).
# #####
# #cnf(i_0_28315, plain, (m(f(two,a),X1)!=m(a,X1)|~d(a,X1))).
# ###
# #cnf(i_0_18449, plain, (d(X1,X2)|~d(m(X1,X3),one))).
# ###
# #cnf(i_0_602, plain, (m(X3,m(X1,f(X1,X2)))=m(X2,X3)|~d(X1,X2))).
# ###########
# #cnf(i_0_603, plain, (X1=one|m(X3,X1)!=m(X2,f(X2,X3))|~d(X2,X3))).
# ###
# #cnf(i_0_28944, plain, (m(X1,f(two,a))!=m(a,X1)|~d(a,X1))).
# ######
# #cnf(i_0_29506, plain, (X1=one|m(b,b)!=a|m(a,X1)!=two)).
# ##
# #cnf(i_0_604, plain, (X1=X2|m(X4,X1)!=m(X3,m(f(X3,X4),X2))|~d(X3,X4))).
# ############
# #cnf(i_0_27335, plain, (d(a,m(b,m(X1,b))))).
# ##
# #cnf(i_0_14478, plain, (f(two,X1)!=X1|~d(X2,f(a,X2))|~d(a,X2))).
# ########
# #cnf(i_0_606, plain, (f(X1,X2)=one|m(X2,X3)!=m(X3,X1)|~d(X1,X2))).
# ##
# #cnf(i_0_14907, plain, (f(two,X1)!=X1|~d(m(X2,X3),one)|~d(a,X2))).
# ############
# #cnf(i_0_14908, plain, (f(two,X1)!=X1|~d(m(X3,X2),one)|~d(a,X2))).
# #######
# #cnf(i_0_24803, plain, (d(a,X1)|~d(m(b,b),X1))).
# #
# #cnf(i_0_613, plain, (m(X2,f(f(X1,X2),X3))=m(X1,X3)|~d(f(X1,X2),X3)|~d(X1,X2))).
# #
# #cnf(i_0_30024, plain, (d(a,b)|~d(b,one))).
# #
# #cnf(i_0_14909, plain, (f(two,X1)!=X1|~d(m(a,X2),X3)|~d(X3,one))).
# #######
# #cnf(i_0_24934, plain, (d(b,X1)|m(a,m(b,b))!=two)).
# ##
# #cnf(i_0_614, plain, (m(X2,m(X3,f(m(f(X1,X2),X3),X4)))=m(X1,X4)|~d(m(f(X1,X2),X3),X4)|~d(X1,X2))).
# ##
# #cnf(i_0_14910, plain, (f(two,X1)!=X1|~d(m(X2,a),X3)|~d(X3,one))).
# #######
# #cnf(i_0_27327, plain, (d(a,one)|m(a,m(a,b))!=two)).
# ##
# #cnf(i_0_615, plain, (m(X1,m(X4,m(f(X1,X2),X3)))=m(X2,m(X3,X4))|~d(X1,X2))).
# ####
# #cnf(i_0_28238, plain, (f(two,X1)!=X1|~d(m(X2,a),X1)|~d(a,X2))).
# ###
# #cnf(i_0_28694, plain, (d(a,b)|~d(m(X1,b),X1))).
# ###
# #cnf(i_0_28722, plain, (d(a,b)|m(a,m(a,X1))!=two)).
# #
# #cnf(i_0_616, plain, (m(X1,m(X3,m(X4,f(X1,X2))))=m(X2,m(X3,X4))|~d(X1,X2))).
# #########
# #cnf(i_0_28740, plain, (d(a,one)|m(a,m(a,X1))!=two)).
# ##
# #cnf(i_0_618, plain, (m(X1,m(X3,f(X1,X2)))=m(X2,X3)|~d(X1,X2))).
# ##################
# #cnf(i_0_28812, plain, (d(b,X1)|~d(m(a,a),one))).
# ##
# #cnf(i_0_28951, plain, (d(a,X1)|~d(m(b,b),one))).
# #
# #cnf(i_0_28956, plain, (d(two,X1)|~d(m(a,a),one))).
# ############
# #cnf(i_0_622, plain, (d(X1,m(X2,m(X3,m(X1,X4)))))).
# ###########
# #cnf(i_0_623, plain, (d(X1,m(X2,m(X3,m(X4,X1)))))).
# ##########
# #cnf(i_0_31688, plain, (d(a,b)|~d(m(b,X1),X1))).
# #
# #cnf(i_0_624, plain, (d(X1,m(X2,m(X3,X4)))|~d(X1,X4))).
# #########
# #cnf(i_0_31690, plain, (d(a,b)|~d(m(a,b),two))).
# ##
# #cnf(i_0_626, plain, (d(m(b,b),m(X1,m(a,a))))).
# #######
# #cnf(i_0_31732, plain, (d(a,b)|m(a,m(X1,a))!=two)).
# ###
# #cnf(i_0_31734, plain, (d(a,b)|m(a,m(b,b))!=two)).
# #
# #cnf(i_0_627, plain, (d(m(b,m(b,X1)),m(X2,m(a,m(a,X1)))))).
# #######
# #cnf(i_0_31751, plain, (d(a,b)|m(X1,m(a,a))!=two)).
# #######
# #cnf(i_0_14411, plain, (f(two,X1)!=X1|~d(m(a,a),X2)|~d(X2,X1))).
# ########
# #cnf(i_0_630, plain, (d(f(X1,X2),m(X3,X2))|~d(X1,X2))).
# #
# #cnf(i_0_29476, plain, (m(X1,two)=m(a,X1)|m(b,b)!=a)).
# #######
# #cnf(i_0_32385, plain, (d(a,one)|m(a,m(X1,a))!=two)).
# ###
# #cnf(i_0_631, plain, (d(m(f(X1,X2),X3),m(X4,m(X2,X3)))|~d(X1,X2))).
# #######
# #cnf(i_0_32387, plain, (d(a,one)|m(a,m(b,b))!=two)).
# #
# #cnf(i_0_32405, plain, (d(a,one)|m(X1,m(a,a))!=two)).
# ###
# #cnf(i_0_632, plain, (d(m(X1,f(m(X2,X1),X3)),m(X4,X3))|~d(m(X2,X1),X3))).
# ####
# #cnf(i_0_14906, plain, (f(two,X1)!=X1|~d(X3,one)|~d(a,X2)|~d(X2,X3))).
# #######
# #cnf(i_0_633, plain, (d(m(X1,X2),m(X3,m(X2,m(X4,X1)))))).
# #####
# #cnf(i_0_34259, plain, (m(two,X1)!=X1|~d(X2,one)|~d(a,X3)|~d(X3,X2))).
# ######
# #cnf(i_0_634, plain, (d(m(X1,X2),m(X3,m(X1,m(X2,X4)))))).
# ###
# #cnf(i_0_34260, plain, (m(X1,two)!=X1|~d(X2,one)|~d(a,X3)|~d(X3,X2))).
# ########
# #cnf(i_0_639, plain, (d(m(b,X1),m(a,m(a,X1))))).
# ##############
# #cnf(i_0_14409, plain, (f(two,X1)!=X1|~d(m(a,m(X2,a)),X1))).
# ###
# #cnf(i_0_34935, plain, (f(two,a)!=a|~d(m(a,m(X1,a)),two))).
# ##########
# #cnf(i_0_14420, plain, (f(two,X1)!=X1|~d(m(X2,m(a,a)),X1))).
# ####
# #cnf(i_0_34981, plain, (f(two,a)!=a|~d(m(X1,m(a,a)),two))).
# #############
# #cnf(i_0_652, plain, (X1=one|m(X2,f(X1,X3))!=m(X2,X3)|~d(X1,X3))).
# ###########
# #cnf(i_0_653, plain, (X1=one|m(X2,m(f(X1,X3),X4))!=m(X2,m(X3,X4))|~d(X1,X3))).
# ##
# #cnf(i_0_14445, plain, (f(two,m(a,X1))!=m(a,X1)|~d(m(a,X2),X1))).
# #########
# #cnf(i_0_654, plain, (X1=one|m(X2,m(X3,f(m(X1,X3),X4)))!=m(X2,X4)|~d(m(X1,X3),X4))).
# ####
# #cnf(i_0_14894, plain, (f(two,X1)!=X1|~d(m(X2,m(X3,a)),one))).
# #######
# #cnf(i_0_655, plain, (X1=one|m(X2,m(X4,m(X1,X3)))!=m(X2,m(X3,X4)))).
# ####
# #cnf(i_0_14918, plain, (f(two,X1)!=X1|~d(m(X3,m(a,X2)),one))).
# ##################
# #cnf(i_0_662, plain, (X1=one|m(X2,m(X3,m(X1,X4)))!=m(X2,m(X3,X4)))).
# ###########
# #cnf(i_0_666, plain, (f(X1,X2)=one|m(X2,X3)!=m(X1,X3)|~d(X1,X2))).
# #####
# #cnf(i_0_18149, plain, (a!=one|a!=two|~d(m(X1,m(X2,a)),X1))).
# ##
# #cnf(i_0_35811, plain, (m(a,m(a,a))!=two|a!=one|a!=two)).
# #
# #cnf(i_0_35815, plain, (a!=one|a!=two|~d(m(X1,a),one))).
# ######
# #cnf(i_0_35848, plain, (a!=one|a!=two|~d(m(a,X1),one))).
# ##########
# #cnf(i_0_35859, plain, (a!=one|a!=two|~d(X1,one)|~d(a,X1))).
# #########
# #cnf(i_0_672, plain, (m(b,m(X1,m(b,X2)))!=m(a,m(a,m(X1,X2))))).
# ######
# #cnf(i_0_35889, plain, (a!=one|a!=two|~d(m(b,b),one))).
# #####
# #cnf(i_0_677, plain, (m(b,b)=m(X1,X2)|m(X1,m(two,X2))!=m(a,a))).
# ###
# #cnf(i_0_35818, plain, (a!=one|a!=two|~d(m(X2,a),X1)|~d(X1,X2))).
# ########
# #cnf(i_0_678, plain, (m(X1,m(X3,m(f(X1,X2),X4)))=m(X2,m(X3,X4))|~d(X1,X2))).
# ##
# #cnf(i_0_36112, plain, (a!=one|a!=two|~d(m(X1,X2),X1)|~d(a,X2))).
# ###########
# #cnf(i_0_36842, plain, (a!=one|a!=two|~d(m(X2,X1),X1)|~d(a,X2))).
# #####################
# #cnf(i_0_18507, plain, (d(m(X2,X1),X1)|~d(X2,one))).
# #####################
# #cnf(i_0_684, plain, (X1=X2|m(X1,m(X3,X4))!=m(X3,m(X2,X4)))).
# ##############################
# #cnf(i_0_37019, plain, (X1=one|f(X1,X2)!=X2|~d(X1,one))).
# ##############
# #cnf(i_0_690, plain, (m(X1,m(X2,m(X3,f(m(X2,m(X1,X3)),X4))))=X4|~d(m(X2,m(X1,X3)),X4))).
# ###########
# #cnf(i_0_691, plain, (d(m(X2,m(X1,X3)),m(X1,m(X2,m(X3,X4)))))).
# ######
# #cnf(i_0_23787, plain, (m(b,m(X1,b))!=two|m(a,m(a,X1))!=two)).
# ###########
# #cnf(i_0_24911, plain, (m(a,m(b,b))!=one|m(a,m(b,b))!=two)).
# ######################
# #cnf(i_0_27279, plain, (m(X2,m(a,X1))!=m(X1,X2)|m(b,b)!=a)).
# #####
# #cnf(i_0_695, plain, (d(two,m(X1,X2))|d(two,X3)|~d(two,m(X1,m(X3,X2))))).
# ###
# #cnf(i_0_35819, plain, (a!=one|a!=two|~d(m(a,X2),X1)|~d(X1,X2))).
# #########
# #cnf(i_0_24720, plain, (d(X1,m(b,b))|~d(X1,a))).
# ######
# #cnf(i_0_38677, plain, (d(two,b))).
#
# # Proof found!
# # SZS status Unsatisfiable
# # SZS output start CNFRefutation
# cnf(sos, axiom, (d(X1,X3)|m(X1,X2)!=X3), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (m(X1,f(X1,X2))=X2|~d(X1,X2)), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (m(X1,m(X2,X3))=m(m(X1,X2),X3)), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (X2=X3|m(X1,X2)!=m(X1,X3)), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (d(two,X1)|d(two,X2)|~d(two,m(X1,X2))), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (m(a,a)=m(two,m(b,b))), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (m(X1,X2)=m(X2,X1)), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (X1=one|~d(X1,a)|~d(X1,b)), file('/tmp/sqrt.p', sos)).
# cnf(sos, axiom, (two!=one), file('/tmp/sqrt.p', sos)).
# cnf(c_0_9, plain, (d(X1,X3)|m(X1,X2)!=X3), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_10, plain, (m(X1,f(X1,X2))=X2|~d(X1,X2)), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_11, plain, (d(X1,X3)|m(X1,X2)!=X3), c_0_9).
# cnf(c_0_12, plain, (m(X1,f(X1,X2))=X2|~d(X1,X2)), c_0_10).
# cnf(c_0_13, axiom, (m(X1,m(X2,X3))=m(m(X1,X2),X3)), sos).
# cnf(c_0_14, plain, (X2=X3|m(X1,X2)!=m(X1,X3)), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_15, plain, (d(X1,m(X1,X2))), inference(er,[status(thm)],[c_0_11])).
# cnf(c_0_16, plain, (m(X1,m(X2,f(m(X1,X2),X3)))=X3|~d(m(X1,X2),X3)), inference(spm,[status(thm)],[c_0_12, c_0_13])).
# cnf(c_0_17, plain, (X2=X3|m(X1,X2)!=m(X1,X3)), c_0_14).
# cnf(c_0_18, plain, (d(two,X1)|d(two,X2)|~d(two,m(X1,X2))), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_19, axiom, (m(a,a)=m(two,m(b,b))), sos).
# cnf(c_0_20, plain, (d(X1,X2)|~d(m(X1,X3),X2)), inference(spm,[status(thm)],[c_0_15, c_0_16])).
# cnf(c_0_21, plain, (f(X1,m(X1,X2))=X2), inference(cn,[status(thm)],[inference(rw,[status(thm)],[inference(er,[status(thm)],[inference(spm,[status(thm)],[c_0_17, c_0_12])]), c_0_15])])).
# cnf(c_0_22, plain, (m(X1,m(f(X1,X2),X3))=m(X2,X3)|~d(X1,X2)), inference(spm,[status(thm)],[c_0_13, c_0_12])).
# cnf(c_0_23, plain, (d(two,X1)|d(two,X2)|~d(two,m(X1,X2))), c_0_18).
# cnf(c_0_24, plain, (d(two,m(a,a))), inference(spm,[status(thm)],[c_0_15, c_0_19])).
# cnf(c_0_25, plain, (d(X1,X2)|~d(X3,X2)|~d(X1,X3)), inference(spm,[status(thm)],[c_0_20, c_0_12])).
# cnf(c_0_26, plain, (f(two,m(a,a))=m(b,b)), inference(spm,[status(thm)],[c_0_21, c_0_19])).
# cnf(c_0_27, plain, (f(X1,m(X2,X3))=m(f(X1,X2),X3)|~d(X1,X2)), inference(spm,[status(thm)],[c_0_21, c_0_22])).
# cnf(c_0_28, plain, (d(two,a)), inference(spm,[status(thm)],[c_0_23, c_0_24])).
# cnf(c_0_29, axiom, (m(X1,X2)=m(X2,X1)), sos).
# cnf(c_0_30, plain, (d(X1,m(X2,X3))|~d(X1,X2)), inference(spm,[status(thm)],[c_0_25, c_0_15])).
# cnf(c_0_31, plain, (m(a,f(two,a))=m(b,b)), inference(rw,[status(thm)],[inference(cn,[status(thm)],[inference(rw,[status(thm)],[inference(spm,[status(thm)],[c_0_26, c_0_27]), c_0_28])]), c_0_29])).
# cnf(c_0_32, plain, (X1=one|~d(X1,a)|~d(X1,b)), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_33, plain, (d(X1,m(b,b))|~d(X1,a)), inference(spm,[status(thm)],[c_0_30, c_0_31])).
# cnf(c_0_34, plain, (two!=one), inference(fof_simplification,[status(thm)],[sos])).
# cnf(c_0_35, plain, (X1=one|~d(X1,a)|~d(X1,b)), c_0_32).
# cnf(c_0_36, plain, (d(two,b)), inference(cn,[status(thm)],[inference(rw,[status(thm)],[inference(spm,[status(thm)],[c_0_23, c_0_33]), c_0_28])])).
# cnf(c_0_37, plain, (two!=one), c_0_34).
# cnf(c_0_38, plain, ($false), inference(sr,[status(thm)],[inference(cn,[status(thm)],[inference(rw,[status(thm)],[inference(spm,[status(thm)],[c_0_35, c_0_36]), c_0_28])]), c_0_37]), ['proof']).
# # SZS output end CNFRefutation

# %% [markdown]
# Anyhow, with that guidance, we can attempt to write a proof like thing in python.
#
# I've been tinkering with trying to enforce a proof discipline / kernel in python, but I've been leaning towards reducing it all to idioms until I'm more sure what I want.
#
# - https://github.com/philzook58/knuckledragger github
# - https://www.philipzucker.com/knuckledrag2/ second blog post
# - https://www.philipzucker.com/python-itp/ first blog post
#
# The kernel is only enforcing rules that I think make sense anyway.
#
# A small wrapper enables us the make stepwise proofs. We only give python names to things that we want to accept as axioms or things that come out of `lemma`. The justifications that go into `by` should only be previously named theorems.
#
# This avoids all the rigamorole of keeping a separate `Theorem` datatype or theorem database, but is more susceptible to accidental error than the styles I've used in those other posts.

# %%
def lemma(thm, by=[]):
    prove(Implies(And(by), thm))
    return thm

# %% [markdown]
# The following let's me see last assignment, prewtty printing the statement of the lemma in a nice form.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %% [markdown]
# The strategy is to make opaque functions that we can hide the definitions that may be confusing the solver. The approach semi fails.

# %%
Z = IntSort()
B = BoolSort()
x,y,z = Ints("x y z")
mul = Function("mul", Z, Z, Z)
mul_def = ForAll([x,y], mul(x, y) == x*y)
# Out:
# proved
# ForAll(x, mul(x, 1) == x)

# %% [markdown]
# Z3 easily proves the basic algebraic properties of multiplication

# %%
mul_x_1 = lemma(ForAll([x], mul(x, 1) == x), by=[mul_def])
# Out:
# proved
# ForAll(x, mul(x, 1) == x)

# %%
mul_1_x = lemma(ForAll([x], mul(1, x) == x), by=[mul_def])
# Out:
# proved
# ForAll(x, mul(1, x) == x)

# %%
mul_assoc = lemma(ForAll([x,y,z], mul(x, mul(y,z)) == mul(mul(x,y), z)), by=[mul_def])
# Out:
# proved
# ForAll([x, y, z], mul(x, mul(y, z)) == mul(mul(x, y), z))

# %%
mul_comm = lemma(ForAll([x,y], mul(x,y) == mul(y,x)), by=[mul_def])
# Out:
# proved
# ForAll([x, y], mul(x, y) == mul(y, x))

# %%
mul_cancel = lemma(ForAll([x,y,z], Implies(And(x != 0, mul(x,y) == mul(x,z)), y == z)), by=[mul_def])
# Out:
# proved
# ForAll([x, y, z],
#        Implies(And(x != 0, mul(x, y) == mul(x, z)), y == z))

# %% [markdown]
# We can define a [divides](https://en.wikipedia.org/wiki/Divisor) relation. I define it in terms of `x/y` which is flooring division. Is there a built in divides relation in SMT?

# %%
divides = Function("divides", Z, Z, B)
divides_def = ForAll([x,y], divides(x,y) == (x == y*(x/y)))
# Out:
# ForAll([x, y], divides(x, y) == (x == y*(x/y)))

# %%
div_mul_cancel = lemma(ForAll([x,y], Implies(divides(x,y), mul(x/y, y) == x)), by=[divides_def, mul_def])
# Out:
# proved
# ForAll([x, y], Implies(divides(x, y), mul(x/y, y) == x))

# %% [markdown]
# Here we have two properties that I can't get to pass. They are basic facts. We don't get a counterexample, so perhaps that lends a mild amount of credence.

# %%
#mul_divides = lemma(ForAll([x,y,z], Implies(mul(x,y) == z, divides(z,x))), by=[mul_def, divides_def])
# can't get this one to prove
mul_divides = ForAll([x,y,z], Implies(mul(x,y) == z, divides(z,x)))
# Out:
# ForAll([x, y, z], Implies(mul(x, y) == z, divides(z, x)))

# %%
#two_prime = lemma(ForAll([x,y], Implies(divides(mul(x,y),2), Or(divides(x,2), divides(y,2)))), by=[divides_def, mul_def])
# can't get this one to pass
two_prime = ForAll([x,y], Implies(divides(mul(x,y),2), Or(divides(x,2), divides(y,2))))
# Out:
# ForAll([x, y],
#        Implies(divides(mul(x, y), 2),
#                Or(divides(x, 2), divides(y, 2))))

# %% [markdown]
# Part of the cleverness of the Otter proof is abusing this notion that every fraction can be expressed in lowest common terms. This is a nontrivial seeming fact.
#
# Here I use an expanded form of `solve` because I was fiddling with the smt formula.

# %%
no_common_factor = ForAll([z], Implies(And(divides(x,z), divides(y,z)), z == 1))
prime_thm = Not(Exists([x,y], And(no_common_factor, x != 0, mul(x,x) == mul(2,mul(y,y)))))
lemmas = [mul_1_x, mul_x_1, mul_comm, mul_assoc, mul_divides, mul_cancel, div_mul_cancel, two_prime]
s = Solver()
s.add(lemmas)
s.add(Not(prime_thm))
with open("/tmp/prime.smt2", "w") as f:
    f.write(s.sexpr()) 
#lemma(Not(Exists([x,y], And(no_factor, mul(x,x) == mul(2,mul(y,y))))), by=[mul_1_x, mul_x_1, mul_assoc, two_prime, div_mul_cancel])
s.check()
# Out:
# unsat

# %% [markdown]
# ## Bits and Bobbles
#
# I am not satisfied. There are big holes and there was some nontrivial workarounds. I'm not particularly sure my thrashing even helped that much.

# %%
# !vampire --mode tclausify /tmp/prime.smt2  # vampire is useful for converting to clauses or smt to tptp
# Out:
# % Running in auto input_syntax mode. Trying SMTLIB2
# tff(func_def_0, type, mul: ($int * $int) > $int).
# tff(func_def_12, type, sK3: $int).
# tff(func_def_13, type, sK4: $int).
# tff(pred_def_1, type, divides: ($int * $int) > $o).
# tff(pred_def_5, type, lG2: ($int * $int) > $o).
# tff(u63,axiom,
#     (lG2(sK4,sK3) | ~sLP1)).
#
# tff(u62,axiom,
#     ((0 != sK3) | ~sLP1)).
#
# tff(u61,axiom,
#     ((mul(2,mul(sK4,sK4)) = mul(sK3,sK3)) | ~sLP1)).
#
# tff(u64,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : (((1 = X2) | ~divides(X1,X2) | ~divides(X0,X2) | ~lG2(X0,X1))))).
#
# tff(u35,axiom,
#     (![X0 : $o] : (((($true = X0)) | (($false = X0)))))).
#
# tff(u34,axiom,
#     (($true != $false))).
#
# tff(u33,axiom,
#     (![X0 : $int, X1 : $int] : ((~$less(X0,X1) | ~$less(X1,$sum(X0,1)))))).
#
# tff(u32,axiom,
#     (![X2 : $int, X1 : $int] : (((0 = X2) | ~$less($sum($abs(X2),$uminus(1)),$remainder_e(X1,X2)))))).
#
# tff(u31,axiom,
#     (![X2 : $int, X1 : $int] : (((0 = X2) | ~$less($remainder_e(X1,X2),0))))).
#
# tff(u30,axiom,
#     (![X2 : $int, X1 : $int] : (((0 = X2) | ($sum($remainder_e(X1,X2),$product(X2,$quotient_e(X1,X2))) = X1))))).
#
# tff(u29,axiom,
#     (![X1 : $int] : ((~$less(X1,0) | ($uminus(X1) = $abs(X1)))))).
#
# tff(u28,axiom,
#     (![X1 : $int] : ((~$less(0,X1) | ($abs(X1) = X1))))).
#
# tff(u74,axiom,
#     (![X2 : $int, X0 : $int, X3 : $int] : (((0 = X0) | ($product(X0,X2) != $product(X0,X3)) | (X2 = X3))))).
#
# tff(u26,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : (($product(X0,$sum(X1,X2)) = $sum($product(X0,X1),$product(X0,X2)))))).
#
# tff(u25,axiom,
#     (![X0 : $int] : ((0 = $product(X0,0))))).
#
# tff(u24,axiom,
#     (![X0 : $int] : (($product(X0,1) = X0)))).
#
# tff(u23,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : (($product(X0,$product(X1,X2)) = $product($product(X0,X1),X2))))).
#
# tff(u22,axiom,
#     (![X0 : $int, X1 : $int] : (($product(X0,X1) = $product(X1,X0))))).
#
# tff(u21,axiom,
#     (![X0 : $int] : (($uminus($uminus(X0)) = X0)))).
#
# tff(u20,axiom,
#     (![X0 : $int, X1 : $int] : (($less(X0,X1) | $less(X1,$sum(X0,1)))))).
#
# tff(u19,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : ((~$less(X0,X1) | $less($sum(X0,X2),$sum(X1,X2)))))).
#
# tff(u18,axiom,
#     (![X0 : $int, X1 : $int] : (($less(X0,X1) | $less(X1,X0) | (X0 = X1))))).
#
# tff(u17,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : ((~$less(X0,X1) | ~$less(X1,X2) | $less(X0,X2))))).
#
# tff(u16,axiom,
#     (![X0 : $int] : (~$less(X0,X0)))).
#
# tff(u15,axiom,
#     (![X0 : $int] : ((0 = $sum(X0,$uminus(X0)))))).
#
# tff(u14,axiom,
#     (![X0 : $int, X1 : $int] : (($uminus($sum(X0,X1)) = $sum($uminus(X1),$uminus(X0)))))).
#
# tff(u13,axiom,
#     (![X0 : $int] : (($sum(X0,0) = X0)))).
#
# tff(u12,axiom,
#     (![X2 : $int, X0 : $int, X1 : $int] : (($sum(X0,$sum(X1,X2)) = $sum($sum(X0,X1),X2))))).
#
# tff(u11,axiom,
#     (![X0 : $int, X1 : $int] : (($sum(X0,X1) = $sum(X1,X0))))).
#
# tff(u65,hypothesis,
#     (![X0 : $int] : ((mul(1,X0) = X0)))).
#
# tff(u66,hypothesis,
#     (![X0 : $int] : ((mul(X0,1) = X0)))).
#
# tff(u67,hypothesis,
#     (![X0 : $int, X1 : $int] : ((mul(X1,X0) = mul(X0,X1))))).
#
# tff(u68,hypothesis,
#     (![X2 : $int, X0 : $int, X1 : $int] : ((mul(mul(X1,X0),X2) = mul(X1,mul(X0,X2)))))).
#
# tff(u75,hypothesis,
#     (![X0 : $int, X1 : $int] : (divides(mul(X1,X0),X1)))).
#
# tff(u70,hypothesis,
#     (![X2 : $int, X0 : $int, X1 : $int] : (((X0 = X2) | (0 = X1) | (mul(X1,X0) != mul(X1,X2)))))).
#
# tff(u71,hypothesis,
#     (![X0 : $int, X1 : $int] : (((mul($quotient_e(X1,X0),X0) = X1) | ~divides(X1,X0))))).
#
# tff(u72,hypothesis,
#     (![X0 : $int, X1 : $int] : ((divides(X1,2) | divides(X0,2) | ~divides(mul(X1,X0),2))))).
#
# tff(u73,hypothesis,
#     sLP1).

# %% [markdown]
# I think I have less interest in rigor than others who might be interested in such things.
#
#
# I was once stumped on how to derive the irrationality of the square root of 2 in Z3. Here I'm going to recpliate it.
# I suspect ATP systems like vampire or eprover will not get stuck
#
# It can be formulated as proving `not exists m n, n^2 = 2 m^2`  $\neg \exists m n, n^2 = 2 m^2$
#
# Cody also suggested infinitude of primes.
#
# This is all math shit. These are not my theorems. I think maybe they are the wrong ones to attack.
#
# Facts about evens and odds.

# %%
#from cvc5.pythonic import *
from z3 import *
x,y,z = Ints("x y z")
p = Real("p")
Z = IntSort()
R = RealSort()
B = BoolSort()

# %% [markdown]
# The paper mentions that many systems don't have the reals. Z3 and CVC5 do. So you can state something closer to what you meant.
#
# In a certain sense, the SMT "reals" are not the reals at all. They can prove some under approximation of reasonable facts about the reals. They are based around the rationals, linear equations, linear inequalities, polynomials and algebraic numbers.

# %%
rational = Function("rational", R, B)
rat_def = ForAll([p], rational(p) == Exists([x,y], p == ToReal(x)/ToReal(y)))
rat_def
# Out:
# ForAll(p,
#        (Exists([x, y], p == ToReal(x)/ToReal(y))) ==
#        rational(p))

# %%
step1 = Implies(And(rational(p), p*p == 2), Exists([x,y], x*x == 2*y*y))
prove(Implies(rat_def, step1))

# %%
#prove(ForAll([p], Implies(rational(p), Not(p*p == 2))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 prove(ForAll([p], Implies(rational(p), Not(p*p == 2))))
#
# NameError: name 'rational' is not defined

# %% [markdown]
# Lemmas about even and oddness

# %% [markdown]
# I have a suspicion that it is wise to define things in "open" and explicitly skolemized form.
#
# `evenp(x,y)` is the "evidence" form of evenness, where you give explicitly the number that is half of x. This perhaps gives you the option of helping the solver find the needed existential by just giving it.
#  `even(x) = exists p, evenp(x,p)`
#
# Explicit skolem function help you refer to something that is guaranteed to exist.
#
# Choice functions would make this easier probably.

# %%
evenp = Function("evenp", I, I, B)
evenp_def = ForAll([x,y], evenp(x,y) == (x == 2*y))


xsq_even = Implies(x*x == 2*y*y, evenp(x*x, y*y))
prove(Implies(evenp_def, xsq_even))


ForAll([x,y], Implies( evenp(x,y), even(x)))
#ForAll([x,y], Implies( evenp(x,y), even(y)))

# %%
rearrange = Implies(x*x == 2*y*y, y*y == (x*x)/2)
prove(rearrange)
# Out:
# proved

# %%
rearrange = Implies(x*x == 2*y*y, y*y == (x*x)/2)
prove(rearrange)

# %%
xsq_even = Implies(x*x == 2*y, even(x*x))
prove(Implies(even_def, xsq_even))
xsq_even

# %%
#from cvc5.pythonic import *
#from z3 
x,y,z = Ints("x y z")
even = Function("even", IntSort(), BoolSort())
even_def = ForAll(x, even(x) == Exists([y], x == 2*y))
odd = Function("odd", IntSort(), BoolSort())
odd_def = ForAll(x, odd(x) == Exists([y], x == 2*y+1))

even_not_odd = ForAll([x], Implies(even(x), Not(odd(x))))
prove(Implies(And(even_def, odd_def), even_not_odd))

even_or_odd = ForAll(x, even(x) != odd(x))
prove(Implies(And(even_def, odd_def), even_or_odd))
# Out:
# proved
# proved
# proved

# %% [markdown]
# Facts about even odd

# %%
even_not_odd = ForAll(x, Implies(even(x), Not(odd(x))))
prove(Implies(And(even_def, odd_def), even_not_odd))

odd_not_even = ForAll(x, Implies(odd(x), Not(even(x))))
prove(Implies(And(even_def, odd_def), odd_not_even))


not_even_odd = ForAll(x, Not(And(even(x),odd(x))))
prove(Implies(And(even_def, odd_def), not_even_odd))




def induct(P):
    return Implies(
            And(P(0), 
                ForAll([x], Implies(P(x),  And(P(x + 1), P(x - 1))))),
            ForAll([x], P(x)))

even_or_odd = ForAll(x, Or(even(x), odd(x)))
#prove(Implies(And(even_def, odd_def, induct(lambda n: Or(even(n), odd(n)))), even_or_odd))

evenodd = lambda n: Or(even(n), odd(n))
prove(Implies(And(even_def, odd_def), Or(even(0), odd(0))))
prove(Implies(And(even_def, odd_def), ForAll([x], Implies(evenodd(x), evenodd(x+1)))))
#prove(Implies(And(even_def, odd_def), ForAll([x], Implies(evenodd(x), evenodd(x-1)))))

prove(Implies(And(even_def, odd_def), ForAll([x], Implies(odd(x), Exists([y], x == 2*y-1)))))

#prove(Implies(And(even_def, odd_def), ForAll([x], odd(x) == Exists([y], x == 2*y-1))))

even_or_odd = ForAll(x, even(x) != odd(x))
# Z3 can't prove this for some reason. I suppose this might be a complex diophantine equation or something.
prove(Implies(And(even_def, odd_def), even_or_odd))


sqrt_thm = ForAll([x,y], Implies(x != 0, 2*x*x != y*y))
#prove(sqrt_thm)

#solve(2*x*x == y*y)

even_sq = ForAll([x,y], Implies(even(x), even(x*x)))
#prove(Implies(even_def, even_sq))

# %%
#def divides(x,y):
#    return x == y*(x/y)

divides = Function("divides", I, I, B)
divides_def = ForAll([x,y], divides(x,y) == (x == y*(x/y)))
prove(ForAll([x], divides(x, 0)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #def divides(x,y):
#       2 #    return x == y*(x/y)
# ----> 4 divides = Function("divides", I, I, B)
#       5 divides_def = ForAll([x,y], divides(x,y) == (x == y*(x/y)))
#       6 prove(ForAll([x], divides(x, 0)))
#
# NameError: name 'Function' is not defined

# %%
# %%file /tmp/prime2.smt2
# (declare-sort I 0)
# (declare-fun mul (I I) I)
# (declare-fun divsk (I I) I)
# (declare-fun divides (I I) Bool)
# (declare-const one I)
# (declare-const two I)
# (declare-const a I)
# (declare-const b I)
# (assert (distinct one two))
# (assert (forall ((x I)) (= (mul one x) x)))
# (assert (forall ((x I)) (= (mul x one) x)))
# (assert (forall ((x I) (y I) (z I)) (= (mul x (mul y z)) (mul (mul x y) z))))
# (assert (forall ((x I) (y I)) (= (mul x y) (mul y x))))
# (assert (forall ((x I) (y I) (z I))
#   (=> (= (mul x y) (mul x z)) (= y z))))
# (assert (forall ((x I) (y I)) (=> (divides x y) (= (mul y (divsk x y)) x))))
# (assert (forall ((x I) (y I))
#   (=> (divides (mul x y) two) (or (divides x two) (divides y two)))))
# (assert (= (mul a a) (mul two (mul b b)))) ;
# (assert (forall ((x I)) (=> (and (divides a x) (divides b x)) (= x one)))) ; lowest common terms
# ;(assert (let ((a!1 (exists ((x I) (y I))
# ;             (let ((a!1 (forall ((z I))
# ;                         (=> (and (divides x z) (divides y z)) (= z one)))))
# ;               (and a!1 (= (mul x x) (mul two (mul y y))))))))
# ;  (not (not a!1))))
# Out:
# Writing /tmp/prime2.smt2

# %%
# Out:
# Overwriting /tmp/sqrt2.in

# %%
! prover9 -f /tmp/sqrt2.in
# Out:
# ============================== Prover9 ===============================
# Prover9 (64) version 2017-11A (CIIRC), November 2017.
# Process 259687 was started by philip on philip-ThinkPad-Z13-Gen-2,
# Mon Apr 29 17:27:10 2024
# The command was "prover9 -f /tmp/sqrt2.in".
# ============================== end of head ===========================
#
# ============================== INPUT =================================
#
# % Reading from file /tmp/sqrt2.in
#
# set(auto).
#     % set(auto) -> set(auto_inference).
#     % set(auto) -> set(auto_setup).
#     % set(auto_setup) -> set(predicate_elim).
#     % set(auto_setup) -> assign(eq_defs, unfold).
#     % set(auto) -> set(auto_limits).
#     % set(auto_limits) -> assign(max_weight, "100.000").
#     % set(auto_limits) -> assign(sos_limit, 20000).
#     % set(auto) -> set(auto_denials).
#     % set(auto) -> set(auto_process).
#
# formulas(sos).
# x = x.
# m(1,x) = x.
# m(x,1) = x.
# m(x,m(y,z)) = m(m(x,y),z).
# m(x,y) = m(y,x).
# m(x,y) != m(x,z) | y = z.
# -d(x,y) | m(x,f(x,y)) = y.
# m(x,z) != y | d(x,y).
# -d(2,m(x,y)) | d(2,x) | d(2,y).
# m(a,a) = m(2,m(b,b)).
# -d(x,a) | -d(x,b) | x = 1.
# 2 != 1.
# end_of_list.
#
# ============================== end of input ==========================
#
# ============================== PROCESS NON-CLAUSAL FORMULAS ==========
#
# % Formulas that are not ordinary clauses:
#
# ============================== end of process non-clausal formulas ===
#
# ============================== PROCESS INITIAL CLAUSES ===============
#
# % Clauses before input processing:
#
# formulas(usable).
# end_of_list.
#
# formulas(sos).
# x = x.  [assumption].
# m(1,x) = x.  [assumption].
# m(x,1) = x.  [assumption].
# m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# m(x,y) = m(y,x).  [assumption].
# m(x,y) != m(x,z) | y = z.  [assumption].
# -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# m(x,y) != z | d(x,z).  [assumption].
# -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# m(a,a) = m(2,m(b,b)).  [assumption].
# -d(x,a) | -d(x,b) | x = 1.  [assumption].
# 2 != 1.  [assumption].
# end_of_list.
#
# formulas(demodulators).
# end_of_list.
#
# ============================== PREDICATE ELIMINATION =================
#
# No predicates eliminated.
#
# ============================== end predicate elimination =============
#
# Auto_denials:  (non-Horn, no changes).
#
# Term ordering decisions:
# Predicate symbol precedence:  predicate_order([ =, d ]).
# Function symbol precedence:  function_order([ 2, 1, a, b, m, f ]).
# After inverse_order:  (no changes).
# Unfolding symbols: (none).
#
# Auto_inference settings:
#   % set(paramodulation).  % (positive equality literals)
#   % set(binary_resolution).  % (non-Horn)
#   % set(neg_ur_resolution).  % (non-Horn, less than 100 clauses)
#
# Auto_process settings:
#   % set(factor).  % (non-Horn)
#   % set(unit_deletion).  % (non-Horn)
#
# kept:      1 m(1,x) = x.  [assumption].
# kept:      2 m(x,1) = x.  [assumption].
#            3 m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# kept:      4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
#
# % Operation m is commutative; C redundancy checks enabled.
# kept:      5 m(x,y) = m(y,x).  [assumption].
# kept:      6 m(x,y) != m(x,z) | y = z.  [assumption].
# kept:      7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# kept:      8 m(x,y) != z | d(x,z).  [assumption].
# kept:      9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
#            10 m(a,a) = m(2,m(b,b)).  [assumption].
# kept:      11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
#            12 -d(x,a) | -d(x,b) | x = 1.  [assumption].
# kept:      13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
#            14 2 != 1.  [assumption].
# kept:      15 1 != 2.  [copy(14),flip(a)].
# kept:      16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
#
# ============================== end of process initial clauses ========
#
# ============================== CLAUSES FOR SEARCH ====================
#
# % Clauses after input processing:
#
# formulas(usable).
# end_of_list.
#
# formulas(sos).
# 1 m(1,x) = x.  [assumption].
# 2 m(x,1) = x.  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
# 6 m(x,y) != m(x,z) | y = z.  [assumption].
# 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# 8 m(x,y) != z | d(x,z).  [assumption].
# 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
# 15 1 != 2.  [copy(14),flip(a)].
# 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
# end_of_list.
#
# formulas(demodulators).
# 1 m(1,x) = x.  [assumption].
# 2 m(x,1) = x.  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
#         % (lex-dep)
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# end_of_list.
#
# ============================== end of clauses for search =============
#
# ============================== SEARCH ================================
#
# % Starting search at 0.00 seconds.
#
# given #1 (I,wt=5): 1 m(1,x) = x.  [assumption].
#
# given #2 (I,wt=5): 2 m(x,1) = x.  [assumption].
#
# given #3 (I,wt=11): 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
#
# given #4 (I,wt=7): 5 m(x,y) = m(y,x).  [assumption].
#
# % Operation m is associative-commutative; CAC redundancy checks enabled.
#
# given #5 (I,wt=10): 6 m(x,y) != m(x,z) | y = z.  [assumption].
#
# given #6 (I,wt=10): 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
#
# given #7 (I,wt=8): 8 m(x,y) != z | d(x,z).  [assumption].
#
# given #8 (I,wt=11): 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
#
# given #9 (I,wt=9): 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
#
# given #10 (I,wt=9): 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
#
# given #11 (I,wt=3): 15 1 != 2.  [copy(14),flip(a)].
#
# given #12 (I,wt=8): 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
#
# given #13 (A,wt=11): 17 m(x,m(y,z)) = m(y,m(x,z)).  [para(5(a,1),4(a,1,1)),rewrite([4(2)])].
#
# given #14 (F,wt=5): 38 m(x,2) != x.  [ur(6,b,15,a),rewrite([2(2)]),flip(a)].
#
# given #15 (F,wt=5): 45 m(2,x) != x.  [para(5(a,1),38(a,1))].
#
# given #16 (F,wt=7): 47 m(b,b) != m(a,a).  [para(11(a,1),45(a,1)),flip(a)].
#
# given #17 (F,wt=9): 44 m(x,m(y,2)) != m(x,y).  [ur(6,b,38,a)].
#
# given #18 (T,wt=3): 24 d(x,x).  [resolve(8,a,2,a)].
#
# given #19 (T,wt=3): 25 d(1,x).  [resolve(8,a,1,a)].
#
# given #20 (T,wt=5): 22 d(x,m(y,x)).  [resolve(8,a,5,a)].
#
# given #21 (T,wt=5): 27 d(x,m(x,y)).  [resolve(8,a,2,a(flip)),rewrite([5(3),1(3)])].
#
# given #22 (A,wt=8): 18 m(x,y) != x | 1 = y.  [para(2(a,1),6(a,1)),flip(a)].
#
# given #23 (F,wt=9): 46 m(x,m(2,y)) != m(x,y).  [ur(6,b,45,a)].
#
# given #24 (F,wt=9): 50 m(x,m(2,y)) != m(y,x).  [para(5(a,1),44(a,1)),rewrite([4(3)])].
#
# given #25 (F,wt=9): 51 m(x,m(y,2)) != m(y,x).  [para(5(a,1),44(a,2))].
#
# given #26 (F,wt=9): 66 m(2,m(x,y)) != m(y,x).  [para(5(a,1),46(a,1)),rewrite([4(3)])].
#
# given #27 (T,wt=5): 33 d(2,m(a,a)).  [resolve(11,a,8,a)].
#
# given #28 (T,wt=3): 79 d(2,a).  [resolve(33,a,16,a)].
#
# given #29 (T,wt=5): 55 f(1,x) = x.  [resolve(25,a,7,a),rewrite([1(4)])].
#
# given #30 (T,wt=6): 28 x != y | d(x,y).  [para(2(a,1),8(a,1))].
#
# given #31 (A,wt=14): 19 m(x,m(y,z)) != m(x,m(y,u)) | z = u.  [para(4(a,1),6(a,1)),rewrite([4(4)])].
#
# given #32 (F,wt=3): 82 -d(2,b).  [ur(13,a,79,a,c,15,a)].
#
# given #33 (F,wt=3): 100 b != 2.  [ur(28,b,82,a),flip(a)].
#
# given #34 (F,wt=5): 101 -d(2,m(b,b)).  [ur(16,b,82,a)].
#
# given #35 (F,wt=5): 102 m(2,x) != b.  [ur(8,b,82,a)].
#
# given #36 (T,wt=6): 53 -d(b,a) | b = 1.  [resolve(24,a,13,b),flip(b)].
#
# given #37 (T,wt=7): 39 d(x,m(y,m(x,z))).  [resolve(17,a,8,a)].
#
# given #38 (T,wt=5): 118 d(b,m(a,a)).  [para(11(a,1),39(a,2))].
#
# given #39 (T,wt=7): 54 m(x,f(x,x)) = x.  [resolve(24,a,7,a)].
#
# given #40 (A,wt=10): 20 m(x,y) != m(z,x) | z = y.  [para(5(a,1),6(a,1)),flip(a)].
#
# given #41 (F,wt=5): 105 m(b,b) != 2.  [ur(28,b,101,a),flip(a)].
#
# given #42 (F,wt=5): 111 m(x,2) != b.  [para(5(a,1),102(a,1))].
#
# given #43 (F,wt=5): 112 m(a,a) != b.  [para(11(a,1),102(a,1))].
#
# given #44 (F,wt=7): 104 m(x,b) != m(x,2).  [ur(6,b,100,a)].
#
# given #45 (T,wt=5): 120 f(x,x) = 1.  [resolve(54,a,18,a),flip(a)].
#
# given #46 (T,wt=6): 131 x != y | y = x.  [para(1(a,1),20(a,1)),rewrite([2(2)])].
#
# given #47 (T,wt=7): 57 d(x,m(y,m(z,x))).  [para(4(a,1),22(a,2))].
#
# given #48 (T,wt=7): 58 d(m(b,b),m(a,a)).  [para(11(a,1),22(a,2))].
#
# given #49 (A,wt=10): 21 m(x,y) != m(z,x) | y = z.  [para(5(a,1),6(a,2))].
#
# given #50 (F,wt=7): 107 -d(2,m(b,m(b,b))).  [ur(9,b,82,a,c,101,a)].
#
# given #51 (F,wt=7): 108 m(b,b) != m(2,x).  [ur(8,b,101,a),flip(a)].
#
# given #52 (F,wt=7): 113 m(x,m(2,y)) != b.  [para(17(a,1),102(a,1))].
#
# given #53 (F,wt=7): 122 m(b,x) != m(x,2).  [ur(20,b,100,a),flip(a)].
#
# given #54 (T,wt=7): 81 m(2,f(2,a)) = a.  [resolve(79,a,7,a)].
#
# given #55 (T,wt=5): 191 d(f(2,a),a).  [para(81(a,1),22(a,2))].
#
# given #56 (T,wt=5): 197 d(2,m(x,a)).  [para(81(a,1),39(a,2,2))].
#
# given #57 (T,wt=5): 206 d(2,m(a,x)).  [para(5(a,1),197(a,2))].
#
# given #58 (A,wt=9): 23 d(m(x,y),m(x,m(y,z))).  [resolve(8,a,4,a)].
#
# given #59 (F,wt=3): 196 b != a.  [para(81(a,1),102(a,1)),flip(a)].
#
# given #60 (F,wt=5): 190 f(2,a) != a.  [para(81(a,1),45(a,1)),flip(a)].
#
# given #61 (F,wt=5): 201 m(b,b) != a.  [para(81(a,1),108(a,2))].
#
# given #62 (F,wt=5): 202 m(x,a) != b.  [para(81(a,1),113(a,1,2))].
#
# given #63 (T,wt=6): 188 a != x | d(2,x).  [para(81(a,1),8(a,1))].
#
# given #64 (T,wt=7): 84 d(m(x,y),m(y,x)).  [resolve(28,a,5,a)].
#
# given #65 (T,wt=7): 200 d(f(2,a),m(x,a)).  [para(81(a,1),57(a,2,2))].
#
# given #66 (T,wt=7): 205 d(2,m(x,m(y,a))).  [para(4(a,1),197(a,2))].
#
# given #67 (A,wt=12): 29 m(x,m(y,z)) != u | d(m(x,y),u).  [para(4(a,1),8(a,1))].
#
# given #68 (F,wt=5): 233 m(a,x) != b.  [para(5(a,1),202(a,1))].
#
# given #69 (F,wt=3): 255 -d(a,b).  [ur(7,b,233,a)].
#
# given #70 (F,wt=7): 128 m(2,x) != m(x,b).  [ur(20,b,100,a(flip)),flip(a)].
#
# given #71 (F,wt=7): 147 m(x,m(y,2)) != b.  [para(4(a,1),111(a,1))].
#
# given #72 (T,wt=7): 208 d(2,m(x,m(a,y))).  [para(17(a,1),206(a,2))].
#
# given #73 (T,wt=7): 214 d(m(2,b),m(a,a)).  [para(11(a,1),23(a,2))].
#
# given #74 (T,wt=7): 217 d(m(x,2),m(x,a)).  [para(81(a,1),23(a,2,2))].
#
# given #75 (T,wt=7): 241 d(f(2,a),m(a,x)).  [para(5(a,1),200(a,2))].
#
# given #76 (A,wt=8): 30 m(x,y) != z | d(y,z).  [para(5(a,1),8(a,1))].
#
# given #77 (F,wt=7): 164 m(b,m(b,b)) != 2.  [ur(28,b,107,a),flip(a)].
#
# given #78 (F,wt=7): 172 m(b,b) != m(x,2).  [para(5(a,1),108(a,2))].
#
# given #79 (F,wt=7): 184 m(b,x) != m(2,x).  [para(5(a,1),122(a,2))].
#
# given #80 (F,wt=7): 218 m(a,x) != m(x,b).  [ur(21,b,196,a),flip(a)].
#
# given #81 (T,wt=7): 275 d(m(2,x),m(x,a)).  [para(5(a,1),217(a,1))].
#
# given #82 (T,wt=7): 276 d(m(x,2),m(a,x)).  [para(5(a,1),217(a,2))].
#
# given #83 (T,wt=7): 304 d(m(2,x),m(a,x)).  [para(5(a,1),275(a,2))].
#
# given #84 (T,wt=8): 37 m(a,a) != x | d(2,x).  [para(11(a,1),8(a,1))].
#
# given #85 (A,wt=15): 31 -d(2,m(x,m(y,z))) | d(2,m(x,y)) | d(2,z).  [para(4(a,1),9(a,2))].
#
# given #86 (F,wt=7): 219 m(b,x) != m(x,a).  [ur(20,b,196,a),flip(a)].
#
# given #87 (F,wt=7): 221 m(x,b) != m(x,a).  [ur(6,b,196,a)].
#
# given #88 (F,wt=7): 232 m(x,m(y,a)) != b.  [para(4(a,1),202(a,1))].
#
# given #89 (F,wt=7): 234 m(b,m(b,b)) != a.  [ur(188,b,107,a),flip(a)].
#
# given #90 (T,wt=8): 62 m(x,y) != y | 1 = x.  [para(5(a,1),18(a,1))].
#
# given #91 (T,wt=8): 192 a != 2 | f(2,a) = 1.  [para(81(a,1),18(a,1)),flip(b)].
#
# given #92 (T,wt=8): 282 a != x | d(f(2,a),x).  [para(81(a,1),30(a,1))].
#
# given #93 (T,wt=9): 59 d(m(x,y),m(x,m(z,y))).  [para(17(a,1),22(a,2))].
#
# given #94 (A,wt=14): 32 -d(2,m(x,m(y,m(x,y)))) | d(2,m(x,y)).  [factor(31,b,c)].
#
# given #95 (F,wt=7): 257 m(x,m(a,y)) != b.  [para(17(a,1),233(a,1))].
#
# given #96 (F,wt=7): 263 m(b,f(2,a)) != a.  [para(81(a,1),128(a,1)),rewrite([5(6)]),flip(a)].
#
# given #97 (F,wt=7): 301 m(b,x) != m(a,x).  [para(5(a,1),218(a,2)),flip(a)].
#
# given #98 (F,wt=9): 106 -d(2,m(b,m(b,m(b,b)))).  [ur(16,b,101,a),rewrite([17(8),5(7)])].
#
# given #99 (T,wt=9): 116 d(x,m(y,m(z,m(x,u)))).  [para(4(a,1),39(a,2))].
#
# given #100 (T,wt=7): 368 d(b,m(x,m(a,a))).  [para(11(a,1),116(a,2,2))].
#
# given #101 (T,wt=7): 371 d(b,m(a,m(a,x))).  [para(5(a,1),368(a,2)),rewrite([4(5)])].
#
# given #102 (T,wt=7): 372 d(b,m(a,m(x,a))).  [para(17(a,1),368(a,2))].
#
# given #103 (A,wt=13): 34 m(2,m(b,m(b,x))) = m(a,m(a,x)).  [para(11(a,1),4(a,1,1)),rewrite([4(4),4(9)]),flip(a)].
#
# given #104 (F,wt=9): 110 m(x,m(2,y)) != m(x,b).  [ur(6,b,102,a)].
#
# given #105 (F,wt=9): 121 m(2,m(x,y)) != m(y,b).  [ur(20,b,102,a),rewrite([4(5)]),flip(a)].
#
# given #106 (F,wt=9): 127 m(b,x) != m(x,m(2,y)).  [ur(20,b,102,a(flip)),flip(a)].
#
# given #107 (F,wt=9): 139 m(b,m(b,x)) != m(x,2).  [ur(20,b,105,a),rewrite([4(6)]),flip(a)].
#
# given #108 (T,wt=9): 158 d(x,m(y,m(z,m(u,x)))).  [para(4(a,1),57(a,2,2))].
#
# given #109 (T,wt=9): 159 d(m(b,b),m(x,m(a,a))).  [para(11(a,1),57(a,2,2))].
#
# given #110 (T,wt=9): 211 d(m(x,y),m(y,m(x,z))).  [para(5(a,1),23(a,1))].
#
# given #111 (T,wt=9): 212 d(m(x,y),m(y,m(z,x))).  [para(5(a,1),23(a,2)),rewrite([4(3)])].
#
# given #112 (A,wt=13): 35 m(b,m(b,m(x,2))) = m(x,m(a,a)).  [para(11(a,1),4(a,2,2)),rewrite([17(6),5(5)])].
#
# given #113 (F,wt=9): 141 m(x,m(b,b)) != m(x,2).  [ur(6,b,105,a)].
#
# given #114 (F,wt=7): 513 m(a,a) != m(2,2).  [para(11(a,1),141(a,1))].
#
# given #115 (F,wt=9): 142 m(2,x) != m(x,m(b,b)).  [ur(20,b,105,a(flip)),flip(a)].
#
# given #116 (F,wt=9): 143 m(x,m(2,y)) != m(y,b).  [ur(20,b,111,a),rewrite([4(5)]),flip(a)].
#
# given #117 (T,wt=9): 213 d(m(x,2),m(x,m(a,a))).  [para(11(a,1),23(a,2,2))].
#
# given #118 (T,wt=9): 240 d(f(2,a),m(x,m(y,a))).  [para(4(a,1),200(a,2))].
#
# given #119 (T,wt=9): 243 d(2,m(x,m(y,m(z,a)))).  [para(4(a,1),205(a,2,2))].
#
# given #120 (T,wt=9): 270 d(2,m(x,m(y,m(a,z)))).  [para(4(a,1),208(a,2))].
#
# given #121 (A,wt=12): 36 m(a,a) != m(2,x) | m(b,b) = x.  [para(11(a,1),6(a,1))].
#
# given #122 (F,wt=7): 548 m(a,a) != m(2,a).  [ur(36,b,201,a)].
#
# given #123 (F,wt=9): 145 m(x,m(y,2)) != m(x,b).  [ur(6,b,111,a)].
#
# given #124 (F,wt=9): 146 m(b,x) != m(x,m(y,2)).  [ur(20,b,111,a(flip)),flip(a)].
#
# given #125 (F,wt=9): 167 m(b,m(b,b)) != m(2,x).  [ur(8,b,107,a),flip(a)].
#
# given #126 (T,wt=9): 278 d(f(2,a),m(x,m(a,y))).  [para(17(a,1),241(a,2))].
#
# given #127 (T,wt=9): 305 d(m(a,a),m(a,m(b,b))).  [para(11(a,1),275(a,1)),rewrite([5(8)])].
#
# given #128 (T,wt=9): 339 d(m(x,y),m(z,m(y,x))).  [para(5(a,1),59(a,2)),rewrite([4(3)])].
#
# given #129 (T,wt=9): 342 d(m(x,f(2,a)),m(x,a)).  [para(81(a,1),59(a,2,2))].
#
# given #130 (A,wt=14): 40 m(x,m(y,z)) != m(y,u) | m(x,z) = u.  [para(17(a,1),6(a,1))].
#
# given #131 (F,wt=9): 173 m(b,b) != m(x,m(2,y)).  [para(17(a,1),108(a,2))].
#
# given #132 (F,wt=7): 639 m(b,b) != m(x,a).  [para(81(a,1),173(a,2,2))].
# -------- Proof 1 --------
#
# ============================== PROOF =================================
#
# % Proof 1 at 0.02 (+ 0.06) seconds.
# % Length of proof is 27.
# % Level of proof is 10.
# % Maximum clause weight is 12.000.
# % Given clauses 132 (13.200 givens/level).
#
# 3 m(x,m(y,z)) = m(m(x,y),z).  [assumption].
# 4 m(m(x,y),z) = m(x,m(y,z)).  [copy(3),flip(a)].
# 5 m(x,y) = m(y,x).  [assumption].
# 6 m(x,y) != m(x,z) | y = z.  [assumption].
# 7 -d(x,y) | m(x,f(x,y)) = y.  [assumption].
# 8 m(x,y) != z | d(x,z).  [assumption].
# 9 -d(2,m(x,y)) | d(2,x) | d(2,y).  [assumption].
# 10 m(a,a) = m(2,m(b,b)).  [assumption].
# 11 m(2,m(b,b)) = m(a,a).  [copy(10),flip(a)].
# 12 -d(x,a) | -d(x,b) | x = 1.  [assumption].
# 13 -d(x,a) | -d(x,b) | 1 = x.  [copy(12),flip(c)].
# 14 2 != 1.  [assumption].
# 15 1 != 2.  [copy(14),flip(a)].
# 16 -d(2,m(x,x)) | d(2,x).  [factor(9,b,c)].
# 17 m(x,m(y,z)) = m(y,m(x,z)).  [para(5(a,1),4(a,1,1)),rewrite([4(2)])].
# 33 d(2,m(a,a)).  [resolve(11,a,8,a)].
# 36 m(a,a) != m(2,x) | m(b,b) = x.  [para(11(a,1),6(a,1))].
# 79 d(2,a).  [resolve(33,a,16,a)].
# 81 m(2,f(2,a)) = a.  [resolve(79,a,7,a)].
# 82 -d(2,b).  [ur(13,a,79,a,c,15,a)].
# 101 -d(2,m(b,b)).  [ur(16,b,82,a)].
# 108 m(b,b) != m(2,x).  [ur(8,b,101,a),flip(a)].
# 173 m(b,b) != m(x,m(2,y)).  [para(17(a,1),108(a,2))].
# 186 m(2,m(f(2,a),x)) = m(a,x).  [para(81(a,1),4(a,1,1)),flip(a)].
# 639 m(b,b) != m(x,a).  [para(81(a,1),173(a,2,2))].
# 642 m(a,a) != m(2,m(x,a)).  [ur(36,b,639,a)].
# 643 $F.  [resolve(642,a,186,a(flip))].
#
# ============================== end of proof ==========================
#
# ============================== STATISTICS ============================
#
# Given=132. Generated=2152. Kept=638. proofs=1.
# Usable=127. Sos=485. Demods=56. Limbo=1, Disabled=36. Hints=0.
# Kept_by_rule=0, Deleted_by_rule=0.
# Forward_subsumed=1514. Back_subsumed=15.
# Sos_limit_deleted=0. Sos_displaced=0. Sos_removed=0.
# New_demodulators=58 (2 lex), Back_demodulated=9. Back_unit_deleted=0.
# Demod_attempts=18123. Demod_rewrites=1480.
# Res_instance_prunes=0. Para_instance_prunes=0. Basic_paramod_prunes=0.
# Nonunit_fsub_feature_tests=1506. Nonunit_bsub_feature_tests=528.
# Megabytes=0.81.
# User_CPU=0.02, System_CPU=0.06, Wall_clock=0.
#
# ============================== end of statistics =====================
#
# ============================== end of search =========================
#
# THEOREM PROVED
#
# THEOREM PROVED
#
# Exiting with 1 proof.
#
# ------ process 259687 exit (max_proofs) ------
#
# Process 259687 exit (max_proofs) Mon Apr 29 17:27:10 2024

# %%
# Out:
# Overwriting /tmp/sqrt.p

# %%
# %%file /tmp/prime3.smt2
# (declare-sort I 0)
# (declare-fun m (I I) I)
# (declare-fun f (I I) I)
# (declare-fun d (I I) Bool)
# (declare-const one I)
# (declare-const two I)
# (declare-const a I)
# (declare-const b I)
#
# (assert (forall ((x I)) (= (m one x) x)))
# (assert (forall ((x I)) (= (m x one) x)))
# (assert (forall ((x I) (y I) (z I)) (= (m x (m y z)) (m (m x y) z))))
# (assert (forall ((x I) (y I)) (= (m x y) (m y x))))
# (assert (forall ((x I) (y I) (z I))
#   (=> (= (m x y) (m x z)) (= y z))))
# (assert (forall ((x I) (y I)) (=> (d y x) (= (m y (f y x)) x))))
# (assert (forall ((x I) (y I))
#   (=> (d two (m x y)) (or (d two x) (d two y)))))
# (assert (= (m a a) (m two (m b b)))) ;
# (assert (forall ((x I)) (=> (and (d x a) (d x b)) (= x one)))) ; lowest common terms
# (assert (distinct one two))
# (check-sat)
# Out:
# Overwriting /tmp/prime3.smt2

# %%
! time vampire /tmp/sqrt.p
# Out:
# % Running in auto input_syntax mode. Trying TPTP
# % Refutation found. Thanks to Tanya!
# % SZS status Unsatisfiable for sqrt
# % SZS output start Proof for sqrt
# 3. m(X0,m(X1,X2)) = m(m(X0,X1),X2) [input]
# 4. m(X0,X1) = m(X1,X0) [input]
# 5. m(X0,X1) != m(X0,X2) | X1 = X2 [input]
# 6. ~d(X0,X1) | m(X0,f(X0,X1)) = X1 [input]
# 7. d(X0,X2) | m(X0,X1) != X2 [input]
# 8. ~d(two,m(X0,X1)) | d(two,X0) | d(two,X1) [input]
# 9. m(a,a) = m(two,m(b,b)) [input]
# 10. ~d(X0,b) | one = X0 | ~d(X0,a) [input]
# 11. one != two [input]
# 12. d(X0,m(X0,X1)) [equality resolution 7]
# 21. d(X0,m(X1,X0)) [superposition 12,4]
# 25. d(two,m(a,a)) [superposition 12,9]
# 46. m(a,a) != m(two,X0) | m(b,b) = X0 [superposition 5,9]
# 53. m(X0,X1) = m(X0,f(X0,m(X0,X1))) [resolution 6,12]
# 57. m(a,a) = m(two,f(two,m(a,a))) [resolution 6,25]
# 74. d(X2,m(X0,m(X1,X2))) [superposition 21,3]
# 88. d(two,a) | d(two,a) [resolution 8,25]
# 98. d(two,a) [duplicate literal removal 88]
# 99. a = m(two,f(two,a)) [resolution 98,6]
# 198. m(X0,X1) != m(X0,X2) | f(X0,m(X0,X1)) = X2 [superposition 5,53]
# 264. d(X1,m(X2,m(X1,X0))) [superposition 74,4]
# 486. m(a,X0) = m(two,m(f(two,a),X0)) [superposition 3,99]
# 684. d(two,m(X0,a)) [superposition 264,99]
# 1125. m(a,a) != m(a,a) | m(b,b) = f(two,m(a,a)) [superposition 46,57]
# 1160. m(b,b) = f(two,m(a,a)) [trivial inequality removal 1125]
# 7642. f(X0,m(X0,X1)) = X1 [equality resolution 198]
# 58952. m(f(two,a),X0) = f(two,m(a,X0)) [superposition 7642,486]
# 154801. m(b,b) = m(f(two,a),a) [superposition 58952,1160]
# 154861. d(two,m(b,b)) [superposition 684,154801]
# 163619. d(two,b) | d(two,b) [resolution 154861,8]
# 163621. d(two,b) [duplicate literal removal 163619]
# 163624. one = two | ~d(two,a) [resolution 163621,10]
# 163626. ~d(two,a) [subsumption resolution 163624,11]
# 163627. $false [subsumption resolution 163626,98]
# % SZS output end Proof for sqrt
# % ------------------------------
# % Version: Vampire 4.8 (commit 23d7e9c3b on 2024-03-22 08:41:08 +0000)
# % Linked with Z3 4.12.3.0 79bbbf76d0c123481c8ca05cd3a98939270074d3 z3-4.8.4-7980-g79bbbf76d
# % Termination reason: Refutation
#
# % Memory used [KB]: 34500
# % Time elapsed: 10.284 s
# perf_event_open failed (instruction limiting will be disabled): Permission denied
# (If you are seeing 'Permission denied' ask your admin to run 'sudo sysctl -w kernel.perf_event_paranoid=-1' for you.)
# % ------------------------------
# % ------------------------------
#
# real	0m10.291s
# user	0m10.242s
# sys	0m0.045s

# %%
# %%file /tmp/sqrtcluase.p
#
# cnf(sos,axiom,
#     m(one,X0) = X0).
#
# cnf(sos,axiom,
#     m(X0,one) = X0).
#
# cnf(sos,axiom,
#     m(m(X1,X0),X2) = m(X1,m(X0,X2))).
#
# cnf(sos,axiom,
#     m(X0,X1) = m(X1,X0)).
#
# cnf(sos,axiom,
#     X0 = X2 | m(X1,X2) != m(X1,X0)).
#
# cnf(sos,axiom,
#     m(X0,f(X0,X1)) = X1 | ~d(X0,X1)).
#
# cnf(sos,axiom,
#     d(two,X1) | d(two,X0) | ~d(two,m(X1,X0))).
#
# cnf(sos,axiom,
#     m(two,m(b,b)) = m(a,a)).
#
# cnf(sos,axiom,
#     one = X0 | ~d(X0,a) | ~d(X0,b)).
#
# cnf(sos,axiom,
#     one != two).
#
# %cnf(sos,axiom,~ d(A,B) | m(A,f(A,B)) = B).
# cnf(sos,axiom, m(A,B) != C | d(A,C)).
# %cnf(sos,axiom,~ d(two,m(A,B)) | d(two,A) | d(two,B)).
# %cnf(sos,axiom,m(a,a) = m(two,m(b,b))).
# %cnf(sos,axiom,~ d(A,a) | ~ d(A,b) | A = one).
# %cnf(sos,axiom,~ two = one).
# Out:
# Overwriting /tmp/sqrtcluase.p

# %%
! time eprover-ho /tmp/sqrt.p

# %%
import z3

x = z3.Int("x")
e = x+2
e.sexpr()
x.decl().sexpr()
def collect_symbols(expr, symbols):
    """ Recursively collect constants and function symbols from an expression. """
    if expr.num_args() == 0:
        # It's a constant if it has no arguments (excluding bound variables in quantifiers)
        if expr.decl().kind() == z3.Z3_OP_UNINTERPRETED:
            symbols.add(expr)
    else:
        # If the node is a function application, add the function declaration
        if expr.decl().kind() == z3.Z3_OP_UNINTERPRETED or expr.decl().kind() == z3.Z3_OP_APPLY:
            symbols.add(expr.decl())
        # Go deeper into the expression for nested function applications
        for i in range(expr.num_args()):
            collect_symbols(expr.arg(i), symbols)
# naw this is ridiculous. I'll just collect up my constants manually.
#collect_symbols(e, set())
z3.ForAll([x],e > 2).sexpr()
Nat = z3.Datatype("Nat")
Nat.declare("zero")
Nat.declare("succ", ("prev", Nat))
Nat = Nat.create()
Nat.sexpr()
Nat.succ.sexpr()
# Out:
# '(declare-fun succ (Nat) Nat)'

# %% [markdown]
# ## PySMT
# I thought maybe I should use pysmt. But I dunno. I'm so familiar with the z3 bindings.

# %%
from pysmt.shortcuts import Symbol, And, GE, LT, Plus, Equals, Int, get_model
from pysmt.typing import INT

hello = [Symbol(s, INT) for s in "hello"]
world = [Symbol(s, INT) for s in "world"]
letters = set(hello+world)
domains = And([And(GE(l, Int(1)),
                   LT(l, Int(10))) for l in letters])

sum_hello = Plus(hello) # n-ary operators can take lists
sum_world = Plus(world) # as arguments
problem = And(Equals(sum_hello, sum_world),
              Equals(sum_hello, Int(25)))
formula = And(domains, problem)

print("Serialization of the formula:")
print(formula)

model = get_model(formula)
if model:
  print(model)
else:
  print("No solution found")
# Out:
# Serialization of the formula:
# ((((1 <= h) & (h < 10)) & ((1 <= e) & (e < 10)) & ((1 <= l) & (l < 10)) & ((1 <= o) & (o < 10)) & ((1 <= w) & (w < 10)) & ((1 <= r) & (r < 10)) & ((1 <= d) & (d < 10))) & (((h + e + l + l + o) = (w + o + r + l + d)) & ((h + e + l + l + o) = 25)))
# d := 9
# o := 5
# r := 1
# w := 1
# h := 1
# l := 9
# e := 1

# %%
from pysmt.logics import QF_UFLRA, QF_UFIDL, QF_LRA, QF_IDL, QF_LIA
from pysmt.shortcuts import get_env, GT, Solver, Symbol
logics = [QF_UFLRA, QF_UFIDL, QF_LIA],  # Some of the supported logics

env = get_env()

# Add the solver to the environment
env.factory.add_generic_solver("vampire","/usr/local/bin/vampire" , logics)

# %%
with Solver(name="vampire", logic=QF_LIA) as s:
    s.add_assertion(formula)
    if s.solve():
        print(s.get_model())
    else:
        print("No solution found")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with Solver(name="vampire", logic=QF_LIA) as s:
#       2     s.add_assertion(formula)
#       3     if s.solve():
#
# File ~/.local/lib/python3.10/site-packages/pysmt/shortcuts.py:908, in Solver(name, logic, **kwargs)
#     901 def Solver(name=None, logic=None, **kwargs):
#     902     """Returns a solver.
#     903
#     904     :param name: Specify the name of the solver
#     905     :param logic: Specify the logic that is going to be used.
#     906     :rtype: Solver
#     907     """
# --> 908     return get_env().factory.Solver(name=name,
#     909                                     logic=logic,
#     910                                     **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pysmt/factory.py:437, in Factory.Solver(self, name, logic, **options)
#     436 def Solver(self, name=None, logic=None, **options):
# --> 437     return self.get_solver(name=name,
#     438                            logic=logic,
#     439                            **options)
#
# File ~/.local/lib/python3.10/site-packages/pysmt/factory.py:91, in Factory.get_solver(self, name, logic, **options)
#      89 def get_solver(self, name=None, logic=None, **options):
#      90     SolverClass, closer_logic = \
# ---> 91        self._get_solver_class(solver_list=self._all_solvers,
#      92                               solver_type="Solver",
#      93                               preference_list=self.solver_preference_list,
#      94                               default_logic=self.default_logic,
#      95                               name=name,
#      96                               logic=logic)
#      98     return SolverClass(environment=self.environment,
#      99                        logic=closer_logic,
#     100                        **options)
#
# File ~/.local/lib/python3.10/site-packages/pysmt/factory.py:155, in Factory._get_solver_class(self, solver_list, solver_type, preference_list, default_logic, name, logic)
#     150 if name not in solver_list:
#     151     raise NoSolverAvailableError("%s '%s' is not available" % \
#     152                                  (solver_type, name))
#     154 if logic is not None and \
# --> 155    name not in self._filter_solvers(solver_list, logic=logic):
#     156     raise NoSolverAvailableError("%s '%s' does not support logic %s"%
#     157                                  (solver_type, name, logic))
#     159 SolverClass = solver_list[name]
#
# File ~/.local/lib/python3.10/site-packages/pysmt/factory.py:361, in Factory._filter_solvers(self, solver_list, logic)
#     359 for s, v in solver_list.items():
#     360     for l in v.LOGICS:
# --> 361         if logic <= l:
#     362             res[s] = v
#     363             break
#
# File ~/.local/lib/python3.10/site-packages/pysmt/logics.py:273, in Logic.__le__(self, other)
#     272 def __le__(self, other):
# --> 273     return (self.theory <= other.theory and
#     274             self.quantifier_free >= other.quantifier_free)
#
# AttributeError: 'list' object has no attribute 'theory'

# %% [markdown]
# ### A Manual Proof Discipline
# Here were some old experiments using raw smtlib idioms
#
# Separation between module signature and proofs. Seperate files.
# Proof datatype to separate from bool definitions
#
# ```z3
# ;re
# (declare-datatypes () (
#   (Proof (Proof (getformula Bool)))
# ))
# (define-fun proved ((p Proof)) Bool
#   (match p (
#     ((Proof p) (not p))
#   ))
# )
# (define-fun instan-lemma1 ((x Int)) Bool  (or (> x 0) (< x 0) (= x 0)))
# (define-const lemma1 Proof (Proof (forall ((x Int)) (instan-lemma1 x))))
#
# (push)
# ;------------
# (assert (proved lemma1))
# (check-sat)
# (pop)
#
# ```
#
# Other possibility for Proof type
# Forall (Expr)
# Exists (Expr)
# Eh. I don't really want to reflect everything.
#
# A shallower HOAS embedding
#
# ```z3
# ;re
# (declare-datatype Formula (
#   (Bool (bool1 Bool))
#   (Forall (forall1 (Array Int Formula)))
#   (Exists (exists1 (Array Int Formula)))
# ))
#
#
# ```
#
# ```z3
# ;re
# (declare-datatype Exists
#   (
#     (Pair (x Int) (pred (Array Int Bool)))
#   ))
#
# ```
#
# Universals can be proven by having
# (define-const x)
#
# ```
# ; other hypothesis do not mention x
# ;-----------------
# (instan-lemma1 x)
# ```
#
# or by
# ; other hypothesis can't possibly mention x
# ;-----------
# (assert (proved lemma1))
#
# Universal can be used by using lemma1 or by instan-lemma1 on anything
#
# Existentials can be proved
#
# ```
# ----------
# (exists x (relx x))
# ```
#
# or by
#
# ```
# whatever
# ---------
# (relx 3)
#
# ```
#
# They can be used via
#
# ```
# define-const x
# (relx x)
# ; no other use of x
# ;----------------
# conclusion may refer to x
#
# ```
#
# ExistsE (ExistsE Bool)
# ForallE (ForallE (forallE Bool)) ; (apply?)
# Forall (ForallI (forallE Bool))
#
# (Exists Int Bool) ; can I pack the witness?
#
# define-const lemma Forall (forall x (forallE (instan-lemma x)))
# define-fun instan-lemma ((x Int)) ForallE
#
# The method is related to lambda lifting.
# We need to give names to different free parameter things.
#
# ```z3
# ;re
# (declare-fun even-fun (Int) Int)
# (define-fun even ((x Int)) Bool (= (* 2 (even-fun x)) x))
#
# (declare-fun odd-fun (Int) Int)
# (define-fun odd ((x Int)) Bool (= (+ 1 (* 2 (odd-fun x))) x))
#
# ;(define-fun even ((x Int)) Bool (exists ((y Int)) (= (* 2 y) x)))
# (define-const even-axiom Bool (forall ((x Int)) (=> (exists ((y Int)) (= (* 2 y) x)) (= (* 2 (even-fun x)) x))))
# ;(define-fun even ((x Int)) Bool (exists ((y Int)) (and (= y (even-fun x)) (= (* 2 y) x))))
# (define-fun not-even ((x Int)) Bool (forall ((y Int)) (distinct x (* 2 y))))
# ;(define-fun instan-not-even ((x Int) (y Int)) (distinct x (2 * y)))
#
# (declare-const m Int)
# (declare-const n Int)
# (assert (odd m))
# (assert (odd n))
# (assert (not (even m)))
# (assert (not (even n)))
# ;(assert (instan-not-even m (even-fun )))
# (assert-not (even (+ n m)))
# ;(assert (not-even (+ n m)))
# (check-sat)
# (get-model)
#
# ```
#
# ```z3
# ;re
# (define-fun even ((x Int) (y Int)) Bool (= (* 2 y) x))
# (define-fun odd ((x Int) (y Int)) Bool (= (+ 1 (* 2 y)) x))
#
#
# (declare-const m Int)
# (declare-const n Int)
# (declare-const mo Int)
# (declare-const no Int)
# (assert (odd m mo))
# (assert (odd n no))
# (assert-not (exists ((x Int)) (even (+ m n) x)))
# (check-sat)
#
# ```
#
# ```z3
# ;re
# (define-fun even ((x Int)) Bool (exists ((y Int)) (= (* 2 y) x)))
# (define-fun odd ((x Int)) Bool (exists ((y Int)) (= (+ 1 (* 2 y)) x)))
#
# (declare-const m Int)
# (declare-const n Int)
# (assert (odd m))
# (assert (odd n))
# ;--------------------------
# (assert-not (even (+ m n)))
# (check-sat)
# ```
#
# ```z3
#
# ```z3
# ;re
# (define-fun even ((x Int)) Bool (exists ((y Int)) (= (* 2 y) x)))
# (define-fun div4 ((x Int)) Bool (exists ((y Int)) (= (* 4 y) x)))
#
# (declare-const m Int)
# (assert (not (even m)))
# ;---------------------------
# (assert-not (not (div4 m)))
# (check-sat)
# ```
#
# Positively asserting existence isn't so bad. It is just asserting on a fresh variable.
#
# Only allow mention variable once on existential elim in hyps
#
# I'm a little worried about circulaity if I pack everything into one proof thing.
#
# existential lemma can be used in hyps.
# Instantiated version in a conc (give explicitly). Or just let it crank.
#
# ```
# (declare-const e) appears only once in hyp for existential elim
#
# (assert-not
#   (=> (and (existse e) (instan-lemma1 ))
#       (and lemma1 )
#   )
#
# )
#
# ```
#
# ```z3
# ;re
# (define-fun instan-theorem ((m Int) (n Int)) Bool (not (= (* m m) (* 2 (* n n)))))
# (define-const theorem Bool (forall ((m Int) (n Int)) (not (= (* m m) (* 2 (* n n))))))
#
#
# ```

# %% [markdown]
# ### Python Hilbert Proof
# An older database style attempt
#
# Hilbert style proofs where the only inference rule is Z3_check.
# Register known theorems to central repository. Refer to them later.
# There are some basic theorems with quantifiers I couldn't get Z3 to do even the most basic step of, so this idea feels sunk.
# I guess I could also admit vampire.
#
# ```python
# from z3 import *
# class Kernel():
#     def __init__(self):
#         self._formula = {}
#         self._schema = {}
#         self._explanations = {}
#     def axiom(self, name, formula):
#         assert name not in self._formula
#         self._formula[name] = (formula, None)
#         return name
#     def add_schema(self, name, schema):
#         assert name not in self._schema
#         self._schema[name] = schema
#         return name
#     def instan_schema(self, schema, name, *args):
#         #name = self.fresh(name)
#         self._formula[name] = (self._schema[schema](*args), ("schema", schema))
#         return name
#     def theorem(self, name, formula, *reasons, timeout=1):
#         assert name not in self._formula
#         s = Solver()
#         #s.set("timeout", timeout)
#
#         s.add([ self._formula[reason][0] for reason in reasons])
#         # snity check here. s.check(). should return unknown. If returns unsat, we have an incosisitency
#         # Even if we have inconsistency but z3 isn't finding it, that is a small comfort.
#         s.add(Not(formula))
#         status = s.check()
#         if status == unsat:
#             self._formula[name] = (formula, reasons)
#             print(f"Accepted {name}")
#         elif status == sat:
#             print(f"Counterexample : {s.model()}")
#         elif status == unknown:
#             print("Failed: reason unknown")
#         else:
#             print(f"unexpected status {status}")
#     #def calc(self):
#     #    pass
#     #def definition: # is definition distinct from axiom?
#
# t = Kernel()
# p = Real("p")
# t.axiom("p_def", p*p == 2)
# m,n = [ToReal(x) for x in Ints("m n")]
#
# #t.theorem("p irrational", p != m / n)
# #(m / n == p)
# def even(x):
#     y = FreshInt()
#     return Exists([y], 2 * y == x)
# def odd(x):
#     y = FreshInt()
#     return Exists([y], 2 * y + 1 == x)
# r,w = Ints("r w")
# t.theorem("even odd", ForAll([r], even(r) != odd(r)))
# def rational(p):
#     m = FreshInt("m")
#     n = FreshInt("n")
#     return Exists([m,n], And(n != 0, p == ToReal(m) / ToReal(n) ))
# rational(p)
#
# #t.theorem("mndef", Implies(rational(p), p == m / n) )
#
# #t.theorem( Implies( p == m / n, Exists([r,w], And(p == r / w,  Or(And(even(r), odd(w)), And(odd(r), even(w)) ) ))))
# # how do you use this exists?
#
# #t.theorem(   )
# def evenodd(n,m):
#     return even(n) != even(m)
#
# t.theorem(0, Implies(  And(p == m / n, n != 0) , p * n == m  ))
# t.theorem(1, Implies(  And(p == m / n, n != 0, evenodd(m,n)) , p * n == m  ))
# #t.theorem(2, Implies(  And(p == m / n, n != 0, evenodd(m,n)) , 2 * n * n == m * m , "p_def"))
# t.theorem(3, even(r) != odd(r))
# #t.theorem(4, even(r * r) != odd(r * r))
# t.theorem(5, Implies(r == 2 * w, even(r*r) ))
# t.theorem(6, Implies(r == 2 * w, r*r == 4 * w * w ))
#
# #t.theorem(7, Implies(r == 2 * w, even(r) ))
# #t.theorem(8, Implies(even(r), even(r*r)), 5, 6, 7)
# t.theorem("even or odd", Or(even(r), odd(r)))
# #t.theorem("even or odd r*r", Or(even(r*r), odd(r*r)))
# t.theorem(8, ForAll([r], even(r) != odd(r)))
# t.theorem(9, even(r*r) != odd(r*r), 8)
# # I dunno. This idea is sunk. I can't even get this to work?
# # I could try not using the built in stuff I guess and wwork in FOL.
#
#
# #t.theorem(5, odd(r) == odd(r * r), 3, 4)
# #t.theorem(3, Implies(even(r * r), even(r) ))
# #t.theorem(3, Implies(  And(2 * n * n == m * m), even(m)))
#
#
#
#
# #t.theorem(0, Implies(  p == m / n , m * m == 2 * n * n   ), "p_def" )
# even(r * r) != odd(r * r)
# ```
#
# ```python
# t = Hilbert()
#
# Nat = Datatype('Nat')
# Nat.declare('Zero')
# Nat.declare('Succ', ('pred', Nat))
# # Create the datatype
# Nat = Nat.create()
# Zero = Nat.Zero
# Succ = Nat.Succ
#
# n,m = Consts("n m", Nat)
# plus = Function("+", Nat,Nat,Nat)
# DatatypeRef.__add__ = lambda self, rhs : plus(self, rhs)
# #type(n)
# plus_zero = t.axiom("plus_zero", ForAll([m], Zero + m == m))
# plus_succ = t.axiom("plus_succ", ForAll([n,m], Succ(n) + m == Succ(n + m)))
# plus_def = [plus_zero, plus_succ]
# def induction_schema(P):
#     return  Implies(
#                 And(P(Zero),
#                     ForAll([n], Implies(P(n), P(Succ(n))))) ,
#                 ForAll([n], P(n))
#     )
# induction = t.add_schema("induction", induction_schema)
#
# t.theorem( "plus_zero'",  ForAll([m], Zero + m == m , patterns=[Zero + m]), plus_zero) # guardedc version of the axiom
# mylemma = t.instan(induction, "mylemma", lambda m : Zero + m == m + Zero )
#
# t.theorem( "n_plus_zero", ForAll([m], Zero + m == m + Zero) ,  plus_zero, plus_succ,  mylemma )
# t.theorem("test guarding", Zero + Zero == Succ(Zero), "plus_zero")
#
# lte = Function("<=", Nat, Nat, BoolSort())
# DatatypeRef.__le__ = lambda self, rhs : lte(self, rhs)
#
# t.axiom("zero lte", ForAll([n], Zero <= n))
# t.axiom("succ lte", ForAll([n,m], (Succ(n) <= Succ(m)) == (n <= m) ))
# lte_def = ["zero lte", "succ lte"]
#
#
# t.theorem("example",  (Zero + Zero) <= Zero,  *plus_def, *lte_def  )
#
#
# reflect = Function("reflect", Nat  , IntSort())
# x = Int("x")
# t.axiom( "reflect succ", ForAll([x, n], (reflect(Succ(n)) == 1 + x) == (reflect(n) == x) ))
# t.axiom( "reflect zero", reflect(Zero) == 0)
#
# t.formula
#
# ```
