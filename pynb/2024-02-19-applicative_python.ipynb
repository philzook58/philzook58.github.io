# %% [markdown]
# ---
# date: 2024-02-19
# title: Applicative Python
# ---
#
# I've been reading about [ACL2](https://www.cs.utexas.edu/users/moore/acl2/), a theorem prover designed for common lisp. It has good automation and has been quite successfully applied to significant [software/hrdware verificaton](https://royalsocietypublishing.org/doi/10.1098/rsta.2015.0399) and mathematics.
#
# Python and lisp are actually similar in a lot of ways. Something not sufficiently explored is how to apply the ACL2 design pattern in more popular languages like python.
#
# ACL2's logic is based on an applicative subset of common lisp (pure functions). This design has a number of good points
# - Your specs are executable. "Logical" Specs often take the form of an interpreter, model, or emulator of the system in question.
# - The constructs of the logic are familiar programming constructs.
#
# One step towards porting such a thing is describing an applicative subset of python. This is a subset of python that is pure and has a simple(er) mathematical semantics.
#
# There is a design balance to be struck here. The subset should be small enough to be easily understood and reasoned about, but large enough to be useful and not feel constraining.
#
# I think I tend to use pretty close to pure python programming.
#
# ## Mutation
#
# For an applicative python, we want to restrict ourselves to immutable values. In python these include basic types like strings, tuples, and floats, but als compound types like tuples, frozenset, and namedtuples
#
# ## What about the types?
#
# Most theorem prover languages are strongly typed. This is not ACL2's design nor would it make sense for the untyped language of python.
#
# There is a standard method for relating the two worlds. You can model an untyped language by making an algebraic datatype of all the possible values. This is an inefficient thing to do from the perspective of typed languages, but it works. Sometimes "untyped" languages are referred to as ["unityped"](https://news.ycombinator.com/item?id=8206562) for this reason
#
#
# ```ocaml
# type univ =
#  | Cons of univ * univ
#  | Nil
#  | Bool of bool
#  | Float of float
#  | Int of int
# ```
#
# While python tuple are flat, it is easiest to model them as linked lists. Hence the python tuple `("fred", 42, (True, False))` would be `Cons("fred", Cons(42, Cons(Cons(True, Cons(False, Nil)), Nil)))`

# %%
from z3 import *
U = Datatype('Univ') # Basic PyObject
U.declare('cons', ('car', U), ('cdr', U))
U.declare('bool', ('bool_val', BoolSort()))

# Interesting but questionable
#U.declare('real', ('real_val', RealSort()))
#U.declare('float', ('float_val', FloatSort())
U.declare('string', ('string_val', StringSort()))
U.declare('int', ('int_val', IntSort()))
U.declare('nil') # None

U = U.create()

U.cons(U.string(StringVal('fred')), 
U.cons(U.int(42), 
U.cons(U.cons(U.bool(True), 
       U.cons(U.bool(False), 
       U.nil)),
U.nil)))
# Out:
# cons(string("fred"),
#      cons(int(42),
#           cons(cons(bool(True), cons(bool(False), nil)),
#                nil)))

# %% [markdown]
# # What about statements?
# One can take a look at the python ast to get some clarity on what is available as expressions and statements. <https://greentreesnakes.readthedocs.io/en/latest/nodes.html>
#
# Python expressions are mostly ok from a purely functional perspective.
#
# However, python is not a expression oriented language. It is mostly oriented around statement and imperative programming. To restrict ourselves to only expressions is close to impossible and very awkward.
#
# However, I think there is a reasonable subset of imperative python that is effectively pure (applicative). We can consider statements of the following form as syntax sugar for a purely applicative equivalent.
#
# - Sequences of assignments are allowed and are interpreted as `let` expressions scoped to the end of the block.
# - Every sequence of statements is terminated by a `return` or an `if then else` statement. Recursively, the bodies of the `if else` do eventually terminate in a `return`.`
# - `if` `else` statements are allowed and are interpreted as `if` expressions.
# - Many expressions are allowed. tuples, strings, integers are immutable and allowed.
#
# What is disallowed:
# - `indexed` assignment like `foo.a = 3` or `bar[7] = 8`
# - mutable data structures like lists, dicts, sets, etc. We could perhaps skirt by this by just disallowing the mutating functions. The loss of dictionaries is close to unacceptable.
# - Nonterminating functions. More on this another day.
#
#
# Overloading in python is a nice language feature that can make for some clean and fun library design. This is nice for example when you are writing logical expressions for a theorem prover like z3. It s somewhat unfortunate that you can't overload some particular constructs like `if else`, `and`, `or`, `not` expressions, comprehensions or `for` `while` `assert` statements. You can switch over to a bit clunkier syntax of using functions like `If(cond,the,else)`
#
# I did show a style of doing this for a weakest precondition analysis here. <https://www.philipzucker.com/weakest-precondition-z3py/>

# %%
# https://greentreesnakes.readthedocs.io/en/latest/nodes.html 
from ast import *
import ast
import z3
import functools
def applpy_const(x):
    if isinstance(x, int):
        return U.int(z3.IntVal(x))

def op_pretty(op):
    #<class 'ast.Eq'>
    return str(type(op))[12:-2]

def uite(test, then, els):
    f = z3.Function("Uite", U, U, U, U)
    return f(test, then, els)

def applpy_expr(expr):
    match expr:
        case Constant(value, kind=None):
            return applpy_const(value)
        case UnaryOp(op, operand):
            assert type(op) in (UAdd, USub, Not, Invert)
            f = z3.Function(op_pretty(op), U, U)
            return f(applpy_expr(operand))
        case BinOp(left, op, right):
            assert type(op) in (Add, Sub, Mult, MatMult, Div, Mod, Pow, LShift, RShift, BitOr, BitXor, BitAnd, FloorDiv)
            f = z3.Function(op_pretty(op), U, U, U)
            return f(applpy_expr(left), applpy_expr(right))
        case BoolOp(op, values):
            assert type(op) in (And, Or)
            f = z3.Function(op_pretty(op), U, U, U)
            return functools.reduce(f, map(applpy_expr, values))
        case Compare(left, [op], [right]):
            #for op in ops:
            #    assert type(op) in (Eq, NotEq, Lt, LtE, Gt, GtE, Is, IsNot, In, NotIn)
            #print(dump(left))
            #acc = left
            #res = U.bool(True)
            #UAnd = z3.Function(repr(type(op)), U, U, U)
            # TODO handle multiple ops
            #for op, right in zip(ops, comparators):
            #    f = z3.Function(repr(type(op)), U, U, U)
            #    res =   UAnd(res, cur, applpy_expr(right)
            f = z3.Function(op_pretty(op), U, U, U)
            return f(applpy_expr(left), applpy_expr(right))
        case Call(Name(id,ctx), args, keywords):
            assert keywords == []
            targs = [U] * (len(args) + 1)
            f = z3.Function(id, *targs)
            return f(*map(applpy_expr, args))
        case IfExp(test, body, orelse):
            return uite(applpy_expr(test), applpy_expr(body), applpy_expr(orelse))
        case Name(id, ctx):
            return z3.Const(id, U)
        case Tuple(elts, ctx):
            res = U.nil
            for e in reversed(elts):
                res = U.cons(applpy_expr(e), res)
            return res
        case x:
            print("non applpy expresion", x)
            assert False

def applpy_stmts(stmts):
    match stmts[-1]:
        case Return(value):
            res = applpy_expr(value)
        case If(test, body, orelse):
            res = uite(applpy_expr(test), applpy_stmts(body), applpy_stmts(orelse))
        case _:
            raise ValueError("last statement must be a return or ifthenelse", stmts[-1])
    for stmt in stmts[-2::-1]:
        print(stmt)
        match stmt:
            case Assign([Name(id,ctx)], value):
                e = applpy_expr(value)
                res = z3.substitute(res, (z3.Const(id, U), e))
            case _:
                raise ValueError("intermediate statement must be assignment", dump(stmt))
    return res


applpy_db = {}
def fundef(ast):
    assert isinstance(ast, Module)
    assert len(ast.body) == 1
    ast = ast.body[0]
    assert isinstance(ast, FunctionDef)
    args  = [arg.arg for arg in ast.args.args]
    assert ast.args.posonlyargs == [] and ast.args.kwonlyargs == []
    targs = [U] * (len(args) + 1)
    f = z3.Function(ast.name,*targs)
    print("Applypydef", f(*map(lambda x: z3.Const(x,U), args)), "==", applpy_stmts(ast.body))
    applpy_db[ast.name] = (ast.args, applpy_stmts(ast.body))
    return f

import inspect
def applpy(f):
    fun = ast.parse(inspect.getsource(f))
    z3_f = fundef(fun)
    """
    def res(*args):
        if all(not isinstance(args, z3.AstRef) for arg in args):
           f(*args)
        else:
           z3_f(*args) 
    return res
    """
    return z3_f
"""
@applpy
def foo(x):
    return not x

@applpy
def foo(x,y):
    z = 3
    q = (1,2,3,4 + 5)
    return x + z, 4, q
"""
@applpy
def fact(n):
    if n == 0:
        return 1
    else:
        return n * fact(n-1)
# Hmm. Using python bytecode might be interesting.
# Combined with C interpreter...
fact(U.int(3))
#act(3)
# Out:
# Applypydef fact(n) == Uite(Eq(n, int(0)), int(1), Mult(n, fact(Sub(n, int(1)))))
# fact(int(3))

# %% [markdown]
# # What about Errors?
# Indexing into a field that does not exist for example. What do we do? The ACL2 way is totalizing the function by returning `None` basically in this case. This does not strike me as elegant, but it's workable.
#
# # Bits and Bobbles
#
# I'm undecided how to deal with generators. One could perhaps treat them as coinductive, but that is a can of worms.
#
# Class might be ok if immutable.
#
# To be clear, if one really wanted to attack the totality of python as it stands, you'd have to go a more Hoare logic / weakest precondtion route.
#
# - WhyML has a [pseudo python](https://www.why3.org/doc/input_formats.html#micro-python) notation,
# - Viper has Nagini https://github.com/marcoeilers/nagini
# - https://deal.readthedocs.io/index.html
# - https://github.com/pschanely/CrossHair
#
# [Imandra](https://docs.imandra.ai/imandra-docs/notebooks/welcome/) has a language that is like an acl2 for Ocaml. It actually can be imported as a python package. Maybe what I want is to just pretty print applicative python as ocaml and toss it in there.

# %%
import imandra

with imandra.session() as s:
    verify_result = s.verify("fun x -> x * x = 0 ")
print("\n", verify_result)
# oh wait... Its only a cloud service? I can't run it locally?

# %% [markdown]
#  They are untyped and garbage collected. There are first class functions and other features that are. Python is missing the rich macro system of lisp. Somehow or other, common lisp has a reputation of being performant because it has good jits I believe.
#
# These points are shared by common theorem proving languages like Coq, Isabelle, and Agda. Proof by reflection. However, these languages are not as familiar to the average programmer. They are more ambitious in their descriptive power as well.
#
# https://news.ycombinator.com/item?id=1803815 norvig and python

# %% [markdown]
# # ACL2
#
# ACL2 is a theorem prover in Common Lisp. The logic is a simplified and purified variation of common lisp itself.
#
# It is a very powerful (in the automation and polish sense) semiautomated system. The logic itself it offers is quite weak by logical standards. This perhaps good
#
# It is somewhat natural to look to this design for inspiration for one that might be appropriate for python. Python shares many properties with lisp. It's a dynamic language with first class functions.
#
# - Untyped lispy terms
# - Quantifier free

# %%
from z3 import *
U = Datatype('Univ') # PyObject
U.declare('cons', ('car', U), ('cdr', U))
U.declare('bool', ('bool_val', BoolSort()))
U.declare('real', ('real_val', RealSort()))
U.declare('string', ('string_val', StringSort()))
U.declare('int', ('int_val', IntSort()))
U.declare('nil') # None
# float
U = U.create()
print(dir(U))
print(simplify(U.is_bool(U.bool(True))))
print(simplify(U.int_val(U.int(1))))
print(U.cons(U.int(1), U.nil))

# Can I add operations?
#U.__add__ = lambda self, other: U.int(self, other)
car = U.car
cdr = U.cdr
cons = U.cons
nil = U.nil

def atom(x):
    return Not(U.is_cons(x))
def consp(x):
    return U.is_cons(x)
def integerp(x):
    return U.is_int(x)

#Function("ite")

"""
Function("order", U, U, BoolSort())
= RecursiveFunc()
If(is_cons(x),
  And(e0_ordinalp(car(x)), car(x) != U.int(0), 
      e0_ordinalp(cdr(x)), 
      Or(atom(cdr(x)), 
      Not(e0-ord-<(car(x), cadr(x)))),
  And(integerp(x), U.int_val(x) >= 0)))
"""
# Out:
# ['__bool__', '__class__', '__copy__', '__deepcopy__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_repr_html_', 'accessor', 'as_ast', 'ast', 'bool', 'bool_val', 'car', 'cast', 'cdr', 'cons', 'constructor', 'ctx', 'ctx_ref', 'eq', 'get_id', 'hash', 'int', 'int_val', 'is_bool', 'is_cons', 'is_int', 'is_nil', 'is_real', 'is_string', 'kind', 'name', 'nil', 'num_constructors', 'real', 'real_val', 'recognizer', 'sexpr', 'string', 'string_val', 'subsort', 'translate', 'use_pp']
# True
# 1
# cons(int(1), nil)
# '\nFunction("order", U, U, BoolSort())\n= RecursiveFunc()\nIf(is_cons(x),\n  And(e0_ordinalp(car(x)), car(x) != U.int(0), \n      e0_ordinalp(cdr(x)), \n      Or(atom(cdr(x)), \n      Not(e0-ord-<(car(x), cadr(x)))),\n  And(integerp(x), U.int_val(x) >= 0)))\n'

# %% [markdown]
# #
# One of the appeals of the ACL2 approach is that it is an pplicative susbet of the underlying language common lisp. Then your specs or models are programs by definition and you can "extract" these simulators. Also perhas some kind of normalization by eval?

# %% [markdown]
# # Applicative Python
# If I wanted to really hew close to ACL2's design, I could take a subset of python that is purely functional. It'll be harder.
#
# ApplPy (apple-pie)
#
# So I could just use python expressions and be ok.
# But "let" statements are pretty sweet.
#
# I could use assignment but only a sequence of them such that the last is a return.
# No
#
# if expressions are wonky. I'd like to use if statement syntax.
# If I allow joining of the if, it's annoying. I could restrict variables to be scoped to a block (local if) ?
# These weird restrictions might be hard to enforce
#
# Could also desugar loops to recursive calls.

# %%
# https://greentreesnakes.readthedocs.io/en/latest/nodes.html 
from ast import *
import z3

def applpy_const(x):
    if isinstance(x, int):
        return U.int(z3.IntVal(x))
    else:
        raise ValueError("unsupported constant", x)
def applpy_expr(expr):
    match expr:
        case Constant(value, kind=None):
            print(value)
            return applpy_const(value)
        case UnaryOp(op, operand):
            print(op)
            print(Not)
            assert type(op) in (UAdd, USub, Not, Invert)
            print(type(op))
            print(dump(operand))
            f = z3.Function(str(op), U, U)
            return f(applpy_expr(operand))
        case BinOp(left, op, right):
            assert op in (Add, Sub, Mult, MatMult, Div, Mod, Pow, LShift, RShift, BitOr, BitXor, BitAnd, FloorDiv)
            print(dump(left))
            print(dump(right))
            f = z3.Function(str(op), U, U, U)
            return f(applpy_expr(left), applpy_expr(right))
        case BoolOp(op, values):
            assert op in (And, Or)
            for v in values:
                print(dump(v))
        case Compare(left, ops, comparators):
            for op in ops:
                assert op in (Eq, NotEq, Lt, LtE, Gt, GtE, Is, IsNot, In, NotIn)
            print(dump(left))
            for c in comparators:
                print(dump(c))
        case Call(func, args, keywords):
            assert keywords == []
            print(dump(func))
            for a in args:
                print(dump(a))
            targs = [U] * (len(args) + 1)
            f = z3.Function("call", *targs)
            f(*map(applpy_expr, args))
        case IfExp(test, body, orelse):
            print(dump(test))
            print(dump(body))
            print(dump(orelse))
            
        case Attribute(value, attr, ctx):
            print(dump(value))
        case Subscript(value, slice, ctx):
            print(dump(value))
        case Name(id, ctx):
            print(id)
            return z3.Const(id, U)
        case List(elts, ctx):
            for e in elts:
                print(dump(e))
        case Tuple(elts, ctx):
            for e in elts:
                print(dump(e))
        case Dict(keys, values):
            for k, v in zip(keys, values):
                print(dump(k))
                print(dump(v))
        case Set(elts):
            for e in elts:
                print(dump(e))
        case ListComp(elt, generators):
            print(dump(elt))
            for g in generators:
                print(dump(g))
        case SetComp(elt, generators):
            print(dump(elt))
            for g in generators:
                print(dump(g))
        case DictComp(key, value, generators):
            print(dump(key))
            print(dump(value))
            for g in generators:
                print(dump(g))
        case GeneratorExp(elt, generators):
            print(dump(elt))
            for g in generators:
                print(dump(g))
        case comprehension(target, iter, ifs, is_async):
            print(dump(target))
            print(dump(iter))
            for i in ifs:
                print(dump(i))
        # not going to handle Await, Yield, YieldFrom, FormattedValue, JoinedStr
        case x:
            print("non applpy expresion", x)
            assert False

def lvalue(expr):
    match expr:
        case Name(id, Store):
            print(id)
        # Starred could be handled.
        #case Tuple(elts, Store):
        case x:
            print("disallowed lvalue", x)
            assert False

def applpy_stmt(stmt):
    match stmt:
        case Assign(targets, value):
            for t in targets:
                print(dump(t))
            print(dump(value))
        case Return(value):
            print(dump(value))
            applpy_expr(value)
        case _:
            assert False

def fundef(ast):
    assert isinstance(ast, Module)
    assert len(ast.body) == 1
    ast = ast.body[0]
    assert isinstance(ast, FunctionDef)
    print(ast.name)
    print(ast.args)
    assert ast.args.posonlyargs == [] and ast.args.kwonlyargs == []
    print(ast.body)
    for stmt in ast.body:
        applpy_stmt(stmt)
    print(ast.decorator_list)
    print(ast.returns)
    print(ast.type_comment)
    
tree = parse("not 3", mode="eval")
print(dump(tree))
#apy(tree.body)

import inspect
def applpy(f):
    print(dir(f))
    print(dir(f.__code__))
    print(f.__code__.co_code)
    print(inspect.getsource(f))
    fun = parse(inspect.getsource(f))
    print(dump(fun))
    print(fundef(fun))

@applpy
def foo(x):
    return not x

# Hmm. Using python bytecode might be interesting.
# Combined with C interpreter...
# Out:
# Expression(body=UnaryOp(op=Not(), operand=Constant(value=3)))
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'co_argcount', 'co_cellvars', 'co_code', 'co_consts', 'co_filename', 'co_firstlineno', 'co_flags', 'co_freevars', 'co_kwonlyargcount', 'co_lines', 'co_linetable', 'co_lnotab', 'co_name', 'co_names', 'co_nlocals', 'co_posonlyargcount', 'co_stacksize', 'co_varnames', 'replace']
# b'|\x00\x0c\x00S\x00'
# @applpy
# def foo(x):
#     return not x
#
# Module(body=[FunctionDef(name='foo', args=arguments(posonlyargs=[], args=[arg(arg='x')], kwonlyargs=[], kw_defaults=[], defaults=[]), body=[Return(value=UnaryOp(op=Not(), operand=Name(id='x', ctx=Load())))], decorator_list=[Name(id='applpy', ctx=Load())])], type_ignores=[])
# foo
# <ast.arguments object at 0x7f50a81efac0>
# [<ast.Return object at 0x7f5083aa41f0>]
# UnaryOp(op=Not(), operand=Name(id='x', ctx=Load()))
# <ast.Not object at 0x7f50afc17c70>
# <class 'ast.Not'>
# <class 'ast.Not'>
# Name(id='x', ctx=Load())
# x
# [<ast.Name object at 0x7f5083aa4280>]
# None
# None
# None

# %%
# Out:
# Applypydef fact(n) == ite(Eq(n, int(0)), int(1), Mult(n, fact(Sub(n, int(1)))))
# fact(int(3))

# %%
def is_int(x):
    return U.bool(U.is_int(x))
def pred(f):
    def res(*args):
        return U.bool(f(*args))
    return res
Add_ = RecFunction('UAdd',U,U)
n = FreshConst(U)
RecAddDefinition(Negate, ,  z3.If(   , , U.int(   )  )

# %%
import pysmt

# %%
[1,2,3,4,5,6][-2::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
dump(Add)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 dump(Add)
#
# File /usr/lib/python3.10/ast.py:174, in dump(node, annotate_fields, include_attributes, indent)
#     171     return repr(node), True
#     173 if not isinstance(node, AST):
# --> 174     raise TypeError('expected AST, got %r' % node.__class__.__name__)
#     175 if indent is not None and not isinstance(indent, str):
#     176     indent = ' ' * indent
#
# TypeError: expected AST, got 'type'

# %%
Add
# Out:
# ast.Add

# %% [markdown]
# # Termination
# We want the ability to make recursive definitions of functions.
# Without carefulness these definitions may not terminate or be partial in other ways
# This is something to be careful about.
#
# AProve
# Dafny termination
# ACL2 termination. Ordinal.
#
# Show how to do manually.
# Then pythonize
# https://aprove.informatik.rwth-aachen.de/

# %%
# %%file /tmp/ex.trs
# (VAR x y)
# (RULES
#     plus(0,y) -> y
#     plus(s(x),y) -> s(plus(x,y))
# )
# Out:
# Writing /tmp/ex.trs

# %%
! java -ea -jar ~/Downloads/aprove.jar -m wst /tmp/ex.trs -p cpf
# Out:
# YES
# <?xml version="1.0" encoding="UTF-8" standalone="no"?><?xml-stylesheet type="text/xsl" href="cpfHTML.xsl"?><certificationProblem xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="cpf.xsd"><input><trsInput><trs><rules><rule><lhs><funapp><name>plus</name><arg><funapp><name>0</name></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><var>y</var></rhs></rule><rule><lhs><funapp><name>plus</name><arg><funapp><name>s</name><arg><var>x</var></arg></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><funapp><name>s</name><arg><funapp><name>plus</name><arg><var>x</var></arg><arg><var>y</var></arg></funapp></arg></funapp></rhs></rule></rules></trs></trsInput></input><cpfVersion>2.1</cpfVersion><proof><trsTerminationProof><ruleRemoval><orderingConstraintProof><redPair><knuthBendixOrder><w0>1</w0><precedenceWeight><precedenceWeightEntry><name>0</name><arity>0</arity><precedence>0</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>s</name><arity>1</arity><precedence>1</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>plus</name><arity>2</arity><precedence>2</precedence><weight>0</weight></precedenceWeightEntry></precedenceWeight></knuthBendixOrder></redPair></orderingConstraintProof><trs><rules/></trs><trsTerminationProof><rIsEmpty/></trsTerminationProof></ruleRemoval></trsTerminationProof></proof><origin><proofOrigin><tool><name>AProVE</name><version>AProVE Commit ID: 314de9e47ad18e927546098510ed7c36e443eb6d jan-christoph 20231211 unpublished
# </version><strategy>Statistics for single proof: 100.00 % (2 real / 0 unknown / 0 assumptions / 2 total proof steps)</strategy><url>http://aprove.informatik.rwth-aachen.de</url></tool><toolUser><firstName>John</firstName><lastName>Doe</lastName></toolUser></proofOrigin><inputOrigin/></origin></certificationProblem>

# %%
import subprocess
res = subprocess.run(["java", "-ea", "-jar", "/home/philip/Downloads/aprove.jar", "/tmp/ex.trs", "-p", "cpf"], capture_output=True, check=True)
print(res)
print(dir(res.stdout))
import xml.etree.ElementTree as ET
tree = ET.fromstring(res.stdout.decode())
print(tree)
print(tree.tag)
# Out:
# CompletedProcess(args=['java', '-ea', '-jar', '/home/philip/Downloads/aprove.jar', '/tmp/ex.trs', '-p', 'cpf'], returncode=0, stdout=b'<?xml version="1.0" encoding="UTF-8" standalone="no"?><?xml-stylesheet type="text/xsl" href="cpfHTML.xsl"?><certificationProblem xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="cpf.xsd"><input><trsInput><trs><rules><rule><lhs><funapp><name>plus</name><arg><funapp><name>0</name></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><var>y</var></rhs></rule><rule><lhs><funapp><name>plus</name><arg><funapp><name>s</name><arg><var>x</var></arg></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><funapp><name>s</name><arg><funapp><name>plus</name><arg><var>x</var></arg><arg><var>y</var></arg></funapp></arg></funapp></rhs></rule></rules></trs></trsInput></input><cpfVersion>2.1</cpfVersion><proof><trsTerminationProof><ruleRemoval><orderingConstraintProof><redPair><knuthBendixOrder><w0>1</w0><precedenceWeight><precedenceWeightEntry><name>0</name><arity>0</arity><precedence>0</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>s</name><arity>1</arity><precedence>1</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>plus</name><arity>2</arity><precedence>2</precedence><weight>0</weight></precedenceWeightEntry></precedenceWeight></knuthBendixOrder></redPair></orderingConstraintProof><trs><rules/></trs><trsTerminationProof><rIsEmpty/></trsTerminationProof></ruleRemoval></trsTerminationProof></proof><origin><proofOrigin><tool><name>AProVE</name><version>AProVE Commit ID: 314de9e47ad18e927546098510ed7c36e443eb6d jan-christoph 20231211 unpublished\n</version><strategy>Statistics for single proof: 100.00 % (2 real / 0 unknown / 0 assumptions / 2 total proof steps)</strategy><url>http://aprove.informatik.rwth-aachen.de</url></tool><toolUser><firstName>John</firstName><lastName>Doe</lastName></toolUser></proofOrigin><inputOrigin/></origin></certificationProblem>', stderr=b'')
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'center', 'count', 'decode', 'endswith', 'expandtabs', 'find', 'fromhex', 'hex', 'index', 'isalnum', 'isalpha', 'isascii', 'isdigit', 'islower', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# <Element 'certificationProblem' at 0x7f07274c90d0>
# certificationProblem

# %%
tree.tag
tree.attrib
print([elem.tag for elem in tree])
input = tree.find("input")
print(dir(input))
input.text
ET.tostring(input)
ET.dump(input)
# Out:
# ['input', 'cpfVersion', 'proof', 'origin']
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'attrib', 'clear', 'extend', 'find', 'findall', 'findtext', 'get', 'insert', 'items', 'iter', 'iterfind', 'itertext', 'keys', 'makeelement', 'remove', 'set', 'tag', 'tail', 'text']
# <input><trsInput><trs><rules><rule><lhs><funapp><name>plus</name><arg><funapp><name>0</name></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><var>y</var></rhs></rule><rule><lhs><funapp><name>plus</name><arg><funapp><name>s</name><arg><var>x</var></arg></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><funapp><name>s</name><arg><funapp><name>plus</name><arg><var>x</var></arg><arg><var>y</var></arg></funapp></arg></funapp></rhs></rule></rules></trs></trsInput></input>

# %%
def etree_to_dict(t):
    d = {t.tag : map(etree_to_dict, t.getchildren())}
    d.update(('@' + k, v) for k, v in t.attrib.iteritems())
    d['text'] = t.text
    return d

# %%
etree_to_dict(input)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [77], line 1
# ----> 1 etree_to_dict(input)
#
# Cell In [76], line 2, in etree_to_dict(t)
#       1 def etree_to_dict(t):
# ----> 2     d = {t.tag : map(etree_to_dict, t.getchildren())}
#       3     d.update(('@' + k, v) for k, v in t.attrib.iteritems())
#       4     d['text'] = t.text
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'getchildren'

# %%
print(res)
# Out:
# CompletedProcess(args=['java', '-ea', '-jar', '/home/philip/Downloads/aprove.jar', '/tmp/ex.trs', '-p', 'cpf'], returncode=0)

# %%
# %%file /tmp/term.c
# extern int __VERIFIER_nondet_int(void);
#
# int cstrlen(const char *s) {
#     const char *p = s;
#     while (*p != '\0')
#         p++;
#     return (int)(p - s);
# }
#
# int main() {
#     int length = __VERIFIER_nondet_int();
#     if (length < 1) {
#         length = 1;
#     }
#     char* nondetString = __builtin_alloca(length * sizeof(char));
#     nondetString[length-1] = '\0';
#     return cstrlen(nondetString);
# }
# Out:
# Overwriting /tmp/term.c

# %%
! jar tf ~/Downloads/aprove.jar  # table file
# Out:
# META-INF/
# META-INF/MANIFEST.MF
# aprove/
# aprove/Benchmarking/
# aprove/CommandLineInterface/
# aprove/CommandLineInterface/Generic/
# aprove/CommandLineInterface/ObligationCache/
# aprove/CommandLineInterface/tpdbConverter/
# aprove/Complexity/
# aprove/Complexity/AcdtProblem/
# aprove/Complexity/AcdtProblem/Processors/
# aprove/Complexity/AcdtProblem/Utils/
# aprove/Complexity/CIdtProblem/
# aprove/Complexity/CIdtProblem/Processors/
# aprove/Complexity/CIdtProblem/Utility/
# aprove/Complexity/CdpProblem/
# aprove/Complexity/CdpProblem/Processors/
# aprove/Complexity/CdpProblem/Processors/Util/
# aprove/Complexity/CdpProblem/Processors/Util/QtrsDirectGcdp/
# aprove/Complexity/CdtProblem/
# aprove/Complexity/CdtProblem/Processors/
# aprove/Complexity/CdtProblem/Utils/
# aprove/Complexity/CpxGTrsProblem/
# aprove/Complexity/CpxITrsProblem/
# aprove/Complexity/CpxITrsProblem/Processors/
# aprove/Complexity/CpxIntTrsProblem/
# aprove/Complexity/CpxIntTrsProblem/Algorithms/
# aprove/Complexity/CpxIntTrsProblem/Exceptions/
# aprove/Complexity/CpxIntTrsProblem/Processors/
# aprove/Complexity/CpxIntTrsProblem/Structures/
# aprove/Complexity/CpxRelTrsProblem/
# aprove/Complexity/CpxRelTrsProblem/Processors/
# aprove/Complexity/CpxRntsProblem/
# aprove/Complexity/CpxRntsProblem/Algorithms/
# aprove/Complexity/CpxRntsProblem/Exceptions/
# aprove/Complexity/CpxRntsProblem/Processors/
# aprove/Complexity/CpxRntsProblem/Structures/
# aprove/Complexity/CpxTrsProblem/
# aprove/Complexity/CpxTrsProblem/Processors/
# aprove/Complexity/CpxTrsProblem/Processors/Utility/
# aprove/Complexity/CpxTypedWeightedCompleteTrsProblem/
# aprove/Complexity/CpxTypedWeightedCompleteTrsProblem/Processors/
# aprove/Complexity/CpxTypedWeightedTrsProblem/
# aprove/Complexity/CpxTypedWeightedTrsProblem/Processors/
# aprove/Complexity/CpxWeightedTrsProblem/
# aprove/Complexity/CpxWeightedTrsProblem/Processors/
# aprove/Complexity/Implications/
# aprove/Complexity/LowerBounds/
# aprove/Complexity/LowerBounds/AnalysisOrder/
# aprove/Complexity/LowerBounds/BasicStructures/
# aprove/Complexity/LowerBounds/ComplexityComputation/
# aprove/Complexity/LowerBounds/ConjectureGeneration/
# aprove/Complexity/LowerBounds/ConjectureGeneration/SampleConjecturesToEqSystem/
# aprove/Complexity/LowerBounds/ConjectureProving/
# aprove/Complexity/LowerBounds/EquationalRewriting/
# aprove/Complexity/LowerBounds/EquationalRewriting/Structures/
# aprove/Complexity/LowerBounds/EquationalUnification/
# aprove/Complexity/LowerBounds/GeneratorEquations/
# aprove/Complexity/LowerBounds/Slicing/
# aprove/Complexity/LowerBounds/Types/
# aprove/Complexity/LowerBounds/Util/
# aprove/Complexity/LowerBounds/Util/Renaming/
# aprove/Complexity/LowerBounds/Util/Transformations/
# aprove/Complexity/TruthValue/
# aprove/Complexity/Utility/
# aprove/Complexity/WdpCProblem/
# aprove/Complexity/WdpCProblem/Processors/
# aprove/DPFramework/
# aprove/DPFramework/BasicStructures/
# aprove/DPFramework/BasicStructures/AFSPrecalculation/
# aprove/DPFramework/BasicStructures/Matchbounds/
# aprove/DPFramework/BasicStructures/MaxMinPolynomials/
# aprove/DPFramework/BasicStructures/NegativePolynomials/
# aprove/DPFramework/BasicStructures/Unification/
# aprove/DPFramework/BasicStructures/Unification/Equational/
# aprove/DPFramework/BasicStructures/Unification/Equational/Problems/
# aprove/DPFramework/BasicStructures/Unification/Equational/Utility/
# aprove/DPFramework/BasicStructures/Utility/
# aprove/DPFramework/CLSProblem/
# aprove/DPFramework/CLSProblem/Processors/
# aprove/DPFramework/CLSProblem/Properties/
# aprove/DPFramework/CLSProblem/Utility/
# aprove/DPFramework/CSDPProblem/
# aprove/DPFramework/CSDPProblem/Processors/
# aprove/DPFramework/CSDPProblem/Solvers/
# aprove/DPFramework/DPConstraints/
# aprove/DPFramework/DPConstraints/idp/
# aprove/DPFramework/DPProblem/
# aprove/DPFramework/DPProblem/Processors/
# aprove/DPFramework/DPProblem/SMT_LIA/
# aprove/DPFramework/DPProblem/SMT_LIA/SMTLIB/
# aprove/DPFramework/DPProblem/Solvers/
# aprove/DPFramework/DPProblem/TheoremProver/
# aprove/DPFramework/DPProblem/TheoremProver/OrderCalculators/
# aprove/DPFramework/DPProblem/TheoremProver/RuleCandidateHeuristics/
# aprove/DPFramework/DPProblem/TheoremProver/TheoremProverRunners/
# aprove/DPFramework/DebugProcessors/
# aprove/DPFramework/ExternalTpdbTool/
# aprove/DPFramework/HaskellProblem/
# aprove/DPFramework/HaskellProblem/Processors/
# aprove/DPFramework/Heuristics/
# aprove/DPFramework/Heuristics/Conditions/
# aprove/DPFramework/Heuristics/Processors/
# aprove/DPFramework/Heuristics/ReductionPair/
# aprove/DPFramework/Heuristics/RootLabeling/
# aprove/DPFramework/IDPProblem/
# aprove/DPFramework/IDPProblem/PfFunctions/
# aprove/DPFramework/IDPProblem/PfFunctions/domains/
# aprove/DPFramework/IDPProblem/PfManager/
# aprove/DPFramework/IDPProblem/Processors/
# aprove/DPFramework/IDPProblem/Processors/JBCPreprocessing/
# aprove/DPFramework/IDPProblem/Processors/algorithms/
# aprove/DPFramework/IDPProblem/Processors/algorithms/bisimulation/
# aprove/DPFramework/IDPProblem/Processors/algorithms/cap/
# aprove/DPFramework/IDPProblem/Processors/algorithms/filter/
# aprove/DPFramework/IDPProblem/Processors/algorithms/orders/
# aprove/DPFramework/IDPProblem/Processors/algorithms/usableRules/
# aprove/DPFramework/IDPProblem/Processors/cgirp/
# aprove/DPFramework/IDPProblem/Processors/itpfExecution/
# aprove/DPFramework/IDPProblem/Processors/nonInf/
# aprove/DPFramework/IDPProblem/Processors/nonInf/poly/
# aprove/DPFramework/IDPProblem/Processors/processorHistory/
# aprove/DPFramework/IDPProblem/Properties/
# aprove/DPFramework/IDPProblem/idpGraph/
# aprove/DPFramework/IDPProblem/itpf/
# aprove/DPFramework/IDPProblem/itpf/rules/
# aprove/DPFramework/IDPProblem/utility/
# aprove/DPFramework/JBCProblem/
# aprove/DPFramework/MCSProblem/
# aprove/DPFramework/MCSProblem/Processors/
# aprove/DPFramework/MCSProblem/graphics/
# aprove/DPFramework/MCSProblem/mcnp/
# aprove/DPFramework/MCSProblem/run/
# aprove/DPFramework/MCSProblem/sat_tools/
# aprove/DPFramework/MCSProblem/satsolver/
# aprove/DPFramework/Orders/
# aprove/DPFramework/Orders/SAT/
# aprove/DPFramework/Orders/SAT/PLEncoders/
# aprove/DPFramework/Orders/SizeChangeNP/
# aprove/DPFramework/Orders/SizeChangeNP/OrderEncoders/
# aprove/DPFramework/Orders/SizeChangeNP/PEncoders/
# aprove/DPFramework/Orders/Solvers/
# aprove/DPFramework/Orders/Utility/
# aprove/DPFramework/Orders/Utility/GPOLO/
# aprove/DPFramework/Orders/Utility/GPOLO/Heuristics/
# aprove/DPFramework/Orders/Utility/GPOLO/OPCSolvers/
# aprove/DPFramework/Orders/Utility/KBO/
# aprove/DPFramework/Orders/Utility/NonMonMaxPolo/
# aprove/DPFramework/Orders/Utility/NonMonMaxPolo/Heuristics/
# aprove/DPFramework/Orders/Utility/PMATRO/
# aprove/DPFramework/Orders/Utility/POLO/
# aprove/DPFramework/PADPProblem/
# aprove/DPFramework/PADPProblem/Processors/
# aprove/DPFramework/PADPProblem/Utility/
# aprove/DPFramework/PATRSProblem/
# aprove/DPFramework/PATRSProblem/Processors/
# aprove/DPFramework/PATRSProblem/Utility/
# aprove/DPFramework/PiDPProblem/
# aprove/DPFramework/PiDPProblem/Processors/
# aprove/DPFramework/SimplifierProblem/
# aprove/DPFramework/TRSProblem/
# aprove/DPFramework/TRSProblem/Processors/
# aprove/DPFramework/TRSProblem/Processors/FromITRS/
# aprove/DPFramework/TRSProblem/Solvers/
# aprove/DPFramework/TRSProblem/Utility/
# aprove/DPFramework/TRSProblem/Utility/SRSNonLoop/
# aprove/DPFramework/Utility/
# aprove/DPFramework/Utility/NonLoop/
# aprove/DPFramework/Utility/NonLoop/NonLoopSearch/
# aprove/DPFramework/Utility/NonLoop/NonLoopSearch/heuristics/
# aprove/DPFramework/Utility/NonLoop/heuristic/
# aprove/DPFramework/Utility/NonLoop/structures/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/combination/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/creation/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/equivalence/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/equivalence/eproofs/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/intantiating/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/nontermination/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/rewriting/
# aprove/DPFramework/Utility/NonLoop/structures/proofed/testing/
# aprove/DiophantineSolver/
# aprove/DiophantineSolver/GlobalConstraintAnalyzers/
# aprove/DiophantineSolver/rat/
# aprove/Framework/
# aprove/Framework/Algebra/
# aprove/Framework/Algebra/GeneralPolynomials/
# aprove/Framework/Algebra/GeneralPolynomials/Coefficients/
# aprove/Framework/Algebra/GeneralPolynomials/DAGNodes/
# aprove/Framework/Algebra/GeneralPolynomials/Factories/
# aprove/Framework/Algebra/GeneralPolynomials/Monoids/
# aprove/Framework/Algebra/GeneralPolynomials/Rings/
# aprove/Framework/Algebra/GeneralPolynomials/SMTSearch/
# aprove/Framework/Algebra/GeneralPolynomials/SatSearch/
# aprove/Framework/Algebra/GeneralPolynomials/SatSearch/ArcticInt/
# aprove/Framework/Algebra/GeneralPolynomials/SatSearch/Nat/
# aprove/Framework/Algebra/GeneralPolynomials/Variables/
# aprove/Framework/Algebra/GeneralPolynomials/Visitors/
# aprove/Framework/Algebra/LimitPolynomials/
# aprove/Framework/Algebra/Matrices/
# aprove/Framework/Algebra/Matrices/Filters/
# aprove/Framework/Algebra/Matrices/Interpretation/
# aprove/Framework/Algebra/MinMaxExprs/
# aprove/Framework/Algebra/Orders/
# aprove/Framework/Algebra/Orders/Solvers/
# aprove/Framework/Algebra/Orders/Utility/
# aprove/Framework/Algebra/Orders/Utility/POLO/
# aprove/Framework/Algebra/PolyMatrices/
# aprove/Framework/Algebra/Polynomials/
# aprove/Framework/Algebra/Polynomials/OpVarPolynomials/
# aprove/Framework/Algebra/Polynomials/OpVarPolynomials/InterHeuristics/
# aprove/Framework/Algebra/Polynomials/PBSearch/
# aprove/Framework/Algebra/Polynomials/PBSearch/PBCheckers/
# aprove/Framework/Algebra/Polynomials/SMTSearch/
# aprove/Framework/Algebra/Polynomials/SPCFormulae/
# aprove/Framework/Algebra/Polynomials/SatSearch/
# aprove/Framework/Algebra/Polynomials/Utility/
# aprove/Framework/Algebra/Terms/
# aprove/Framework/Algebra/Terms/Visitors/
# aprove/Framework/Automata/
# aprove/Framework/BasicStructures/
# aprove/Framework/BasicStructures/Arithmetic/
# aprove/Framework/BasicStructures/Arithmetic/Integer/
# aprove/Framework/BooleanSemanticLabelling/
# aprove/Framework/Bytecode/
# aprove/Framework/Bytecode/Consistency/
# aprove/Framework/Bytecode/Graphs/
# aprove/Framework/Bytecode/Graphs/FiniteInterpretation/
# aprove/Framework/Bytecode/Graphs/Reachability/
# aprove/Framework/Bytecode/Intersector/
# aprove/Framework/Bytecode/Merger/
# aprove/Framework/Bytecode/Merger/StatePosition/
# aprove/Framework/Bytecode/Natives/
# aprove/Framework/Bytecode/OpCodes/
# aprove/Framework/Bytecode/Parser/
# aprove/Framework/Bytecode/Parser/Attributes/
# aprove/Framework/Bytecode/Parser/ConstantPool/
# aprove/Framework/Bytecode/Parser/Exceptions/
# aprove/Framework/Bytecode/Processors/
# aprove/Framework/Bytecode/Processors/PathLength/
# aprove/Framework/Bytecode/Processors/ToComplexity/
# aprove/Framework/Bytecode/Processors/ToGraph/
# aprove/Framework/Bytecode/Processors/ToGraph/CallExpander/
# aprove/Framework/Bytecode/Processors/ToIDPv1/
# aprove/Framework/Bytecode/Processors/ToIDPv2/
# aprove/Framework/Bytecode/Processors/ToIntTRS/
# aprove/Framework/Bytecode/Processors/ToMCNP/
# aprove/Framework/Bytecode/Processors/ToMethodSummary/
# aprove/Framework/Bytecode/Processors/ToSCC/
# aprove/Framework/Bytecode/StateRepresentation/
# aprove/Framework/Bytecode/StateRepresentation/AbstractVariables/
# aprove/Framework/Bytecode/StateRepresentation/Annotations/
# aprove/Framework/Bytecode/StateRepresentation/InputReferenceChangeInformation/
# aprove/Framework/Bytecode/Utils/
# aprove/Framework/Bytecode/Utils/MethodSummary/
# aprove/Framework/CPF/
# aprove/Framework/ConditionalRewriting/
# aprove/Framework/CostEquationSystem/
# aprove/Framework/DifferenceUnification/
# aprove/Framework/Exceptions/
# aprove/Framework/ExternalProcess/
# aprove/Framework/Haskell/
# aprove/Framework/Haskell/BasicTerms/
# aprove/Framework/Haskell/Collectors/
# aprove/Framework/Haskell/Declarations/
# aprove/Framework/Haskell/Evaluator/
# aprove/Framework/Haskell/Expressions/
# aprove/Framework/Haskell/Literals/
# aprove/Framework/Haskell/Modules/
# aprove/Framework/Haskell/Narrowing/
# aprove/Framework/Haskell/Patterns/
# aprove/Framework/Haskell/Qualifiers/
# aprove/Framework/Haskell/Substitutors/
# aprove/Framework/Haskell/Syntax/
# aprove/Framework/Haskell/Transformations/
# aprove/Framework/Haskell/Typing/
# aprove/Framework/Haskell/Visitors/
# aprove/Framework/IRSwT/
# aprove/Framework/IRSwT/Digraph/
# aprove/Framework/IRSwT/Engines/
# aprove/Framework/IRSwT/Engines/FormulaGenerators/
# aprove/Framework/IRSwT/Engines/Formulae/
# aprove/Framework/IRSwT/Filters/
# aprove/Framework/IRSwT/Orders/
# aprove/Framework/IRSwT/Processors/
# aprove/Framework/IRSwT/Processors/ExportProcessors/
# aprove/Framework/IRSwT/Processors/FilterProcessors/
# aprove/Framework/IRSwT/Processors/TraceTermination/
# aprove/Framework/IRSwT/Processors/TreeTraces/
# aprove/Framework/IRSwT/Sorts/
# aprove/Framework/IRSwT/Utils/
# aprove/Framework/Input/
# aprove/Framework/Input/Annotations/
# aprove/Framework/Input/Annotators/
# aprove/Framework/Input/TypeAnalyzers/
# aprove/Framework/IntTRS/
# aprove/Framework/IntTRS/BoundedInts/
# aprove/Framework/IntTRS/CaseAnalysis/
# aprove/Framework/IntTRS/CommutativeComponents/
# aprove/Framework/IntTRS/Compression/
# aprove/Framework/IntTRS/InvariantGen/
# aprove/Framework/IntTRS/Labeling/
# aprove/Framework/IntTRS/LinearRedPair/
# aprove/Framework/IntTRS/Nonterm/
# aprove/Framework/IntTRS/PoloRedPair/
# aprove/Framework/IntTRS/Ranking/
# aprove/Framework/IntTRS/RankingRedPair/
# aprove/Framework/IntTRS/SafetyRedPair/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/PolyConstraintsSystems/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/PolyConstraintsSystems/ConstraintsSystems/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/PolyConstraintsSystems/Disjunctions/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/ProgramGraph/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/ProgramGraph/Locations/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/Relation/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/Relation/LinearRelation/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/Relation/TermRelation/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/TransitionPair/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/TransitionPair/LinearTransitionPair/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Data/TransitionPair/TermTransitionPair/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Debug/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Interpolation/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/SAT/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Safety/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Safety/Tree/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Safety/Tree/Vertex/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Termination/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Termination/CooperationGraph/
# aprove/Framework/IntTRS/SafetyRedPair/Tools/Solvers/Termination/CooperationGraph/Locations/
# aprove/Framework/IntTRS/TerminationGraph/
# aprove/Framework/IntTRS/Utils/
# aprove/Framework/IntegerReasoning/
# aprove/Framework/IntegerReasoning/constants/
# aprove/Framework/IntegerReasoning/equalSides/
# aprove/Framework/IntegerReasoning/inequality/
# aprove/Framework/IntegerReasoning/llvm/
# aprove/Framework/IntegerReasoning/octagondomain/
# aprove/Framework/IntegerReasoning/octagondomain/dbm/
# aprove/Framework/IntegerReasoning/octagondomain/utils/
# aprove/Framework/IntegerReasoning/processors/
# aprove/Framework/IntegerReasoning/relationset/
# aprove/Framework/IntegerReasoning/skeletons/
# aprove/Framework/IntegerReasoning/smt/
# aprove/Framework/IntegerReasoning/utils/
# aprove/Framework/IntegerReasoning/utils/additionboundinference/
# aprove/Framework/IntegerReasoning/utils/boundinference/
# aprove/Framework/IntegerReasoning/utils/intervals/
# aprove/Framework/LemmaApplication/
# aprove/Framework/LemmaDatabase/
# aprove/Framework/LemmaDatabase/Index/
# aprove/Framework/LinearArithmetic/
# aprove/Framework/LinearArithmetic/QuantifierEliminator/
# aprove/Framework/LinearArithmetic/Structure/
# aprove/Framework/Logic/
# aprove/Framework/Logic/FOFormulas/
# aprove/Framework/Logic/Formulas/
# aprove/Framework/Logic/Formulas/Visitors/
# aprove/Framework/Output/
# aprove/Framework/Programs/
# aprove/Framework/PropositionalLogic/
# aprove/Framework/PropositionalLogic/Formulae/
# aprove/Framework/PropositionalLogic/SATCheckers/
# aprove/Framework/PropositionalLogic/SMTLIB/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBBitVector/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBBitVector/SMTLIBBVComparison/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBBitVector/SMTLIBBVFunctions/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBBool/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBFunctions/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBInt/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBInt/SMTLIBIntComparison/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBInt/SMTLIBIntFunctions/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBRat/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBRat/SMTLIBRatComparison/
# aprove/Framework/PropositionalLogic/SMTLIB/SMTLIBRat/SMTLIBRatFunctions/
# aprove/Framework/PropositionalLogic/TheoryPropositions/
# aprove/Framework/PropositionalLogic/Translation/
# aprove/Framework/PropositionalLogic/ValueCaches/
# aprove/Framework/Rewriting/
# aprove/Framework/Rewriting/SemanticLabelling/
# aprove/Framework/Rewriting/Transformers/
# aprove/Framework/Rewriting/Visitors/
# aprove/Framework/Rippling/
# aprove/Framework/SMT/
# aprove/Framework/SMT/Expressions/
# aprove/Framework/SMT/Expressions/Calls/
# aprove/Framework/SMT/Expressions/Sorts/
# aprove/Framework/SMT/Expressions/StaticBuilders/
# aprove/Framework/SMT/Expressions/Symbols/
# aprove/Framework/SMT/Macros/
# aprove/Framework/SMT/Solver/
# aprove/Framework/SMT/Solver/Factories/
# aprove/Framework/SMT/Solver/SMTInterpol/
# aprove/Framework/SMT/Solver/SMTLIB/
# aprove/Framework/SMT/Solver/SMTLIB/SExp/
# aprove/Framework/SMT/Solver/Z3/
# aprove/Framework/SMT/Utils/
# aprove/Framework/Syntax/
# aprove/Framework/TreeAutomaton/
# aprove/Framework/Typing/
# aprove/Framework/Unification/
# aprove/Framework/Unification/Problems/
# aprove/Framework/Unification/Utility/
# aprove/Framework/Utility/
# aprove/Framework/Utility/GenericStructures/
# aprove/Framework/Utility/Graph/
# aprove/Framework/Utility/JSON/
# aprove/Framework/Utility/Multithread/
# aprove/Framework/Utility/NameGenerators/
# aprove/Framework/Utility/Obligations/
# aprove/Framework/Utility/Profiling/
# aprove/Framework/Utility/Profiling/Utility/
# aprove/Framework/Utility/SMTUtility/
# aprove/Framework/Utility/Time/
# aprove/Framework/Verifier/
# aprove/Framework/WeightedIntTrs/
# aprove/GraphUserInterface/
# aprove/GraphUserInterface/Factories/
# aprove/GraphUserInterface/Factories/Solvers/
# aprove/GraphUserInterface/Factories/Solvers/DiophantineSATConverters/
# aprove/GraphUserInterface/Factories/Solvers/Engines/
# aprove/IDPFramework/
# aprove/IDPFramework/Algorithms/
# aprove/IDPFramework/Algorithms/Cap/
# aprove/IDPFramework/Algorithms/Confluence/
# aprove/IDPFramework/Algorithms/Filter/
# aprove/IDPFramework/Algorithms/Matching/
# aprove/IDPFramework/Algorithms/Unification/
# aprove/IDPFramework/Algorithms/UsableRules/
# aprove/IDPFramework/Core/
# aprove/IDPFramework/Core/BasicStructures/
# aprove/IDPFramework/Core/BasicStructures/Substitutions/
# aprove/IDPFramework/Core/IDPGraph/
# aprove/IDPFramework/Core/Itpf/
# aprove/IDPFramework/Core/PredefinedFunctions/
# aprove/IDPFramework/Core/PredefinedFunctions/Domains/
# aprove/IDPFramework/Core/SemiRings/
# aprove/IDPFramework/Core/Utility/
# aprove/IDPFramework/Core/Utility/Marking/
# aprove/IDPFramework/Core/Utility/PrimeNumbers/
# aprove/IDPFramework/ImplicationEngine/
# aprove/IDPFramework/Polynomials/
# aprove/IDPFramework/Polynomials/Interpretation/
# aprove/IDPFramework/Polynomials/Interpretation/ShapeHeuristics/
# aprove/IDPFramework/Processors/
# aprove/IDPFramework/Processors/Filters/
# aprove/IDPFramework/Processors/Filters/Bisimulation/
# aprove/IDPFramework/Processors/GraphProcessors/
# aprove/IDPFramework/Processors/GraphProcessors/EdgeCollapse/
# aprove/IDPFramework/Processors/GraphProcessors/EdgeCollapse/EdgeProviders/
# aprove/IDPFramework/Processors/GraphProcessors/EdgeCollapse/PathGenerators/
# aprove/IDPFramework/Processors/GraphProcessors/LoopUnroll/
# aprove/IDPFramework/Processors/ItpfRules/
# aprove/IDPFramework/Processors/ItpfRules/Execution/
# aprove/IDPFramework/Processors/ItpfRules/Execution/Strategy/
# aprove/IDPFramework/Processors/ItpfRules/poly/
# aprove/IDPFramework/Processors/NonInf/
# aprove/IDPFramework/Processors/NonInf/ItpfRules/
# aprove/IDPFramework/Processors/NonInf/Solving/
# aprove/IDPFramework/Processors/Poly/
# aprove/InputModules/
# aprove/InputModules/Diophantine/
# aprove/InputModules/Formulas/
# aprove/InputModules/Formulas/pl/
# aprove/InputModules/Generated/
# aprove/InputModules/Generated/IntProg/
# aprove/InputModules/Generated/IntTRS/
# aprove/InputModules/Generated/InterprocInvariant/
# aprove/InputModules/Generated/SMTLIB/
# aprove/InputModules/Generated/Strategy/
# aprove/InputModules/Generated/T2IntSys/
# aprove/InputModules/Generated/acl/
# aprove/InputModules/Generated/acl/analysis/
# aprove/InputModules/Generated/acl/lexer/
# aprove/InputModules/Generated/acl/node/
# aprove/InputModules/Generated/acl/parser/
# aprove/InputModules/Generated/cls/
# aprove/InputModules/Generated/cls/analysis/
# aprove/InputModules/Generated/cls/lexer/
# aprove/InputModules/Generated/cls/node/
# aprove/InputModules/Generated/cls/parser/
# aprove/InputModules/Generated/diologic/
# aprove/InputModules/Generated/diologic/analysis/
# aprove/InputModules/Generated/diologic/lexer/
# aprove/InputModules/Generated/diologic/node/
# aprove/InputModules/Generated/diologic/parser/
# aprove/InputModules/Generated/diophantine/
# aprove/InputModules/Generated/diophantine/analysis/
# aprove/InputModules/Generated/diophantine/lexer/
# aprove/InputModules/Generated/diophantine/node/
# aprove/InputModules/Generated/diophantine/parser/
# aprove/InputModules/Generated/fp/
# aprove/InputModules/Generated/fp/analysis/
# aprove/InputModules/Generated/fp/lexer/
# aprove/InputModules/Generated/fp/node/
# aprove/InputModules/Generated/fp/parser/
# aprove/InputModules/Generated/fppp/
# aprove/InputModules/Generated/fppp/analysis/
# aprove/InputModules/Generated/fppp/lexer/
# aprove/InputModules/Generated/fppp/node/
# aprove/InputModules/Generated/fppp/parser/
# aprove/InputModules/Generated/haskell/
# aprove/InputModules/Generated/haskell/analysis/
# aprove/InputModules/Generated/haskell/lexer/
# aprove/InputModules/Generated/haskell/node/
# aprove/InputModules/Generated/haskell/parser/
# aprove/InputModules/Generated/idp/
# aprove/InputModules/Generated/idp/analysis/
# aprove/InputModules/Generated/idp/lexer/
# aprove/InputModules/Generated/idp/node/
# aprove/InputModules/Generated/idp/parser/
# aprove/InputModules/Generated/impact/
# aprove/InputModules/Generated/impact/analysis/
# aprove/InputModules/Generated/impact/lexer/
# aprove/InputModules/Generated/impact/node/
# aprove/InputModules/Generated/impact/parser/
# aprove/InputModules/Generated/ipad/
# aprove/InputModules/Generated/ipad/analysis/
# aprove/InputModules/Generated/ipad/lexer/
# aprove/InputModules/Generated/ipad/node/
# aprove/InputModules/Generated/ipad/parser/
# aprove/InputModules/Generated/llvm/
# aprove/InputModules/Generated/newIDP/
# aprove/InputModules/Generated/newPtrs/
# aprove/InputModules/Generated/newTrs/
# aprove/InputModules/Generated/patrs/
# aprove/InputModules/Generated/patrs/analysis/
# aprove/InputModules/Generated/patrs/lexer/
# aprove/InputModules/Generated/patrs/node/
# aprove/InputModules/Generated/patrs/parser/
# aprove/InputModules/Generated/pl/
# aprove/InputModules/Generated/pl/analysis/
# aprove/InputModules/Generated/pl/lexer/
# aprove/InputModules/Generated/pl/node/
# aprove/InputModules/Generated/pl/parser/
# aprove/InputModules/Generated/polynomial/
# aprove/InputModules/Generated/polynomial/analysis/
# aprove/InputModules/Generated/polynomial/lexer/
# aprove/InputModules/Generated/polynomial/node/
# aprove/InputModules/Generated/polynomial/parser/
# aprove/InputModules/Generated/prolog/
# aprove/InputModules/Generated/prolog/analysis/
# aprove/InputModules/Generated/prolog/lexer/
# aprove/InputModules/Generated/prolog/node/
# aprove/InputModules/Generated/prolog/parser/
# aprove/InputModules/Generated/simplify/
# aprove/InputModules/Generated/simplify/analysis/
# aprove/InputModules/Generated/simplify/lexer/
# aprove/InputModules/Generated/simplify/node/
# aprove/InputModules/Generated/simplify/parser/
# aprove/InputModules/Generated/srs/
# aprove/InputModules/Generated/srs/analysis/
# aprove/InputModules/Generated/srs/lexer/
# aprove/InputModules/Generated/srs/node/
# aprove/InputModules/Generated/srs/parser/
# aprove/InputModules/Generated/srs2/
# aprove/InputModules/Generated/srs2/analysis/
# aprove/InputModules/Generated/srs2/lexer/
# aprove/InputModules/Generated/srs2/node/
# aprove/InputModules/Generated/srs2/parser/
# aprove/InputModules/Generated/strs/
# aprove/InputModules/Generated/strs/analysis/
# aprove/InputModules/Generated/strs/lexer/
# aprove/InputModules/Generated/strs/node/
# aprove/InputModules/Generated/strs/parser/
# aprove/InputModules/Generated/term/
# aprove/InputModules/Generated/term/analysis/
# aprove/InputModules/Generated/term/lexer/
# aprove/InputModules/Generated/term/node/
# aprove/InputModules/Generated/term/parser/
# aprove/InputModules/Generated/tes/
# aprove/InputModules/Generated/tes/analysis/
# aprove/InputModules/Generated/tes/lexer/
# aprove/InputModules/Generated/tes/node/
# aprove/InputModules/Generated/tes/parser/
# aprove/InputModules/Generated/ttt/
# aprove/InputModules/Generated/ttt/analysis/
# aprove/InputModules/Generated/ttt/lexer/
# aprove/InputModules/Generated/ttt/node/
# aprove/InputModules/Generated/ttt/parser/
# aprove/InputModules/Generated/xsrs/
# aprove/InputModules/Generated/xsrs/analysis/
# aprove/InputModules/Generated/xsrs/lexer/
# aprove/InputModules/Generated/xsrs/node/
# aprove/InputModules/Generated/xsrs/parser/
# aprove/InputModules/Polynomials/
# aprove/InputModules/Programs/
# aprove/InputModules/Programs/Predef/
# aprove/InputModules/Programs/Predef/IntegerPredef/
# aprove/InputModules/Programs/SMTLIB/
# aprove/InputModules/Programs/SMTLIB/Exceptions/
# aprove/InputModules/Programs/SMTLIB/Namespaces/
# aprove/InputModules/Programs/SMTLIB/Sorts/
# aprove/InputModules/Programs/SMTLIB/Terms/
# aprove/InputModules/Programs/SMTLIB/Terms/CoreTheory/
# aprove/InputModules/Programs/SMTLIB/Terms/IntsTheory/
# aprove/InputModules/Programs/Strategy/
# aprove/InputModules/Programs/c/
# aprove/InputModules/Programs/cint/
# aprove/InputModules/Programs/cls/
# aprove/InputModules/Programs/diologic/
# aprove/InputModules/Programs/fp/
# aprove/InputModules/Programs/haskell/
# aprove/InputModules/Programs/idp/
# aprove/InputModules/Programs/impact/
# aprove/InputModules/Programs/impact/GTP/
# aprove/InputModules/Programs/impact/GTP/nodes/
# aprove/InputModules/Programs/impact/Program/
# aprove/InputModules/Programs/intClauses/
# aprove/InputModules/Programs/intProg/
# aprove/InputModules/Programs/intTrs/
# aprove/InputModules/Programs/ipad/
# aprove/InputModules/Programs/itrs/
# aprove/InputModules/Programs/jbc/
# aprove/InputModules/Programs/jbc/classpath/
# aprove/InputModules/Programs/jbc/classpath/java/
# aprove/InputModules/Programs/jbc/classpath/java/io/
# aprove/InputModules/Programs/jbc/classpath/java/lang/
# aprove/InputModules/Programs/jbc/classpath/java/util/
# aprove/InputModules/Programs/llvm/
# aprove/InputModules/Programs/llvm/exceptions/
# aprove/InputModules/Programs/llvm/internalStructures/
# aprove/InputModules/Programs/llvm/internalStructures/dataType/
# aprove/InputModules/Programs/llvm/internalStructures/expressions/
# aprove/InputModules/Programs/llvm/internalStructures/expressions/relations/
# aprove/InputModules/Programs/llvm/internalStructures/instructions/
# aprove/InputModules/Programs/llvm/internalStructures/intersecting/
# aprove/InputModules/Programs/llvm/internalStructures/intersecting/relationeval/
# aprove/InputModules/Programs/llvm/internalStructures/intersecting/tracker/
# aprove/InputModules/Programs/llvm/internalStructures/literals/
# aprove/InputModules/Programs/llvm/internalStructures/literals/const_expr/
# aprove/InputModules/Programs/llvm/internalStructures/memory/
# aprove/InputModules/Programs/llvm/internalStructures/module/
# aprove/InputModules/Programs/llvm/parseStructures/
# aprove/InputModules/Programs/llvm/parseStructures/dataTypes/
# aprove/InputModules/Programs/llvm/parseStructures/exceptions/
# aprove/InputModules/Programs/llvm/parseStructures/literals/
# aprove/InputModules/Programs/llvm/problems/
# aprove/InputModules/Programs/llvm/processors/
# aprove/InputModules/Programs/llvm/segraph/
# aprove/InputModules/Programs/llvm/segraph/edges/
# aprove/InputModules/Programs/llvm/segraph/graphConstructionSteps/
# aprove/InputModules/Programs/llvm/segraph/graphListeners/
# aprove/InputModules/Programs/llvm/states/
# aprove/InputModules/Programs/llvm/utils/
# aprove/InputModules/Programs/llvm/utils/static_analysis/
# aprove/InputModules/Programs/loat/
# aprove/InputModules/Programs/loat/debug/
# aprove/InputModules/Programs/mcs/
# aprove/InputModules/Programs/newIDP/
# aprove/InputModules/Programs/newPtrs/
# aprove/InputModules/Programs/newTrs/
# aprove/InputModules/Programs/patrs/
# aprove/InputModules/Programs/prolog/
# aprove/InputModules/Programs/prolog/graph/
# aprove/InputModules/Programs/prolog/graph/rules/
# aprove/InputModules/Programs/prolog/nodes/
# aprove/InputModules/Programs/prolog/processors/
# aprove/InputModules/Programs/prolog/processors/toirswt/
# aprove/InputModules/Programs/prolog/structure/
# aprove/InputModules/Programs/pushdownSMT/
# aprove/InputModules/Programs/simplify/
# aprove/InputModules/Programs/srs/
# aprove/InputModules/Programs/srs2/
# aprove/InputModules/Programs/strategy_OLD/
# aprove/InputModules/Programs/strs/
# aprove/InputModules/Programs/t2/
# aprove/InputModules/Programs/tes/
# aprove/InputModules/Programs/triples/
# aprove/InputModules/Programs/triples/processors/
# aprove/InputModules/Programs/ttt/
# aprove/InputModules/Programs/xsrs/
# aprove/InputModules/Programs/xtc/
# aprove/InputModules/Programs/xtc/tagHandler/
# aprove/InputModules/Terms/
# aprove/InputModules/Terms/term/
# aprove/InputModules/Utility/
# aprove/InputModules/Utility/XML/
# aprove/Logging/
# aprove/Logging/config/
# aprove/OldFramework/
# aprove/OldFramework/TRSProblem/
# aprove/OldFramework/TheoremProverProblem/
# aprove/PredefinedStrategies/
# aprove/PredefinedStrategies/Auto/
# aprove/PredefinedStrategies/Cage/
# aprove/PredefinedStrategies/Certify/
# aprove/PredefinedStrategies/FrontendExport/
# aprove/PredefinedStrategies/Modules/
# aprove/Probabilistic/
# aprove/Probabilistic/ADPProblem/
# aprove/Probabilistic/ADPProblem/AST/
# aprove/Probabilistic/ADPProblem/AST/Processors/
# aprove/Probabilistic/BasicStructures/
# aprove/Probabilistic/PTRSProblem/
# aprove/Probabilistic/PTRSProblem/AST/
# aprove/Probabilistic/PTRSProblem/AST/Processors/
# aprove/Probabilistic/PTRSProblem/PAST/
# aprove/Probabilistic/PTRSProblem/PAST/Processors/
# aprove/Probabilistic/PTRSProblem/Processors/
# aprove/Processors/
# aprove/Processors/Parameters/
# aprove/Processors/Parameters/Properties/
# aprove/ProofTree/
# aprove/ProofTree/Export/
# aprove/ProofTree/Export/ProofPurposeDescriptors/
# aprove/ProofTree/Export/Utility/
# aprove/ProofTree/Obligations/
# aprove/ProofTree/Obligations/Junctors/
# aprove/ProofTree/Proofs/
# aprove/Runtime/
# aprove/Strategies/
# aprove/Strategies/Abortions/
# aprove/Strategies/Annotations/
# aprove/Strategies/ExecutableStrategies/
# aprove/Strategies/ExecutableStrategies/impl/
# aprove/Strategies/InstantiationUtils/
# aprove/Strategies/Parameters/
# aprove/Strategies/UserStrategies/
# aprove/Strategies/Util/
# aprove/Testing/
# aprove/Testing/Manual/
# aprove/Testing/Manual/Haskell/
# aprove/Testing/Manual/Prolog/
# aprove/Testing/Manual/SafetyRedPair/
# aprove/Testing/Manual/llvm/
# aprove/VerificationModules/
# aprove/VerificationModules/ObligationFactories/
# aprove/VerificationModules/Simplifier/
# aprove/VerificationModules/Simplify/
# aprove/VerificationModules/TerminationProcedures/
# aprove/VerificationModules/TerminationProofs/
# aprove/VerificationModules/TerminationVerifier/
# aprove/VerificationModules/TheoremProver/
# aprove/VerificationModules/TheoremProverProcedures/
# aprove/VerificationModules/TheoremProverProcedures/Induction/
# aprove/VerificationModules/TheoremProverProcedures/LemmaDirectors/
# aprove/VerificationModules/TheoremProverProofs/
# aprove/XML/
# aprove/XML/DTDs/
# aprove/XML/Haskell/
# aprove/XML/Nodes/
# aprove/XML/XSDs/
# aprove/XML/XSL/
# aprove/api/
# aprove/api/decisions/
# aprove/api/decisions/factory/
# aprove/api/decisions/impl/
# aprove/api/decisions/results/
# aprove/api/details/
# aprove/api/details/impl/
# aprove/api/impl/
# aprove/api/osgi/
# aprove/api/prooftree/
# aprove/api/prooftree/impl/
# aprove/exit/
# VERSION
# aprove/Benchmarking/Benchmark.class
# aprove/Benchmarking/BenchmarkManager.class
# aprove/Benchmarking/BenchmarkResult.class
# aprove/Benchmarking/DBAdapter.class
# aprove/Benchmarking/Example.class
# aprove/Benchmarking/PassInputData.class
# aprove/CommandLineInterface/Batch$1.class
# aprove/CommandLineInterface/Batch$MODE.class
# aprove/CommandLineInterface/Batch.class
# aprove/CommandLineInterface/CFrontendMain$CFrontendOpts.class
# aprove/CommandLineInterface/CFrontendMain.class
# aprove/CommandLineInterface/Certifier.class
# aprove/CommandLineInterface/Client$1.class
# aprove/CommandLineInterface/Client.class
# aprove/CommandLineInterface/FrontendMain$FrontendOpts.class
# aprove/CommandLineInterface/FrontendMain.class
# aprove/CommandLineInterface/Generic/CommandLineOptions.class
# aprove/CommandLineInterface/Generic/GenericMain.class
# aprove/CommandLineInterface/Generic/InputUtil.class
# aprove/CommandLineInterface/Generic/ProblemExecutor.class
# aprove/CommandLineInterface/Generic/SocketAborterThread.class
# aprove/CommandLineInterface/Generic/SocketServerThread.class
# aprove/CommandLineInterface/HaskellFrontendMain$HaskellFrontendOpts.class
# aprove/CommandLineInterface/HaskellFrontendMain.class
# aprove/CommandLineInterface/JBCFrontendMain$JBCFrontendOpts.class
# aprove/CommandLineInterface/JBCFrontendMain.class
# aprove/CommandLineInterface/LLVMFrontendMain$LLVMFrontendOpts.class
# aprove/CommandLineInterface/LLVMFrontendMain.class
# aprove/CommandLineInterface/Main$CLIOpts.class
# aprove/CommandLineInterface/Main$Mode.class
# aprove/CommandLineInterface/Main.class
# aprove/CommandLineInterface/MultiServer$MainThread.class
# aprove/CommandLineInterface/MultiServer$RequestHandler$1.class
# aprove/CommandLineInterface/MultiServer$RequestHandler.class
# aprove/CommandLineInterface/MultiServer.class
# aprove/CommandLineInterface/ObligationCache/AllBasicObligationCache.class
# aprove/CommandLineInterface/ObligationCache/BasicObligationCache$1.class
# aprove/CommandLineInterface/ObligationCache/BasicObligationCache$CACHE.class
# aprove/CommandLineInterface/ObligationCache/BasicObligationCache$CacheTruthValueListener.class
# aprove/CommandLineInterface/ObligationCache/BasicObligationCache.class
# aprove/CommandLineInterface/ObligationCache/LRUBasicObligationCache.class
# aprove/CommandLineInterface/PrologFrontendMain$PrologFrontendOpts.class
# aprove/CommandLineInterface/PrologFrontendMain.class
# aprove/CommandLineInterface/ProofExport$1.class
# aprove/CommandLineInterface/ProofExport$2.class
# aprove/CommandLineInterface/ProofExport$3.class
# aprove/CommandLineInterface/ProofExport$4.class
# aprove/CommandLineInterface/ProofExport$5.class
# aprove/CommandLineInterface/ProofExport$6.class
# aprove/CommandLineInterface/ProofExport$7.class
# aprove/CommandLineInterface/ProofExport$8.class
# aprove/CommandLineInterface/ProofExport$9.class
# aprove/CommandLineInterface/ProofExport.class
# aprove/CommandLineInterface/Runme.class
# aprove/CommandLineInterface/RunmeA3PAT.class
# aprove/CommandLineInterface/RunmeCeTA.class
# aprove/CommandLineInterface/RunmeCertifyCommon.class
# aprove/CommandLineInterface/RunmeRainbow.class
# aprove/CommandLineInterface/RunmeXML.class
# aprove/CommandLineInterface/Server$RequestHandler.class
# aprove/CommandLineInterface/Server.class
# aprove/CommandLineInterface/tpdbConverter/Converter.class
# aprove/CommandLineInterface/tpdbConverter/TPDB_Exporter$1.class
# aprove/CommandLineInterface/tpdbConverter/TPDB_Exporter$NotExpressibleException.class
# aprove/CommandLineInterface/tpdbConverter/TPDB_Exporter.class
# aprove/Complexity/AcdtProblem/Acdt$CdtCreateRes.class
# aprove/Complexity/AcdtProblem/Acdt.class
# aprove/Complexity/AcdtProblem/AcdtProblem$TupleComputeState.class
# aprove/Complexity/AcdtProblem/AcdtProblem.class
# aprove/Complexity/AcdtProblem/Processors/AcdtForwardInstantiationProcessor$CdtForwardInstantiatonProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtForwardInstantiationProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphRemoveDanglingNodesProcessor$CdtGraphRemoveDanglingProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphRemoveDanglingNodesProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphRemoveTrailingTuplepartsProcessor$CdtGraphRemoveTrailingProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphRemoveTrailingTuplepartsProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphSplitProcessor$CdtGraphSplitProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphSplitProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphSplitRhsProcessor$CdtGraphSplitRhsProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtGraphSplitRhsProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtInstantiationProcessor$CdtInstantiationProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtInstantiationProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtOrderProcessor$AdditionalRestrictions.class
# aprove/Complexity/AcdtProblem/Processors/AcdtOrderProcessor$Arguments.class
# aprove/Complexity/AcdtProblem/Processors/AcdtOrderProcessor$QtrsDirectGcdpComplexityProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtOrderProcessor$State.class
# aprove/Complexity/AcdtProblem/Processors/AcdtOrderProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtPrintGraphProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtProblemProcessor$TIsEmptyProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtProblemProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtSimpleNontermProcessor$CdtSimpleNontermProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtSimpleNontermProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtTransformationProcessor$State.class
# aprove/Complexity/AcdtProblem/Processors/AcdtTransformationProcessor$Transformation.class
# aprove/Complexity/AcdtProblem/Processors/AcdtTransformationProcessor.class
# aprove/Complexity/AcdtProblem/Processors/AcdtUsableRulesProcessor$CdtUsableRulesProof.class
# aprove/Complexity/AcdtProblem/Processors/AcdtUsableRulesProcessor.class
# aprove/Complexity/AcdtProblem/Processors/CpxTrsToAcdtProcessor$QtrsToCdtProof.class
# aprove/Complexity/AcdtProblem/Processors/CpxTrsToAcdtProcessor.class
# aprove/Complexity/AcdtProblem/Utils/BasicAcdtGraph.class
# aprove/Complexity/AcdtProblem/Utils/CollectionUtil.class
# aprove/Complexity/AcdtProblem/Utils/DefinedPositionsTree.class
# aprove/Complexity/AcdtProblem/Utils/IcapAlgorithm$IcapState.class
# aprove/Complexity/AcdtProblem/Utils/IcapAlgorithm.class
# aprove/Complexity/AcdtProblem/Utils/IcapCalculator$CacheKey.class
# aprove/Complexity/AcdtProblem/Utils/IcapCalculator.class
# aprove/Complexity/AcdtProblem/Utils/TupleDefinedPositions$TDPIterator.class
# aprove/Complexity/AcdtProblem/Utils/TupleDefinedPositions$TupleDefinedPosition.class
# aprove/Complexity/AcdtProblem/Utils/TupleDefinedPositions.class
# aprove/Complexity/AcdtProblem/Utils/UsableRulesCalculator.class
# aprove/Complexity/CIdtProblem/CIdtProblem.class
# aprove/Complexity/CIdtProblem/Processors/CIdtCNDGraphProcessor$Arguments.class
# aprove/Complexity/CIdtProblem/Processors/CIdtCNDGraphProcessor$CIdtCNDGraphProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtCNDGraphProcessor$GraphStrategy.class
# aprove/Complexity/CIdtProblem/Processors/CIdtCNDGraphProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtKnowledgePropagationProcessor$CIdtKnowledgePropagationProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtKnowledgePropagationProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtLeafRemovalProcessor$CIdtLeafRemovalProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtLeafRemovalProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtNodeSplitProcessor$CIdtNodeSplitProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtNodeSplitProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPathCollapseProcessor$Arguments.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPathCollapseProcessor$CIdtPathCollapseProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPathCollapseProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPolyIntRedPairProcessor$Arguments.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPolyIntRedPairProcessor$CIdtPolyIntRedPairGraphProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPolyIntRedPairProcessor$CIdtPolyIntRedPairProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPolyIntRedPairProcessor$PolyIntRedPairResult.class
# aprove/Complexity/CIdtProblem/Processors/CIdtPolyIntRedPairProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtProcessor$SIsEmptyProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtProcessor.class
# aprove/Complexity/CIdtProblem/Processors/CIdtUsableRulesProcessor$UsableRulesProof.class
# aprove/Complexity/CIdtProblem/Processors/CIdtUsableRulesProcessor.class
# aprove/Complexity/CIdtProblem/Utility/CIdtCollapsedPathsResult.class
# aprove/Complexity/CIdtProblem/Utility/CIdtInitialGraphGenerator$InitialNodesResult.class
# aprove/Complexity/CIdtProblem/Utility/CIdtInitialGraphGenerator.class
# aprove/Complexity/CIdtProblem/Utility/CIdtPolyIntRedPairImplicationGraph.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$1.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$2.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$3.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$4.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$5.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$6.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$7.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy$8.class
# aprove/Complexity/CIdtProblem/Utility/CNDStrategy.class
# aprove/Complexity/CdpProblem/CdpProblem$PairComputeState.class
# aprove/Complexity/CdpProblem/CdpProblem.class
# aprove/Complexity/CdpProblem/Processors/CdpDirectComplexityProcessor$Arguments.class
# aprove/Complexity/CdpProblem/Processors/CdpDirectComplexityProcessor$CdpDirectComplexityProof.class
# aprove/Complexity/CdpProblem/Processors/CdpDirectComplexityProcessor.class
# aprove/Complexity/CdpProblem/Processors/CdpProblemProcessor.class
# aprove/Complexity/CdpProblem/Processors/CdpUsableRulesProcessor$CdpUsableRulesProof.class
# aprove/Complexity/CdpProblem/Processors/CdpUsableRulesProcessor.class
# aprove/Complexity/CdpProblem/Processors/CpxTrsToCdpProcessor$QTRSToCdpProof.class
# aprove/Complexity/CdpProblem/Processors/CpxTrsToCdpProcessor.class
# aprove/Complexity/CdpProblem/Processors/Util/QtrsDirectGcdp/DefinedPositionsTree.class
# aprove/Complexity/CdpProblem/Processors/Util/QtrsDirectGcdp/ImmutableRuleSet.class
# aprove/Complexity/CdpProblem/Processors/Util/QtrsDirectGcdp/RuleSet.class
# aprove/Complexity/CdtProblem/Cdt.class
# aprove/Complexity/CdtProblem/CdtProblem$TupleComputeState.class
# aprove/Complexity/CdtProblem/CdtProblem.class
# aprove/Complexity/CdtProblem/ComplexCdtProblem.class
# aprove/Complexity/CdtProblem/CpxProof.class
# aprove/Complexity/CdtProblem/Processors/CdtForwardInstantiationProcessor$CdtForwardInstantiationProof.class
# aprove/Complexity/CdtProblem/Processors/CdtForwardInstantiationProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtGraphSplitRhsProcessor$CdtGraphSplitRhsProof.class
# aprove/Complexity/CdtProblem/Processors/CdtGraphSplitRhsProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtInstantiationProcessor$CdtInstantiationProof.class
# aprove/Complexity/CdtProblem/Processors/CdtInstantiationProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtKnowledgeProcessor$CdtKnowledgeProof.class
# aprove/Complexity/CdtProblem/Processors/CdtKnowledgeProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtLeafRemovalProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtLeafRemovalProcessor$CdtLeafRemovalProof.class
# aprove/Complexity/CdtProblem/Processors/CdtLeafRemovalProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtMatrixRedPairProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtMatrixRedPairProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtNarrowingProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtNarrowingProcessor$CdtNarrowingProof.class
# aprove/Complexity/CdtProblem/Processors/CdtNarrowingProcessor$NarrowingPos.class
# aprove/Complexity/CdtProblem/Processors/CdtNarrowingProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtPolyRedPairProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtPolyRedPairProcessor$CdtRuleRemovalProof.class
# aprove/Complexity/CdtProblem/Processors/CdtPolyRedPairProcessor$State.class
# aprove/Complexity/CdtProblem/Processors/CdtPolyRedPairProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtPrintGraphProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtProblemProcessor$SIsEmptyProof.class
# aprove/Complexity/CdtProblem/Processors/CdtProblemProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtRelMatchBoundsTAProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtRelMatchBoundsTAProcessor$CdtRelMatchBoundsTAProof.class
# aprove/Complexity/CdtProblem/Processors/CdtRelMatchBoundsTAProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtRewritingProcessor$CdtRewritingProof.class
# aprove/Complexity/CdtProblem/Processors/CdtRewritingProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtRhsSimplificationProcessor$CdtRhsSimplificationProcessorProof.class
# aprove/Complexity/CdtProblem/Processors/CdtRhsSimplificationProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtSccSplitProcessor$CdtSccSplitProof.class
# aprove/Complexity/CdtProblem/Processors/CdtSccSplitProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtToCpxRelTrsProcessor$CdtToCpxRelTrsProof.class
# aprove/Complexity/CdtProblem/Processors/CdtToCpxRelTrsProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtToCpxWeightedTrsProcessor$CdtToCpxWeightedTrsProof.class
# aprove/Complexity/CdtProblem/Processors/CdtToCpxWeightedTrsProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtTransformationProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtTransformationProcessor$State.class
# aprove/Complexity/CdtProblem/Processors/CdtTransformationProcessor$Transformation.class
# aprove/Complexity/CdtProblem/Processors/CdtTransformationProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtUnreachableProcessor$CdtUnreachableProof.class
# aprove/Complexity/CdtProblem/Processors/CdtUnreachableProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtUsableRulesProcessor$CdtUsableRulesProof.class
# aprove/Complexity/CdtProblem/Processors/CdtUsableRulesProcessor.class
# aprove/Complexity/CdtProblem/Processors/CdtViaRntsProcessor$1.class
# aprove/Complexity/CdtProblem/Processors/CdtViaRntsProcessor$Arguments.class
# aprove/Complexity/CdtProblem/Processors/CdtViaRntsProcessor$CdtViaRntsProof.class
# aprove/Complexity/CdtProblem/Processors/CdtViaRntsProcessor.class
# aprove/Complexity/CdtProblem/Processors/ComplexCdtProblemProcessor$IsEmptyProof.class
# aprove/Complexity/CdtProblem/Processors/ComplexCdtProblemProcessor$MaxProof.class
# aprove/Complexity/CdtProblem/Processors/ComplexCdtProblemProcessor$MultiplicationProof.class
# aprove/Complexity/CdtProblem/Processors/ComplexCdtProblemProcessor.class
# aprove/Complexity/CdtProblem/Processors/CpxTrsToCdtProcessor$CpxTrsToCdtProof.class
# aprove/Complexity/CdtProblem/Processors/CpxTrsToCdtProcessor.class
# aprove/Complexity/CdtProblem/Utils/BasicCdtGraph.class
# aprove/Complexity/CdtProblem/Utils/GraphHistory$Technique.class
# aprove/Complexity/CdtProblem/Utils/GraphHistory.class
# aprove/Complexity/CdtProblem/Utils/IcapCalculator$CacheKey.class
# aprove/Complexity/CdtProblem/Utils/IcapCalculator.class
# aprove/Complexity/CpxGTrsProblem/CpxGTrsExtraVarProcessor$ExtraVarProof.class
# ...
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/FixProofDAG$ExpandClause.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/FixProofDAG$Worker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/FixProofDAG.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/IProofTracker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/LeafNode.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/NoopProofTracker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/OccurrenceCounter.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofConstants.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofNode.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTermGenerator$Expander.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTermGenerator$GenerateTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTermGenerator$Visitor.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTermGenerator.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$ExpandRewrite.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$FlattenHelper.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$InternRewrite.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$RemoveConnective.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$ResultRewrite.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker$Rewrite.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ProofTracker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/PropProofChecker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/RecyclePivots$SetAndExpand.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/RecyclePivots$Worker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/RecyclePivots.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ResolutionNode$Antecedent.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/ResolutionNode.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/SourceAnnotation.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations$2.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations$3.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations$4.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations$5.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations$AvailableTransformations.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/Transformations.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/UnitCollector.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/proof/UnsatCoreCollector.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Benchmark$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Benchmark.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Lexer.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/LexerSymbols.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Main.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Parser$Action$.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/Parser.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib/SMTLIBParser.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Div0Remover$BuildAnnotationTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Div0Remover.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/ExitHook.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/InterpolationInfo.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Lexer.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/LexerSymbols.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Main.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/ParseEnvironment$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/ParseEnvironment.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Parser$Action$$Binding.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Parser$Action$$IndexedIdentifier.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Parser$Action$$QualIdentifier.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Parser$Action$.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Parser.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$2.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$3.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$BoolOption.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$CheckType$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$CheckType$2.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$CheckType$3.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$CheckType.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$IntOption.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$NoUserCancellation.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$Option.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$OptionMap.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$SMTInterpolSetup$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$SMTInterpolSetup$RewriteProofFactory.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$SMTInterpolSetup.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol$StringOption.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTInterpol.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/SMTLIB2Parser.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/TerminationRequest.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/smtlib2/Version.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCAnnotation.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCAppTerm$Parent.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCAppTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCBaseTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCEquality$Entry.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCEquality.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCParentInfo.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTerm$CongruenceInfo.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTerm$TermPairMergeInfo.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTermPairHash$Info$Entry.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTermPairHash$Info.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CCTermPairHash.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CClosure$CCAppTermPair.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CClosure.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CongruenceBlockPair.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CongruenceBlockerSet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CongruencePath$SubPath.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/CongruencePath.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/ModelBuilder$Delay.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/ModelBuilder.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/StackData.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/cclosure/UpdatableCongruenceBlocker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/AnnotationToProofTerm$AnnotationInfo.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/AnnotationToProofTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/BoundConstraint.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/CompositeReason.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/CutCreator$1LinVarBigInt.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/CutCreator$Column.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/CutCreator$Row.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/CutCreator.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/ExactInfinitNumber.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/Explainer.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/InfinitNumber.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LAAnnotation.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LAEquality.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LAReason.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LinArSolve$UnsimpData.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LinArSolve.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LinTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LinVar.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/LiteralReason.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/MatrixEntry.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/MutableAffinTerm.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/theory/linar/MutableInfinitNumber.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayMap$1$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayMap$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayMap$ArrayMapEntry.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayMap.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayQueue$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ArrayQueue.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/Coercion.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/CollectionsHelper.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/CuckooHashSet$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/CuckooHashSet$StashList.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/CuckooHashSet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/DAGSize$ConstantEmptySet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/DAGSize$TermOnceWalker.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/DAGSize.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/IdentityHashSet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/IntAllocator$IntervalNode.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/IntAllocator.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet$2.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet$ListSetElem.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet$ListSetIterator.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet$ScopeIterator.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ListSet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/MySymbolFactory$LineColumnSymbol.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/MySymbolFactory.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$1$1$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$1$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$2$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$2.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$3$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$3.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$4$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap$4.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/ScopedIdentityHashMap.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/SharingSet$1.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/SharingSet$SharingSetData.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/SharingSet.class
# de/uni_freiburg/informatik/ultimate/smtinterpol/util/SymmetricPair.class
# de/uni_freiburg/informatik/ultimate/util/DebugMessage$1.class
# de/uni_freiburg/informatik/ultimate/util/DebugMessage$TermDirectFormat.class
# de/uni_freiburg/informatik/ultimate/util/DebugMessage.class
# de/uni_freiburg/informatik/ultimate/util/HashUtils.class
# de/uni_freiburg/informatik/ultimate/util/ScopeUtils.class
# de/uni_freiburg/informatik/ultimate/util/ScopedArrayList$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedArrayList.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$1$1$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$1$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$2$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$2.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$3$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$3.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$4$1.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap$4.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashMap.class
# de/uni_freiburg/informatik/ultimate/util/ScopedHashSet.class
# de/uni_freiburg/informatik/ultimate/util/UnifyHash$1.class
# de/uni_freiburg/informatik/ultimate/util/UnifyHash$2$1.class
# de/uni_freiburg/informatik/ultimate/util/UnifyHash$2.class
# de/uni_freiburg/informatik/ultimate/util/UnifyHash$Bucket.class
# de/uni_freiburg/informatik/ultimate/util/UnifyHash.class
# java_cup/
# java_cup/anttask/
# java_cup/runtime/
# java_cup/CombRow.class
# java_cup/ErrorManager.class
# java_cup/Grammar.class
# java_cup/Lexer.class
# java_cup/Main.class
# java_cup/action_part.class
# java_cup/action_production.class
# java_cup/anttask/CUPTask.class
# java_cup/assoc.class
# java_cup/emit.class
# java_cup/lalr_state.class
# java_cup/lalr_transition.class
# java_cup/lookaheads.class
# java_cup/lr_item.class
# java_cup/non_terminal.class
# java_cup/parse_action_table.class
# java_cup/parse_reduce_table.class
# java_cup/parser$Action$.class
# java_cup/parser.class
# java_cup/production.class
# java_cup/production_part.class
# java_cup/runtime/ComplexSymbolFactory$ComplexSymbol.class
# java_cup/runtime/ComplexSymbolFactory$Location.class
# java_cup/runtime/ComplexSymbolFactory.class
# java_cup/runtime/DefaultSymbolFactory.class
# java_cup/runtime/LRParser.class
# java_cup/runtime/Scanner.class
# java_cup/runtime/Symbol.class
# java_cup/runtime/SymbolFactory.class
# java_cup/runtime/TableDecoder.class
# java_cup/runtime/virtual_parse_stack.class
# java_cup/sym.class
# java_cup/symbol.class
# java_cup/symbol_part.class
# java_cup/terminal.class
# java_cup/terminal_set.class
# java_cup/version.class

# %%
! java -ea -jar ~/Downloads/aprove.jar -
# Out:
# ^C

# %%
# Out:
# YES
# <?xml version="1.0" encoding="UTF-8" standalone="no"?><?xml-stylesheet type="text/xsl" href="cpfHTML.xsl"?><certificationProblem xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="cpf.xsd"><input><trsInput><trs><rules><rule><lhs><funapp><name>plus</name><arg><funapp><name>0</name></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><var>y</var></rhs></rule><rule><lhs><funapp><name>plus</name><arg><funapp><name>s</name><arg><var>x</var></arg></funapp></arg><arg><var>y</var></arg></funapp></lhs><rhs><funapp><name>s</name><arg><funapp><name>plus</name><arg><var>x</var></arg><arg><var>y</var></arg></funapp></arg></funapp></rhs></rule></rules></trs></trsInput></input><cpfVersion>2.1</cpfVersion><proof><trsTerminationProof><ruleRemoval><orderingConstraintProof><redPair><knuthBendixOrder><w0>1</w0><precedenceWeight><precedenceWeightEntry><name>0</name><arity>0</arity><precedence>0</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>s</name><arity>1</arity><precedence>1</precedence><weight>1</weight></precedenceWeightEntry><precedenceWeightEntry><name>plus</name><arity>2</arity><precedence>2</precedence><weight>0</weight></precedenceWeightEntry></precedenceWeight></knuthBendixOrder></redPair></orderingConstraintProof><trs><rules/></trs><trsTerminationProof><rIsEmpty/></trsTerminationProof></ruleRemoval></trsTerminationProof></proof><origin><proofOrigin><tool><name>AProVE</name><version>AProVE Commit ID: 314de9e47ad18e927546098510ed7c36e443eb6d jan-christoph 20231211 unpublished
# </version><strategy>Statistics for single proof: 100.00 % (2 real / 0 unknown / 0 assumptions / 2 total proof steps)</strategy><url>http://aprove.informatik.rwth-aachen.de</url></tool><toolUser><firstName>John</firstName><lastName>Doe</lastName></toolUser></proofOrigin><inputOrigin/></origin></certificationProblem>

# %%
! java -ea -cp ~/Downloads/aprove.jar aprove.CommandLineInterface.CFrontendMain /tmp/term.c
# Out:
# line 7:30 no viable alternative at input 'ptr'
# line 7:44 mismatched input ')' expecting ASSIGN
# line 8:7 mismatched input 'alloca' expecting TYPE
# line 9:7 mismatched input 'alloca' expecting TYPE
# line 10:14 mismatched input ',' expecting ASSIGN
# line 10:22 mismatched input ',' expecting ASSIGN
# line 11:7 mismatched input 'load' expecting TYPE
# line 11:23 mismatched input ',' expecting ASSIGN
# line 12:14 mismatched input ',' expecting ASSIGN
# line 12:22 mismatched input ',' expecting ASSIGN
# line 15:0 mismatched input '5' expecting ASSIGN
# line 16:7 mismatched input 'load' expecting TYPE
# line 16:23 mismatched input ',' expecting ASSIGN
# line 17:7 mismatched input 'load' expecting TYPE
# line 17:22 mismatched input ',' expecting ASSIGN
# line 18:7 mismatched input 'sext' expecting TYPE
# line 18:18 mismatched input 'to' expecting ASSIGN
# line 19:7 mismatched input 'icmp' expecting TYPE
# line 19:21 mismatched input ',' expecting ASSIGN
# line 20:10 mismatched input ',' expecting ASSIGN
# line 20:21 mismatched input ',' expecting ASSIGN
# line 22:0 mismatched input '10' expecting ASSIGN
# line 23:8 mismatched input 'load' expecting TYPE
# line 23:24 mismatched input ',' expecting ASSIGN
# line 24:8 mismatched input 'getelementptr' expecting TYPE
# line 24:42 mismatched input ',' expecting ASSIGN
# line 25:15 mismatched input ',' expecting ASSIGN
# line 25:23 mismatched input ',' expecting ASSIGN
# line 26:13 mismatched input ',' expecting ASSIGN
# line 26:26 missing ASSIGN at '!'
# line 26:27 mismatched input '6' expecting OPENC
# line 29:8 mismatched input 'load' expecting TYPE
# line 29:24 mismatched input ',' expecting ASSIGN
# line 30:8 mismatched input 'load' expecting TYPE
# line 30:24 mismatched input ',' expecting ASSIGN
# line 31:8 mismatched input 'ptrtoint' expecting TYPE
# line 31:25 mismatched input 'to' expecting ASSIGN
# line 32:8 mismatched input 'ptrtoint' expecting TYPE
# line 32:25 mismatched input 'to' expecting ASSIGN
# line 33:8 mismatched input 'sub' expecting TYPE
# line 33:19 mismatched input ',' expecting ASSIGN
# line 34:2 extraneous input '%19' expecting ASSIGN
# line 34:22 mismatched input 'to' expecting ASSIGN
# line 36:0 mismatched input '}' expecting ASSIGN
# line 42:14 no viable alternative at input 'ptr'
# line 43:15 no viable alternative at input 'ptr'
# line 45:16 no viable alternative at input 'ptr'
# line 46:17 no viable alternative at input 'ptr'
# line 51:15 no viable alternative at input 'ptr'
# line 55:17 no viable alternative at input 'ptr'
# line 59:8 no viable alternative at input 'ptr'
# line 59:17 no viable alternative at input 'ptr'
# line 60:13 no viable alternative at input 'ptr'
# line 60:18 no viable alternative at input 'ptr'
# line 61:18 no viable alternative at input 'ptr'
# line 64:35 no viable alternative at input 'ptr'
# line 65:14 no viable alternative at input 'ptr'
# line 66:13 no viable alternative at input 'ptr'
# line 66:18 no viable alternative at input 'ptr'
# line 67:26 mismatched input 'ptr' expecting CLOSEP
# line 67:41 mismatched input ')' expecting ASSIGN
# java.lang.AssertionError: Did not find any first block!
# 	at aprove.InputModules.Programs.llvm.parseStructures.LLVMParseFunctionDefinition.convertToFnDefinition(LLVMParseFunctionDefinition.java:37)
# 	at aprove.InputModules.Programs.llvm.parseStructures.LLVMParseModule.createBasicStructure(LLVMParseModule.java:114)
# 	at aprove.InputModules.Programs.llvm.Translator.translate(Translator.java:136)
# 	at aprove.InputModules.Programs.llvm.Translator.translate(Translator.java:115)
# 	at aprove.Framework.Input.Translator$TranslatorSkeleton.translate(Translator.java:91)
# 	at aprove.InputModules.Programs.c.CToLLVMProcessor.process(CToLLVMProcessor.java:69)
# 	at aprove.Strategies.ExecutableStrategies.Executor.execute(Executor.java:326)
# 	at aprove.Strategies.ExecutableStrategies.Executor$Runner.wrappedRun(Executor.java:377)
# 	at aprove.Strategies.Abortions.PooledJob.run(PooledJob.java:99)
# 	at aprove.Strategies.Util.PrioritizableThreadPool$Worker.run(PrioritizableThreadPool.java:274)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
! java -jar ~/Downloads/aprove.jar
# Out:
# ^C

# %%
# %%bash
# wget https://github.com/aprove-developers/aprove-releases/releases/download/master_2023_12_29/aprove.jar

# %%
# %%file

# %%
! java -jar aprove.jar -i test.smt2 -o test.out
